# %% [markdown]
# ## setup

# %%
import os, cv2, shutil, heapq, random, tempfile
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
from multiprocessing import Pool
from collections import Counter, defaultdict
from skimage.metrics import mean_squared_error
from skimage.transform import resize
from concurrent.futures import ThreadPoolExecutor

random.seed(0)

# %%
class DataProcessor:

    def __init__(self):
        """Initialize the DataProcessor class."""
        # Common image file extensions
        self.image_extensions = ('.jpg', '.jpeg', '.png')
        self.mask_extension = ".png"

    def get_all_images(self, folder_path, recursive=True):
        """
        Find all image files in the given folder path and optionally its subfolders.
        
        Args:
            folder_path (str): Path to the folder to search for images
            recursive (bool): Whether to include subfolders in the search (default: True)
            
        Returns:
            list: List of full paths to all image files found
        """
        # Validate input path
        if not os.path.isdir(folder_path):
            raise ValueError(f"The path {folder_path} is not a valid directory")
            
        image_files = []
        
        # Helper function to check if a file is an image based on extension
        def is_image_file(filename):
            return any(filename.lower().endswith(ext) for ext in self.image_extensions)
        
        # Walk through the directory structure
        if recursive:
            # Use os.walk to traverse the directory tree
            for root, _, files in os.walk(folder_path):
                for filename in files:
                    if is_image_file(filename):
                        full_path = os.path.join(root, filename)
                        image_files.append(full_path)
        else:
            # Only look at files in the top directory
            for filename in os.listdir(folder_path):
                full_path = os.path.join(folder_path, filename)
                if os.path.isfile(full_path) and is_image_file(filename):
                    image_files.append(full_path)
                    
        return image_files

    def get_all_files(self, folder_path, recursive=True):
        """
        Find all image files in the given folder path and optionally its subfolders.
        
        Args:
            folder_path (str): Path to the folder to search for images
            recursive (bool): Whether to include subfolders in the search (default: True)
            
        Returns:
            list: List of full paths to all image files found
        """
        # Validate input path
        if not os.path.isdir(folder_path):
            raise ValueError(f"The path {folder_path} is not a valid directory")
            
        files = []
        
        # Walk through the directory structure
        if recursive:
            # Use os.walk to traverse the directory tree
            for root, _, files in os.walk(folder_path):
                for filename in files:
                    full_path = os.path.join(root, filename)
                    files.append(full_path)
        else:
            # Only look at files in the top directory
            for filename in os.listdir(folder_path):
                full_path = os.path.join(folder_path, filename)
                if os.path.isfile(full_path):
                    files.append(full_path)
                    
        return files


    def crop_to_square(self, folder_path, recursive=True):
        """
        Crop all images in the folder to make them square.
        The crop is centered on the image.
        Overwrites the original images with the cropped versions.
        
        Args:
            folder_path (str): Path to the folder containing images
            recursive (bool): Whether to include subfolders (default: True)
            
        Returns:
            dict: Summary of operations performed
        """
        # Get all images in the folder
        image_paths = self.get_all_images(folder_path, recursive)
        
        stats = {
            "processed": 0,
            "errors": 0,
            "skipped": 0,  # Images that are already square
            "total": len(image_paths)
        }
        
        with Pool() as pool:
            results = pool.map(self._process_crop_image, image_paths)
        
        stats["processed"] = results.count('processed')
        stats["skipped"] = results.count('skipped')
        stats["errors"] = results.count('error')
        
        print(f"Square crop operation completed.")
        print(f"Processed: {stats['processed']}, Skipped (already square): {stats['skipped']}, Errors: {stats['errors']}")
        return stats
    
    def _process_crop_image(self, path):
        try:
            with Image.open(path) as img:
                width, height = img.size
                
                # Skip if already square
                if width == height:
                    return 'skipped'
                
                # Determine the size of the square
                size = min(width, height)
                
                # Calculate coordinates for center crop
                left = (width - size) // 2
                top = (height - size) // 2
                right = left + size
                bottom = top + size
                
                # Crop the image
                cropped_img = img.crop((left, top, right, bottom))
                
                # Save back to the same file, preserving format
                cropped_img.save(path, format=img.format)
                return 'processed'
                
        except Exception as e:
            print(f"Error processing {path}: {str(e)}")
            return 'error'


    def scale_images(self, folder_path, target_resolution, recursive=True):
        """
        Scale images in the given folder to the specified resolution using Lanczos resampling.
        Always overwrites the original images with their scaled versions.
        
        Args:
            folder_path (str): Path to the folder containing images
            target_resolution (tuple): Target resolution as (width, height) in pixels
            recursive (bool): Whether to include subfolders (default: True)
                
        Returns:
            dict: Summary of operations performed
        """
        # Get all images in the folder
        image_paths = self.get_all_images(folder_path, recursive)
        
        stats = {
            "processed": 0,
            "errors": 0,
            "skipped": 0,  # Images that are already at the target resolution
            "total": len(image_paths)
        }
        
        # Prepare arguments for each image path
        args = [(path, target_resolution) for path in image_paths]
        
        with Pool() as pool:
            results = pool.starmap(self._process_scale_image, args)
        
        stats["processed"] = results.count('processed')
        stats["skipped"] = results.count('skipped')
        stats["errors"] = results.count('error')
        
        print(f"Scale operation completed.")
        print(f"Processed: {stats['processed']}, Skipped (already at target resolution): {stats['skipped']}, Errors: {stats['errors']}")
        return stats

    def _process_scale_image(scale,path, target_resolution):
        target_width, target_height = target_resolution
        try:
            with Image.open(path) as img:
                original_width, original_height = img.size
                
                # Skip if already at target resolution
                if original_width == target_width and original_height == target_height:
                    return 'skipped'
                
                # Resize using Lanczos resampling to exact target dimensions
                resized_img = img.resize((target_width, target_height), Image.LANCZOS)
                
                # Save the resized image, overwriting the original and preserving format
                resized_img.save(path, format=img.format)
                return 'processed'
                
        except Exception as e:
            print(f"Error processing {path}: {str(e)}")
            return 'error'


    def get_summary(self, folder_path, recursive=True):
        """
        Generate a comprehensive summary of images in the given folder.
        
        Args:
            folder_path (str): Path to the folder containing images
            recursive (bool): Whether to include subfolders (default: True)
            
        Returns:
            dict: Summary information about the images
        """
        # Get all images in the folder
        image_paths = self.get_all_images(folder_path, recursive)
        
        if not image_paths:
            return {"error": "No images found in the specified folder"}
        
        # Initialize counters and data structures
        total_images = len(image_paths)
        total_size_bytes = 0
        resolutions = Counter()
        aspect_ratios = Counter()
        formats = Counter()
        sizes = []
        errors = []
        
        # Process each image
        for path in image_paths:
            try:
                # Get file size
                file_size = os.path.getsize(path)
                total_size_bytes += file_size
                sizes.append(file_size)
                
                # Open and analyze the image
                with Image.open(path) as img:
                    width, height = img.size
                    
                    # Resolution
                    resolution = f"{width}x{height}"
                    resolutions[resolution] += 1
                    
                    # Format
                    if img.format:
                        formats[img.format] += 1
                    else:
                        formats["Unknown"] += 1
                    
                    # Aspect ratio (rounded to 2 decimal places)
                    if height > 0:
                        ratio = round(width / height, 2)
                        aspect_ratios[ratio] += 1
                    
            except Exception as e:
                errors.append({"path": path, "error": str(e)})
        
        # Calculate statistics
        successful_images = total_images - len(errors)
        
        # Size statistics (in MB)
        if sizes:
            avg_size_mb = sum(sizes) / len(sizes) / (1024 * 1024)
            min_size_mb = min(sizes) / (1024 * 1024)
            max_size_mb = max(sizes) / (1024 * 1024)
            total_size_mb = total_size_bytes / (1024 * 1024)
        else:
            avg_size_mb = min_size_mb = max_size_mb = total_size_mb = 0
        
        # Most common attributes
        most_common_resolution = resolutions.most_common(1)[0] if resolutions else None
        most_common_aspect = aspect_ratios.most_common(1)[0] if aspect_ratios else None
        
        # Prepare summary
        summary = {
            "total_images": total_images,
            "successful_analyses": successful_images,
            "errors": len(errors),
            "error_details": errors if errors else None,
            
            "size_stats": {
                "total_size_mb": round(total_size_mb, 2),
                "average_size_mb": round(avg_size_mb, 2),
                "min_size_mb": round(min_size_mb, 2),
                "max_size_mb": round(max_size_mb, 2)
            },
            
            "resolutions": {
                "most_common": most_common_resolution,
                "all": dict(resolutions.most_common())
            },
            
            "formats": dict(formats.most_common()),
            
            "aspect_ratios": {
                "most_common": most_common_aspect,
                "all": dict(aspect_ratios.most_common(10))
            }
        }
        
        # Print a summary report (without Orientation, Color modes, and Dimension statistics)
        print("\n=== IMAGE SUMMARY REPORT ===")
        print(f"Total images analyzed: {total_images}")
        print(f"Successful: {successful_images}, Errors: {len(errors)}")
        print(f"Total size: {round(total_size_mb, 2)} MB")
        print("\nResolutions:")
        for res, count in resolutions.most_common(5):
            print(f"  {res}: {count} images ({round(count/total_images*100, 1)}%)")
        print(f"  ... and {len(resolutions) - 5} more resolutions") if len(resolutions) > 5 else None
        
        print("\nFormats:")
        for fmt, count in formats.most_common():
            print(f"  {fmt}: {count} images ({round(count/total_images*100, 1)}%)")
        
        return summary


    def generate_object_density_data(self, folder_path, recursive=True):
        """
        Generate object density data from mask images in a given folder.

        Args:
            folder_path (str): Path to the folder containing object masks.
            recursive (bool): Whether to include subfolders (default: True).

        Returns:
            dict: Contains density map, number of masks, and image dimensions.
        """
        mask_paths = self.get_all_images(folder_path, recursive)
        
        if not mask_paths:
            return {"error": "No mask images found in the specified folder"}
        
        # Load the first mask to get image dimensions
        with Image.open(mask_paths[0]) as img:
            width, height = img.size

        # Initialize the density map
        density_map = np.zeros((height, width), dtype=np.uint32)

        # Process each mask image
        for path in mask_paths:
            try:
                with Image.open(path) as img:
                    img = img.convert('L')
                    img_array = np.array(img)
                    binary_mask = (img_array > 128).astype(np.uint32)
                    density_map += binary_mask
            except Exception as e:
                print(f"Error processing {path}: {str(e)}")

        # Normalize the density map
        density_map = density_map / len(mask_paths)

        return {
            "density_map": density_map,
            "mask_count": len(mask_paths),
            "image_dimensions": (width, height)
        }

    def visualize_object_density(self, density_data):
        """
        Visualize the object density data using a heatmap.

        Args:
            density_data (dict): Data containing the density map, mask count, and image dimensions.
        """
        if "error" in density_data:
            print(density_data["error"])
            return

        density_map = density_data["density_map"]

        plt.figure(figsize=(10, 10))
        img = plt.imshow(density_map, cmap='hot', interpolation='nearest', vmin=0.00, vmax=0.30)
        cbar = plt.colorbar(img)
        cbar.set_label('Object Density')
        plt.title('Heatmap of Object Density')
        plt.show()


    def get_bbox_coords(self, folder_path):
        """
        Get bounding box coordinates for all images in a folder.

        :param folder_path: Path to the folder containing images.
        :return: Dictionary with image paths as keys and bounding box coordinates (x_min, y_min, x_max, y_max) as values.
        """
        image_paths = self.get_all_images(folder_path, recursive=True)
        bbox_dict = {}

        for image_path in image_paths:
            # Load the image in grayscale
            image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
            if image is None:
                continue  # Skip unreadable images

            # Threshold to ensure binary mask
            _, binary = cv2.threshold(image, 127, 255, cv2.THRESH_BINARY)

            # Find contours
            contours, _ = cv2.findContours(binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
            if not contours:
                continue  # Skip images with no detected objects

            # Get bounding box of the largest contour
            x, y, w, h = cv2.boundingRect(max(contours, key=cv2.contourArea))
            bbox_dict[image_path] = (x, y, x + w, y + h)

        return bbox_dict

    def generate_centralization_data(self, bbox_dict):
        """
        Compute and normalize how close each object's bounding box center is to the image center using Euclidean distance.
        The image resolution is automatically detected using a sample image from bbox_dict.

        :param bbox_dict: Dictionary with image paths as keys and bounding box coordinates (x_min, y_min, x_max, y_max) as values.
        :return: Dictionary with image paths as keys and normalized centralization scores (0 to 1) as values.
        """
        # Get a sample image path from bbox_dict to detect resolution
        sample_image_path = next(iter(bbox_dict.keys()), None)
        if sample_image_path is None:
            raise ValueError("bbox_dict is empty. Cannot detect resolution.")
        
        sample_img = cv2.imread(sample_image_path)
        if sample_img is None:
            raise ValueError(f"Unable to read sample image: {sample_image_path}")

        # Get resolution from sample image; OpenCV returns (height, width, channels)
        height, width = sample_img.shape[:2]
        img_center = np.array([width / 2, height / 2])
        max_distance = np.linalg.norm(img_center)  # Max possible distance from center

        scores = {}
        for image_path, (x_min, y_min, x_max, y_max) in bbox_dict.items():
            obj_center = np.array([(x_min + x_max) / 2, (y_min + y_max) / 2])
            distance = np.linalg.norm(obj_center - img_center)
            normalized_score = 1 - distance / max_distance  # Normalize to [0, 1]
            scores[image_path] = normalized_score

        return scores
    
    def visualize_centralization_scores(self, scores_dict):
        """
        Analyzes and visualizes the distribution of centralization scores.
        It plots a histogram with overlaid mean and median values and returns basic statistics.
        
        Args:
            scores_dict (dict): Dictionary of scores (e.g., as returned by generate_centralization_data).
        
        Returns:
            dict: Dictionary containing analysis results (mean, median, std, min, and max scores).
        """
        # Extract scores.
        scores = list(scores_dict.values())
        
        # Compute statistics.
        mean_score = np.mean(scores)
        median_score = np.median(scores)
        std_score = np.std(scores)
        min_score = np.min(scores)
        max_score = np.max(scores)
        
        # Plot histogram of the scores.
        plt.figure(figsize=(10, 6))
        plt.hist(scores, bins=20, color='skyblue', edgecolor='black')
        plt.title("Distribution of Centralization Scores")
        plt.xlabel("Score")
        plt.ylabel("Frequency")
        plt.axvline(mean_score, color='red', linestyle='dashed', linewidth=1, label=f'Mean: {mean_score:.2f}')
        plt.axvline(median_score, color='green', linestyle='dashed', linewidth=1, label=f'Median: {median_score:.2f}')
        plt.legend()
        plt.show()
        
        analysis_data = {
            "mean": mean_score,
            "median": median_score,
            "std": std_score,
            "min": min_score,
            "max": max_score
        }
        
        return analysis_data
    
    
    def remove_highest_scored_images(self, centralization_scores, N):
        """
        Removes the first N images with the highest centralization scores.
        The keys of centralization_scores are full image paths.
        It deletes these images from the file system and returns a list of removed image paths.

        Args:
            centralization_scores (dict): Dictionary with image paths as keys and centralization scores as values.
            N (int): Number of images to remove (those with the highest scores).

        Returns:
            list: List of image names that were successfully removed.
        """
        # Sort images by score in descending order.
        sorted_items = sorted(centralization_scores.items(), key=lambda x: x[1], reverse=True)
        # Select the top N images.
        images_to_remove = sorted_items[:N]
        
        removed_images = []
        for image_path, _ in images_to_remove:
            try:
                if os.path.exists(image_path):
                    os.remove(image_path)
                    image_name = os.path.splitext(os.path.basename(image_path))[0]
                    removed_images.append(image_name)
                else:
                    print(f"File not found: {image_path}")
            except Exception as e:
                print(f"Error removing {image_path}: {e}")
        return removed_images


    def remove_files_by_base_names(self, folder_path, base_names):

            # Retrieve all image files in the folder using get_all_images()
            image_paths = self.get_all_images(folder_path, recursive=True)
            removed_files = []
            base_names_wo_ext = [os.path.splitext(filename)[0] for filename in base_names]
            # Loop through all image paths
            for file_path in image_paths:
                # Extract the base filename (without extension)
                base_filename = os.path.splitext(os.path.basename(file_path))[0]
                # If the base filename is in the provided list, remove the file
                if base_filename in base_names_wo_ext:
                    try:
                        os.remove(file_path)
                        removed_files.append(file_path)
                    except Exception as e:
                        print(f"Error removing {file_path}: {e}")
                        
            return removed_files


    def augment_data_4x4_balance(self, folder_path, top_n):
        """
        Augment images to balance 4x4 grid distribution, applying at most one operation per image.
        Saves new images into the input folder and returns dictionary with new paths, bboxes, and applied operations.
        
        :param folder_path: Path to folder containing original images
        :param top_n: Number of most off-center images to process
        :return: Dictionary of new image paths, their bounding boxes, and applied operations
        """
        # Get the resolution dynamically from any image in the folder
        sample_img_path = next((os.path.join(folder_path, f) for f in os.listdir(folder_path) if f.endswith(('.png', '.jpg', '.jpeg'))), None)
        if not sample_img_path:
            raise ValueError("No images found in the folder.")
        
        img = cv2.imread(sample_img_path)
        if img is None:
            raise ValueError(f"Unable to read image: {sample_img_path}")
        
        height, width = img.shape[:2]  # Get detected resolution

        bbox_dict = self.get_bbox_coords(folder_path)
        scores = self.generate_centralization_data(bbox_dict)

        # Sort images by most off-center first
        sorted_images = sorted(bbox_dict.keys(), key=lambda x: scores[x], reverse=True)[:top_n]

        # Initialize grid counts
        grid_counts = np.zeros((4, 4), dtype=int)
        for img_path, bbox in bbox_dict.items():
            row, col = self._get_grid_cell(bbox, width, height)
            grid_counts[row, col] += 1

        augmented_data = {}
        current_grid = grid_counts.copy()

        # Define valid single transformations
        valid_transforms = ['flip_h', 'flip_v', 'rotate_90', 'rotate_180', 'rotate_270']

        for img_path in sorted_images:
            original_bbox = bbox_dict[img_path]
            original_cell = self._get_grid_cell(original_bbox, width, height)

            best_transform = None
            best_cell = None
            min_count = float('inf')

            # Check all valid single transforms
            for transform in valid_transforms:
                # Calculate resulting cell
                cell = self._transform_cell(original_cell, transform)

                # Skip transforms that don't change the cell
                if cell == original_cell:
                    continue

                # Track the most needed cell
                if current_grid[cell] < min_count:
                    min_count = current_grid[cell]
                    best_transform = transform
                    best_cell = cell

            if best_transform:
                # Apply transformation
                new_img, new_bbox = self._apply_transformation(img_path, original_bbox, best_transform, (width, height))
                new_path = self._generate_new_path(img_path, folder_path, [best_transform])

                cv2.imwrite(new_path, new_img)
                augmented_data[new_path] = {
                    'bbox': new_bbox,
                    'operation': best_transform,
                    'previous_name': os.path.basename(img_path)
                }
                current_grid[best_cell] += 1

        return augmented_data

    def _get_grid_cell(self, bbox, width, height):
        """
        Convert bounding box center to 4x4 grid cell coordinates.
        
        :param bbox: Tuple (x_min, y_min, x_max, y_max)
        :param width: Image width
        :param height: Image height
        :return: Tuple (row, col) in 4x4 grid
        """
        x_min, y_min, x_max, y_max = bbox
        center_x = (x_min + x_max) / 2
        center_y = (y_min + y_max) / 2
        row = int(center_y // (height / 4))
        col = int(center_x // (width / 4))
        return (row, col)

    def _transform_cell(self, cell, operation):
        """
        Transform grid cell coordinates based on operation.
        
        :param cell: Tuple (row, col) in 4x4 grid
        :param operation: Transformation operation (e.g., 'flip_h', 'rotate_90')
        :return: New cell coordinates (row, col)
        """
        row, col = cell
        if operation == 'flip_h':
            return (row, 3 - col)
        elif operation == 'flip_v':
            return (3 - row, col)
        elif operation == 'rotate_90':
            return (col, 3 - row)
        elif operation == 'rotate_180':
            return (3 - row, 3 - col)
        elif operation == 'rotate_270':
            return (3 - col, row)
        return cell

    def _apply_transformation(self, img_path, bbox, op, resolution):

        img = cv2.imread(img_path)
        width, height = resolution
        x_min, y_min, x_max, y_max = bbox

        if op == 'flip_h':
            img = cv2.flip(img, 1)
        elif op == 'flip_v':
            img = cv2.flip(img, 0)
        elif op == 'rotate_90':
            img = cv2.rotate(img, cv2.ROTATE_90_CLOCKWISE)
        elif op == 'rotate_180':
            img = cv2.rotate(img, cv2.ROTATE_180)
        elif op == 'rotate_270':
            img = cv2.rotate(img, cv2.ROTATE_90_COUNTERCLOCKWISE)
        
        # Transform bounding box coordinates
        x_min, y_min, x_max, y_max = self._transform_bbox(
            (x_min, y_min, x_max, y_max), op, width, height)
    
        return img, (x_min, y_min, x_max, y_max)

    def _transform_bbox(self, bbox, operation, width, height):
        """
        Adjust bounding box coordinates after transformation.
        
        :param bbox: Tuple (x_min, y_min, x_max, y_max)
        :param operation: Transformation operation
        :param width: Image width
        :param height: Image height
        :return: Adjusted bounding box (x_min, y_min, x_max, y_max)
        """
        x_min, y_min, x_max, y_max = bbox
        if operation == 'flip_h':
            return (width - x_max, y_min, width - x_min, y_max)
        elif operation == 'flip_v':
            return (x_min, height - y_max, x_max, height - y_min)
        elif operation == 'rotate_90':
            return (y_min, height - x_max, y_max, height - x_min)
        elif operation == 'rotate_180':
            return (width - x_max, height - y_max, width - x_min, height - y_min)
        elif operation == 'rotate_270':
            return (width - y_max, x_min, width - y_min, x_max)
        return bbox

    def _is_identical(self, original_path, transformed_img):
        """
        Check if transformed image is identical to original.
        
        :param original_path: Path to original image
        :param transformed_img: Transformed image as numpy array
        :return: True if images are identical, False otherwise
        """
        original = cv2.imread(original_path)
        return np.array_equal(original, transformed_img)

    def _generate_new_path(self, original_path, folder_path, transforms):
        """
        Generate unique filename for transformed image.
        
        :param original_path: Path to original image
        :param folder_path: Folder to save new image
        :param transforms: List of transformations applied
        :return: New file path
        """
        base_name = os.path.basename(original_path)
        name, ext = os.path.splitext(base_name)
        transform_str = '_'.join(transforms) if transforms else 'original'
        return os.path.join(folder_path, f"{name}_{transform_str}{ext}")
    
    def apply_augmentations_to_matching_images(self, folder_path, augmented_data):
        """
        For each entry in augmented_data, find the matching image in folder_path (ignoring extensions),
        apply the same operation, and save it with the new name but original extension.
        
        :param folder_path: Path to folder containing images
        :param augmented_data: Dictionary of augmented data (output from augment_data_4x4_balance)
        """
        # Get all images in the folder
        all_images = self.get_all_images(folder_path, recursive=True)
        
        # Create a mapping of base names (without extension) to full paths
        base_name_to_path = {}
        for img_path in all_images:
            base_name = os.path.splitext(os.path.basename(img_path))[0]
            base_name_to_path[base_name] = img_path
        
        # Process each augmented entry
        for new_path, data in augmented_data.items():
            previous_name = data['previous_name']
            operation = data['operation']
            
            # Find matching image (ignoring extension)
            base_name = os.path.splitext(previous_name)[0]
            if base_name not in base_name_to_path:
                continue  # Skip if no matching image found
            
            original_path = base_name_to_path[base_name]
            
            # Load the original image
            img = cv2.imread(original_path)
            if img is None:
                continue  # Skip unreadable images
            
            # Apply the transformation
            transformed_img = self._apply_single_transformation(img, operation)
            
            # Save with the new name but original extension
            new_base_name = os.path.splitext(os.path.basename(new_path))[0]
            original_ext = os.path.splitext(original_path)[1]
            save_path = os.path.join(folder_path, f"{new_base_name}{original_ext}")
            
            cv2.imwrite(save_path, transformed_img)

    def _apply_single_transformation(self, img, operation):
        """
        Apply a single transformation to an image.
        
        :param img: Image as numpy array
        :param operation: Transformation operation (e.g., 'flip_h', 'rotate_90')
        :return: Transformed image
        """
        if operation == 'flip_h':
            return cv2.flip(img, 1)
        elif operation == 'flip_v':
            return cv2.flip(img, 0)
        elif operation == 'rotate_90':
            return cv2.rotate(img, cv2.ROTATE_90_CLOCKWISE)
        elif operation == 'rotate_180':
            return cv2.rotate(img, cv2.ROTATE_180)
        elif operation == 'rotate_270':
            return cv2.rotate(img, cv2.ROTATE_90_COUNTERCLOCKWISE)
        return img  # Return original if operation is invalid
    

    def augment_random_images(self, folder_path, n):
        """
        For n random images in the given folder, apply one random geometric transformation
        (rotate (90, 180, or 270 degrees) or flip (horizontal or vertical)) along with small random
        adjustments to brightness, contrast, and saturation (color), taking care to preserve skin tones.
        Saves the new images next to the original ones with suffixes indicating the transformation.
        
        :param folder_path: Path to the folder containing images.
        :param n: Number of random images to augment.
        """
        # List image files (you can extend the extensions as needed)
        valid_extensions = ('.png', '.jpg', '.jpeg', '.bmp')
        image_files = [f for f in os.listdir(folder_path) if f.lower().endswith(valid_extensions)]
        
        if len(image_files) == 0:
            print("No valid image files found.")
            return
        
        # Randomly choose n images (or all if n > available images)
        n = min(n, len(image_files))
        selected_files = random.sample(image_files, n)
        
        for file in selected_files:
            img_path = os.path.join(folder_path, file)
            img = cv2.imread(img_path)
            if img is None:
                print(f"Unable to read image: {img_path}")
                continue
            
            # --- Geometric Transformation ---
            transform = None
            suffix = ""
            # Choose transformation type: flip or rotate
            if random.choice([True, False]):
                # Flip: choose horizontal or vertical
                flip_type = random.choice(["flip_h", "flip_v"])
                if flip_type == "flip_h":
                    transformed_img = cv2.flip(img, 1)  # horizontal flip
                else:
                    transformed_img = cv2.flip(img, 0)  # vertical flip
                transform = flip_type
                suffix = f"_{flip_type}"
            else:
                # Rotate: choose an angle among 90, 180, 270
                angle = random.choice([90, 180, 270])
                # Compute rotation matrix
                (h, w) = img.shape[:2]
                center = (w // 2, h // 2)
                M = cv2.getRotationMatrix2D(center, angle, 1.0)
                transformed_img = cv2.warpAffine(img, M, (w, h))
                transform = f"rotate_{angle}"
                suffix = f"_{transform}"
            
            # --- Brightness and Contrast Adjustments ---
            # Choose small random factors: contrast factor between 0.9 and 1.1 and brightness offset between -10 and 10
            alpha = random.uniform(0.9, 1.1)   # Contrast
            beta = random.randint(-10, 10)       # Brightness
            adjusted_img = cv2.convertScaleAbs(transformed_img, alpha=alpha, beta=beta)
            
            # --- Saturation (Color) Adjustment ---
            # Convert to HSV to slightly adjust saturation without altering hue (to preserve skin tones)
            hsv = cv2.cvtColor(adjusted_img, cv2.COLOR_BGR2HSV)
            h, s, v = cv2.split(hsv)
            # Adjust saturation by a small factor (e.g. ±10%)
            sat_factor = random.uniform(0.9, 1.1)
            s = np.clip(s * sat_factor, 0, 255).astype(np.uint8)
            hsv_adjusted = cv2.merge([h, s, v])
            final_img = cv2.cvtColor(hsv_adjusted, cv2.COLOR_HSV2BGR)
            
            # --- Save the New Image ---
            base, ext = os.path.splitext(file)
            new_filename = f"{base}{suffix}{ext}"
            new_path = os.path.join(folder_path, new_filename)
            cv2.imwrite(new_path, final_img)


    def remove_most_similar_images(self, image_folder, N, K=5, resize_shape=(64, 64)):
        # 1. Load and sort image filenames
        image_files = sorted(os.listdir(image_folder))
        image_paths = [os.path.join(image_folder, f) for f in image_files]
        
        # 2. Precompute resized images for faster comparison
        resized_images = []
        for path in image_paths:
            img = np.array(Image.open(path))
            resized = resize(img, resize_shape, anti_aliasing=True)
            resized_images.append(resized)
        
        # 3. Compute similarity scores using sliding window (parallelized)
        heap = []
        removed = set()

        def process_pair(i, j):
            score = mean_squared_error(resized_images[i], resized_images[j])
            return (-score, (i, j))  # Use negative score for max-heap

        with ThreadPoolExecutor() as executor:
            futures = []
            for i in range(len(resized_images)):
                for j in range(i+1, min(i+1+K, len(resized_images))):
                    futures.append(executor.submit(process_pair, i, j))

            for future in futures:
                heapq.heappush(heap, future.result())

        # 4. Greedy removal of most similar pairs
        while heap and len(removed) < N:
            score, (i, j) = heapq.heappop(heap)
            if i not in removed and j not in removed:
                removed.add(j)  # Remove the latter image (prioritize keeping earlier frames)

        # 5. Collect filenames of removed images
        removed_filenames = [image_files[idx] for idx in sorted(removed)]
        
        # 6. Delete the N removed images
        for idx in sorted(removed, reverse=True):
            os.remove(image_paths[idx])

        return removed_filenames  # Return the list of removed image names


    def analyze_contrast(self, folder_path):
        """
        Analyze images from a given list of paths.
        Extracts brightness, contrast, and color histogram data.

        Args:
            image_paths (list): List of image file paths.

        Returns:
            dict: Dictionary containing analysis results for each image.
        """
        image_paths = self.get_all_images(folder_path)
        
        analysis_data = {}

        for path in image_paths:
            try:
                image = cv2.imread(path)
                if image is None:
                    continue  # Skip if the image is not loaded
                
                gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

                # Calculate brightness (mean intensity)
                brightness = np.mean(gray)

                # Calculate contrast (standard deviation of intensity)
                contrast = np.std(gray)

                # Calculate color histogram
                hist_data = {}
                for i, color in enumerate(['blue', 'green', 'red']):
                    hist = cv2.calcHist([image], [i], None, [256], [0, 256])
                    hist_data[color] = hist.flatten().tolist()  # Convert to list for JSON compatibility

                analysis_data[path] = {
                    "brightness": brightness,
                    "contrast": contrast,
                    "color_histogram": hist_data
                }
            except Exception as e:
                print(f"Error processing {path}: {e}")

        return analysis_data

    def visualize_contrast_analysis(self, analysis_data):
        """
        Visualize the extracted image analysis data.

        Args:
            analysis_data (dict): Dictionary returned from analyze_images.
        """
        brightness_vals = []
        contrast_vals = []
        color_histograms = defaultdict(list)

        # Extract data for visualization
        for path, data in analysis_data.items():
            brightness_vals.append(data["brightness"])
            contrast_vals.append(data["contrast"])
            for color in ['blue', 'green', 'red']:
                color_histograms[color].append(np.array(data["color_histogram"][color]))

        # Reduce number of points plotted
        sample_fraction = 0.25  # Adjust this value to control sparsity
        num_samples = max(1, int(len(brightness_vals) * sample_fraction))
        sampled_indices = np.random.choice(len(brightness_vals), num_samples, replace=False)
        sampled_brightness = [brightness_vals[i] for i in sampled_indices]
        sampled_contrast = [contrast_vals[i] for i in sampled_indices]

        # Brightness and Contrast Scatter Plot
        plt.figure(figsize=(10, 5))
        plt.scatter(sampled_brightness, sampled_contrast, color='purple', alpha=0.7)
        plt.xlabel("Brightness")
        plt.ylabel("Contrast")
        plt.title("Brightness vs. Contrast")
        plt.grid(True)
        plt.show()

        # Color Histograms
        plt.figure(figsize=(12, 5))
        for color, hist_list in color_histograms.items():
            avg_hist = np.mean(hist_list, axis=0)
            plt.plot(avg_hist, color=color, label=f'{color.capitalize()} Histogram')
        plt.xlabel("Pixel Intensity")
        plt.ylabel("Frequency")
        plt.title("Average Color Histogram")
        plt.legend()
        plt.show()


    def analyze_color(self, folder_path):
        """
        Analyze images from a given folder to extract mean color values and color histograms.

        Args:
            folder_path (str): Path to the folder containing images.

        Returns:
            dict: Dictionary containing analysis results for each image.
        """
        image_paths = self.get_all_images(folder_path)
        
        analysis_data = {}

        for path in image_paths:
            try:
                image = cv2.imread(path)
                if image is None:
                    continue  # Skip if the image is not loaded
                
                # Compute mean color values
                mean_colors = cv2.mean(image)[:3]  # Ignore alpha channel if present
                mean_color_dict = {
                    "blue": mean_colors[0],
                    "green": mean_colors[1],
                    "red": mean_colors[2]
                }

                # Compute color histograms
                hist_data = {}
                for i, color in enumerate(['blue', 'green', 'red']):
                    hist = cv2.calcHist([image], [i], None, [256], [0, 256])
                    hist_data[color] = hist.flatten().tolist()  # Convert to list for JSON compatibility

                analysis_data[path] = {
                    "mean_color": mean_color_dict,
                    "color_histogram": hist_data
                }
            except Exception as e:
                print(f"Error processing {path}: {e}")

        return analysis_data

    def visualize_color_analysis(self, analysis_data):
        """
        Visualize the extracted color analysis data.

        Args:
            analysis_data (dict): Dictionary returned from analyze_color.
        """
        mean_colors = defaultdict(list)
        color_histograms = defaultdict(list)

        # Extract data for visualization
        for path, data in analysis_data.items():
            for color in ['blue', 'green', 'red']:
                mean_colors[color].append(data["mean_color"][color])
                color_histograms[color].append(np.array(data["color_histogram"][color]))

        # Scatter Plot of Mean Colors
        plt.figure(figsize=(10, 5))
        plt.scatter(mean_colors["red"], mean_colors["green"], color='red', alpha=0.6, label="Red vs. Green")
        plt.scatter(mean_colors["red"], mean_colors["blue"], color='blue', alpha=0.6, label="Red vs. Blue")
        plt.scatter(mean_colors["green"], mean_colors["blue"], color='green', alpha=0.6, label="Green vs. Blue")
        plt.xlabel("Red / Green / Blue Intensity")
        plt.ylabel("Other Color Intensity")
        plt.title("Mean Color Distribution")
        plt.legend()
        plt.grid(True)
        plt.show()

        # Average Color Histograms
        plt.figure(figsize=(12, 5))
        for color, hist_list in color_histograms.items():
            avg_hist = np.mean(hist_list, axis=0)
            plt.plot(avg_hist, color=color, label=f'{color.capitalize()} Histogram')
        plt.xlabel("Pixel Intensity")
        plt.ylabel("Frequency")
        plt.title("Average Color Histogram")
        plt.legend()
        plt.show()


    def move_last_n_files(self, folder_path: str, target_folder: str, n: int):
        if not os.path.exists(folder_path):
            raise FileNotFoundError(f"Source folder '{folder_path}' does not exist.")
        if not os.path.exists(target_folder):
            os.makedirs(target_folder)
        
        files = sorted(self.get_all_images(folder_path))
        files_to_move = files[-n:] if n > 0 else []
        
        for src in files_to_move:
            dest = os.path.join(target_folder, os.path.basename(src))
            shutil.move(src, dest)
        
        print(f"Moved {len(files_to_move)} files from '{folder_path}' to '{target_folder}'.")
    
    def move_random_n_images(self, input_folder, output_folder, n):
        files = [f for f in os.listdir(input_folder) if os.path.isfile(os.path.join(input_folder, f))]
        
        if not os.path.exists(output_folder):
            os.makedirs(output_folder)
        
        selected_files = random.sample(files, min(n, len(files)))
        
        for file in selected_files:
            old_path = os.path.join(input_folder, file)
            new_path = os.path.join(output_folder, file)
            os.rename(old_path, new_path)
        
        return selected_files
    
    def move_images_by_name(self, input_folder: str, output_folder: str, image_names: list):
        """
        Moves images from input_folder to output_folder based on given image names (ignoring extensions).
        
        :param input_folder: Path to the source folder containing images.
        :param output_folder: Path to the destination folder.
        :param image_names: List of image names (with extensions) to match.
        """
        if not os.path.exists(output_folder):
            os.makedirs(output_folder)
        
        base_names = {os.path.splitext(name)[0] for name in image_names}
        
        moved_images = []
        for file in os.listdir(input_folder):
            file_base, file_ext = os.path.splitext(file)
            if file_base in base_names:
                src_path = os.path.join(input_folder, file)
                dest_path = os.path.join(output_folder, file)
                shutil.move(src_path, dest_path)
                moved_images.append(file)
        
        return moved_images


    def remove_images_in_period(self, folder_path, n):
        images = sorted(self.get_all_images(folder_path))
        
        total_images = len(images)
        if n >= total_images:
            print("Cannot delete all or more images than available.")
            return []
        
        step = total_images / n  # Define the step interval (can be float)
        
        to_delete = [images[int(i * step)] for i in range(n)]
        removed_files = []
        
        for img in to_delete:
            os.remove(img)
            removed_files.append(os.path.basename(img))
        
        print(f"Deleted {len(removed_files)} files")
        return removed_files


    def compare_filenames(self, folder1, folder2):
        files1 = self.get_all_files(folder1)
        files2 = self.get_all_files(folder2)
        
        names1 = {os.path.splitext(os.path.basename(f))[0] for f in files1}
        names2 = {os.path.splitext(os.path.basename(f))[0] for f in files2}
        
        if names1 == names2:
            print("All filenames match.")
            return True
        else:
            print("Filenames do not match.")
            print("Only in folder1:", len(names1 - names2), names1 - names2)
            print("Only in folder2:", len(names2 - names1), names2 - names1)
            return False


    def masks_to_polygons(self, images_folder, mask_folder, target_folder, class_id=0):
        """
        For each image in images_folder, generate polygon coordinates from the corresponding mask in mask_folder,
        and save the coordinates in text files in target_folder. Matching is done based on the image filename
        (ignoring extension). If no corresponding mask exists, an empty text file is created.
        
        Args:
            images_folder (str): Path to folder containing original images.
            mask_folder (str): Path to folder containing mask images.
            target_folder (str): Path to folder where .txt files will be saved; will be emptied first.
            class_id (int): Class ID for objects in masks (default: 0).
        """
        # Empty the target folder if it exists, then recreate it.
        if os.path.exists(target_folder):
            shutil.rmtree(target_folder)
        os.makedirs(target_folder, exist_ok=True)
        
        # List valid image extensions.
        valid_extensions = ('.png', '.jpg', '.jpeg')
        
        skipped_masks = 0  # Counter for skipped masks (loading failures)
        empty_files = 0    # Counter for empty text files (no contours or no mask file)
        
        # Get all mask files for lookup, mapped by base name (without extension)
        mask_lookup = {}
        for mask_file in os.listdir(mask_folder):
            if mask_file.lower().endswith(valid_extensions):
                base = os.path.splitext(mask_file)[0]
                mask_lookup[base] = mask_file  # If multiple, last one wins.
        
        # Process each image in the images folder.
        for image_file in os.listdir(images_folder):
            if image_file.lower().endswith(valid_extensions):
                image_base = os.path.splitext(image_file)[0]
                target_txt = os.path.join(target_folder, image_base + '.txt')
                
                # Check if a corresponding mask exists.
                if image_base in mask_lookup:
                    mask_file = mask_lookup[image_base]
                    mask_path = os.path.join(mask_folder, mask_file)
                    mask = cv2.imread(mask_path, 0)  # Read mask as grayscale
                    if mask is None:
                        print(f"Failed to load mask {mask_file} for image {image_file}")
                        skipped_masks += 1
                        # Create an empty text file for this image.
                        open(target_txt, 'w').close()
                        continue
                    
                    # Find contours in the mask.
                    contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
                    height, width = mask.shape
                    
                    with open(target_txt, 'w') as f:
                        if not contours:
                            print(f"No contours found in mask {mask_file} for image {image_file}. Creating empty file.")
                            empty_files += 1
                        else:
                            for contour in contours:
                                coords = contour.flatten()
                                if len(coords) % 2 != 0 or len(coords) < 6:
                                    print(f"Skipping invalid contour in {mask_file}")
                                    continue
                                # Reshape and normalize coordinates.
                                coords = coords.reshape(-1, 2)
                                coords = coords / np.array([width, height], dtype=np.float32)
                                coords_flat = coords.flatten()
                                coord_str = ' '.join(map(str, coords_flat))
                                f.write(f"{class_id} {coord_str}\n")
                else:
                    # No corresponding mask file; create an empty annotation file.
                    print(f"No mask found for image {image_file}. Creating empty annotation file.")
                    open(target_txt, 'w').close()
                    empty_files += 1
        
        print(f"Finished processing. Skipped {skipped_masks} masks due to loading failures. Created {empty_files} empty annotation files.")

    def create_empty_text_files(self, source_folder, target_folder):
        """
        For each file in the source_folder, create an empty text file in the target_folder.
        The empty file will have the same base name as the original file, with a '.txt' extension.
        
        :param source_folder: Path to the folder containing source files.
        :param target_folder: Path to the folder where empty text files will be created.
        """
        # Create the target folder if it doesn't exist
        if not os.path.exists(target_folder):
            os.makedirs(target_folder)
        
        # Iterate over each file in the source folder
        for filename in os.listdir(source_folder):
            # Only consider files (skip directories)
            source_path = os.path.join(source_folder, filename)
            if os.path.isfile(source_path):
                base_name = os.path.splitext(filename)[0]
                target_file = os.path.join(target_folder, base_name + '.txt')
                # Create an empty text file
                with open(target_file, 'w') as f:
                    pass  # Create an empty file

    def visualize_polygon(self, folder_mask, folder_polygon):
        # Get list of image files from mask folder
        image_files = sorted([f for f in os.listdir(folder_mask) if f.lower().endswith(self.image_extensions)])
        
        if not image_files:
            print("No image files found.")
            return
        
        # Select a random image file
        index = random.randint(0, len(image_files) - 1)
        image_file = image_files[index]
        image_path = os.path.join(folder_mask, image_file)
        
        # Build the corresponding text file path using the image's base name
        base_name = os.path.splitext(image_file)[0]
        text_path = os.path.join(folder_polygon, base_name + '.txt')
        
        # Check if the annotation file exists
        if not os.path.exists(text_path):
            print(f"No polygon annotation file found for image: {image_file}")
            return
        
        # Read image (assuming it's a mask)
        image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
        if image is None:
            print(f"Failed to load image: {image_path}")
            return
        
        h, w = image.shape  # Get image dimensions
        
        # Read polygon coordinates from the text file
        with open(text_path, 'r') as f:
            lines = f.readlines()
        
        if not lines:
            print(f"No polygon data in {text_path}")
            return
        
        # Parse polygon coordinates from the first line, ignoring the class label
        polygon = np.array(list(map(float, lines[0].split()[1:])))  # Ignore class label
        if len(polygon) < 6 or len(polygon) % 2 != 0:
            print(f"Invalid polygon data in {text_path}")
            return
        
        polygon = polygon.reshape(-1, 2)  # Reshape to (N, 2)
        
        # Denormalize coordinates
        polygon[:, 0] *= w  # Scale x-coordinates
        polygon[:, 1] *= h  # Scale y-coordinates
        polygon = polygon.astype(np.int32)  # Convert to integer
        
        # Ensure correct shape for OpenCV
        polygon = polygon.reshape((-1, 1, 2))  # Reshape to (N,1,2)
        
        # Draw polygon on the image
        overlay = cv2.cvtColor(image, cv2.COLOR_GRAY2BGR)  # Convert to 3-channel for visualization
        cv2.polylines(overlay, [polygon], isClosed=True, color=(0, 255, 0), thickness=2)
        
        # Display the result
        plt.figure(figsize=(6, 6))
        plt.imshow(overlay, cmap='gray')
        plt.axis("off")
        plt.show()


    def generate_abnormality_data(self, folder_path):
        """
        Analyze images in a folder and compute abnormality scores based on darkness,
        blue, and green color dominance.
        
        :param folder_path: Path to the folder containing images
        :return: Dictionary {image_path: abnormality_score}
        """
        abnormality_scores = {}

        for filename in os.listdir(folder_path):
            img_path = os.path.join(folder_path, filename)
            img = cv2.imread(img_path)
            
            if img is None:
                continue  # Skip non-image files or unreadable images
            
            # Convert to grayscale for brightness analysis
            gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
            mean_brightness = np.mean(gray)  # Average pixel intensity
            
            # Convert to HSV for color analysis
            hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
            hue, sat, val = cv2.split(hsv)
            
            # Create masks for blue and green:
            # Blue: hue roughly between 170 and 250 (adjust as needed)
            blue_mask = ((hue > 170) & (hue < 250)) & (sat > 50)
            blue_ratio = np.sum(blue_mask) / (img.shape[0] * img.shape[1])
            
            # Green: hue roughly between 35 and 85 (adjust as needed)
            green_mask = ((hue > 35) & (hue < 85)) & (sat > 50)
            green_ratio = np.sum(green_mask) / (img.shape[0] * img.shape[1])
            
            # Define abnormality score:
            # Darkness penalty: if mean brightness is low, increase abnormality.
            # Color penalty: higher ratios of blue or green increase abnormality.
            darkness_penalty = max(0, 50 - mean_brightness)  # Only penalize if brightness is below 50
            blue_penalty = blue_ratio * 100  # Weight factor for blue
            green_penalty = green_ratio * 100  # Weight factor for green
            
            abnormality_score = darkness_penalty + blue_penalty + green_penalty
            abnormality_scores[img_path] = abnormality_score

        return abnormality_scores

    def remove_most_abnormal(self, folder_path, n):
        """
        Removes the top n most abnormal images based on darkness and unusual colors (blue/green)
        and returns the names of removed files.
        
        :param folder_path: Path to the folder containing images
        :param n: Number of most abnormal images to remove
        :return: List of filenames of removed images
        """
        abnormality_data = self.generate_abnormality_data(folder_path)
        
        # Sort images by abnormality score (highest first) and select top n
        most_abnormal = sorted(abnormality_data.keys(), key=lambda x: abnormality_data[x], reverse=True)[:n]
        
        removed_files = []
        # Remove selected images
        for img_path in most_abnormal:
            os.remove(img_path)
            removed_files.append(os.path.basename(img_path))
        
        return removed_files


    def move_all_files(self, source_folder, dest_folder):
        """
        Move all files from source_folder to dest_folder.
        
        :param source_folder: Path to the source folder
        :param dest_folder: Path to the destination folder
        """
        # Create destination folder if it doesn't exist
        if not os.path.exists(dest_folder):
            os.makedirs(dest_folder)
        
        # List all items in the source folder
        for filename in os.listdir(source_folder):
            source_path = os.path.join(source_folder, filename)
            dest_path = os.path.join(dest_folder, filename)
            
            # Only move if it's a file (skip directories if needed)
            if os.path.isfile(source_path):
                shutil.move(source_path, dest_path)

    def copy_all_files(self, source_folder, dest_folder):
        """
        Copy all files from source_folder to dest_folder.
        
        :param source_folder: Path to the source folder
        :param dest_folder: Path to the destination folder
        """
        # Create destination folder if it doesn't exist
        if not os.path.exists(dest_folder):
            os.makedirs(dest_folder)
        
        # List all items in the source folder
        for filename in os.listdir(source_folder):
            source_path = os.path.join(source_folder, filename)
            dest_path = os.path.join(dest_folder, filename)
            
            # Only copy if it's a file (skip directories if needed)
            if os.path.isfile(source_path):
                shutil.copy2(source_path, dest_path)


    def recreate_images_from_arrays(self, folder_path):
        """
        For all images in the given folder, load each image as a NumPy array,
        then recreate and overwrite the image using the array.
        Uses self.get_all_images(folder_path) to obtain the image paths.
        
        :param folder_path: Path to the folder containing images.
        """
        image_paths = self.get_all_images(folder_path)
        
        for image_path in image_paths:
            # Read the image into a numpy array (keeping the original image data)
            img = cv2.imread(image_path, cv2.IMREAD_UNCHANGED)
            if img is None:
                print(f"Failed to load image: {image_path}")
                continue
            
            # Overwrite the original image using the numpy array
            if not cv2.imwrite(image_path, img):
                print(f"Failed to write image: {image_path}")


    def flatten_directory(self, main_folder_path):
        """
        Moves all files from inner folders directly into the main folder.
        Deletes any inner folders that become empty.
        
        Args:
            main_folder_path (str): Path to the main folder
        """
        # Make sure the path exists and is a directory
        if not os.path.isdir(main_folder_path):
            raise ValueError(f"The path {main_folder_path} is not a valid directory")
        
        # Get a list of all items in the main folder
        items = os.listdir(main_folder_path)
        
        # Process each item in the main folder
        for item in items:
            item_path = os.path.join(main_folder_path, item)
            
            # If the item is a directory, process its contents
            if os.path.isdir(item_path):
                # Get all files in the inner folder
                inner_items = os.listdir(item_path)
                
                # Move each file to the main folder
                for inner_item in inner_items:
                    inner_item_path = os.path.join(item_path, inner_item)
                    
                    # Only move files, not directories
                    if os.path.isfile(inner_item_path):
                        # Create destination path
                        destination_path = os.path.join(main_folder_path, inner_item)
                        
                        # Handle name conflicts
                        if os.path.exists(destination_path):
                            base, extension = os.path.splitext(inner_item)
                            counter = 1
                            while os.path.exists(destination_path):
                                new_name = f"{base}_{counter}{extension}"
                                destination_path = os.path.join(main_folder_path, new_name)
                                counter += 1
                        
                        # Move the file
                        shutil.move(inner_item_path, destination_path)
                
                # Check if the inner folder is now empty
                if len(os.listdir(item_path)) == 0:
                    # Remove the empty directory
                    os.rmdir(item_path)
                else:
                    print(f"Note: Directory {item} still contains subdirectories and was not removed")


    def create_empty_masks(self, folder1_path, folder2_path, target_extension):
        """
        Efficiently creates black images matching the dimensions of images in folder1 and saves them to folder2.
        Clears all contents of folder2 before starting.
        Optimizes by creating one template black image per unique resolution.
        
        Args:
            folder1_path (str): Path to the source folder with original images
            folder2_path (str): Path to the destination folder for black images
            target_extension (str): The extension to use for the new images (e.g., 'jpg', 'png')
        
        Returns:
            dict: Dictionary with stats about the process
        """
        # Make sure the target extension starts with a dot
        if not target_extension.startswith('.'):
            target_extension = '.' + target_extension
        
        # Validate paths
        if not os.path.isdir(folder1_path):
            raise ValueError(f"The source path {folder1_path} is not a valid directory")
        
        # Clear and recreate destination folder
        if os.path.exists(folder2_path):
            if os.path.isdir(folder2_path):
                print(f"Clearing existing directory: {folder2_path}")
                # Remove all contents of the directory
                for item in os.listdir(folder2_path):
                    item_path = os.path.join(folder2_path, item)
                    if os.path.isfile(item_path):
                        os.unlink(item_path)
                    elif os.path.isdir(item_path):
                        shutil.rmtree(item_path)
            else:
                # It exists but is not a directory, remove it and create a directory
                os.remove(folder2_path)
                os.makedirs(folder2_path)
                print(f"Removed file and created directory: {folder2_path}")
        else:
            # Create new directory
            os.makedirs(folder2_path)
            print(f"Created new directory: {folder2_path}")
        
        # Common image extensions
        image_extensions = {'.jpg', '.jpeg', '.png', '.bmp', '.gif', '.tiff', '.webp'}
        
        # Step 1: Analyze the images and find unique resolutions
        unique_resolutions = {}  # Maps (width, height) to list of files with that resolution
        skipped_files = []
        
        print("Analyzing image resolutions...")
        for file in os.listdir(folder1_path):
            file_path = os.path.join(folder1_path, file)
            
            # Skip directories and non-image files
            if os.path.isdir(file_path):
                continue
                
            # Check if file is an image by extension
            _, extension = os.path.splitext(file)
            if extension.lower() not in image_extensions:
                continue
                
            try:
                # Open the image and get its resolution
                with Image.open(file_path) as img:
                    resolution = img.size  # (width, height)
                    
                    # Add to our resolution mapping
                    if resolution not in unique_resolutions:
                        unique_resolutions[resolution] = []
                    unique_resolutions[resolution].append(file)
                    
            except Exception as e:
                print(f"Error analyzing {file}: {str(e)}")
                skipped_files.append(file)
        
        print(f"Found {len(unique_resolutions)} unique resolutions across {sum(len(files) for files in unique_resolutions.values())} images")
        
        # Step 2: Create one black template image for each unique resolution
        temp_black_images = {}  # Maps resolution to temp file path
        with tempfile.TemporaryDirectory() as temp_dir:
            print("Creating template black images...")
            for resolution in unique_resolutions:
                width, height = resolution
                # Create black image
                black_img = Image.new('RGB', resolution, color=(0, 0, 0))
                
                # Save to temporary file
                temp_path = os.path.join(temp_dir, f"black_{width}x{height}{target_extension}")
                black_img.save(temp_path)
                temp_black_images[resolution] = temp_path
                print(f"Created template black image: {width}x{height}")
            
            # Step 3: Use the templates to create the final images
            print("Generating output images...")
            created_count = 0
            
            for resolution, files in unique_resolutions.items():
                temp_image_path = temp_black_images[resolution]
                width, height = resolution
                
                for file in files:
                    # Get base name without extension
                    base_name = os.path.splitext(file)[0]
                    
                    # Create new filename with target extension
                    new_filename = base_name + target_extension
                    new_file_path = os.path.join(folder2_path, new_filename)
                    
                    # Copy the temporary black image
                    with open(temp_image_path, 'rb') as src_file:
                        with open(new_file_path, 'wb') as dst_file:
                            dst_file.write(src_file.read())
                    
                    created_count += 1
                    if created_count % 50 == 0:
                        print(f"Progress: {created_count} images created")
        
        # Final summary
        stats = {
            "total_processed": sum(len(files) for files in unique_resolutions.values()),
            "unique_resolutions": len(unique_resolutions),
            "created_images": created_count,
            "skipped_files": skipped_files
        }
        
        print(f"\nSummary: Created {created_count} black images in {folder2_path}")
        print(f"Unique resolutions: {len(unique_resolutions)}")
        
        return stats


data_processor = DataProcessor()

# %%
F_DATA = "./data"

F_TRAIN = F_DATA+"/train"
F_TRAIN_IMAGES = F_TRAIN+"/images"
F_TRAIN_IMAGES_POS = F_TRAIN_IMAGES+"/positive"
F_TRAIN_IMAGES_NEG = F_TRAIN_IMAGES+"/negative"
F_TRAIN_MASKS = F_TRAIN+"/masks"
F_TRAIN_MASKS_POS = F_TRAIN_MASKS+"/positive"
F_TRAIN_MASKS_NEG = F_TRAIN_MASKS+"/negative"
F_TRAIN_LABELS = F_TRAIN+"/labels"

F_VAL = F_DATA+"/val"
F_VAL_IMAGES = F_VAL+"/images"
F_VAL_IMAGES_POS = F_VAL_IMAGES+"/positive"
F_VAL_IMAGES_NEG = F_VAL_IMAGES+"/negative"
F_VAL_MASKS = F_VAL+"/masks"
F_VAL_MASKS_POS = F_VAL_MASKS+"/positive"
F_VAL_MASKS_NEG = F_VAL_MASKS+"/negative"
F_VAL_LABELS = F_VAL+"/labels"

F_TEST = F_DATA+"/test"
F_TEST_IMAGES = F_TEST+"/images"
F_TEST_IMAGES_POS = F_TEST_IMAGES+"/positive"
F_TEST_IMAGES_NEG = F_TEST_IMAGES+"/negative"
F_TEST_MASKS = F_TEST+"/masks"
F_TEST_MASKS_POS = F_TEST_MASKS+"/positive"
F_TEST_MASKS_NEG = F_TEST_MASKS+"/negative"

F_DATASETS = F_DATA+"/datasets"
F_DATASET_1 = F_DATASETS+"/CVC-ColonDB"
F_DATASET_1_IMAGES = F_DATASET_1+"/images"
F_DATASET_1_MASKS = F_DATASET_1+"/masks"
F_DATASET_2 = F_DATASETS+"/BKAI-IGH"
F_DATASET_2_IMAGES = F_DATASET_2+"/images"
F_DATASET_2_MASKS = F_DATASET_2+"/masks"

# %% [markdown]
# ## process

# %% [markdown]
# ### review

# %%
data_processor.get_summary(F_TRAIN)
# Out:
# === IMAGE SUMMARY REPORT ===
# Total images analyzed: 36000
# Successful: 36000, Errors: 0
# Total size: 851.71 MB
#
# Resolutions:
#   512x512: 36000 images (100.0%)
#
# Formats:
#   JPEG: 20000 images (55.6%)
#   PNG: 16000 images (44.4%)
# {'total_images': 36000,
#  'successful_analyses': 36000,
#  'errors': 0,
#  'error_details': None,
#  'size_stats': {'total_size_mb': 851.71,
#   'average_size_mb': 0.02,
#   'min_size_mb': 0.0,
#   'max_size_mb': 0.07},
#  'resolutions': {'most_common': ('512x512', 36000), 'all': {'512x512': 36000}},
#  'formats': {'JPEG': 20000, 'PNG': 16000},
#  'aspect_ratios': {'most_common': (1.0, 36000), 'all': {1.0: 36000}}}

# %% [markdown]
# ### remove images periodically

# %%
removed = data_processor.remove_images_in_period(F_TRAIN_IMAGES_POS, 20_535)
data_processor.remove_files_by_base_names(F_TRAIN_MASKS_POS, removed)
# Out:
# Cannot delete all or more images than available.
# []

# %%
removed = data_processor.remove_images_in_period(F_TRAIN_IMAGES_NEG, 22_186)
data_processor.remove_files_by_base_names(F_TRAIN_MASKS_NEG, removed)
# Out:
# Cannot delete all or more images than available.
# []

# %% [markdown]
# ### crop images to square

# %%
data_processor.crop_to_square(F_TRAIN)
# Out:
# Square crop operation completed.
# Processed: 25147, Skipped (already square): 19853, Errors: 0
# {'processed': 25147, 'errors': 0, 'skipped': 19853, 'total': 45000}

# %% [markdown]
# ### scale images to fixed size (Lanczos techniques)

# %%
data_processor.scale_images(F_TRAIN, (512,512))
# Out:
# Scale operation completed.
# Processed: 25147, Skipped (already at target resolution): 19853, Errors: 0
# {'processed': 25147, 'errors': 0, 'skipped': 19853, 'total': 45000}

# %% [markdown]
# ### test split

# %%
moved = data_processor.move_random_n_images(F_TRAIN_IMAGES_POS, F_TEST_IMAGES_POS, 4000)
data_processor.move_images_by_name(F_TRAIN_MASKS_POS, F_TEST_MASKS_POS, moved)
# Out:
# Moved: case_M_20190115123306_0U62368011540606_1_002_001-1_a4_ayy_image0022.jpg -> ./data/test/images/positive
# Moved: case_M_20181022094701_0U62368102271800_1_005_001-1_a4_ayy_image0034.jpg -> ./data/test/images/positive
# Moved: case_M_20181029094800_0U62368102981259_1_005_001-1_a13_ayy_image0040.jpg -> ./data/test/images/positive
# Moved: case_M_20181025093921_0U62363102537521_1_002_001-1_a10_ayy_image0098.jpg -> ./data/test/images/positive
# Moved: case_M_20181213131150_0U62365121395349_1_002_002-1_a18_ayy_image0075.jpg -> ./data/test/images/positive
# Moved: case_M_20190112093830_0U62372011292129_1_001_001-1_a8_ayy_image0030.jpg -> ./data/test/images/positive
# Moved: case_M_20181010094822_0U62363101085921_1_003_001-1_a1_ayy_image0158.jpg -> ./data/test/images/positive
# Moved: case_M_20181018093806_0U62363101890605_1_006_001-1_a2_ayy_image0063.jpg -> ./data/test/images/positive
# Moved: case_M_20190110094509_0U62363011095308_1_001_001-1_a5_ayy_image0031.jpg -> ./data/test/images/positive
# Moved: case_M_20181004093748_0U62372100445348_1_001_001-1_a8_ayy_image0036.jpg -> ./data/test/images/positive
# Moved: case_M_20181015101337_0U62363101576536_1_005_001-1_a21_ayy_image0103.jpg -> ./data/test/images/positive
# Moved: case_M_20181226125224_0U62363122631224_1_003_001-1_a10_ayy_image0394.jpg -> ./data/test/images/positive
# Moved: case_M_20181214095357_0U62368121473456_1_005_001-1_a3_ayy_image0029.jpg -> ./data/test/images/positive
# Moved: case_M_20181017100226_0U62367101735926_1_001_002-1_a15_ayy_image0140.jpg -> ./data/test/images/positive
# Moved: case_M_20181019122218_0U62368101948418_1_002_001-1_a2_ayy_image0037.jpg -> ./data/test/images/positive
# Moved: case_M_20181213131150_0U62365121395349_1_002_001-1_a11_ayy_image0028.jpg -> ./data/test/images/positive
# Moved: case_M_20190109095638_0U62372010945338_1_001_001-1_a3_ayy_image0044.jpg -> ./data/test/images/positive
# Moved: case_M_20190121095240_0U62368012118740_1_004_001-1_a5_ayy_image0069.jpg -> ./data/test/images/positive
# Moved: case_M_20190121095240_0U62368012118740_1_005_001-1_a1_ayy_image0080.jpg -> ./data/test/images/positive
# Moved: case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0351.jpg -> ./data/test/images/positive
# Moved: case_M_20181020093033_0U62363102007833_1_003_002-1_a9_ayy_image0047.jpg -> ./data/test/images/positive
# Moved: case_M_20190112093830_0U62372011292129_1_001_001-1_a10_ayy_image0104.jpg -> ./data/test/images/positive
# Moved: case_M_20181029094800_0U62368102981259_1_002_001-1_a5_ayy_image0032.jpg -> ./data/test/images/positive
# Moved: case_M_20181226125224_0U62363122631224_1_003_001-1_a5_ayy_image0022.jpg -> ./data/test/images/positive
# Moved: case_M_20190109095638_0U62372010945338_1_001_001-1_a2_ayy_image0068.jpg -> ./data/test/images/positive
# Moved: case_M_20181129152014_0U62366112981213_1_001_001-1_a17_ayy_image0026.jpg -> ./data/test/images/positive
# Moved: case_M_20190121095240_0U62368012118740_1_004_001-1_a5_ayy_image0075.jpg -> ./data/test/images/positive
# Moved: case_M_20190115123306_0U62368011540606_1_002_001-1_a3_ayy_image0010.jpg -> ./data/test/images/positive
# Moved: case_M_20181212144657_0U62366121262556_1_001_001-1_a42_ayy_image0027.jpg -> ./data/test/images/positive
# Moved: case_M_20181213092448_0U62363121315648_1_003_001-1_a1_ayy_image0021.jpg -> ./data/test/images/positive
# Moved: case_M_20181228140523_0U62365122821823_1_001_001-1_a6_ayy_image0002.jpg -> ./data/test/images/positive
# Moved: case_M_20181025095048_0U62372102595347_1_004_001-1_a13_ayy_image0017.jpg -> ./data/test/images/positive
# Moved: case_M_20181213131150_0U62365121395349_1_002_001-1_a11_ayy_image0006.jpg -> ./data/test/images/positive
# Moved: case_M_20190117095926_0U62372011750026_1_002_001-1_a4_ayy_image0065.jpg -> ./data/test/images/positive
# Moved: case_M_20190115123306_0U62368011540606_1_002_001-1_a4_ayy_image0143.jpg -> ./data/test/images/positive
# Moved: case_M_20181129152014_0U62366112981213_1_001_001-1_a21_ayy_image0022.jpg -> ./data/test/images/positive
# Moved: case_M_20181217131216_0U62368121700016_1_002_001-1_a10_ayy_image0189.jpg -> ./data/test/images/positive
# Moved: case_M_20181001100941_0U62372100109341_1_005_001-1_a10_ayy_image0134.jpg -> ./data/test/images/positive
# Moved: case_M_20181026100314_0U62363102665613_1_004_001-1_a5_ayy_image0051.jpg -> ./data/test/images/positive
# Moved: case_M_20181203093846_0U62367120345345_1_005_001-1_a6_ayy_image0003.jpg -> ./data/test/images/positive
# Moved: case_M_20181015101337_0U62363101576536_1_005_001-1_a21_ayy_image0545.jpg -> ./data/test/images/positive
# Moved: case_M_20181109094641_0U62372110931241_1_005_001-1_a5_ayy_image0010.jpg -> ./data/test/images/positive
# Moved: case_M_20181226125224_0U62363122631224_1_003_001-1_a8_ayy_image0076.jpg -> ./data/test/images/positive
# Moved: case_M_20181120115731_0U62368112064030_1_004_001-1_a42_ayy_image0060.jpg -> ./data/test/images/positive
# Moved: case_M_20181226125224_0U62363122631224_1_003_001-1_a2_ayy_image0087.jpg -> ./data/test/images/positive
# Moved: case_M_20181119111911_0U62363111914011_1_005_001-1_a8_ayy_image0076.jpg -> ./data/test/images/positive
# Moved: case_M_20190109095638_0U62372010945338_1_003_001-1_a23_ayy_image0402.jpg -> ./data/test/images/positive
# Moved: case_M_20190112093830_0U62372011292129_1_001_001-1_a7_ayy_image0015.jpg -> ./data/test/images/positive
# Moved: case_M_20181226125224_0U62363122631224_1_003_001-1_a8_ayy_image0224.jpg -> ./data/test/images/positive
# Moved: case_M_20181120115731_0U62368112064030_1_001_001-1_a7_ayy_image0028.jpg -> ./data/test/images/positive
# Moved: case_M_20190131094430_0U62372013151529_1_003_001-1_a5_ayy_image0040.jpg -> ./data/test/images/positive
# Moved: case_M_20181205095418_0U62367120576517_1_007_001-1_a26_ayy_image0048.jpg -> ./data/test/images/positive
# Moved: case_M_20181109101724_0U62368110954624_1_005_001-1_a3_ayy_image0090.jpg -> ./data/test/images/positive
# Moved: case_M_20181214095357_0U62368121473456_1_006_003-1_a17_ayy_image0011.jpg -> ./data/test/images/positive
# Moved: case_M_20181203093846_0U62367120345345_1_005_001-1_a8_ayy_image0007.jpg -> ./data/test/images/positive
# Moved: case_M_20181018093806_0U62363101890605_1_007_001-1_a1_ayy_image0002.jpg -> ./data/test/images/positive
# Moved: case_M_20181004140507_0U62366100460906_1_001_001-1_a1_ayy_image0046.jpg -> ./data/test/images/positive
# Moved: case_M_20190131094104_0U62367013193703_1_003_001-1_a9_ayy_image0047.jpg -> ./data/test/images/positive
# Moved: case_M_20181003094031_0U62363100354631_1_001_002-1_a1_ayy_image0260.jpg -> ./data/test/images/positive
# Moved: case_M_20181010094822_0U62363101085921_1_003_001-1_a1_ayy_image0079.jpg -> ./data/test/images/positive
# Moved: case_M_20190117105747_0U62368011712547_1_002_001-1_a17_ayy_image0051.jpg -> ./data/test/images/positive
# Moved: case_M_20181003094031_0U62363100354631_1_001_002-1_a1_ayy_image0001.jpg -> ./data/test/images/positive
# Moved: case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0702.jpg -> ./data/test/images/positive
# Moved: case_M_20181117100025_0U62363111779624_1_007_003-1_a8_ayy_image0320.jpg -> ./data/test/images/positive
# Moved: case_M_20190107094528_0U62367010726528_1_002_001-1_a5_ayy_image0004.jpg -> ./data/test/images/positive
# Moved: case_M_20190121095240_0U62368012118740_1_004_001-1_a1_ayy_image0085.jpg -> ./data/test/images/positive
# Moved: case_M_20181017100226_0U62367101735926_1_007_001-1_a4_ayy_image0028.jpg -> ./data/test/images/positive
# Moved: case_M_20181105095958_0U62368110576557_1_003_002-1_a7_ayy_image0088.jpg -> ./data/test/images/positive
# Moved: case_M_20181015101337_0U62363101576536_1_005_001-1_a21_ayy_image0281.jpg -> ./data/test/images/positive
# Moved: case_M_20181109094641_0U62372110931241_1_005_001-1_a1_ayy_image0122.jpg -> ./data/test/images/positive
# Moved: case_M_20181213092448_0U62363121315648_1_003_001-1_a14_ayy_image0011.jpg -> ./data/test/images/positive
# Moved: case_M_20181022094701_0U62368102271800_1_005_001-1_a3_ayy_image0025.jpg -> ./data/test/images/positive
# Moved: case_M_20190115123306_0U62368011540606_1_002_001-1_a7_ayy_image0047.jpg -> ./data/test/images/positive
# Moved: case_M_20181105095958_0U62368110576557_1_003_002-1_a7_ayy_image0050.jpg -> ./data/test/images/positive
# Moved: case_M_20181214095357_0U62368121473456_1_006_003-1_a17_ayy_image0017.jpg -> ./data/test/images/positive
# Moved: case_M_20181226125224_0U62363122631224_1_003_001-1_a8_ayy_image0109.jpg -> ./data/test/images/positive
# Moved: case_M_20190116094421_0U62363011675020_1_002_001-1_a1_ayy_image0008.jpg -> ./data/test/images/positive
# Moved: case_M_20181119111911_0U62363111914011_1_005_001-1_a12_ayy_image0490.jpg -> ./data/test/images/positive
# Moved: case_M_20181015101337_0U62363101576536_1_005_001-1_a14_ayy_image0030.jpg -> ./data/test/images/positive
# Moved: case_M_20181214095357_0U62368121473456_1_006_003-1_a5_ayy_image0109.jpg -> ./data/test/images/positive
# Moved: case_M_20181214095357_0U62368121473456_1_006_003-1_a17_ayy_image0112.jpg -> ./data/test/images/positive
# Moved: case_M_20190115123306_0U62368011540606_1_002_001-1_a1_ayy_image0049.jpg -> ./data/test/images/positive
# Moved: case_M_20181001140915_0U62366100164014_1_001_001-1_a7_ayy_image0102.jpg -> ./data/test/images/positive
# Moved: case_M_20190116093042_0U62372011685941_1_001_001-1_a6_ayy_image0005.jpg -> ./data/test/images/positive
# Moved: case_M_20181214095357_0U62368121473456_1_006_003-1_a5_ayy_image0034.jpg -> ./data/test/images/positive
# Moved: case_M_20181119111911_0U62363111914011_1_005_001-1_a16_ayy_image0244.jpg -> ./data/test/images/positive
# Moved: case_M_20181003094031_0U62363100354631_1_001_002-1_a1_ayy_image0194.jpg -> ./data/test/images/positive
# Moved: case_M_20190115123306_0U62368011540606_1_002_001-1_a3_ayy_image0132.jpg -> ./data/test/images/positive
# Moved: case_M_20181201091914_0U62363120125014_1_005_001-1_a10_ayy_image0167.jpg -> ./data/test/images/positive
# Moved: case_M_20181022094701_0U62368102271800_1_001_001-1_a9_ayy_image0017.jpg -> ./data/test/images/positive
# Moved: case_M_20190112093830_0U62372011292129_1_001_001-1_a2_ayy_image0083.jpg -> ./data/test/images/positive
# Moved: case_M_20181020093033_0U62363102007833_1_003_002-1_a9_ayy_image0040.jpg -> ./data/test/images/positive
# Moved: case_M_20190128094801_0U62372012857800_1_002_001-1_a6_ayy_image0035.jpg -> ./data/test/images/positive
# Moved: case_M_20181129152014_0U62366112981213_1_001_001-1_a17_ayy_image0090.jpg -> ./data/test/images/positive
# Moved: case_M_20181119111911_0U62363111914011_1_005_001-1_a12_ayy_image0375.jpg -> ./data/test/images/positive
# Moved: case_M_20181029094800_0U62368102981259_1_005_001-1_a12_ayy_image0057.jpg -> ./data/test/images/positive
# Moved: case_M_20181017100226_0U62367101735926_1_007_003-1_a6_ayy_image0062.jpg -> ./data/test/images/positive
# Moved: case_M_20181105095958_0U62368110576557_1_003_002-1_a6_ayy_image0281.jpg -> ./data/test/images/positive
# Moved: case_M_20181029094800_0U62368102981259_1_005_001-1_a14_ayy_image0058.jpg -> ./data/test/images/positive
# Moved: case_M_20181017100226_0U62367101735926_1_007_001-1_a4_ayy_image0040.jpg -> ./data/test/images/positive
# Moved: case_M_20190107094528_0U62367010726528_1_002_001-1_a7_ayy_image0051.jpg -> ./data/test/images/positive
# Moved: case_M_20190112093830_0U62372011292129_1_001_001-1_a10_ayy_image0191.jpg -> ./data/test/images/positive
# Moved: case_M_20181015101337_0U62363101576536_1_005_001-1_a21_ayy_image0484.jpg -> ./data/test/images/positive
# Moved: case_M_20181203093846_0U62367120345345_1_005_001-1_a10_ayy_image0075.jpg -> ./data/test/images/positive
# Moved: case_M_20181025095048_0U62372102595347_1_004_001-1_a2_ayy_image0043.jpg -> ./data/test/images/positive
# Moved: case_M_20181017100226_0U62367101735926_1_007_003-1_a4_ayy_image0087.jpg -> ./data/test/images/positive
# Moved: case_M_20181019101517_0U62367101935917_1_003_001-1_a14_ayy_image0012.jpg -> ./data/test/images/positive
# Moved: case_M_20190112093830_0U62372011292129_1_001_001-1_a1_ayy_image0029.jpg -> ./data/test/images/positive
# Moved: case_M_20181227102913_0U62363122725013_1_004_001-1_a11_ayy_image0118.jpg -> ./data/test/images/positive
# Moved: case_M_20181211093229_0U62367121175028_1_002_002-1_a3_ayy_image0035.jpg -> ./data/test/images/positive
# Moved: case_M_20181119111911_0U62363111914011_1_005_001-1_a2_ayy_image0049.jpg -> ./data/test/images/positive
# Moved: case_M_20181017100226_0U62367101735926_1_007_001-1_a4_ayy_image0060.jpg -> ./data/test/images/positive
# Moved: case_M_20181015101337_0U62363101576536_1_005_002-1_a18_ayy_image0049.jpg -> ./data/test/images/positive
# Moved: case_M_20181010094822_0U62363101085921_1_003_001-1_a17_ayy_image0081.jpg -> ./data/test/images/positive
# Moved: case_M_20190126102153_0U62372012695352_1_001_001-1_a4_ayy_image0144.jpg -> ./data/test/images/positive
# Moved: case_M_20190123101017_0U62372012395316_1_004_001-1_a7_ayy_image0073.jpg -> ./data/test/images/positive
# Moved: case_M_20181117100025_0U62363111779624_1_007_003-1_a2_ayy_image0003.jpg -> ./data/test/images/positive
# Moved: case_M_20190112093830_0U62372011292129_1_001_001-1_a6_ayy_image0032.jpg -> ./data/test/images/positive
# Moved: case_M_20181119111911_0U62363111914011_1_005_001-1_a12_ayy_image0038.jpg -> ./data/test/images/positive
# Moved: case_M_20181119111911_0U62363111914011_1_005_001-1_a12_ayy_image0302.jpg -> ./data/test/images/positive
# Moved: case_M_20190121095240_0U62368012118740_1_004_001-1_a8_ayy_image0076.jpg -> ./data/test/images/positive
# Moved: case_M_20181119111911_0U62363111914011_1_005_001-1_a19_ayy_image0058.jpg -> ./data/test/images/positive
# Moved: case_M_20181213131150_0U62365121395349_1_002_001-1_a11_ayy_image0039.jpg -> ./data/test/images/positive
# Moved: case_M_20181022094701_0U62368102271800_1_005_001-1_a2_ayy_image0013.jpg -> ./data/test/images/positive
# Moved: case_M_20181213131150_0U62365121395349_1_002_002-1_a25_ayy_image0152.jpg -> ./data/test/images/positive
# Moved: case_M_20190112093830_0U62372011292129_1_001_001-1_a1_ayy_image0116.jpg -> ./data/test/images/positive
# Moved: case_M_20181117100025_0U62363111779624_1_007_003-1_a8_ayy_image0172.jpg -> ./data/test/images/positive
# Moved: case_M_20181015093223_0U62372101593722_1_007_002-1_a12_ayy_image0025.jpg -> ./data/test/images/positive
# Moved: case_M_20181018093806_0U62363101890605_1_007_002-1_a14_ayy_image0011.jpg -> ./data/test/images/positive
# Moved: case_M_20181213131150_0U62365121395349_1_002_002-1_a18_ayy_image0089.jpg -> ./data/test/images/positive
# Moved: case_M_20190128094801_0U62372012857800_1_002_001-1_a6_ayy_image0110.jpg -> ./data/test/images/positive
# Moved: case_M_20181214095357_0U62368121473456_1_006_003-1_a17_ayy_image0065.jpg -> ./data/test/images/positive
# Moved: case_M_20190131094104_0U62367013193703_1_003_001-1_a8_ayy_image0099.jpg -> ./data/test/images/positive
# Moved: case_M_20181212144657_0U62366121262556_1_001_001-1_a42_ayy_image0029.jpg -> ./data/test/images/positive
# Moved: case_M_20181213131150_0U62365121395349_1_002_002-1_a18_ayy_image0072.jpg -> ./data/test/images/positive
# Moved: case_M_20181112100700_0U62368111270359_1_005_001-1_a11_ayy_image0017.jpg -> ./data/test/images/positive
# Moved: case_M_20190126102153_0U62372012695352_1_001_001-1_a4_ayy_image0025.jpg -> ./data/test/images/positive
# Moved: case_M_20181213092448_0U62363121315648_1_003_001-1_a3_ayy_image0036.jpg -> ./data/test/images/positive
# Moved: case_M_20181001140915_0U62366100164014_1_001_001-1_a7_ayy_image0141.jpg -> ./data/test/images/positive
# Moved: case_M_20181214095357_0U62368121473456_1_006_003-1_a20_ayy_image0135.jpg -> ./data/test/images/positive
# Moved: case_M_20181001100941_0U62372100109341_1_005_001-1_a2_ayy_image0145.jpg -> ./data/test/images/positive
# Moved: case_M_20190121095240_0U62368012118740_1_004_001-1_a1_ayy_image0027.jpg -> ./data/test/images/positive
# Moved: case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0730.jpg -> ./data/test/images/positive
# Moved: case_M_20181205095418_0U62367120576517_1_007_001-1_a23_ayy_image0027.jpg -> ./data/test/images/positive
# Moved: case_M_20181025093921_0U62363102537521_1_002_001-1_a9_ayy_image0048.jpg -> ./data/test/images/positive
# Moved: case_M_20181129152014_0U62366112981213_1_001_001-1_a17_ayy_image0127.jpg -> ./data/test/images/positive
# Moved: case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0821.jpg -> ./data/test/images/positive
# Moved: case_M_20181226125224_0U62363122631224_1_003_001-1_a10_ayy_image0274.jpg -> ./data/test/images/positive
# Moved: case_M_20181030135203_0U62365103062502_1_001_001-1_a4_ayy_image0025.jpg -> ./data/test/images/positive
# Moved: case_M_20181017100226_0U62367101735926_1_005_001-1_a6_ayy_image0019.jpg -> ./data/test/images/positive
# Moved: case_M_20181119111911_0U62363111914011_1_005_001-1_a16_ayy_image0113.jpg -> ./data/test/images/positive
# Moved: case_M_20181218101803_0U62372121864002_1_001_001-1_a6_ayy_image0104.jpg -> ./data/test/images/positive
# Moved: case_M_20190112093830_0U62372011292129_1_001_001-1_a7_ayy_image0080.jpg -> ./data/test/images/positive
# Moved: case_M_20181017100226_0U62367101735926_1_007_004-1_a4_ayy_image0086.jpg -> ./data/test/images/positive
# Moved: case_M_20190107094528_0U62367010726528_1_002_001-1_a7_ayy_image0097.jpg -> ./data/test/images/positive
# Moved: case_M_20181029094800_0U62368102981259_1_005_001-1_a18_ayy_image0054.jpg -> ./data/test/images/positive
# Moved: case_M_20190109095638_0U62372010945338_1_003_001-1_a24_ayy_image0158.jpg -> ./data/test/images/positive
# Moved: case_M_20181017100226_0U62367101735926_1_007_004-1_a6_ayy_image0343.jpg -> ./data/test/images/positive
# Moved: case_M_20181226125224_0U62363122631224_1_003_001-1_a7_ayy_image0018.jpg -> ./data/test/images/positive
# Moved: case_M_20181207092523_0U62372120765622_1_005_001-1_a17_ayy_image0046.jpg -> ./data/test/images/positive
# Moved: case_M_20181119111911_0U62363111914011_1_005_001-1_a3_ayy_image0050.jpg -> ./data/test/images/positive
# Moved: case_M_20190109095638_0U62372010945338_1_003_001-1_a23_ayy_image0288.jpg -> ./data/test/images/positive
# Moved: case_M_20181018093806_0U62363101890605_1_006_001-1_a3_ayy_image0001.jpg -> ./data/test/images/positive
# Moved: case_M_20181214095357_0U62368121473456_1_006_003-1_a4_ayy_image0117.jpg -> ./data/test/images/positive
# Moved: case_M_20181015101337_0U62363101576536_1_005_001-1_a21_ayy_image0068.jpg -> ./data/test/images/positive
# Moved: case_M_20181010094822_0U62363101085921_1_003_001-1_a2_ayy_image0044.jpg -> ./data/test/images/positive
# Moved: case_M_20181010094822_0U62363101085921_1_003_001-1_a13_ayy_image0252.jpg -> ./data/test/images/positive
# Moved: case_M_20190116094421_0U62363011675020_1_004_001-1_a2_ayy_image0069.jpg -> ./data/test/images/positive
# Moved: case_M_20181010094822_0U62363101085921_1_003_001-1_a17_ayy_image0018.jpg -> ./data/test/images/positive
# Moved: case_M_20190109095638_0U62372010945338_1_003_001-1_a24_ayy_image0186.jpg -> ./data/test/images/positive
# Moved: case_M_20190107094528_0U62367010726528_1_002_002-1_a3_ayy_image0027.jpg -> ./data/test/images/positive
# Moved: case_M_20181119111911_0U62363111914011_1_005_001-1_a16_ayy_image0450.jpg -> ./data/test/images/positive
# Moved: case_M_20181217131216_0U62368121700016_1_002_001-1_a10_ayy_image0130.jpg -> ./data/test/images/positive
# Moved: case_M_20181207092523_0U62372120765622_1_002_001-1_a2_ayy_image0007.jpg -> ./data/test/images/positive
# Moved: case_M_20181022094701_0U62368102271800_1_005_001-1_a3_ayy_image0165.jpg -> ./data/test/images/positive
# Moved: case_M_20181113100307_0U62372111373406_1_005_001-1_a26_ayy_image0196.jpg -> ./data/test/images/positive
# Moved: case_M_20190116094421_0U62363011675020_1_004_001-1_a6_ayy_image0009.jpg -> ./data/test/images/positive
# Moved: case_M_20181119111911_0U62363111914011_1_005_001-1_a16_ayy_image0383.jpg -> ./data/test/images/positive
# Moved: case_M_20181017100226_0U62367101735926_1_007_003-1_a9_ayy_image0131.jpg -> ./data/test/images/positive
# Moved: case_M_20181017100226_0U62367101735926_1_007_004-1_a6_ayy_image0057.jpg -> ./data/test/images/positive
# Moved: case_M_20181031103335_0U62368103151535_1_006_001-1_a4_ayy_image0045.jpg -> ./data/test/images/positive
# Moved: case_M_20181126095408_0U62367112660907_1_001_002-1_a7_ayy_image0026.jpg -> ./data/test/images/positive
# Moved: case_M_20190115123306_0U62368011540606_1_002_001-1_a7_ayy_image0005.jpg -> ./data/test/images/positive
# Moved: case_M_20190112093830_0U62372011292129_1_001_001-1_a1_ayy_image0162.jpg -> ./data/test/images/positive
# Moved: case_M_20190112093830_0U62372011292129_1_001_001-1_a8_ayy_image0079.jpg -> ./data/test/images/positive
# Moved: case_M_20190121095240_0U62368012118740_1_004_001-1_a5_ayy_image0009.jpg -> ./data/test/images/positive
# Moved: case_M_20190109095638_0U62372010945338_1_003_001-1_a24_ayy_image0172.jpg -> ./data/test/images/positive
# Moved: case_M_20190116093042_0U62372011685941_1_001_001-1_a3_ayy_image0118.jpg -> ./data/test/images/positive
# Moved: case_M_20190121095240_0U62368012118740_1_005_001-1_a1_ayy_image0559.jpg -> ./data/test/images/positive
# Moved: case_M_20181025093921_0U62363102537521_1_002_001-1_a10_ayy_image0047.jpg -> ./data/test/images/positive
# Moved: case_M_20181018093806_0U62363101890605_1_007_002-1_a14_ayy_image0057.jpg -> ./data/test/images/positive
# Moved: case_M_20190123101017_0U62372012395316_1_004_001-1_a2_ayy_image0007.jpg -> ./data/test/images/positive
# Moved: case_M_20181217131216_0U62368121700016_1_002_001-1_a10_ayy_image0120.jpg -> ./data/test/images/positive
# Moved: case_M_20181109094641_0U62372110931241_1_005_001-1_a2_ayy_image0018.jpg -> ./data/test/images/positive
# Moved: case_M_20181010094822_0U62363101085921_1_003_001-1_a13_ayy_image0434.jpg -> ./data/test/images/positive
# Moved: case_M_20190109095638_0U62372010945338_1_003_001-1_a24_ayy_image0006.jpg -> ./data/test/images/positive
# Moved: case_M_20181031103335_0U62368103151535_1_006_001-1_a6_ayy_image0014.jpg -> ./data/test/images/positive
# Moved: case_M_20181201091914_0U62363120125014_1_005_001-1_a10_ayy_image0155.jpg -> ./data/test/images/positive
# Moved: case_M_20181025095048_0U62372102595347_1_004_001-1_a17_ayy_image0017.jpg -> ./data/test/images/positive
# Moved: case_M_20190109095638_0U62372010945338_1_003_001-1_a23_ayy_image0396.jpg -> ./data/test/images/positive
# Moved: case_M_20190109095638_0U62372010945338_1_003_001-1_a24_ayy_image0235.jpg -> ./data/test/images/positive
# Moved: case_M_20181017100226_0U62367101735926_1_007_001-1_a12_ayy_image0076.jpg -> ./data/test/images/positive
# Moved: case_M_20181212144657_0U62366121262556_1_001_002-1_a2_ayy_image0161.jpg -> ./data/test/images/positive
# Moved: case_M_20181211093229_0U62367121175028_1_004_001-1_a15_ayy_image0006.jpg -> ./data/test/images/positive
# Moved: case_M_20190121095240_0U62368012118740_1_004_001-1_a3_ayy_image0092.jpg -> ./data/test/images/positive
# Moved: case_M_20190111094523_0U62372011160922_1_005_001-1_a1_ayy_image0072.jpg -> ./data/test/images/positive
# Moved: case_M_20190111094523_0U62372011160922_1_004_002-1_a12_ayy_image0016.jpg -> ./data/test/images/positive
# Moved: case_M_20181119111911_0U62363111914011_1_005_001-1_a9_ayy_image0038.jpg -> ./data/test/images/positive
# Moved: case_M_20181226125224_0U62363122631224_1_003_001-1_a4_ayy_image0080.jpg -> ./data/test/images/positive
# Moved: case_M_20181022094701_0U62368102271800_1_001_001-1_a10_ayy_image0043.jpg -> ./data/test/images/positive
# Moved: case_M_20190112093830_0U62372011292129_1_001_001-1_a1_ayy_image0345.jpg -> ./data/test/images/positive
# Moved: case_M_20181105095958_0U62368110576557_1_003_002-1_a9_ayy_image0021.jpg -> ./data/test/images/positive
# Moved: case_M_20190115123306_0U62368011540606_1_002_001-1_a6_ayy_image0207.jpg -> ./data/test/images/positive
# Moved: case_M_20181117100025_0U62363111779624_1_007_003-1_a8_ayy_image0520.jpg -> ./data/test/images/positive
# Moved: case_M_20190126102153_0U62372012695352_1_001_001-1_a4_ayy_image0142.jpg -> ./data/test/images/positive
# Moved: case_M_20181207092523_0U62372120765622_1_005_001-1_a12_ayy_image0049.jpg -> ./data/test/images/positive
# Moved: case_M_20181113100307_0U62372111373406_1_005_001-1_a15_ayy_image0070.jpg -> ./data/test/images/positive
# Moved: case_M_20181126095408_0U62367112660907_1_001_002-1_a6_ayy_image0066.jpg -> ./data/test/images/positive
# Moved: case_M_20181214095357_0U62368121473456_1_005_001-1_a3_ayy_image0035.jpg -> ./data/test/images/positive
# Moved: case_M_20190121095240_0U62368012118740_1_005_001-1_a1_ayy_image0295.jpg -> ./data/test/images/positive
# Moved: case_M_20190109095638_0U62372010945338_1_003_001-1_a30_ayy_image0044.jpg -> ./data/test/images/positive
# Moved: case_M_20190109095638_0U62372010945338_1_001_001-1_a1_ayy_image0034.jpg -> ./data/test/images/positive
# Moved: case_M_20181025095048_0U62372102595347_1_004_001-1_a4_ayy_image0014.jpg -> ./data/test/images/positive
# Moved: case_M_20190116094421_0U62363011675020_1_002_001-1_a2_ayy_image0092.jpg -> ./data/test/images/positive
# Moved: case_M_20190109095638_0U62372010945338_1_003_001-1_a23_ayy_image0530.jpg -> ./data/test/images/positive
# Moved: case_M_20181025095048_0U62372102595347_1_004_001-1_a13_ayy_image0045.jpg -> ./data/test/images/positive
# Moved: case_M_20181029094800_0U62368102981259_1_005_001-1_a12_ayy_image0035.jpg -> ./data/test/images/positive
# Moved: case_M_20181205095418_0U62367120576517_1_007_001-1_a24_ayy_image0064.jpg -> ./data/test/images/positive
# Moved: case_M_20181026100314_0U62363102665613_1_004_001-1_a8_ayy_image0028.jpg -> ./data/test/images/positive
# Moved: case_M_20181120115731_0U62368112064030_1_001_001-1_a6_ayy_image0013.jpg -> ./data/test/images/positive
# Moved: case_M_20190109095638_0U62372010945338_1_003_001-1_a23_ayy_image0195.jpg -> ./data/test/images/positive
# Moved: case_M_20181226125224_0U62363122631224_1_003_001-1_a8_ayy_image0018.jpg -> ./data/test/images/positive
# Moved: case_M_20181120115731_0U62368112064030_1_001_001-1_a6_ayy_image0025.jpg -> ./data/test/images/positive
# Moved: case_M_20181217131216_0U62368121700016_1_002_001-1_a10_ayy_image0124.jpg -> ./data/test/images/positive
# Moved: case_M_20190126102153_0U62372012695352_1_001_001-1_a3_ayy_image0018.jpg -> ./data/test/images/positive
# Moved: case_M_20181017100226_0U62367101735926_1_007_003-1_a9_ayy_image0032.jpg -> ./data/test/images/positive
# Moved: case_M_20181226125224_0U62363122631224_1_003_001-1_a8_ayy_image0078.jpg -> ./data/test/images/positive
# Moved: case_M_20190123101017_0U62372012395316_1_004_001-1_a4_ayy_image0036.jpg -> ./data/test/images/positive
# Moved: case_M_20190116093042_0U62372011685941_1_001_001-1_a3_ayy_image0079.jpg -> ./data/test/images/positive
# Moved: case_M_20181207092523_0U62372120765622_1_005_001-1_a10_ayy_image0032.jpg -> ./data/test/images/positive
# Moved: case_M_20181214095357_0U62368121473456_1_006_003-1_a20_ayy_image0060.jpg -> ./data/test/images/positive
# Moved: case_M_20190116094421_0U62363011675020_1_002_001-1_a2_ayy_image0057.jpg -> ./data/test/images/positive
# Moved: case_M_20181212144657_0U62366121262556_1_001_002-1_a2_ayy_image0062.jpg -> ./data/test/images/positive
# Moved: case_M_20181218101803_0U62372121864002_1_001_001-1_a3_ayy_image0016.jpg -> ./data/test/images/positive
# Moved: case_M_20190109095638_0U62372010945338_1_003_001-1_a23_ayy_image0489.jpg -> ./data/test/images/positive
# Moved: case_M_20190123101017_0U62372012395316_1_004_001-1_a8_ayy_image0235.jpg -> ./data/test/images/positive
# Moved: case_M_20181017100226_0U62367101735926_1_007_004-1_a4_ayy_image0272.jpg -> ./data/test/images/positive
# Moved: case_M_20181010094822_0U62363101085921_1_003_001-1_a1_ayy_image0105.jpg -> ./data/test/images/positive
# Moved: case_M_20181214095357_0U62368121473456_1_006_003-1_a5_ayy_image0052.jpg -> ./data/test/images/positive
# Moved: case_M_20181117100025_0U62363111779624_1_007_003-1_a5_ayy_image0028.jpg -> ./data/test/images/positive
# Moved: case_M_20181017100226_0U62367101735926_1_005_001-1_a1_ayy_image0015.jpg -> ./data/test/images/positive
# Moved: case_M_20190116093042_0U62372011685941_1_001_001-1_a3_ayy_image0089.jpg -> ./data/test/images/positive
# Moved: case_M_20190115123306_0U62368011540606_1_002_001-1_a4_ayy_image0036.jpg -> ./data/test/images/positive
# Moved: case_M_20181105095958_0U62368110576557_1_003_002-1_a9_ayy_image0040.jpg -> ./data/test/images/positive
# Moved: case_M_20190110094509_0U62363011095308_1_001_002-1_a2_ayy_image0049.jpg -> ./data/test/images/positive
# Moved: case_M_20181213131150_0U62365121395349_1_002_001-1_a9_ayy_image0074.jpg -> ./data/test/images/positive
# Moved: case_M_20190121095240_0U62368012118740_1_005_001-1_a2_ayy_image0191.jpg -> ./data/test/images/positive
# Moved: case_M_20181015101337_0U62363101576536_1_005_001-1_a14_ayy_image0049.jpg -> ./data/test/images/positive
# Moved: case_M_20181207092523_0U62372120765622_1_005_001-1_a12_ayy_image0035.jpg -> ./data/test/images/positive
# Moved: case_M_20181025095048_0U62372102595347_1_004_001-1_a17_ayy_image0096.jpg -> ./data/test/images/positive
# Moved: case_M_20181010094822_0U62363101085921_1_003_001-1_a13_ayy_image0250.jpg -> ./data/test/images/positive
# Moved: case_M_20181109094641_0U62372110931241_1_005_001-1_a4_ayy_image0062.jpg -> ./data/test/images/positive
# Moved: case_M_20190116094421_0U62363011675020_1_004_001-1_a6_ayy_image0121.jpg -> ./data/test/images/positive
# Moved: case_M_20181117100025_0U62363111779624_1_007_003-1_a8_ayy_image0168.jpg -> ./data/test/images/positive
# Moved: case_M_20181119111911_0U62363111914011_1_005_001-1_a16_ayy_image0139.jpg -> ./data/test/images/positive
# Moved: case_M_20190131094104_0U62367013193703_1_003_001-1_a7_ayy_image0024.jpg -> ./data/test/images/positive
# Moved: case_M_20181018093806_0U62363101890605_1_007_002-1_a10_ayy_image0058.jpg -> ./data/test/images/positive
# Moved: case_M_20190121095240_0U62368012118740_1_005_001-1_a1_ayy_image0220.jpg -> ./data/test/images/positive
# Moved: case_M_20181105095958_0U62368110576557_1_003_002-1_a6_ayy_image0216.jpg -> ./data/test/images/positive
# Moved: case_M_20190109095638_0U62372010945338_1_003_001-1_a24_ayy_image0117.jpg -> ./data/test/images/positive
# Moved: case_M_20181017100226_0U62367101735926_1_007_001-1_a12_ayy_image0060.jpg -> ./data/test/images/positive
# Moved: case_M_20190115123306_0U62368011540606_1_002_001-1_a6_ayy_image0209.jpg -> ./data/test/images/positive
# Moved: case_M_20190121095240_0U62368012118740_1_004_001-1_a1_ayy_image0150.jpg -> ./data/test/images/positive
# Moved: case_M_20181004130627_0U62365100475026_1_002_001-1_a5_ayy_image0044.jpg -> ./data/test/images/positive
# Moved: case_M_20181227102913_0U62363122725013_1_004_001-1_a11_ayy_image0035.jpg -> ./data/test/images/positive
# Moved: case_M_20181117100025_0U62363111779624_1_007_003-1_a4_ayy_image0018.jpg -> ./data/test/images/positive
# Moved: case_M_20181207092523_0U62372120765622_1_002_001-1_a4_ayy_image0004.jpg -> ./data/test/images/positive
# Moved: case_M_20190115123306_0U62368011540606_1_002_001-1_a3_ayy_image0108.jpg -> ./data/test/images/positive
# Moved: case_M_20181004130627_0U62365100475026_1_002_001-1_a1_ayy_image0021.jpg -> ./data/test/images/positive
# Moved: case_M_20181010094822_0U62363101085921_1_003_001-1_a4_ayy_image0222.jpg -> ./data/test/images/positive
# Moved: case_M_20181025095048_0U62372102595347_1_004_001-1_a8_ayy_image0149.jpg -> ./data/test/images/positive
# Moved: case_M_20181226125224_0U62363122631224_1_003_001-1_a10_ayy_image0023.jpg -> ./data/test/images/positive
# Moved: case_M_20181017100226_0U62367101735926_1_007_004-1_a6_ayy_image0369.jpg -> ./data/test/images/positive
# Moved: case_M_20181226125224_0U62363122631224_1_003_001-1_a10_ayy_image0284.jpg -> ./data/test/images/positive
# Moved: case_M_20181030135203_0U62365103062502_1_001_001-1_a3_ayy_image0034.jpg -> ./data/test/images/positive
# Moved: case_M_20181213092448_0U62363121315648_1_003_001-1_a6_ayy_image0002.jpg -> ./data/test/images/positive
# Moved: case_M_20181022094701_0U62368102271800_1_001_001-1_a9_ayy_image0005.jpg -> ./data/test/images/positive
# Moved: case_M_20190115123306_0U62368011540606_1_002_001-1_a5_ayy_image0070.jpg -> ./data/test/images/positive
# Moved: case_M_20181211093229_0U62367121175028_1_004_001-1_a5_ayy_image0026.jpg -> ./data/test/images/positive
# Moved: case_M_20181017100226_0U62367101735926_1_007_003-1_a2_ayy_image0030.jpg -> ./data/test/images/positive
# Moved: case_M_20181003094031_0U62363100354631_1_001_002-1_a1_ayy_image0113.jpg -> ./data/test/images/positive
# Moved: case_M_20181017100226_0U62367101735926_1_007_003-1_a9_ayy_image0103.jpg -> ./data/test/images/positive
# Moved: case_M_20181109094641_0U62372110931241_1_005_001-1_a4_ayy_image0077.jpg -> ./data/test/images/positive
# Moved: case_M_20181017100226_0U62367101735926_1_007_003-1_a2_ayy_image0063.jpg -> ./data/test/images/positive
# Moved: case_M_20181205095418_0U62367120576517_1_007_001-1_a24_ayy_image0013.jpg -> ./data/test/images/positive
# Moved: case_M_20190115123306_0U62368011540606_1_002_001-1_a3_ayy_image0018.jpg -> ./data/test/images/positive
# Moved: case_M_20181113100307_0U62372111373406_1_005_001-1_a15_ayy_image0062.jpg -> ./data/test/images/positive
# Moved: case_M_20190109095638_0U62372010945338_1_003_001-1_a24_ayy_image0342.jpg -> ./data/test/images/positive
# Moved: case_M_20181214095357_0U62368121473456_1_006_003-1_a22_ayy_image0211.jpg -> ./data/test/images/positive
# Moved: case_M_20181025095048_0U62372102595347_1_004_001-1_a7_ayy_image0034.jpg -> ./data/test/images/positive
# Moved: case_M_20190117095926_0U62372011750026_1_002_001-1_a3_ayy_image0021.jpg -> ./data/test/images/positive
# Moved: case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0838.jpg -> ./data/test/images/positive
# Moved: case_M_20181228140523_0U62365122821823_1_001_001-1_a3_ayy_image0162.jpg -> ./data/test/images/positive
# Moved: case_M_20181203093846_0U62367120345345_1_005_001-1_a7_ayy_image0011.jpg -> ./data/test/images/positive
# Moved: case_M_20181214095357_0U62368121473456_1_006_003-1_a20_ayy_image0025.jpg -> ./data/test/images/positive
# Moved: case_M_20190109095638_0U62372010945338_1_003_001-1_a28_ayy_image0079.jpg -> ./data/test/images/positive
# Moved: case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0527.jpg -> ./data/test/images/positive
# Moved: case_M_20181213131150_0U62365121395349_1_002_001-1_a8_ayy_image0010.jpg -> ./data/test/images/positive
# Moved: case_M_20181029094800_0U62368102981259_1_005_001-1_a15_ayy_image0126.jpg -> ./data/test/images/positive
# Moved: case_M_20181018093806_0U62363101890605_1_007_002-1_a12_ayy_image0048.jpg -> ./data/test/images/positive
# Moved: case_M_20181220100816_0U62368122007816_1_002_001-1_a6_ayy_image0123.jpg -> ./data/test/images/positive
# Moved: case_M_20181214095357_0U62368121473456_1_006_003-1_a17_ayy_image0169.jpg -> ./data/test/images/positive
# Moved: case_M_20181214095357_0U62368121473456_1_006_003-1_a22_ayy_image0142.jpg -> ./data/test/images/positive
# Moved: case_M_20181201091914_0U62363120125014_1_005_001-1_a10_ayy_image0084.jpg -> ./data/test/images/positive
# Moved: case_M_20190111094523_0U62372011160922_1_004_002-1_a8_ayy_image0045.jpg -> ./data/test/images/positive
# Moved: case_M_20190109095638_0U62372010945338_1_003_001-1_a23_ayy_image0120.jpg -> ./data/test/images/positive
# Moved: case_M_20181003094031_0U62363100354631_1_001_002-1_a1_ayy_image0092.jpg -> ./data/test/images/positive
# Moved: case_M_20181211093229_0U62367121175028_1_004_001-1_a10_ayy_image0079.jpg -> ./data/test/images/positive
# Moved: case_M_20181015101337_0U62363101576536_1_005_001-1_a21_ayy_image0232.jpg -> ./data/test/images/positive
# Moved: case_M_20190123101017_0U62372012395316_1_004_001-1_a8_ayy_image0101.jpg -> ./data/test/images/positive
# Moved: case_M_20181010094822_0U62363101085921_1_003_001-1_a13_ayy_image0532.jpg -> ./data/test/images/positive
# Moved: case_M_20181105095958_0U62368110576557_1_003_002-1_a6_ayy_image0451.jpg -> ./data/test/images/positive
# Moved: case_M_20181105095958_0U62368110576557_1_003_002-1_a7_ayy_image0028.jpg -> ./data/test/images/positive
# Moved: case_M_20181214095357_0U62368121473456_1_006_003-1_a17_ayy_image0098.jpg -> ./data/test/images/positive
# Moved: case_M_20181105095958_0U62368110576557_1_003_002-1_a6_ayy_image0289.jpg -> ./data/test/images/positive
# Moved: case_M_20190131094104_0U62367013193703_1_003_001-1_a8_ayy_image0069.jpg -> ./data/test/images/positive
# Moved: case_M_20181004093748_0U62372100445348_1_001_001-1_a3_ayy_image0013.jpg -> ./data/test/images/positive
# Moved: case_M_20181213131150_0U62365121395349_1_002_002-1_a25_ayy_image0070.jpg -> ./data/test/images/positive
# Moved: case_M_20190107094528_0U62367010726528_1_002_001-1_a7_ayy_image0014.jpg -> ./data/test/images/positive
# Moved: case_M_20190110094509_0U62363011095308_1_001_002-1_a4_ayy_image0090.jpg -> ./data/test/images/positive
# Moved: case_M_20181017100226_0U62367101735926_1_007_004-1_a6_ayy_image0179.jpg -> ./data/test/images/positive
# Moved: case_M_20190115123306_0U62368011540606_1_002_001-1_a4_ayy_image0093.jpg -> ./data/test/images/positive
# Moved: case_M_20190109095638_0U62372010945338_1_003_001-1_a23_ayy_image0025.jpg -> ./data/test/images/positive
# Moved: case_M_20190117105747_0U62368011712547_1_004_001-1_a13_ayy_image0225.jpg -> ./data/test/images/positive
# Moved: case_M_20181003094031_0U62363100354631_1_001_002-1_a1_ayy_image0149.jpg -> ./data/test/images/positive
# Moved: case_M_20190121095240_0U62368012118740_1_005_001-1_a3_ayy_image0139.jpg -> ./data/test/images/positive
# Moved: case_M_20181126140908_0U62368112685907_1_004_001-1_a16_ayy_image0005.jpg -> ./data/test/images/positive
# Moved: case_M_20181109094641_0U62372110931241_1_005_001-1_a4_ayy_image0119.jpg -> ./data/test/images/positive
# Moved: case_M_20181203093846_0U62367120345345_1_005_001-1_a6_ayy_image0017.jpg -> ./data/test/images/positive
# Moved: case_M_20181004130627_0U62365100475026_1_002_001-1_a5_ayy_image0137.jpg -> ./data/test/images/positive
# Moved: case_M_20181017100226_0U62367101735926_1_007_003-1_a10_ayy_image0013.jpg -> ./data/test/images/positive
# Moved: case_M_20181022094701_0U62368102271800_1_005_001-1_a4_ayy_image0038.jpg -> ./data/test/images/positive
# Moved: case_M_20190121095240_0U62368012118740_1_005_001-1_a1_ayy_image0259.jpg -> ./data/test/images/positive
# Moved: case_M_20181217131216_0U62368121700016_1_002_001-1_a10_ayy_image0065.jpg -> ./data/test/images/positive
# Moved: case_M_20181018093806_0U62363101890605_1_007_001-1_a3_ayy_image0012.jpg -> ./data/test/images/positive
# Moved: case_M_20190112093830_0U62372011292129_1_001_001-1_a1_ayy_image0245.jpg -> ./data/test/images/positive
# Moved: case_M_20181026100314_0U62363102665613_1_004_001-1_a4_ayy_image0033.jpg -> ./data/test/images/positive
# Moved: case_M_20181113100307_0U62372111373406_1_005_001-1_a26_ayy_image0075.jpg -> ./data/test/images/positive
# Moved: case_M_20181018093806_0U62363101890605_1_007_002-1_a3_ayy_image0015.jpg -> ./data/test/images/positive
# Moved: case_M_20181010094822_0U62363101085921_1_003_001-1_a1_ayy_image0057.jpg -> ./data/test/images/positive
# Moved: case_M_20181017100226_0U62367101735926_1_007_003-1_a4_ayy_image0002.jpg -> ./data/test/images/positive
# Moved: case_M_20190107094528_0U62367010726528_1_002_001-1_a7_ayy_image0029.jpg -> ./data/test/images/positive
# Moved: case_M_20181207092523_0U62372120765622_1_005_001-1_a13_ayy_image0019.jpg -> ./data/test/images/positive
# Moved: case_M_20181203093846_0U62367120345345_1_005_001-1_a7_ayy_image0052.jpg -> ./data/test/images/positive
# Moved: case_M_20181019101517_0U62367101935917_1_003_001-1_a18_ayy_image0211.jpg -> ./data/test/images/positive
# Moved: case_M_20181207092523_0U62372120765622_1_002_001-1_a2_ayy_image0038.jpg -> ./data/test/images/positive
# Moved: case_M_20190121095240_0U62368012118740_1_004_001-1_a8_ayy_image0182.jpg -> ./data/test/images/positive
# Moved: case_M_20181029094800_0U62368102981259_1_005_001-1_a12_ayy_image0033.jpg -> ./data/test/images/positive
# Moved: case_M_20181004093748_0U62372100445348_1_001_001-1_a4_ayy_image0110.jpg -> ./data/test/images/positive
# Moved: case_M_20181105095958_0U62368110576557_1_003_002-1_a6_ayy_image0220.jpg -> ./data/test/images/positive
# Moved: case_M_20181001093706_0U62368100179605_1_004_002-1_a25_ayy_image0031.jpg -> ./data/test/images/positive
# Moved: case_M_20190116094421_0U62363011675020_1_004_001-1_a2_ayy_image0083.jpg -> ./data/test/images/positive
# Moved: case_M_20190109095638_0U62372010945338_1_003_001-1_a22_ayy_image0015.jpg -> ./data/test/images/positive
# Moved: case_M_20181119111911_0U62363111914011_1_005_001-1_a3_ayy_image0064.jpg -> ./data/test/images/positive
# Moved: case_M_20181226125224_0U62363122631224_1_003_001-1_a10_ayy_image0319.jpg -> ./data/test/images/positive
# Moved: case_M_20181119111911_0U62363111914011_1_005_001-1_a4_ayy_image0026.jpg -> ./data/test/images/positive
# Moved: case_M_20181017100226_0U62367101735926_1_007_004-1_a4_ayy_image0045.jpg -> ./data/test/images/positive
# Moved: case_M_20181010094822_0U62363101085921_1_003_001-1_a1_ayy_image0002.jpg -> ./data/test/images/positive
# Moved: case_M_20181129152014_0U62366112981213_1_001_001-1_a20_ayy_image0044.jpg -> ./data/test/images/positive
# Moved: case_M_20181029094800_0U62368102981259_1_005_001-1_a15_ayy_image0030.jpg -> ./data/test/images/positive
# Moved: case_M_20181126140908_0U62368112685907_1_004_001-1_a14_ayy_image0022.jpg -> ./data/test/images/positive
# Moved: case_M_20181113100307_0U62372111373406_1_005_001-1_a14_ayy_image0013.jpg -> ./data/test/images/positive
# Moved: case_M_20181029094800_0U62368102981259_1_005_001-1_a15_ayy_image0065.jpg -> ./data/test/images/positive
# Moved: case_M_20181213092448_0U62363121315648_1_003_001-1_a13_ayy_image0019.jpg -> ./data/test/images/positive
# Moved: case_M_20181018093806_0U62363101890605_1_006_001-1_a2_ayy_image0114.jpg -> ./data/test/images/positive
# Moved: case_M_20190121095240_0U62368012118740_1_004_001-1_a8_ayy_image0115.jpg -> ./data/test/images/positive
# Moved: case_M_20181001140915_0U62366100164014_1_001_001-1_a4_ayy_image0038.jpg -> ./data/test/images/positive
# Moved: case_M_20181001093706_0U62368100179605_1_004_002-1_a25_ayy_image0059.jpg -> ./data/test/images/positive
# Moved: case_M_20181003094031_0U62363100354631_1_001_002-1_a1_ayy_image0477.jpg -> ./data/test/images/positive
# Moved: case_M_20181015101337_0U62363101576536_1_005_001-1_a21_ayy_image0198.jpg -> ./data/test/images/positive
# Moved: case_M_20190112093830_0U62372011292129_1_001_001-1_a6_ayy_image0003.jpg -> ./data/test/images/positive
# Moved: case_M_20181022094701_0U62368102271800_1_005_001-1_a3_ayy_image0149.jpg -> ./data/test/images/positive
# Moved: case_M_20181226125224_0U62363122631224_1_003_001-1_a4_ayy_image0066.jpg -> ./data/test/images/positive
# Moved: case_M_20190109095638_0U62372010945338_1_003_001-1_a23_ayy_image0586.jpg -> ./data/test/images/positive
# Moved: case_M_20181015101337_0U62363101576536_1_005_001-1_a21_ayy_image0518.jpg -> ./data/test/images/positive
# Moved: case_M_20190131094104_0U62367013193703_1_003_001-1_a8_ayy_image0111.jpg -> ./data/test/images/positive
# Moved: case_M_20181226125224_0U62363122631224_1_003_001-1_a2_ayy_image0050.jpg -> ./data/test/images/positive
# Moved: case_M_20181010094822_0U62363101085921_1_003_001-1_a4_ayy_image0174.jpg -> ./data/test/images/positive
# Moved: case_M_20181120115731_0U62368112064030_1_001_001-1_a6_ayy_image0017.jpg -> ./data/test/images/positive
# Moved: case_M_20181110093525_0U62372111056224_1_004_001-1_a2_ayy_image0110.jpg -> ./data/test/images/positive
# Moved: case_M_20181119111911_0U62363111914011_1_005_001-1_a4_ayy_image0052.jpg -> ./data/test/images/positive
# Moved: case_M_20181213131150_0U62365121395349_1_002_002-1_a25_ayy_image0084.jpg -> ./data/test/images/positive
# Moved: case_M_20181214095357_0U62368121473456_1_006_003-1_a22_ayy_image0045.jpg -> ./data/test/images/positive
# Moved: case_M_20181019101517_0U62367101935917_1_003_001-1_a17_ayy_image0049.jpg -> ./data/test/images/positive
# Moved: case_M_20181015101337_0U62363101576536_1_005_001-1_a14_ayy_image0079.jpg -> ./data/test/images/positive
# Moved: case_M_20181211093229_0U62367121175028_1_004_001-1_a10_ayy_image0051.jpg -> ./data/test/images/positive
# Moved: case_M_20190121095240_0U62368012118740_1_005_001-1_a3_ayy_image0070.jpg -> ./data/test/images/positive
# Moved: case_M_20181017100226_0U62367101735926_1_007_004-1_a4_ayy_image0023.jpg -> ./data/test/images/positive
# Moved: case_M_20190128094801_0U62372012857800_1_002_001-1_a13_ayy_image0070.jpg -> ./data/test/images/positive
# Moved: case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0813.jpg -> ./data/test/images/positive
# Moved: case_M_20190123101017_0U62372012395316_1_004_001-1_a7_ayy_image0049.jpg -> ./data/test/images/positive
# Moved: case_M_20190110094509_0U62363011095308_1_001_001-1_a5_ayy_image0025.jpg -> ./data/test/images/positive
# Moved: case_M_20181019101517_0U62367101935917_1_003_001-1_a18_ayy_image0146.jpg -> ./data/test/images/positive
# Moved: case_M_20181017100226_0U62367101735926_1_007_004-1_a4_ayy_image0126.jpg -> ./data/test/images/positive
# Moved: case_M_20181120115731_0U62368112064030_1_001_001-1_a4_ayy_image0023.jpg -> ./data/test/images/positive
# Moved: case_M_20181211093229_0U62367121175028_1_004_001-1_a16_ayy_image0040.jpg -> ./data/test/images/positive
# Moved: case_M_20190110094509_0U62363011095308_1_001_002-1_a3_ayy_image0020.jpg -> ./data/test/images/positive
# Moved: case_M_20181025095048_0U62372102595347_1_004_002-1_a8_ayy_image0086.jpg -> ./data/test/images/positive
# Moved: case_M_20181226125224_0U62363122631224_1_003_001-1_a10_ayy_image0195.jpg -> ./data/test/images/positive
# Moved: case_M_20181207092523_0U62372120765622_1_005_001-1_a15_ayy_image0027.jpg -> ./data/test/images/positive
# Moved: case_M_20190117095926_0U62372011750026_1_002_001-1_a4_ayy_image0041.jpg -> ./data/test/images/positive
# Moved: case_M_20181110093525_0U62372111056224_1_004_001-1_a2_ayy_image0007.jpg -> ./data/test/images/positive
# Moved: case_M_20190112093830_0U62372011292129_1_001_001-1_a6_ayy_image0050.jpg -> ./data/test/images/positive
# Moved: case_M_20190107094528_0U62367010726528_1_002_002-1_a3_ayy_image0019.jpg -> ./data/test/images/positive
# Moved: case_M_20181030122608_0U62363103057807_1_002_003-1_a3_ayy_image0025.jpg -> ./data/test/images/positive
# Moved: case_M_20181217131216_0U62368121700016_1_002_001-1_a10_ayy_image0067.jpg -> ./data/test/images/positive
# Moved: case_M_20181226125224_0U62363122631224_1_003_001-1_a10_ayy_image0230.jpg -> ./data/test/images/positive
# Moved: case_M_20190107094528_0U62367010726528_1_002_001-1_a6_ayy_image0016.jpg -> ./data/test/images/positive
# Moved: case_M_20181017100226_0U62367101735926_1_007_004-1_a4_ayy_image0169.jpg -> ./data/test/images/positive
# Moved: case_M_20181031103335_0U62368103151535_1_006_001-1_a4_ayy_image0013.jpg -> ./data/test/images/positive
# Moved: case_M_20181126140908_0U62368112685907_1_004_001-1_a17_ayy_image0047.jpg -> ./data/test/images/positive
# Moved: case_M_20181119111911_0U62363111914011_1_005_001-1_a12_ayy_image0306.jpg -> ./data/test/images/positive
# Moved: case_M_20181207092523_0U62372120765622_1_005_001-1_a13_ayy_image0031.jpg -> ./data/test/images/positive
# Moved: case_M_20181205095418_0U62367120576517_1_007_001-1_a22_ayy_image0009.jpg -> ./data/test/images/positive
# Moved: case_M_20190121095240_0U62368012118740_1_005_001-1_a3_ayy_image0210.jpg -> ./data/test/images/positive
# Moved: case_M_20181019122218_0U62368101948418_1_002_001-1_a4_ayy_image0083.jpg -> ./data/test/images/positive
# Moved: case_M_20181017100226_0U62367101735926_1_007_003-1_a4_ayy_image0022.jpg -> ./data/test/images/positive
# Moved: case_M_20181226125224_0U62363122631224_1_003_001-1_a8_ayy_image0168.jpg -> ./data/test/images/positive
# Moved: case_M_20181029094800_0U62368102981259_1_005_001-1_a15_ayy_image0037.jpg -> ./data/test/images/positive
# Moved: case_M_20181126140908_0U62368112685907_1_004_001-1_a13_ayy_image0044.jpg -> ./data/test/images/positive
# Moved: case_M_20190112093830_0U62372011292129_1_001_001-1_a10_ayy_image0073.jpg -> ./data/test/images/positive
# Moved: case_M_20181017100226_0U62367101735926_1_005_001-1_a1_ayy_image0019.jpg -> ./data/test/images/positive
# Moved: case_M_20181018093806_0U62363101890605_1_006_001-1_a2_ayy_image0004.jpg -> ./data/test/images/positive
# Moved: case_M_20181001140915_0U62366100164014_1_001_001-1_a5_ayy_image0014.jpg -> ./data/test/images/positive
# ...
#  'case_M_20181019101517_0U62367101935917_1_003_001-1_a18_ayy_image0175.png',
#  'case_M_20190109095638_0U62372010945338_1_003_001-1_a30_ayy_image0069.png',
#  'case_M_20181114092617_0U62372111495316_1_007_001-1_a2_ayy_image0080.png',
#  'case_M_20181010094822_0U62363101085921_1_003_001-1_a13_ayy_image0475.png',
#  'case_M_20181022094701_0U62368102271800_1_005_001-1_a2_ayy_image0074.png',
#  'case_M_20181226125224_0U62363122631224_1_003_001-1_a10_ayy_image0102.png',
#  'case_M_20181019101517_0U62367101935917_1_003_001-1_a14_ayy_image0012.png',
#  'case_M_20190109095638_0U62372010945338_1_003_001-1_a22_ayy_image0013.png',
#  'case_M_20190115123306_0U62368011540606_1_002_001-1_a3_ayy_image0105.png',
#  'case_M_20190121095240_0U62368012118740_1_005_001-1_a2_ayy_image0165.png',
#  'case_M_20181105095958_0U62368110576557_1_003_002-1_a6_ayy_image0465.png',
#  'case_M_20181025095048_0U62372102595347_1_004_001-1_a15_ayy_image0068.png',
#  'case_M_20181226125224_0U62363122631224_1_003_001-1_a10_ayy_image0084.png',
#  'case_M_20190121095240_0U62368012118740_1_005_001-1_a1_ayy_image0305.png',
#  'case_M_20181019101517_0U62367101935917_1_003_001-1_a18_ayy_image0270.png',
#  'case_M_20181017100226_0U62367101735926_1_007_001-1_a3_ayy_image0052.png',
#  'case_M_20181119111911_0U62363111914011_1_005_001-1_a16_ayy_image0312.png',
#  'case_M_20190112093830_0U62372011292129_1_001_001-1_a2_ayy_image0083.png',
#  'case_M_20181211093229_0U62367121175028_1_004_001-1_a10_ayy_image0051.png',
#  'case_M_20181010094822_0U62363101085921_1_003_001-1_a17_ayy_image0124.png',
#  'case_M_20181015101337_0U62363101576536_1_005_001-1_a21_ayy_image0457.png',
#  'case_M_20181214095357_0U62368121473456_1_006_003-1_a23_ayy_image0086.png',
#  'case_M_20181119111911_0U62363111914011_1_005_001-1_a16_ayy_image0068.png',
#  'case_M_20181017100226_0U62367101735926_1_005_001-1_a3_ayy_image0101.png',
#  'case_M_20181017100226_0U62367101735926_1_007_004-1_a4_ayy_image0029.png',
#  'case_M_20181214095357_0U62368121473456_1_006_003-1_a22_ayy_image0282.png',
#  'case_M_20190128094801_0U62372012857800_1_002_001-1_a7_ayy_image0028.png',
#  'case_M_20181228140523_0U62365122821823_1_001_001-1_a6_ayy_image0040.png',
#  'case_M_20181129152014_0U62366112981213_1_001_001-1_a18_ayy_image0013.png',
#  'case_M_20181017100226_0U62367101735926_1_007_004-1_a6_ayy_image0321.png',
#  'case_M_20190107094528_0U62367010726528_1_002_002-1_a3_ayy_image0055.png',
#  'case_M_20181120115731_0U62368112064030_1_004_001-1_a42_ayy_image0012.png',
#  'case_M_20181227102913_0U62363122725013_1_004_001-1_a11_ayy_image0086.png',
#  'case_M_20190130094921_0U62367013093720_1_009_001-1_a7_ayy_image0027.png',
#  'case_M_20181022094701_0U62368102271800_1_001_001-1_a11_ayy_image0064.png',
#  'case_M_20181030122608_0U62363103057807_1_002_003-1_a2_ayy_image0017.png',
#  'case_M_20190131094104_0U62367013193703_1_003_001-1_a9_ayy_image0230.png',
#  'case_M_20190109095638_0U62372010945338_1_003_001-1_a23_ayy_image0443.png',
#  'case_M_20181003094031_0U62363100354631_1_001_002-1_a1_ayy_image0270.png',
#  'case_M_20181015101337_0U62363101576536_1_005_002-1_a8_ayy_image0043.png',
#  'case_M_20190116094421_0U62363011675020_1_004_001-1_a3_ayy_image0029.png',
#  'case_M_20181001140915_0U62366100164014_1_001_001-1_a4_ayy_image0060.png',
#  'case_M_20181129152014_0U62366112981213_1_001_001-1_a21_ayy_image0064.png',
#  'case_M_20190112093830_0U62372011292129_1_001_001-1_a8_ayy_image0002.png',
#  'case_M_20181017100226_0U62367101735926_1_007_003-1_a9_ayy_image0142.png',
#  'case_M_20181226125224_0U62363122631224_1_003_001-1_a8_ayy_image0216.png',
#  'case_M_20190115123306_0U62368011540606_1_002_001-1_a3_ayy_image0018.png',
#  'case_M_20181018093806_0U62363101890605_1_007_002-1_a11_ayy_image0002.png',
#  'case_M_20181117100025_0U62363111779624_1_007_003-1_a8_ayy_image0048.png',
#  'case_M_20181214095357_0U62368121473456_1_006_003-1_a22_ayy_image0065.png',
#  'case_M_20181017100226_0U62367101735926_1_007_003-1_a2_ayy_image0028.png',
#  'case_M_20190115123306_0U62368011540606_1_002_001-1_a3_ayy_image0108.png',
#  'case_M_20190123101017_0U62372012395316_1_004_001-1_a7_ayy_image0049.png',
#  'case_M_20181119111911_0U62363111914011_1_005_001-1_a10_ayy_image0030.png',
#  'case_M_20190121095240_0U62368012118740_1_004_001-1_a2_ayy_image0012.png',
#  'case_M_20181019101517_0U62367101935917_1_003_001-1_a18_ayy_image0215.png',
#  'case_M_20190130094921_0U62367013093720_1_009_001-1_a7_ayy_image0006.png',
#  'case_M_20181120115731_0U62368112064030_1_001_001-1_a7_ayy_image0028.png',
#  'case_M_20181120115731_0U62368112064030_1_004_001-1_a42_ayy_image0038.png',
#  'case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0416.png',
#  'case_M_20181129152014_0U62366112981213_1_001_001-1_a21_ayy_image0030.png',
#  'case_M_20181004093748_0U62372100445348_1_001_001-1_a8_ayy_image0036.png',
#  'case_M_20190109095638_0U62372010945338_1_003_001-1_a23_ayy_image0400.png',
#  'case_M_20181119111911_0U62363111914011_1_005_001-1_a3_ayy_image0058.png',
#  'case_M_20181029094800_0U62368102981259_1_005_001-1_a12_ayy_image0035.png',
#  'case_M_20181026100314_0U62363102665613_1_004_001-1_a4_ayy_image0057.png',
#  'case_M_20181017100226_0U62367101735926_1_007_003-1_a4_ayy_image0087.png',
#  'case_M_20181207092523_0U62372120765622_1_005_001-1_a12_ayy_image0035.png',
#  'case_M_20190107094528_0U62367010726528_1_002_001-1_a7_ayy_image0087.png',
#  'case_M_20181211093229_0U62367121175028_1_004_001-1_a10_ayy_image0139.png',
#  'case_M_20181211093229_0U62367121175028_1_004_001-1_a10_ayy_image0043.png',
#  'case_M_20181226125224_0U62363122631224_1_003_001-1_a10_ayy_image0021.png',
#  'case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0552.png',
#  'case_M_20181205095418_0U62367120576517_1_007_001-1_a24_ayy_image0007.png',
#  'case_M_20181015101337_0U62363101576536_1_005_001-1_a21_ayy_image0135.png',
#  'case_M_20181119111911_0U62363111914011_1_005_001-1_a12_ayy_image0174.png',
#  'case_M_20181226125224_0U62363122631224_1_003_001-1_a2_ayy_image0004.png',
#  'case_M_20181213131150_0U62365121395349_1_002_002-1_a18_ayy_image0160.png',
#  'case_M_20181105095958_0U62368110576557_1_003_002-1_a10_ayy_image0013.png',
#  'case_M_20181029094800_0U62368102981259_1_005_001-1_a15_ayy_image0101.png',
#  'case_M_20181018093806_0U62363101890605_1_007_002-1_a3_ayy_image0003.png',
#  'case_M_20190115123306_0U62368011540606_1_002_001-1_a4_ayy_image0157.png',
#  'case_M_20181029094800_0U62368102981259_1_005_001-1_a15_ayy_image0006.png',
#  'case_M_20181017100226_0U62367101735926_1_007_003-1_a4_ayy_image0093.png',
#  'case_M_20190116093042_0U62372011685941_1_001_001-1_a6_ayy_image0005.png',
#  'case_M_20181017100226_0U62367101735926_1_007_004-1_a6_ayy_image0181.png',
#  'case_M_20190116093042_0U62372011685941_1_001_001-1_a3_ayy_image0018.png',
#  'case_M_20181018093806_0U62363101890605_1_007_002-1_a12_ayy_image0030.png',
#  'case_M_20190111094523_0U62372011160922_1_005_001-1_a1_ayy_image0080.png',
#  'case_M_20190111094523_0U62372011160922_1_004_002-1_a13_ayy_image0061.png',
#  'case_M_20181119111911_0U62363111914011_1_005_001-1_a16_ayy_image0355.png',
#  'case_M_20181026100314_0U62363102665613_1_004_001-1_a5_ayy_image0047.png',
#  'case_M_20181029094800_0U62368102981259_1_005_001-1_a18_ayy_image0141.png',
#  'case_M_20181109101724_0U62368110954624_1_005_001-1_a1_ayy_image0004.png',
#  'case_M_20181010094822_0U62363101085921_1_003_001-1_a13_ayy_image0298.png',
#  'case_M_20190131094430_0U62372013151529_1_003_001-1_a4_ayy_image0019.png',
#  'case_M_20181025095048_0U62372102595347_1_004_001-1_a2_ayy_image0055.png',
#  'case_M_20190121095240_0U62368012118740_1_005_001-1_a1_ayy_image0419.png',
#  'case_M_20181017100226_0U62367101735926_1_005_001-1_a6_ayy_image0054.png',
#  'case_M_20181001140915_0U62366100164014_1_001_001-1_a7_ayy_image0114.png',
#  'case_M_20181203093846_0U62367120345345_1_005_001-1_a10_ayy_image0029.png',
#  'case_M_20181017100226_0U62367101735926_1_001_002-1_a15_ayy_image0138.png',
#  'case_M_20190116094421_0U62363011675020_1_004_001-1_a8_ayy_image0030.png',
#  'case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0092.png',
#  'case_M_20181025095048_0U62372102595347_1_004_001-1_a15_ayy_image0107.png',
#  'case_M_20181119111911_0U62363111914011_1_005_001-1_a8_ayy_image0082.png',
#  'case_M_20181211093229_0U62367121175028_1_002_002-1_a2_ayy_image0037.png',
#  'case_M_20181214095357_0U62368121473456_1_006_003-1_a5_ayy_image0136.png',
#  'case_M_20190115123306_0U62368011540606_1_002_001-1_a6_ayy_image0096.png',
#  'case_M_20181003094031_0U62363100354631_1_001_002-1_a1_ayy_image0145.png',
#  'case_M_20190112093830_0U62372011292129_1_001_001-1_a7_ayy_image0048.png',
#  'case_M_20181117100025_0U62363111779624_1_007_003-1_a4_ayy_image0010.png',
#  'case_M_20190107094528_0U62367010726528_1_002_001-1_a7_ayy_image0029.png',
#  'case_M_20181022094701_0U62368102271800_1_005_001-1_a3_ayy_image0039.png',
#  'case_M_20181211093229_0U62367121175028_1_004_001-1_a12_ayy_image0020.png',
#  'case_M_20190121095240_0U62368012118740_1_004_001-1_a3_ayy_image0062.png',
#  'case_M_20181212144657_0U62366121262556_1_001_002-1_a2_ayy_image0137.png',
#  'case_M_20181010094822_0U62363101085921_1_003_001-1_a13_ayy_image0315.png',
#  'case_M_20181119111911_0U62363111914011_1_005_001-1_a16_ayy_image0016.png',
#  'case_M_20190109095638_0U62372010945338_1_003_001-1_a23_ayy_image0023.png',
#  'case_M_20181017100226_0U62367101735926_1_007_004-1_a6_ayy_image0361.png',
#  'case_M_20181004140507_0U62366100460906_1_001_001-1_a2_ayy_image0026.png',
#  'case_M_20181004130627_0U62365100475026_1_002_001-1_a5_ayy_image0125.png',
#  'case_M_20190112093830_0U62372011292129_1_001_001-1_a10_ayy_image0002.png',
#  'case_M_20181120115731_0U62368112064030_1_001_001-1_a6_ayy_image0029.png',
#  'case_M_20181018093806_0U62363101890605_1_007_001-1_a1_ayy_image0081.png',
#  'case_M_20181003094031_0U62363100354631_1_001_002-1_a1_ayy_image0103.png',
#  'case_M_20190131094104_0U62367013193703_1_003_001-1_a9_ayy_image0193.png',
#  'case_M_20190126102153_0U62372012695352_1_001_001-1_a4_ayy_image0088.png',
#  'case_M_20181119111911_0U62363111914011_1_005_001-1_a12_ayy_image0062.png',
#  'case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0846.png',
#  'case_M_20181105095958_0U62368110576557_1_003_002-1_a6_ayy_image0212.png',
#  'case_M_20181211093229_0U62367121175028_1_004_001-1_a7_ayy_image0005.png',
#  'case_M_20181015101337_0U62363101576536_1_005_001-1_a14_ayy_image0030.png',
#  'case_M_20181211093229_0U62367121175028_1_002_002-1_a9_ayy_image0040.png',
#  'case_M_20181022094701_0U62368102271800_1_005_001-1_a2_ayy_image0007.png',
#  'case_M_20181030122608_0U62363103057807_1_002_003-1_a3_ayy_image0010.png',
#  'case_M_20181017100226_0U62367101735926_1_007_003-1_a10_ayy_image0013.png',
#  'case_M_20181025093921_0U62363102537521_1_002_001-1_a9_ayy_image0024.png',
#  'case_M_20181015101337_0U62363101576536_1_005_001-1_a21_ayy_image0032.png',
#  'case_M_20181226125224_0U62363122631224_1_003_001-1_a10_ayy_image0207.png',
#  'case_M_20181029094800_0U62368102981259_1_002_001-1_a5_ayy_image0016.png',
#  'case_M_20190109095638_0U62372010945338_1_003_001-1_a30_ayy_image0026.png',
#  'case_M_20181025095048_0U62372102595347_1_004_001-1_a8_ayy_image0273.png',
#  'case_M_20190126102153_0U62372012695352_1_001_001-1_a3_ayy_image0004.png',
#  'case_M_20181214095357_0U62368121473456_1_005_001-1_a3_ayy_image0080.png',
#  'case_M_20181010094822_0U62363101085921_1_003_001-1_a13_ayy_image0181.png',
#  'case_M_20190116094421_0U62363011675020_1_004_001-1_a1_ayy_image0010.png',
#  'case_M_20181001100941_0U62372100109341_1_005_001-1_a10_ayy_image0124.png',
#  'case_M_20181109094641_0U62372110931241_1_005_001-1_a4_ayy_image0093.png',
#  'case_M_20190111094523_0U62372011160922_1_004_002-1_a8_ayy_image0060.png',
#  'case_M_20181031103335_0U62368103151535_1_006_001-1_a4_ayy_image0084.png',
#  'case_M_20181017100226_0U62367101735926_1_005_001-1_a3_ayy_image0132.png',
#  'case_M_20181003094031_0U62363100354631_1_001_002-1_a1_ayy_image0080.png',
#  'case_M_20181119111911_0U62363111914011_1_005_001-1_a12_ayy_image0533.png',
#  'case_M_20190123101017_0U62372012395316_1_004_001-1_a8_ayy_image0160.png',
#  'case_M_20190115123306_0U62368011540606_1_002_001-1_a4_ayy_image0204.png',
#  'case_M_20181017100226_0U62367101735926_1_007_004-1_a4_ayy_image0359.png',
#  'case_M_20181029094800_0U62368102981259_1_002_001-1_a6_ayy_image0020.png',
#  'case_M_20181117100025_0U62363111779624_1_007_003-1_a8_ayy_image0257.png',
#  'case_M_20181001140915_0U62366100164014_1_001_001-1_a4_ayy_image0040.png',
#  'case_M_20181022094701_0U62368102271800_1_005_001-1_a4_ayy_image0034.png',
#  'case_M_20190117105747_0U62368011712547_1_002_001-1_a18_ayy_image0060.png',
#  'case_M_20181004130627_0U62365100475026_1_002_001-1_a3_ayy_image0005.png',
#  'case_M_20181119111911_0U62363111914011_1_005_001-1_a8_ayy_image0017.png',
#  'case_M_20190126102153_0U62372012695352_1_001_001-1_a4_ayy_image0142.png',
#  'case_M_20181207092523_0U62372120765622_1_005_001-1_a10_ayy_image0032.png',
#  'case_M_20190112093830_0U62372011292129_1_001_001-1_a1_ayy_image0162.png',
#  'case_M_20181113100307_0U62372111373406_1_005_001-1_a23_ayy_image0010.png',
#  'case_M_20190121095240_0U62368012118740_1_005_001-1_a3_ayy_image0015.png',
#  'case_M_20181025093921_0U62363102537521_1_002_001-1_a11_ayy_image0014.png',
#  'case_M_20190115123306_0U62368011540606_1_002_001-1_a4_ayy_image0143.png',
#  'case_M_20190121095240_0U62368012118740_1_004_001-1_a2_ayy_image0010.png',
#  'case_M_20181203093846_0U62367120345345_1_005_001-1_a10_ayy_image0047.png',
#  'case_M_20181226125224_0U62363122631224_1_003_001-1_a5_ayy_image0089.png',
#  'case_M_20181201091914_0U62363120125014_1_005_001-1_a10_ayy_image0220.png',
#  'case_M_20181019122218_0U62368101948418_1_002_001-1_a4_ayy_image0006.png',
#  'case_M_20181211093229_0U62367121175028_1_002_002-1_a3_ayy_image0067.png',
#  'case_M_20181218101803_0U62372121864002_1_001_001-1_a4_ayy_image0016.png',
#  'case_M_20181019101517_0U62367101935917_1_003_001-1_a12_ayy_image0028.png',
#  'case_M_20181025095048_0U62372102595347_1_004_002-1_a8_ayy_image0031.png',
#  'case_M_20181211093229_0U62367121175028_1_004_001-1_a10_ayy_image0063.png',
#  'case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0777.png',
#  'case_M_20181214095357_0U62368121473456_1_006_003-1_a22_ayy_image0333.png',
#  'case_M_20181120115731_0U62368112064030_1_001_001-1_a4_ayy_image0043.png',
#  'case_M_20190121095240_0U62368012118740_1_004_001-1_a5_ayy_image0061.png',
#  'case_M_20190121100011_0U62372012151511_1_006_003-1_a3_ayy_image0041.png',
#  'case_M_20181126095408_0U62367112660907_1_001_002-1_a7_ayy_image0077.png',
#  'case_M_20181220100816_0U62368122007816_1_002_001-1_a6_ayy_image0032.png',
#  'case_M_20181226125224_0U62363122631224_1_003_001-1_a8_ayy_image0192.png',
#  'case_M_20181030135203_0U62365103062502_1_001_001-1_a2_ayy_image0010.png',
#  'case_M_20190121095240_0U62368012118740_1_005_001-1_a1_ayy_image0295.png',
#  'case_M_20181025095048_0U62372102595347_1_004_001-1_a8_ayy_image0105.png',
#  'case_M_20181025093921_0U62363102537521_1_002_001-1_a7_ayy_image0006.png',
#  'case_M_20181109101724_0U62368110954624_1_005_001-1_a3_ayy_image0098.png',
#  'case_M_20181214095357_0U62368121473456_1_006_003-1_a23_ayy_image0049.png',
#  'case_M_20181203093846_0U62367120345345_1_005_001-1_a6_ayy_image0013.png',
#  'case_M_20190121095240_0U62368012118740_1_004_001-1_a8_ayy_image0127.png',
#  'case_M_20181106093315_0U62372110682814_1_007_001-1_a1_ayy_image0031.png',
#  'case_M_20181214095357_0U62368121473456_1_006_003-1_a22_ayy_image0218.png',
#  'case_M_20181010094822_0U62363101085921_1_003_001-1_a3_ayy_image0036.png',
#  'case_M_20190115123306_0U62368011540606_1_002_001-1_a5_ayy_image0045.png',
#  'case_M_20190111094523_0U62372011160922_1_004_002-1_a10_ayy_image0029.png',
#  'case_M_20181018093806_0U62363101890605_1_007_001-1_a1_ayy_image0091.png',
#  'case_M_20181119111911_0U62363111914011_1_005_001-1_a16_ayy_image0199.png',
#  'case_M_20190128094801_0U62372012857800_1_002_001-1_a4_ayy_image0010.png',
#  'case_M_20181218101803_0U62372121864002_1_001_001-1_a8_ayy_image0048.png',
#  'case_M_20190121095240_0U62368012118740_1_005_001-1_a2_ayy_image0134.png',
#  'case_M_20190117105747_0U62368011712547_1_004_001-1_a13_ayy_image0160.png',
#  ...]

# %%
data_processor.move_random_n_images(F_TRAIN_IMAGES_NEG, F_TEST_IMAGES_NEG, 1000)
# Out:
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image004556.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image001305.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006446.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image010756.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image002284.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image005880.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image001583.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006723.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image010144.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image000807.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image003495.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image001355.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image002576.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image005439.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image007017.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image000706.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image010916.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image003289.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image009043.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image006581.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image002594.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image006744.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image006258.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image001737.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006862.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image002428.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image004395.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image006604.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image001806.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image002835.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image010581.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image005789.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_3_ayy_image000193.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image007495.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image004221.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image011069.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image006040.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image000434.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009000.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image001973.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005176.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image008970.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005550.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image008815.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image001881.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image011441.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image002345.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image005409.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image010291.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004635.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image006651.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image005840.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008759.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image004197.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004640.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image000136.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005617.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image000317.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image010356.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image010656.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image005529.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009456.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007866.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image004760.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image011364.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007551.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image002264.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image007544.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image010786.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image002429.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004834.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image001473.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image006645.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008770.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image004835.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006643.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image006901.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image004998.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007316.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image001833.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image003074.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image003060.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image003140.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image010308.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image005386.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image009803.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image001731.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image004054.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image000668.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image002298.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image005955.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image007401.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image001211.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image011002.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image009475.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009588.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image002326.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image006943.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image006917.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image001744.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image003681.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007304.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image007642.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image007039.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image001661.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image009878.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009600.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005562.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image006323.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image000520.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image011270.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image005991.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009256.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image005565.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image005561.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image007838.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image002410.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image000279.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image006931.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009517.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image006681.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008698.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image004599.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image006750.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image000756.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image004728.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image006376.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image011304.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004823.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006498.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image001702.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image001209.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image000353.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image003290.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006966.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image002399.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image008029.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image003588.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image001347.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image001139.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image006720.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image002305.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image006318.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image002306.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image005573.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image003393.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image001644.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005426.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image002947.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image010377.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004550.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image000210.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image006128.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image010391.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image009635.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image001835.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006504.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image008838.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image000832.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image003224.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006881.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image011555.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image000119.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image005925.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005503.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008437.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image002088.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image008914.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image000234.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004508.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image002080.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image010589.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image000945.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image006712.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image003522.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image000245.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image000999.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image003569.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image010704.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image010427.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image000756.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image001003.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_2_ayy_image000046.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image005836.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image011292.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image010749.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008823.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006941.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006179.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image000873.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image001503.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image004789.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005386.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image006344.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image004030.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image011227.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004767.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image003581.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image008729.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005963.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image009454.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image009685.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image006013.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image003658.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image010985.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image001104.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image007568.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image011151.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image004342.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007681.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image007702.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image007387.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image005005.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image003951.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image000480.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image007159.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image005978.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007470.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image001666.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image002673.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image001915.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image003526.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image010442.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008753.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image009752.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image009174.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image006714.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image006321.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image001168.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image003961.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image004580.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image010961.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image005185.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image000984.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image004067.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image001944.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image010325.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image003071.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006316.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image001957.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image009447.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image009072.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image001896.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image001366.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image002346.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image000900.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image010984.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image008278.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image001614.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image009118.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008636.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005290.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006066.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image010364.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006482.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image000743.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image007467.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005013.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image007300.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image001547.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image003266.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image009287.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009093.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image004716.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image003632.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image010497.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image005671.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image001085.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image003900.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image005137.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image002287.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image004060.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image003276.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image009589.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image005260.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image009787.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image006436.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image001145.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006593.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image007486.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image011453.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image001016.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009208.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006230.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image001967.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006133.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006248.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image003421.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image004770.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image002191.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image001134.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image003826.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image000046.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004152.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image002381.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image007235.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image010856.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image010482.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005432.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image011221.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image002197.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image005130.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image006817.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image004946.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image003037.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image007445.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007023.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image006726.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009135.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image003592.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image003924.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007140.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image010012.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image001846.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image003207.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image006274.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image003183.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image003426.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006556.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image000709.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image003776.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image000437.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image001254.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image002542.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007687.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image006351.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image001821.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image007557.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image004251.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image004256.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image000186.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image010335.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image000598.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image007363.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image001109.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image002524.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image005883.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image011536.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004236.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image003618.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image008640.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image005657.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006024.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006104.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004410.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008012.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008319.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image006157.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image004771.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image003417.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image005154.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image004710.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image000445.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image005767.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image003226.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image011477.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image000063.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image002393.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image000698.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005343.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image011135.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image005472.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008817.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image000587.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006518.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image010371.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008540.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image007899.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image004717.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image000827.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image009903.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image002797.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image002310.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image003198.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image002094.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image011210.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image001244.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image011278.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image004297.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image005125.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image000103.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image007267.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image004249.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image005580.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image010577.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008927.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image004790.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image011327.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image010942.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image002071.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image000229.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image000766.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image009512.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image000862.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image003311.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image001439.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004380.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image010058.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005019.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image011261.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image004127.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image001527.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image002116.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image006887.jpg -> ./data/test/images/negative
# Moved: case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image008622.jpg -> ./data/test/images/negative
# Moved: case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image004145.jpg -> ./data/test/images/negative
# ...
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image003845.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image005989.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image000678.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image000907.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image005420.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image009737.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009481.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image005782.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image002881.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image001621.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007104.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007246.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image003170.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image002779.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005239.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image000767.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image002805.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image001146.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image002019.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image002475.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image004243.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image003035.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004362.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006756.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image002898.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image001039.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007321.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image003501.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image001547.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image001596.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image007713.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image003964.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image005842.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006823.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image003670.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image006556.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image001422.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image008324.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image000423.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image011472.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image003155.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image008387.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008350.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image003881.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image010871.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007722.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image000131.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image006512.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image010114.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image001603.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image000603.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image001266.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image004890.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007565.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image007028.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image003238.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image003454.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image001515.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006439.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image002540.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007669.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image002441.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image007272.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image007732.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_2_ayy_image000032.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image001716.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image005421.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image002112.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image000097.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image002372.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009283.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image001867.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image008305.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image003715.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image011439.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image001200.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image005068.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image001413.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image007659.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image000317.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image010936.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image010350.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image000700.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image005744.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image010761.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image010737.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image008952.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006269.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image000850.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image000884.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image001745.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005901.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image001960.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image004158.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image000051.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image009857.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005579.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image000762.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image007030.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image001230.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006550.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image008522.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image004451.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009981.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image011041.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image004457.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image000418.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image000909.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image000257.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image007691.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006360.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image001502.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image010809.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image008997.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image005536.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image000694.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image007145.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image002883.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006868.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image000289.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image004140.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image010607.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image002500.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007207.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image003599.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image003195.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image000878.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image007683.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image004698.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image010447.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004695.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image002535.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image004438.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image002815.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image001468.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image002948.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image003238.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image002469.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image002875.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006139.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image003459.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image001901.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image004973.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image003096.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image006639.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image005549.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image007658.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image010910.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image011146.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image001762.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image010418.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image001309.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image001168.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image006976.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image011191.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image002340.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image003512.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image010244.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image000566.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009356.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004481.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image002254.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image001788.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image000495.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007708.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006302.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006166.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009796.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image004156.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image007694.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image000539.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image009792.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image001589.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image005384.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image006383.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image002055.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009809.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image000166.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image004299.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image005793.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image007974.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image010019.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image002984.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image009569.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image006855.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image006163.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image003270.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image011525.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image010174.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image005318.jpg']

# %% [markdown]
# ### analyze centerization (Euclidean distance formula) & object density

# %%
bbox_coords = data_processor.get_bbox_coords(F_TRAIN_MASKS_POS)
centralization_scores = data_processor.generate_centralization_data(bbox_coords)
data_processor.visualize_centralization_scores(centralization_scores)
# Out:
# {'mean': np.float64(0.6649504234254349),
#  'median': np.float64(0.6806685422317766),
#  'std': np.float64(0.16480340835377408),
#  'min': np.float64(0.19009343815720592),
#  'max': np.float64(0.9930946603399752)}

# %%
density_data = data_processor.generate_object_density_data(F_TRAIN_MASKS_POS)
data_processor.visualize_object_density(density_data)

# %% [markdown]
# ### remove N most close-to-center frames

# %%
removed_center_close_images = data_processor.remove_highest_scored_images(centralization_scores, 4000)
data_processor.remove_files_by_base_names(F_TRAIN_IMAGES_POS, removed_center_close_images)
# Out:
# ['./data/train/images/positive/case_M_20181031103335_0U62368103151535_1_006_001-1_a2_ayy_image0003.jpg',
#  './data/train/images/positive/case_M_20181129152014_0U62366112981213_1_001_001-1_a21_ayy_image0024.jpg',
#  './data/train/images/positive/case_M_20181001100941_0U62372100109341_1_005_001-1_a10_ayy_image0071.jpg',
#  './data/train/images/positive/case_M_20190121095240_0U62368012118740_1_004_001-1_a1_ayy_image0060.jpg',
#  './data/train/images/positive/case_M_20190109095638_0U62372010945338_1_003_001-1_a29_ayy_image0008.jpg',
#  './data/train/images/positive/case_M_20190131094104_0U62367013193703_1_003_001-1_a8_ayy_image0115.jpg',
#  './data/train/images/positive/case_M_20181119111911_0U62363111914011_1_005_001-1_a12_ayy_image0454.jpg',
#  './data/train/images/positive/case_M_20181226125224_0U62363122631224_1_003_001-1_a10_ayy_image0270.jpg',
#  './data/train/images/positive/case_M_20181207092523_0U62372120765622_1_005_001-1_a15_ayy_image0207.jpg',
#  './data/train/images/positive/case_M_20190112093830_0U62372011292129_1_001_001-1_a8_ayy_image0134.jpg',
#  './data/train/images/positive/case_M_20181001140915_0U62366100164014_1_001_001-1_a7_ayy_image0129.jpg',
#  './data/train/images/positive/case_M_20190112093830_0U62372011292129_1_001_001-1_a2_ayy_image0069.jpg',
#  './data/train/images/positive/case_M_20190111094523_0U62372011160922_1_004_002-1_a14_ayy_image0016.jpg',
#  './data/train/images/positive/case_M_20190130094921_0U62367013093720_1_009_001-1_a6_ayy_image0059.jpg',
#  './data/train/images/positive/case_M_20190117095926_0U62372011750026_1_002_001-1_a6_ayy_image0002.jpg',
#  './data/train/images/positive/case_M_20190109095638_0U62372010945338_1_003_001-1_a23_ayy_image0080.jpg',
#  './data/train/images/positive/case_M_20181207092523_0U62372120765622_1_005_001-1_a12_ayy_image0069.jpg',
#  './data/train/images/positive/case_M_20181017100226_0U62367101735926_1_007_003-1_a4_ayy_image0111.jpg',
#  './data/train/images/positive/case_M_20190109095638_0U62372010945338_1_003_001-1_a23_ayy_image0086.jpg',
#  './data/train/images/positive/case_M_20181017100226_0U62367101735926_1_007_003-1_a3_ayy_image0033.jpg',
#  './data/train/images/positive/case_M_20181015101337_0U62363101576536_1_005_001-1_a21_ayy_image0522.jpg',
#  './data/train/images/positive/case_M_20190121095240_0U62368012118740_1_004_001-1_a1_ayy_image0120.jpg',
#  './data/train/images/positive/case_M_20190116094421_0U62363011675020_1_002_001-1_a2_ayy_image0124.jpg',
#  './data/train/images/positive/case_M_20190111094523_0U62372011160922_1_004_002-1_a8_ayy_image0017.jpg',
#  './data/train/images/positive/case_M_20181226125224_0U62363122631224_1_003_001-1_a10_ayy_image0345.jpg',
#  './data/train/images/positive/case_M_20190121095240_0U62368012118740_1_004_001-1_a1_ayy_image0044.jpg',
#  './data/train/images/positive/case_M_20181213092448_0U62363121315648_1_003_001-1_a3_ayy_image0010.jpg',
#  './data/train/images/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0781.jpg',
#  './data/train/images/positive/case_M_20181227102913_0U62363122725013_1_004_001-1_a8_ayy_image0021.jpg',
#  './data/train/images/positive/case_M_20181203093846_0U62367120345345_1_005_001-1_a8_ayy_image0049.jpg',
#  './data/train/images/positive/case_M_20181226125224_0U62363122631224_1_003_001-1_a10_ayy_image0120.jpg',
#  './data/train/images/positive/case_M_20181119111911_0U62363111914011_1_005_001-1_a2_ayy_image0057.jpg',
#  './data/train/images/positive/case_M_20181119111911_0U62363111914011_1_005_001-1_a12_ayy_image0464.jpg',
#  './data/train/images/positive/case_M_20190112093830_0U62372011292129_1_001_001-1_a8_ayy_image0097.jpg',
#  './data/train/images/positive/case_M_20181213131150_0U62365121395349_1_002_002-1_a18_ayy_image0099.jpg',
#  './data/train/images/positive/case_M_20190131094430_0U62372013151529_1_003_001-1_a4_ayy_image0002.jpg',
#  './data/train/images/positive/case_M_20181126095408_0U62367112660907_1_001_002-1_a7_ayy_image0047.jpg',
#  './data/train/images/positive/case_M_20181001093706_0U62368100179605_1_004_002-1_a26_ayy_image0053.jpg',
#  './data/train/images/positive/case_M_20181019101517_0U62367101935917_1_003_001-1_a18_ayy_image0136.jpg',
#  './data/train/images/positive/case_M_20181001140915_0U62366100164014_1_001_001-1_a7_ayy_image0118.jpg',
#  './data/train/images/positive/case_M_20181203093846_0U62367120345345_1_005_001-1_a8_ayy_image0003.jpg',
#  './data/train/images/positive/case_M_20181017100226_0U62367101735926_1_007_003-1_a9_ayy_image0121.jpg',
#  './data/train/images/positive/case_M_20181019101517_0U62367101935917_1_003_001-1_a20_ayy_image0007.jpg',
#  './data/train/images/positive/case_M_20181019101517_0U62367101935917_1_003_001-1_a11_ayy_image0048.jpg',
#  './data/train/images/positive/case_M_20181022094701_0U62368102271800_1_005_001-1_a6_ayy_image0009.jpg',
#  './data/train/images/positive/case_M_20190128094801_0U62372012857800_1_002_001-1_a6_ayy_image0159.jpg',
#  './data/train/images/positive/case_M_20190109095638_0U62372010945338_1_003_001-1_a23_ayy_image0493.jpg',
#  './data/train/images/positive/case_M_20190112093830_0U62372011292129_1_001_001-1_a8_ayy_image0026.jpg',
#  './data/train/images/positive/case_M_20181213131150_0U62365121395349_1_002_002-1_a25_ayy_image0158.jpg',
#  './data/train/images/positive/case_M_20181001140915_0U62366100164014_1_001_001-1_a7_ayy_image0149.jpg',
#  './data/train/images/positive/case_M_20181119111911_0U62363111914011_1_005_001-1_a2_ayy_image0051.jpg',
#  './data/train/images/positive/case_M_20181226125224_0U62363122631224_1_003_001-1_a10_ayy_image0098.jpg',
#  './data/train/images/positive/case_M_20190121095240_0U62368012118740_1_005_001-1_a3_ayy_image0032.jpg',
#  './data/train/images/positive/case_M_20190121100011_0U62372012151511_1_006_002-1_a12_ayy_image0018.jpg',
#  './data/train/images/positive/case_M_20181226125224_0U62363122631224_1_003_001-1_a10_ayy_image0033.jpg',
#  './data/train/images/positive/case_M_20190116094421_0U62363011675020_1_004_001-1_a6_ayy_image0090.jpg',
#  './data/train/images/positive/case_M_20181226125224_0U62363122631224_1_003_001-1_a10_ayy_image0191.jpg',
#  './data/train/images/positive/case_M_20181025095048_0U62372102595347_1_004_001-1_a2_ayy_image0072.jpg',
#  './data/train/images/positive/case_M_20181220100816_0U62368122007816_1_002_001-1_a6_ayy_image0038.jpg',
#  './data/train/images/positive/case_M_20190109095638_0U62372010945338_1_001_001-1_a1_ayy_image0107.jpg',
#  './data/train/images/positive/case_M_20190116094421_0U62363011675020_1_004_001-1_a6_ayy_image0109.jpg',
#  './data/train/images/positive/case_M_20181207092523_0U62372120765622_1_005_001-1_a15_ayy_image0209.jpg',
#  './data/train/images/positive/case_M_20181207092523_0U62372120765622_1_005_001-1_a15_ayy_image0126.jpg',
#  './data/train/images/positive/case_M_20181025095048_0U62372102595347_1_004_001-1_a2_ayy_image0080.jpg',
#  './data/train/images/positive/case_M_20190121095240_0U62368012118740_1_005_001-1_a2_ayy_image0110.jpg',
#  './data/train/images/positive/case_M_20181207092523_0U62372120765622_1_002_001-1_a2_ayy_image0009.jpg',
#  './data/train/images/positive/case_M_20181029094800_0U62368102981259_1_005_001-1_a18_ayy_image0085.jpg',
#  './data/train/images/positive/case_M_20190112093830_0U62372011292129_1_001_001-1_a2_ayy_image0008.jpg',
#  './data/train/images/positive/case_M_20181017100226_0U62367101735926_1_007_004-1_a4_ayy_image0185.jpg',
#  './data/train/images/positive/case_M_20190109095638_0U62372010945338_1_001_001-1_a1_ayy_image0105.jpg',
#  './data/train/images/positive/case_M_20190112093830_0U62372011292129_1_001_001-1_a1_ayy_image0099.jpg',
#  './data/train/images/positive/case_M_20190116094421_0U62363011675020_1_002_001-1_a2_ayy_image0138.jpg',
#  './data/train/images/positive/case_M_20190109095638_0U62372010945338_1_003_001-1_a23_ayy_image0163.jpg',
#  './data/train/images/positive/case_M_20181025095048_0U62372102595347_1_004_001-1_a2_ayy_image0086.jpg',
#  './data/train/images/positive/case_M_20190112093830_0U62372011292129_1_001_001-1_a5_ayy_image0065.jpg',
#  './data/train/images/positive/case_M_20181227102913_0U62363122725013_1_004_001-1_a8_ayy_image0110.jpg',
#  './data/train/images/positive/case_M_20181017100226_0U62367101735926_1_001_002-1_a15_ayy_image0123.jpg',
#  './data/train/images/positive/case_M_20190109095638_0U62372010945338_1_003_001-1_a23_ayy_image0043.jpg',
#  './data/train/images/positive/case_M_20181218101803_0U62372121864002_1_001_001-1_a6_ayy_image0024.jpg',
#  './data/train/images/positive/case_M_20181220100816_0U62368122007816_1_002_001-1_a6_ayy_image0089.jpg',
#  './data/train/images/positive/case_M_20181201091914_0U62363120125014_1_005_001-1_a10_ayy_image0123.jpg',
#  './data/train/images/positive/case_M_20181117100025_0U62363111779624_1_007_003-1_a4_ayy_image0012.jpg',
#  './data/train/images/positive/case_M_20190128094801_0U62372012857800_1_002_001-1_a6_ayy_image0163.jpg',
#  './data/train/images/positive/case_M_20190112093830_0U62372011292129_1_001_001-1_a1_ayy_image0434.jpg',
#  './data/train/images/positive/case_M_20181001140915_0U62366100164014_1_001_001-1_a4_ayy_image0096.jpg',
#  './data/train/images/positive/case_M_20190121095240_0U62368012118740_1_004_001-1_a3_ayy_image0074.jpg',
#  './data/train/images/positive/case_M_20181018093806_0U62363101890605_1_007_002-1_a8_ayy_image0015.jpg',
#  './data/train/images/positive/case_M_20181227102913_0U62363122725013_1_004_001-1_a8_ayy_image0027.jpg',
#  './data/train/images/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a18_ayy_image0048.jpg',
#  './data/train/images/positive/case_M_20190109095638_0U62372010945338_1_003_001-1_a23_ayy_image0495.jpg',
#  './data/train/images/positive/case_M_20181207092523_0U62372120765622_1_005_001-1_a12_ayy_image0031.jpg',
#  './data/train/images/positive/case_M_20181207092523_0U62372120765622_1_005_001-1_a12_ayy_image0008.jpg',
#  './data/train/images/positive/case_M_20181119111911_0U62363111914011_1_005_001-1_a12_ayy_image0101.jpg',
#  './data/train/images/positive/case_M_20181001100941_0U62372100109341_1_005_001-1_a10_ayy_image0087.jpg',
#  './data/train/images/positive/case_M_20181205095418_0U62367120576517_1_007_001-1_a24_ayy_image0003.jpg',
#  './data/train/images/positive/case_M_20181119111911_0U62363111914011_1_005_001-1_a12_ayy_image0504.jpg',
#  './data/train/images/positive/case_M_20181226125224_0U62363122631224_1_003_001-1_a4_ayy_image0070.jpg',
#  './data/train/images/positive/case_M_20190123101017_0U62372012395316_1_004_001-1_a7_ayy_image0061.jpg',
#  './data/train/images/positive/case_M_20190112093830_0U62372011292129_1_001_001-1_a10_ayy_image0193.jpg',
#  './data/train/images/positive/case_M_20190112093830_0U62372011292129_1_001_001-1_a7_ayy_image0104.jpg',
#  './data/train/images/positive/case_M_20181105095958_0U62368110576557_1_003_002-1_a6_ayy_image0236.jpg',
#  './data/train/images/positive/case_M_20181001140915_0U62366100164014_1_001_001-1_a7_ayy_image0096.jpg',
#  './data/train/images/positive/case_M_20181226125224_0U62363122631224_1_003_001-1_a10_ayy_image0171.jpg',
#  './data/train/images/positive/case_M_20190121095240_0U62368012118740_1_004_001-1_a1_ayy_image0066.jpg',
#  './data/train/images/positive/case_M_20181017100226_0U62367101735926_1_007_004-1_a4_ayy_image0195.jpg',
#  './data/train/images/positive/case_M_20181019101517_0U62367101935917_1_003_001-1_a12_ayy_image0034.jpg',
#  './data/train/images/positive/case_M_20181218101803_0U62372121864002_1_001_001-1_a6_ayy_image0002.jpg',
#  './data/train/images/positive/case_M_20181105095958_0U62368110576557_1_003_002-1_a6_ayy_image0471.jpg',
#  './data/train/images/positive/case_M_20181019101517_0U62367101935917_1_003_001-1_a15_ayy_image0066.jpg',
#  './data/train/images/positive/case_M_20190111094523_0U62372011160922_1_004_002-1_a8_ayy_image0027.jpg',
#  './data/train/images/positive/case_M_20190116093042_0U62372011685941_1_001_001-1_a3_ayy_image0071.jpg',
#  './data/train/images/positive/case_M_20190109095638_0U62372010945338_1_003_001-1_a24_ayy_image0093.jpg',
#  './data/train/images/positive/case_M_20190131094104_0U62367013193703_1_003_001-1_a8_ayy_image0016.jpg',
#  './data/train/images/positive/case_M_20181226125224_0U62363122631224_1_003_001-1_a10_ayy_image0290.jpg',
#  './data/train/images/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a5_ayy_image0091.jpg',
#  './data/train/images/positive/case_M_20181211093229_0U62367121175028_1_004_001-1_a10_ayy_image0119.jpg',
#  './data/train/images/positive/case_M_20181227102913_0U62363122725013_1_004_001-1_a8_ayy_image0116.jpg',
#  './data/train/images/positive/case_M_20190109095638_0U62372010945338_1_003_001-1_a23_ayy_image0213.jpg',
#  './data/train/images/positive/case_M_20190109095638_0U62372010945338_1_003_001-1_a23_ayy_image0505.jpg',
#  './data/train/images/positive/case_M_20190121095240_0U62368012118740_1_005_001-1_a3_ayy_image0023.jpg',
#  './data/train/images/positive/case_M_20181226125224_0U62363122631224_1_003_001-1_a10_ayy_image0053.jpg',
#  './data/train/images/positive/case_M_20181001100941_0U62372100109341_1_005_001-1_a10_ayy_image0095.jpg',
#  './data/train/images/positive/case_M_20181226125224_0U62363122631224_1_003_001-1_a10_ayy_image0072.jpg',
#  './data/train/images/positive/case_M_20181129152014_0U62366112981213_1_001_001-1_a18_ayy_image0021.jpg',
#  './data/train/images/positive/case_M_20181015101337_0U62363101576536_1_005_001-1_a20_ayy_image0020.jpg',
#  './data/train/images/positive/case_M_20181015101337_0U62363101576536_1_005_002-1_a19_ayy_image0046.jpg',
#  './data/train/images/positive/case_M_20181019101517_0U62367101935917_1_003_001-1_a18_ayy_image0132.jpg',
#  './data/train/images/positive/case_M_20181019101517_0U62367101935917_1_003_001-1_a13_ayy_image0017.jpg',
#  './data/train/images/positive/case_M_20181019101517_0U62367101935917_1_003_001-1_a18_ayy_image0264.jpg',
#  './data/train/images/positive/case_M_20190112093830_0U62372011292129_1_001_001-1_a8_ayy_image0065.jpg',
#  './data/train/images/positive/case_M_20181003094031_0U62363100354631_1_001_002-1_a1_ayy_image0141.jpg',
#  './data/train/images/positive/case_M_20181220100816_0U62368122007816_1_002_001-1_a6_ayy_image0054.jpg',
#  './data/train/images/positive/case_M_20190112093830_0U62372011292129_1_001_001-1_a2_ayy_image0091.jpg',
#  './data/train/images/positive/case_M_20181001093706_0U62368100179605_1_004_002-1_a26_ayy_image0029.jpg',
#  './data/train/images/positive/case_M_20190110094509_0U62363011095308_1_001_002-1_a3_ayy_image0016.jpg',
#  './data/train/images/positive/case_M_20190121095240_0U62368012118740_1_004_001-1_a3_ayy_image0060.jpg',
#  './data/train/images/positive/case_M_20181213131150_0U62365121395349_1_002_002-1_a18_ayy_image0070.jpg',
#  './data/train/images/positive/case_M_20190131094104_0U62367013193703_1_003_001-1_a7_ayy_image0040.jpg',
#  './data/train/images/positive/case_M_20190109095638_0U62372010945338_1_003_001-1_a24_ayy_image0352.jpg',
#  './data/train/images/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a17_ayy_image0080.jpg',
#  './data/train/images/positive/case_M_20190107094528_0U62367010726528_1_002_002-1_a5_ayy_image0014.jpg',
#  './data/train/images/positive/case_M_20181119111911_0U62363111914011_1_005_001-1_a12_ayy_image0131.jpg',
#  './data/train/images/positive/case_M_20181025095048_0U62372102595347_1_004_001-1_a8_ayy_image0259.jpg',
#  './data/train/images/positive/case_M_20181211093229_0U62367121175028_1_004_001-1_a10_ayy_image0041.jpg',
#  './data/train/images/positive/case_M_20181019101517_0U62367101935917_1_003_001-1_a17_ayy_image0035.jpg',
#  './data/train/images/positive/case_M_20181015101337_0U62363101576536_1_005_001-1_a21_ayy_image0048.jpg',
#  './data/train/images/positive/case_M_20181019101517_0U62367101935917_1_003_001-1_a18_ayy_image0203.jpg',
#  './data/train/images/positive/case_M_20190116094421_0U62363011675020_1_002_001-1_a2_ayy_image0179.jpg',
#  './data/train/images/positive/case_M_20190112093830_0U62372011292129_1_001_001-1_a1_ayy_image0083.jpg',
#  './data/train/images/positive/case_M_20181029094800_0U62368102981259_1_005_001-1_a17_ayy_image0009.jpg',
#  './data/train/images/positive/case_M_20181226125224_0U62363122631224_1_003_001-1_a10_ayy_image0106.jpg',
#  './data/train/images/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a18_ayy_image0066.jpg',
#  './data/train/images/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a5_ayy_image0089.jpg',
#  './data/train/images/positive/case_M_20190112093830_0U62372011292129_1_001_001-1_a10_ayy_image0175.jpg',
#  './data/train/images/positive/case_M_20181001140915_0U62366100164014_1_001_001-1_a7_ayy_image0094.jpg',
#  './data/train/images/positive/case_M_20181119111911_0U62363111914011_1_005_001-1_a12_ayy_image0425.jpg',
#  './data/train/images/positive/case_M_20181117100025_0U62363111779624_1_007_003-1_a8_ayy_image0261.jpg',
#  './data/train/images/positive/case_M_20181126140908_0U62368112685907_1_004_001-1_a14_ayy_image0003.jpg',
#  './data/train/images/positive/case_M_20181211093229_0U62367121175028_1_002_002-1_a3_ayy_image0008.jpg',
#  './data/train/images/positive/case_M_20190112093830_0U62372011292129_1_001_001-1_a1_ayy_image0006.jpg',
#  './data/train/images/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a17_ayy_image0136.jpg',
#  './data/train/images/positive/case_M_20190112093830_0U62372011292129_1_001_001-1_a1_ayy_image0067.jpg',
#  './data/train/images/positive/case_M_20181022094701_0U62368102271800_1_005_001-1_a6_ayy_image0003.jpg',
#  './data/train/images/positive/case_M_20181113100307_0U62372111373406_1_005_001-1_a26_ayy_image0026.jpg',
#  './data/train/images/positive/case_M_20181129152014_0U62366112981213_1_001_001-1_a20_ayy_image0062.jpg',
#  './data/train/images/positive/case_M_20190117095926_0U62372011750026_1_002_001-1_a2_ayy_image0019.jpg',
#  './data/train/images/positive/case_M_20181015101337_0U62363101576536_1_005_001-1_a21_ayy_image0046.jpg',
#  './data/train/images/positive/case_M_20190121095240_0U62368012118740_1_004_001-1_a1_ayy_image0116.jpg',
#  './data/train/images/positive/case_M_20190109095638_0U62372010945338_1_003_001-1_a30_ayy_image0036.jpg',
#  './data/train/images/positive/case_M_20181110093525_0U62372111056224_1_004_001-1_a1_ayy_image0003.jpg',
#  './data/train/images/positive/case_M_20190112093830_0U62372011292129_1_001_001-1_a6_ayy_image0062.jpg',
#  './data/train/images/positive/case_M_20181201091914_0U62363120125014_1_005_001-1_a10_ayy_image0177.jpg',
#  './data/train/images/positive/case_M_20181019101517_0U62367101935917_1_003_001-1_a20_ayy_image0036.jpg',
#  './data/train/images/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a13_ayy_image0432.jpg',
#  './data/train/images/positive/case_M_20181018093806_0U62363101890605_1_007_002-1_a3_ayy_image0031.jpg',
#  './data/train/images/positive/case_M_20181018093806_0U62363101890605_1_007_002-1_a1_ayy_image0065.jpg',
#  './data/train/images/positive/case_M_20181207092523_0U62372120765622_1_005_001-1_a12_ayy_image0045.jpg',
#  './data/train/images/positive/case_M_20190116094421_0U62363011675020_1_004_001-1_a3_ayy_image0035.jpg',
#  './data/train/images/positive/case_M_20181015101337_0U62363101576536_1_005_001-1_a21_ayy_image0534.jpg',
#  './data/train/images/positive/case_M_20181025095048_0U62372102595347_1_004_001-1_a8_ayy_image0331.jpg',
#  './data/train/images/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a17_ayy_image0027.jpg',
#  './data/train/images/positive/case_M_20181029094800_0U62368102981259_1_005_001-1_a17_ayy_image0001.jpg',
#  './data/train/images/positive/case_M_20181211093229_0U62367121175028_1_004_001-1_a8_ayy_image0056.jpg',
#  './data/train/images/positive/case_M_20181003094031_0U62363100354631_1_001_002-1_a13_ayy_image0036.jpg',
#  './data/train/images/positive/case_M_20181015101337_0U62363101576536_1_005_001-1_a21_ayy_image0549.jpg',
#  './data/train/images/positive/case_M_20181211093229_0U62367121175028_1_004_001-1_a10_ayy_image0019.jpg',
#  './data/train/images/positive/case_M_20190112093830_0U62372011292129_1_001_001-1_a5_ayy_image0045.jpg',
#  './data/train/images/positive/case_M_20181105095958_0U62368110576557_1_003_002-1_a6_ayy_image0254.jpg',
#  './data/train/images/positive/case_M_20181003094031_0U62363100354631_1_001_002-1_a1_ayy_image0155.jpg',
#  './data/train/images/positive/case_M_20190109095638_0U62372010945338_1_003_001-1_a24_ayy_image0078.jpg',
#  './data/train/images/positive/case_M_20181207092523_0U62372120765622_1_005_001-1_a12_ayy_image0004.jpg',
#  './data/train/images/positive/case_M_20181017100226_0U62367101735926_1_007_004-1_a4_ayy_image0189.jpg',
#  './data/train/images/positive/case_M_20181017100226_0U62367101735926_1_007_003-1_a6_ayy_image0070.jpg',
#  './data/train/images/positive/case_M_20181113100307_0U62372111373406_1_005_001-1_a26_ayy_image0221.jpg',
#  './data/train/images/positive/case_M_20190109095638_0U62372010945338_1_001_001-1_a1_ayy_image0091.jpg',
#  './data/train/images/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a22_ayy_image0120.jpg',
#  './data/train/images/positive/case_M_20190112093830_0U62372011292129_1_001_001-1_a8_ayy_image0093.jpg',
#  './data/train/images/positive/case_M_20181218101803_0U62372121864002_1_001_001-1_a6_ayy_image0073.jpg',
#  './data/train/images/positive/case_M_20181207092523_0U62372120765622_1_005_001-1_a15_ayy_image0039.jpg',
#  './data/train/images/positive/case_M_20181105095958_0U62368110576557_1_003_002-1_a6_ayy_image0291.jpg',
#  './data/train/images/positive/case_M_20181228140523_0U62365122821823_1_001_001-1_a6_ayy_image0046.jpg',
#  './data/train/images/positive/case_M_20190112093830_0U62372011292129_1_001_001-1_a2_ayy_image0040.jpg',
#  './data/train/images/positive/case_M_20190109095638_0U62372010945338_1_003_001-1_a24_ayy_image0095.jpg',
#  './data/train/images/positive/case_M_20190109095638_0U62372010945338_1_001_001-1_a3_ayy_image0014.jpg',
#  './data/train/images/positive/case_M_20190117095926_0U62372011750026_1_002_001-1_a4_ayy_image0006.jpg',
#  './data/train/images/positive/case_M_20190109095638_0U62372010945338_1_003_001-1_a23_ayy_image0143.jpg',
#  './data/train/images/positive/case_M_20181207092523_0U62372120765622_1_002_001-1_a2_ayy_image0005.jpg',
#  './data/train/images/positive/case_M_20190112093830_0U62372011292129_1_001_001-1_a2_ayy_image0095.jpg',
#  './data/train/images/positive/case_M_20190107094528_0U62367010726528_1_002_001-1_a7_ayy_image0033.jpg',
#  './data/train/images/positive/case_M_20190115123306_0U62368011540606_1_002_001-1_a5_ayy_image0166.jpg',
#  './data/train/images/positive/case_M_20190109095638_0U62372010945338_1_003_001-1_a23_ayy_image0536.jpg',
#  './data/train/images/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a13_ayy_image0319.jpg',
#  './data/train/images/positive/case_M_20181226125224_0U62363122631224_1_003_001-1_a10_ayy_image0363.jpg',
#  './data/train/images/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a13_ayy_image0307.jpg',
#  './data/train/images/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0084.jpg',
#  './data/train/images/positive/case_M_20190131094104_0U62367013193703_1_003_001-1_a9_ayy_image0148.jpg',
#  './data/train/images/positive/case_M_20181126095408_0U62367112660907_1_001_002-1_a7_ayy_image0014.jpg',
#  './data/train/images/positive/case_M_20181003094031_0U62363100354631_1_001_002-1_a1_ayy_image0239.jpg',
#  './data/train/images/positive/case_M_20181207092523_0U62372120765622_1_005_001-1_a15_ayy_image0053.jpg',
#  './data/train/images/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a22_ayy_image0158.jpg',
#  './data/train/images/positive/case_M_20181226125224_0U62363122631224_1_003_001-1_a8_ayy_image0318.jpg',
#  './data/train/images/positive/case_M_20181117100025_0U62363111779624_1_007_003-1_a8_ayy_image0251.jpg',
#  './data/train/images/positive/case_M_20181213131150_0U62365121395349_1_002_002-1_a25_ayy_image0160.jpg',
#  './data/train/images/positive/case_M_20181001100941_0U62372100109341_1_005_001-1_a10_ayy_image0114.jpg',
#  './data/train/images/positive/case_M_20181207092523_0U62372120765622_1_005_001-1_a15_ayy_image0167.jpg',
#  './data/train/images/positive/case_M_20190111094523_0U62372011160922_1_004_002-1_a11_ayy_image0015.jpg',
#  './data/train/images/positive/case_M_20181117100025_0U62363111779624_1_007_003-1_a8_ayy_image0300.jpg',
#  './data/train/images/positive/case_M_20181025095048_0U62372102595347_1_004_001-1_a2_ayy_image0070.jpg',
#  './data/train/images/positive/case_M_20181201091914_0U62363120125014_1_005_001-1_a10_ayy_image0210.jpg',
#  './data/train/images/positive/case_M_20181105095958_0U62368110576557_1_003_002-1_a6_ayy_image0473.jpg',
#  './data/train/images/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a13_ayy_image0294.jpg',
#  './data/train/images/positive/case_M_20181025095048_0U62372102595347_1_004_001-1_a8_ayy_image0208.jpg',
#  './data/train/images/positive/case_M_20190112093830_0U62372011292129_1_001_001-1_a8_ayy_image0083.jpg',
#  './data/train/images/positive/case_M_20181015101337_0U62363101576536_1_005_002-1_a19_ayy_image0030.jpg',
#  './data/train/images/positive/case_M_20181031103335_0U62368103151535_1_006_001-1_a6_ayy_image0051.jpg',
#  './data/train/images/positive/case_M_20181019101517_0U62367101935917_1_003_001-1_a18_ayy_image0252.jpg',
#  './data/train/images/positive/case_M_20181001100941_0U62372100109341_1_005_001-1_a2_ayy_image0125.jpg',
#  './data/train/images/positive/case_M_20181201091914_0U62363120125014_1_005_001-1_a10_ayy_image0121.jpg',
#  './data/train/images/positive/case_M_20181226125224_0U62363122631224_1_003_001-1_a10_ayy_image0041.jpg',
#  './data/train/images/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a5_ayy_image0028.jpg',
#  './data/train/images/positive/case_M_20190128094801_0U62372012857800_1_002_001-1_a6_ayy_image0167.jpg',
#  './data/train/images/positive/case_M_20190112093830_0U62372011292129_1_001_001-1_a10_ayy_image0059.jpg',
#  './data/train/images/positive/case_M_20190109095638_0U62372010945338_1_003_001-1_a23_ayy_image0122.jpg',
#  './data/train/images/positive/case_M_20181001093706_0U62368100179605_1_004_002-1_a26_ayy_image0035.jpg',
#  './data/train/images/positive/case_M_20181001100941_0U62372100109341_1_005_001-1_a2_ayy_image0147.jpg',
#  './data/train/images/positive/case_M_20181226125224_0U62363122631224_1_003_001-1_a8_ayy_image0131.jpg',
#  './data/train/images/positive/case_M_20181015101337_0U62363101576536_1_005_002-1_a17_ayy_image0011.jpg',
#  './data/train/images/positive/case_M_20181015101337_0U62363101576536_1_005_001-1_a21_ayy_image0028.jpg',
#  './data/train/images/positive/case_M_20190109095638_0U62372010945338_1_001_001-1_a2_ayy_image0007.jpg',
#  './data/train/images/positive/case_M_20190128094801_0U62372012857800_1_002_001-1_a6_ayy_image0143.jpg',
#  './data/train/images/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a13_ayy_image0179.jpg',
#  './data/train/images/positive/case_M_20181213131150_0U62365121395349_1_002_002-1_a18_ayy_image0066.jpg',
#  './data/train/images/positive/case_M_20190112093830_0U62372011292129_1_001_001-1_a1_ayy_image0089.jpg',
#  './data/train/images/positive/case_M_20190109095638_0U62372010945338_1_003_001-1_a22_ayy_image0047.jpg',
#  './data/train/images/positive/case_M_20190121095240_0U62368012118740_1_004_001-1_a3_ayy_image0011.jpg',
#  './data/train/images/positive/case_M_20181226125224_0U62363122631224_1_003_001-1_a5_ayy_image0040.jpg',
#  './data/train/images/positive/case_M_20181203093846_0U62367120345345_1_005_001-1_a8_ayy_image0015.jpg',
#  './data/train/images/positive/case_M_20181126095408_0U62367112660907_1_001_002-1_a7_ayy_image0037.jpg',
#  './data/train/images/positive/case_M_20190121095240_0U62368012118740_1_004_001-1_a7_ayy_image0011.jpg',
#  './data/train/images/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a18_ayy_image0076.jpg',
#  './data/train/images/positive/case_M_20190109095638_0U62372010945338_1_001_001-1_a1_ayy_image0075.jpg',
#  './data/train/images/positive/case_M_20181001140915_0U62366100164014_1_001_001-1_a7_ayy_image0153.jpg',
#  './data/train/images/positive/case_M_20190109095638_0U62372010945338_1_003_001-1_a24_ayy_image0074.jpg',
#  './data/train/images/positive/case_M_20190111094523_0U62372011160922_1_004_002-1_a13_ayy_image0041.jpg',
#  './data/train/images/positive/case_M_20181119111911_0U62363111914011_1_005_001-1_a12_ayy_image0119.jpg',
#  './data/train/images/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a22_ayy_image0130.jpg',
#  './data/train/images/positive/case_M_20181126140908_0U62368112685907_1_004_001-1_a14_ayy_image0014.jpg',
#  './data/train/images/positive/case_M_20181015101337_0U62363101576536_1_005_001-1_a21_ayy_image0194.jpg',
#  './data/train/images/positive/case_M_20181207092523_0U62372120765622_1_005_001-1_a12_ayy_image0023.jpg',
#  './data/train/images/positive/case_M_20181025095048_0U62372102595347_1_004_001-1_a13_ayy_image0033.jpg',
#  './data/train/images/positive/case_M_20190109095638_0U62372010945338_1_003_001-1_a24_ayy_image0336.jpg',
#  './data/train/images/positive/case_M_20181119111911_0U62363111914011_1_005_001-1_a12_ayy_image0105.jpg',
#  './data/train/images/positive/case_M_20190131094104_0U62367013193703_1_003_001-1_a7_ayy_image0063.jpg',
#  './data/train/images/positive/case_M_20190112093830_0U62372011292129_1_001_001-1_a10_ayy_image0140.jpg',
#  './data/train/images/positive/case_M_20181001100941_0U62372100109341_1_005_001-1_a2_ayy_image0076.jpg',
#  './data/train/images/positive/case_M_20190123101017_0U62372012395316_1_004_001-1_a7_ayy_image0005.jpg',
#  './data/train/images/positive/case_M_20190121095240_0U62368012118740_1_005_001-1_a2_ayy_image0254.jpg',
#  './data/train/images/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0144.jpg',
#  './data/train/images/positive/case_M_20181207092523_0U62372120765622_1_005_001-1_a11_ayy_image0011.jpg',
#  './data/train/images/positive/case_M_20181019101517_0U62367101935917_1_003_001-1_a18_ayy_image0225.jpg',
#  './data/train/images/positive/case_M_20181117100025_0U62363111779624_1_007_003-1_a6_ayy_image0018.jpg',
#  './data/train/images/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0090.jpg',
#  './data/train/images/positive/case_M_20181226125224_0U62363122631224_1_003_001-1_a10_ayy_image0169.jpg',
#  './data/train/images/positive/case_M_20181001093706_0U62368100179605_1_004_002-1_a26_ayy_image0086.jpg',
#  './data/train/images/positive/case_M_20181119111911_0U62363111914011_1_005_001-1_a12_ayy_image0077.jpg',
#  './data/train/images/positive/case_M_20181119111911_0U62363111914011_1_005_001-1_a12_ayy_image0437.jpg',
#  './data/train/images/positive/case_M_20181001140915_0U62366100164014_1_001_001-1_a7_ayy_image0080.jpg',
#  './data/train/images/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0523.jpg',
#  './data/train/images/positive/case_M_20181227102913_0U62363122725013_1_004_001-1_a8_ayy_image0036.jpg',
#  './data/train/images/positive/case_M_20181213092448_0U62363121315648_1_003_001-1_a6_ayy_image0019.jpg',
#  './data/train/images/positive/case_M_20181211093229_0U62367121175028_1_004_001-1_a10_ayy_image0053.jpg',
#  './data/train/images/positive/case_M_20190121095240_0U62368012118740_1_005_001-1_a3_ayy_image0036.jpg',
#  './data/train/images/positive/case_M_20181226125224_0U62363122631224_1_003_001-1_a5_ayy_image0052.jpg',
#  './data/train/images/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a18_ayy_image0043.jpg',
#  './data/train/images/positive/case_M_20190121100011_0U62372012151511_1_006_003-1_a3_ayy_image0027.jpg',
#  './data/train/images/positive/case_M_20181119111911_0U62363111914011_1_005_001-1_a6_ayy_image0055.jpg',
#  './data/train/images/positive/case_M_20181213092448_0U62363121315648_1_003_001-1_a3_ayy_image0018.jpg',
#  './data/train/images/positive/case_M_20181019101517_0U62367101935917_1_003_001-1_a18_ayy_image0272.jpg',
#  './data/train/images/positive/case_M_20190116094421_0U62363011675020_1_002_001-1_a2_ayy_image0116.jpg',
#  './data/train/images/positive/case_M_20181119111911_0U62363111914011_1_005_001-1_a12_ayy_image0127.jpg',
#  './data/train/images/positive/case_M_20181211093229_0U62367121175028_1_004_001-1_a8_ayy_image0064.jpg',
#  './data/train/images/positive/case_M_20181001140915_0U62366100164014_1_001_001-1_a4_ayy_image0082.jpg',
#  './data/train/images/positive/case_M_20190109095638_0U62372010945338_1_003_001-1_a23_ayy_image0528.jpg',
#  './data/train/images/positive/case_M_20181207092523_0U62372120765622_1_005_001-1_a15_ayy_image0023.jpg',
#  './data/train/images/positive/case_M_20181022094701_0U62368102271800_1_005_001-1_a6_ayy_image0052.jpg',
#  './data/train/images/positive/case_M_20181226125224_0U62363122631224_1_003_001-1_a10_ayy_image0045.jpg',
#  './data/train/images/positive/case_M_20181226125224_0U62363122631224_1_003_001-1_a10_ayy_image0266.jpg',
#  './data/train/images/positive/case_M_20181001100941_0U62372100109341_1_005_001-1_a10_ayy_image0051.jpg',
#  './data/train/images/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a4_ayy_image0115.jpg',
#  './data/train/images/positive/case_M_20181205095418_0U62367120576517_1_007_001-1_a24_ayy_image0031.jpg',
#  './data/train/images/positive/case_M_20190112093830_0U62372011292129_1_001_001-1_a8_ayy_image0120.jpg',
#  './data/train/images/positive/case_M_20181226125224_0U62363122631224_1_003_001-1_a8_ayy_image0240.jpg',
#  './data/train/images/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a13_ayy_image0521.jpg',
#  './data/train/images/positive/case_M_20190121100011_0U62372012151511_1_006_003-1_a3_ayy_image0043.jpg',
#  './data/train/images/positive/case_M_20190111094523_0U62372011160922_1_004_002-1_a10_ayy_image0014.jpg',
#  './data/train/images/positive/case_M_20181126095408_0U62367112660907_1_001_002-1_a7_ayy_image0041.jpg',
#  './data/train/images/positive/case_M_20181026100314_0U62363102665613_1_004_001-1_a4_ayy_image0005.jpg',
#  './data/train/images/positive/case_M_20181019101517_0U62367101935917_1_003_001-1_a18_ayy_image0162.jpg',
#  './data/train/images/positive/case_M_20181119111911_0U62363111914011_1_005_001-1_a12_ayy_image0427.jpg',
#  './data/train/images/positive/case_M_20181207092523_0U62372120765622_1_005_001-1_a17_ayy_image0019.jpg',
#  './data/train/images/positive/case_M_20181025095048_0U62372102595347_1_004_001-1_a8_ayy_image0210.jpg',
#  './data/train/images/positive/case_M_20181226125224_0U62363122631224_1_003_001-1_a4_ayy_image0104.jpg',
#  './data/train/images/positive/case_M_20181203093846_0U62367120345345_1_005_001-1_a7_ayy_image0064.jpg',
#  './data/train/images/positive/case_M_20190112093830_0U62372011292129_1_001_001-1_a8_ayy_image0024.jpg',
#  './data/train/images/positive/case_M_20181226125224_0U62363122631224_1_003_001-1_a10_ayy_image0264.jpg',
#  './data/train/images/positive/case_M_20181226125224_0U62363122631224_1_003_001-1_a8_ayy_image0123.jpg',
#  './data/train/images/positive/case_M_20190112093830_0U62372011292129_1_001_001-1_a2_ayy_image0049.jpg',
#  './data/train/images/positive/case_M_20181017100226_0U62367101735926_1_001_002-1_a14_ayy_image0008.jpg',
#  './data/train/images/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a13_ayy_image0538.jpg',
#  './data/train/images/positive/case_M_20190131094104_0U62367013193703_1_003_001-1_a9_ayy_image0246.jpg',
#  './data/train/images/positive/case_M_20190112093830_0U62372011292129_1_001_001-1_a10_ayy_image0169.jpg',
#  './data/train/images/positive/case_M_20181001100941_0U62372100109341_1_005_001-1_a2_ayy_image0068.jpg',
#  './data/train/images/positive/case_M_20181015101337_0U62363101576536_1_005_001-1_a21_ayy_image0101.jpg',
#  './data/train/images/positive/case_M_20181015101337_0U62363101576536_1_005_002-1_a9_ayy_image0093.jpg',
#  './data/train/images/positive/case_M_20181019101517_0U62367101935917_1_003_001-1_a20_ayy_image0021.jpg',
#  './data/train/images/positive/case_M_20181207092523_0U62372120765622_1_005_001-1_a15_ayy_image0217.jpg',
#  './data/train/images/positive/case_M_20181114092617_0U62372111495316_1_007_001-1_a2_ayy_image0053.jpg',
#  './data/train/images/positive/case_M_20181017100226_0U62367101735926_1_005_001-1_a7_ayy_image0013.jpg',
#  './data/train/images/positive/case_M_20181126095408_0U62367112660907_1_001_002-1_a7_ayy_image0071.jpg',
#  './data/train/images/positive/case_M_20190112093830_0U62372011292129_1_001_001-1_a1_ayy_image0010.jpg',
#  './data/train/images/positive/case_M_20190109095638_0U62372010945338_1_001_001-1_a2_ayy_image0011.jpg',
#  './data/train/images/positive/case_M_20181017100226_0U62367101735926_1_005_001-1_a7_ayy_image0011.jpg',
#  './data/train/images/positive/case_M_20181218101803_0U62372121864002_1_001_001-1_a6_ayy_image0051.jpg',
#  './data/train/images/positive/case_M_20190121095240_0U62368012118740_1_004_001-1_a3_ayy_image0055.jpg',
#  './data/train/images/positive/case_M_20190121095240_0U62368012118740_1_005_001-1_a1_ayy_image0251.jpg',
#  './data/train/images/positive/case_M_20181001100941_0U62372100109341_1_005_001-1_a2_ayy_image0151.jpg',
#  './data/train/images/positive/case_M_20181025095048_0U62372102595347_1_004_001-1_a8_ayy_image0212.jpg',
#  './data/train/images/positive/case_M_20190112093830_0U62372011292129_1_001_001-1_a10_ayy_image0077.jpg',
#  './data/train/images/positive/case_M_20181001140915_0U62366100164014_1_001_001-1_a4_ayy_image0062.jpg',
#  './data/train/images/positive/case_M_20190112093830_0U62372011292129_1_001_001-1_a10_ayy_image0171.jpg',
#  './data/train/images/positive/case_M_20181019101517_0U62367101935917_1_003_001-1_a18_ayy_image0239.jpg',
#  './data/train/images/positive/case_M_20190109095638_0U62372010945338_1_003_001-1_a30_ayy_image0018.jpg',
#  './data/train/images/positive/case_M_20181226125224_0U62363122631224_1_003_001-1_a8_ayy_image0119.jpg',
#  './data/train/images/positive/case_M_20190121100011_0U62372012151511_1_006_003-1_a3_ayy_image0050.jpg',
#  './data/train/images/positive/case_M_20181109094641_0U62372110931241_1_005_001-1_a2_ayy_image0038.jpg',
#  './data/train/images/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a17_ayy_image0134.jpg',
#  './data/train/images/positive/case_M_20181003094031_0U62363100354631_1_001_002-1_a1_ayy_image0117.jpg',
#  './data/train/images/positive/case_M_20190109095638_0U62372010945338_1_001_001-1_a1_ayy_image0071.jpg',
#  './data/train/images/positive/case_M_20181003094031_0U62363100354631_1_001_002-1_a1_ayy_image0470.jpg',
#  './data/train/images/positive/case_M_20190112093830_0U62372011292129_1_001_001-1_a1_ayy_image0142.jpg',
#  './data/train/images/positive/case_M_20181129152014_0U62366112981213_1_001_001-1_a20_ayy_image0054.jpg',
#  './data/train/images/positive/case_M_20190111094523_0U62372011160922_1_004_002-1_a8_ayy_image0049.jpg',
#  './data/train/images/positive/case_M_20181207092523_0U62372120765622_1_005_001-1_a15_ayy_image0011.jpg',
#  './data/train/images/positive/case_M_20190112093830_0U62372011292129_1_001_001-1_a10_ayy_image0179.jpg',
#  './data/train/images/positive/case_M_20181001093706_0U62368100179605_1_004_002-1_a26_ayy_image0084.jpg',
#  './data/train/images/positive/case_M_20190121095240_0U62368012118740_1_004_001-1_a1_ayy_image0101.jpg',
#  './data/train/images/positive/case_M_20190116094421_0U62363011675020_1_002_001-1_a2_ayy_image0154.jpg',
#  './data/train/images/positive/case_M_20181119111911_0U62363111914011_1_005_001-1_a16_ayy_image0093.jpg',
#  './data/train/images/positive/case_M_20190121095240_0U62368012118740_1_004_001-1_a9_ayy_image0017.jpg',
#  './data/train/images/positive/case_M_20190121095240_0U62368012118740_1_004_001-1_a4_ayy_image0052.jpg',
#  './data/train/images/positive/case_M_20181114092617_0U62372111495316_1_007_001-1_a2_ayy_image0068.jpg',
#  './data/train/images/positive/case_M_20181001140915_0U62366100164014_1_001_001-1_a4_ayy_image0072.jpg',
#  './data/train/images/positive/case_M_20181019101517_0U62367101935917_1_003_001-1_a20_ayy_image0013.jpg',
#  './data/train/images/positive/case_M_20190115123306_0U62368011540606_1_002_001-1_a5_ayy_image0172.jpg',
#  './data/train/images/positive/case_M_20181022094701_0U62368102271800_1_005_001-1_a3_ayy_image0108.jpg',
#  './data/train/images/positive/case_M_20190107094528_0U62367010726528_1_002_002-1_a5_ayy_image0026.jpg',
#  './data/train/images/positive/case_M_20181226125224_0U62363122631224_1_003_001-1_a10_ayy_image0005.jpg',
#  './data/train/images/positive/case_M_20181029094800_0U62368102981259_1_005_001-1_a17_ayy_image0011.jpg',
#  './data/train/images/positive/case_M_20181114092617_0U62372111495316_1_007_001-1_a2_ayy_image0108.jpg',
#  './data/train/images/positive/case_M_20181211093229_0U62367121175028_1_004_001-1_a10_ayy_image0061.jpg',
#  './data/train/images/positive/case_M_20190131094430_0U62372013151529_1_003_001-1_a4_ayy_image0007.jpg',
#  './data/train/images/positive/case_M_20181213092448_0U62363121315648_1_003_001-1_a6_ayy_image0035.jpg',
#  './data/train/images/positive/case_M_20181228140523_0U62365122821823_1_001_001-1_a6_ayy_image0032.jpg',
#  './data/train/images/positive/case_M_20190110094922_0U62372011079621_1_005_002-1_a2_ayy_image0013.jpg',
#  './data/train/images/positive/case_M_20181025095048_0U62372102595347_1_004_001-1_a8_ayy_image0246.jpg',
#  './data/train/images/positive/case_M_20181117100025_0U62363111779624_1_007_003-1_a8_ayy_image0253.jpg',
#  './data/train/images/positive/case_M_20181018093806_0U62363101890605_1_007_002-1_a3_ayy_image0005.jpg',
#  './data/train/images/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0148.jpg',
#  './data/train/images/positive/case_M_20181001100941_0U62372100109341_1_005_001-1_a10_ayy_image0089.jpg',
#  './data/train/images/positive/case_M_20181017100226_0U62367101735926_1_007_004-1_a4_ayy_image0290.jpg',
#  './data/train/images/positive/case_M_20181105095958_0U62368110576557_1_003_002-1_a6_ayy_image0264.jpg',
#  './data/train/images/positive/case_M_20190121095240_0U62368012118740_1_004_001-1_a3_ayy_image0013.jpg',
#  './data/train/images/positive/case_M_20181019101517_0U62367101935917_1_003_001-1_a18_ayy_image0276.jpg',
#  './data/train/images/positive/case_M_20190109095638_0U62372010945338_1_003_001-1_a23_ayy_image0355.jpg',
#  './data/train/images/positive/case_M_20181226125224_0U62363122631224_1_003_001-1_a6_ayy_image0024.jpg',
#  './data/train/images/positive/case_M_20181226125224_0U62363122631224_1_003_001-1_a10_ayy_image0051.jpg',
#  './data/train/images/positive/case_M_20181218101803_0U62372121864002_1_001_001-1_a6_ayy_image0006.jpg',
#  './data/train/images/positive/case_M_20181019101517_0U62367101935917_1_003_001-1_a12_ayy_image0052.jpg',
#  './data/train/images/positive/case_M_20181226125224_0U62363122631224_1_003_001-1_a10_ayy_image0246.jpg',
#  './data/train/images/positive/case_M_20190112093830_0U62372011292129_1_001_001-1_a1_ayy_image0087.jpg',
#  './data/train/images/positive/case_M_20181119111911_0U62363111914011_1_005_001-1_a12_ayy_image0071.jpg',
#  './data/train/images/positive/case_M_20190121095240_0U62368012118740_1_004_001-1_a1_ayy_image0097.jpg',
#  './data/train/images/positive/case_M_20181017100226_0U62367101735926_1_007_003-1_a9_ayy_image0129.jpg',
#  './data/train/images/positive/case_M_20181228140523_0U62365122821823_1_001_001-1_a6_ayy_image0016.jpg',
#  './data/train/images/positive/case_M_20181025095048_0U62372102595347_1_004_001-1_a8_ayy_image0220.jpg',
#  './data/train/images/positive/case_M_20190109095638_0U62372010945338_1_003_001-1_a23_ayy_image0538.jpg',
#  './data/train/images/positive/case_M_20190116094421_0U62363011675020_1_002_001-1_a2_ayy_image0079.jpg',
#  './data/train/images/positive/case_M_20190121095240_0U62368012118740_1_004_001-1_a2_ayy_image0022.jpg',
#  './data/train/images/positive/case_M_20190116094421_0U62363011675020_1_004_001-1_a1_ayy_image0004.jpg',
#  './data/train/images/positive/case_M_20181022094701_0U62368102271800_1_005_001-1_a6_ayy_image0060.jpg',
#  './data/train/images/positive/case_M_20190112093830_0U62372011292129_1_001_001-1_a10_ayy_image0152.jpg',
#  './data/train/images/positive/case_M_20181019101517_0U62367101935917_1_003_001-1_a18_ayy_image0231.jpg',
#  './data/train/images/positive/case_M_20190116094421_0U62363011675020_1_002_001-1_a2_ayy_image0136.jpg',
#  './data/train/images/positive/case_M_20181105095958_0U62368110576557_1_003_002-1_a6_ayy_image0295.jpg',
#  './data/train/images/positive/case_M_20181207092523_0U62372120765622_1_005_001-1_a12_ayy_image0126.jpg',
#  './data/train/images/positive/case_M_20181001100941_0U62372100109341_1_005_001-1_a2_ayy_image0046.jpg',
#  './data/train/images/positive/case_M_20181001140915_0U62366100164014_1_001_001-1_a7_ayy_image0110.jpg',
#  './data/train/images/positive/case_M_20181213092448_0U62363121315648_1_003_001-1_a3_ayy_image0053.jpg',
#  './data/train/images/positive/case_M_20181015101337_0U62363101576536_1_005_001-1_a21_ayy_image0125.jpg',
#  './data/train/images/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0138.jpg',
#  './data/train/images/positive/case_M_20181207092523_0U62372120765622_1_005_001-1_a15_ayy_image0100.jpg',
#  './data/train/images/positive/case_M_20181207092523_0U62372120765622_1_005_001-1_a11_ayy_image0001.jpg',
#  './data/train/images/positive/case_M_20181207092523_0U62372120765622_1_005_001-1_a12_ayy_image0016.jpg',
#  './data/train/images/positive/case_M_20181226125224_0U62363122631224_1_003_001-1_a6_ayy_image0034.jpg',
#  './data/train/images/positive/case_M_20190131094104_0U62367013193703_1_003_001-1_a8_ayy_image0087.jpg',
#  './data/train/images/positive/case_M_20181213131150_0U62365121395349_1_002_002-1_a25_ayy_image0146.jpg',
#  './data/train/images/positive/case_M_20181025095048_0U62372102595347_1_004_001-1_a8_ayy_image0271.jpg',
#  './data/train/images/positive/case_M_20181019101517_0U62367101935917_1_003_001-1_a15_ayy_image0082.jpg',
#  './data/train/images/positive/case_M_20181025095048_0U62372102595347_1_004_001-1_a8_ayy_image0263.jpg',
#  './data/train/images/positive/case_M_20190109095638_0U62372010945338_1_003_001-1_a23_ayy_image0114.jpg',
#  './data/train/images/positive/case_M_20181025095048_0U62372102595347_1_004_001-1_a8_ayy_image0327.jpg',
#  './data/train/images/positive/case_M_20181015101337_0U62363101576536_1_005_002-1_a8_ayy_image0010.jpg',
#  './data/train/images/positive/case_M_20181105095958_0U62368110576557_1_003_002-1_a7_ayy_image0026.jpg',
#  './data/train/images/positive/case_M_20190123101017_0U62372012395316_1_004_001-1_a7_ayy_image0025.jpg',
#  './data/train/images/positive/case_M_20181105095958_0U62368110576557_1_003_002-1_a6_ayy_image0256.jpg',
#  './data/train/images/positive/case_M_20181019101517_0U62367101935917_1_003_001-1_a18_ayy_image0282.jpg',
#  './data/train/images/positive/case_M_20181018093806_0U62363101890605_1_007_001-1_a1_ayy_image0158.jpg',
#  './data/train/images/positive/case_M_20181226125224_0U62363122631224_1_003_001-1_a10_ayy_image0388.jpg',
#  './data/train/images/positive/case_M_20181001093706_0U62368100179605_1_004_002-1_a25_ayy_image0061.jpg',
#  './data/train/images/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a3_ayy_image0135.jpg',
#  './data/train/images/positive/case_M_20181201091914_0U62363120125014_1_005_001-1_a10_ayy_image0175.jpg',
#  './data/train/images/positive/case_M_20181031103335_0U62368103151535_1_006_001-1_a4_ayy_image0056.jpg',
#  './data/train/images/positive/case_M_20190112093830_0U62372011292129_1_001_001-1_a5_ayy_image0022.jpg',
#  './data/train/images/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0562.jpg',
#  './data/train/images/positive/case_M_20181119111911_0U62363111914011_1_005_001-1_a6_ayy_image0017.jpg',
#  './data/train/images/positive/case_M_20181015101337_0U62363101576536_1_005_001-1_a20_ayy_image0004.jpg',
#  './data/train/images/positive/case_M_20181226125224_0U62363122631224_1_003_001-1_a10_ayy_image0086.jpg',
#  './data/train/images/positive/case_M_20181105095958_0U62368110576557_1_003_002-1_a6_ayy_image0475.jpg',
#  './data/train/images/positive/case_M_20181019101517_0U62367101935917_1_003_001-1_a18_ayy_image0262.jpg',
#  './data/train/images/positive/case_M_20190121095240_0U62368012118740_1_004_001-1_a1_ayy_image0122.jpg',
#  './data/train/images/positive/case_M_20190109095638_0U62372010945338_1_003_001-1_a23_ayy_image0546.jpg',
#  './data/train/images/positive/case_M_20181218101803_0U62372121864002_1_001_001-1_a4_ayy_image0051.jpg',
#  './data/train/images/positive/case_M_20181025095048_0U62372102595347_1_004_001-1_a8_ayy_image0309.jpg',
#  './data/train/images/positive/case_M_20190109095638_0U62372010945338_1_003_001-1_a24_ayy_image0328.jpg',
#  './data/train/images/positive/case_M_20181119111911_0U62363111914011_1_005_001-1_a6_ayy_image0059.jpg',
# ...
#  './data/train/images/positive/case_M_20190121100011_0U62372012151511_1_006_003-1_a3_ayy_image0017.jpg',
#  './data/train/images/positive/case_M_20190111094523_0U62372011160922_1_004_002-1_a8_ayy_image0031.jpg',
#  './data/train/images/positive/case_M_20181226125224_0U62363122631224_1_003_001-1_a6_ayy_image0038.jpg',
#  './data/train/images/positive/case_M_20181015101337_0U62363101576536_1_005_002-1_a18_ayy_image0029.jpg',
#  './data/train/images/positive/case_M_20181019101517_0U62367101935917_1_003_001-1_a20_ayy_image0031.jpg',
#  './data/train/images/positive/case_M_20181026100314_0U62363102665613_1_004_001-1_a5_ayy_image0011.jpg',
#  './data/train/images/positive/case_M_20181201091914_0U62363120125014_1_005_001-1_a10_ayy_image0185.jpg',
#  './data/train/images/positive/case_M_20190107094528_0U62367010726528_1_002_002-1_a5_ayy_image0010.jpg',
#  './data/train/images/positive/case_M_20181022094701_0U62368102271800_1_005_001-1_a6_ayy_image0029.jpg',
#  './data/train/images/positive/case_M_20190109095638_0U62372010945338_1_003_001-1_a24_ayy_image0034.jpg',
#  './data/train/images/positive/case_M_20181218101803_0U62372121864002_1_001_001-1_a6_ayy_image0016.jpg',
#  './data/train/images/positive/case_M_20181119111911_0U62363111914011_1_005_001-1_a12_ayy_image0429.jpg',
#  './data/train/images/positive/case_M_20190116094421_0U62363011675020_1_004_001-1_a4_ayy_image0009.jpg',
#  './data/train/images/positive/case_M_20181015101337_0U62363101576536_1_005_001-1_a20_ayy_image0067.jpg',
#  './data/train/images/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a13_ayy_image0309.jpg',
#  './data/train/images/positive/case_M_20181001140915_0U62366100164014_1_001_001-1_a7_ayy_image0151.jpg',
#  './data/train/images/positive/case_M_20190121095240_0U62368012118740_1_004_001-1_a3_ayy_image0072.jpg',
#  './data/train/images/positive/case_M_20181207092523_0U62372120765622_1_005_001-1_a15_ayy_image0061.jpg',
#  './data/train/images/positive/case_M_20181019101517_0U62367101935917_1_003_001-1_a18_ayy_image0189.jpg',
#  './data/train/images/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0684.jpg',
#  './data/train/images/positive/case_M_20181207092523_0U62372120765622_1_005_001-1_a11_ayy_image0019.jpg',
#  './data/train/images/positive/case_M_20181228140523_0U62365122821823_1_001_001-1_a6_ayy_image0036.jpg',
#  './data/train/images/positive/case_M_20181031103335_0U62368103151535_1_006_001-1_a4_ayy_image0035.jpg',
#  './data/train/images/positive/case_M_20190109095638_0U62372010945338_1_003_001-1_a23_ayy_image0118.jpg',
#  './data/train/images/positive/case_M_20190112093830_0U62372011292129_1_001_001-1_a5_ayy_image0049.jpg',
#  './data/train/images/positive/case_M_20181119111911_0U62363111914011_1_005_001-1_a13_ayy_image0026.jpg',
#  './data/train/images/positive/case_M_20181015101337_0U62363101576536_1_005_001-1_a21_ayy_image0038.jpg',
#  './data/train/images/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0067.jpg',
#  './data/train/images/positive/case_M_20181031103335_0U62368103151535_1_006_001-1_a4_ayy_image0068.jpg',
#  './data/train/images/positive/case_M_20181207092523_0U62372120765622_1_005_001-1_a15_ayy_image0005.jpg',
#  './data/train/images/positive/case_M_20190109095638_0U62372010945338_1_003_001-1_a23_ayy_image0070.jpg',
#  './data/train/images/positive/case_M_20181218101803_0U62372121864002_1_001_001-1_a8_ayy_image0014.jpg',
#  './data/train/images/positive/case_M_20181001093706_0U62368100179605_1_004_002-1_a25_ayy_image0073.jpg',
#  './data/train/images/positive/case_M_20181201091914_0U62363120125014_1_005_001-1_a10_ayy_image0104.jpg',
#  './data/train/images/positive/case_M_20190121095240_0U62368012118740_1_004_001-1_a7_ayy_image0019.jpg',
#  './data/train/images/positive/case_M_20190112093830_0U62372011292129_1_001_001-1_a2_ayy_image0055.jpg',
#  './data/train/images/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a13_ayy_image0296.jpg',
#  './data/train/images/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a4_ayy_image0008.jpg',
#  './data/train/images/positive/case_M_20190109095638_0U62372010945338_1_003_001-1_a23_ayy_image0059.jpg',
#  './data/train/images/positive/case_M_20181001140915_0U62366100164014_1_001_001-1_a7_ayy_image0167.jpg',
#  './data/train/images/positive/case_M_20181019101517_0U62367101935917_1_003_001-1_a15_ayy_image0058.jpg',
#  './data/train/images/positive/case_M_20181017100226_0U62367101735926_1_007_003-1_a9_ayy_image0093.jpg',
#  './data/train/images/positive/case_M_20181205095418_0U62367120576517_1_007_001-1_a24_ayy_image0017.jpg',
#  './data/train/images/positive/case_M_20181211093229_0U62367121175028_1_004_001-1_a6_ayy_image0010.jpg',
#  './data/train/images/positive/case_M_20181017100226_0U62367101735926_1_007_003-1_a9_ayy_image0119.jpg',
#  './data/train/images/positive/case_M_20181031103335_0U62368103151535_1_006_001-1_a6_ayy_image0041.jpg',
#  './data/train/images/positive/case_M_20190109095638_0U62372010945338_1_003_001-1_a23_ayy_image0353.jpg',
#  './data/train/images/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0793.jpg',
#  './data/train/images/positive/case_M_20190112093830_0U62372011292129_1_001_001-1_a8_ayy_image0089.jpg',
#  './data/train/images/positive/case_M_20190128094801_0U62372012857800_1_002_001-1_a5_ayy_image0012.jpg',
#  './data/train/images/positive/case_M_20181226125224_0U62363122631224_1_003_001-1_a4_ayy_image0094.jpg',
#  './data/train/images/positive/case_M_20190121095240_0U62368012118740_1_004_001-1_a3_ayy_image0082.jpg',
#  './data/train/images/positive/case_M_20190121095240_0U62368012118740_1_005_001-1_a2_ayy_image0183.jpg',
#  './data/train/images/positive/case_M_20190109095638_0U62372010945338_1_001_001-1_a2_ayy_image0042.jpg',
#  './data/train/images/positive/case_M_20181119111911_0U62363111914011_1_005_001-1_a12_ayy_image0093.jpg',
#  './data/train/images/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a18_ayy_image0092.jpg',
#  './data/train/images/positive/case_M_20181227102913_0U62363122725013_1_004_001-1_a11_ayy_image0082.jpg',
#  './data/train/images/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0783.jpg',
#  './data/train/images/positive/case_M_20181226125224_0U62363122631224_1_003_001-1_a10_ayy_image0376.jpg',
#  './data/train/images/positive/case_M_20181226125224_0U62363122631224_1_003_001-1_a10_ayy_image0029.jpg',
#  './data/train/images/positive/case_M_20190121100011_0U62372012151511_1_006_003-1_a3_ayy_image0064.jpg',
#  './data/train/images/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a22_ayy_image0154.jpg',
#  './data/train/images/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a13_ayy_image0416.jpg',
#  './data/train/images/positive/case_M_20190112093830_0U62372011292129_1_001_001-1_a8_ayy_image0061.jpg',
#  './data/train/images/positive/case_M_20181226125224_0U62363122631224_1_003_001-1_a10_ayy_image0256.jpg',
#  './data/train/images/positive/case_M_20190109095638_0U62372010945338_1_003_001-1_a23_ayy_image0084.jpg',
#  './data/train/images/positive/case_M_20190121095240_0U62368012118740_1_005_001-1_a2_ayy_image0140.jpg',
#  './data/train/images/positive/case_M_20181119111911_0U62363111914011_1_005_001-1_a12_ayy_image0142.jpg',
#  './data/train/images/positive/case_M_20190121100011_0U62372012151511_1_006_003-1_a3_ayy_image0054.jpg',
#  './data/train/images/positive/case_M_20181110093525_0U62372111056224_1_004_001-1_a1_ayy_image0001.jpg',
#  './data/train/images/positive/case_M_20190121095240_0U62368012118740_1_005_001-1_a2_ayy_image0128.jpg',
#  './data/train/images/positive/case_M_20190112093830_0U62372011292129_1_001_001-1_a10_ayy_image0146.jpg',
#  './data/train/images/positive/case_M_20190116094421_0U62363011675020_1_004_001-1_a2_ayy_image0008.jpg',
#  './data/train/images/positive/case_M_20190121095240_0U62368012118740_1_004_001-1_a4_ayy_image0040.jpg',
#  './data/train/images/positive/case_M_20190112093830_0U62372011292129_1_001_001-1_a7_ayy_image0090.jpg',
#  './data/train/images/positive/case_M_20181114092617_0U62372111495316_1_007_001-1_a2_ayy_image0059.jpg',
#  './data/train/images/positive/case_M_20181003094031_0U62363100354631_1_001_002-1_a1_ayy_image0109.jpg',
#  './data/train/images/positive/case_M_20181203093846_0U62367120345345_1_005_001-1_a7_ayy_image0080.jpg',
#  './data/train/images/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a5_ayy_image0115.jpg',
#  './data/train/images/positive/case_M_20181105095958_0U62368110576557_1_003_002-1_a7_ayy_image0024.jpg',
#  './data/train/images/positive/case_M_20181218101803_0U62372121864002_1_001_001-1_a6_ayy_image0067.jpg',
#  './data/train/images/positive/case_M_20181015101337_0U62363101576536_1_005_002-1_a8_ayy_image0008.jpg',
#  './data/train/images/positive/case_M_20181001100941_0U62372100109341_1_005_001-1_a10_ayy_image0075.jpg',
#  './data/train/images/positive/case_M_20181003094031_0U62363100354631_1_001_002-1_a1_ayy_image0245.jpg',
#  './data/train/images/positive/case_M_20181001140915_0U62366100164014_1_001_001-1_a7_ayy_image0169.jpg',
#  './data/train/images/positive/case_M_20181211093229_0U62367121175028_1_002_002-1_a8_ayy_image0084.jpg',
#  './data/train/images/positive/case_M_20181001093706_0U62368100179605_1_004_002-1_a26_ayy_image0017.jpg',
#  './data/train/images/positive/case_M_20181207092523_0U62372120765622_1_005_001-1_a11_ayy_image0005.jpg',
#  './data/train/images/positive/case_M_20190112093830_0U62372011292129_1_001_001-1_a5_ayy_image0069.jpg',
#  './data/train/images/positive/case_M_20181226125224_0U62363122631224_1_003_001-1_a8_ayy_image0234.jpg',
#  './data/train/images/positive/case_M_20190112093830_0U62372011292129_1_001_001-1_a7_ayy_image0100.jpg',
#  './data/train/images/positive/case_M_20181019122218_0U62368101948418_1_002_001-1_a4_ayy_image0130.jpg',
#  './data/train/images/positive/case_M_20190121095240_0U62368012118740_1_005_001-1_a2_ayy_image0250.jpg',
#  './data/train/images/positive/case_M_20190116093042_0U62372011685941_1_001_001-1_a3_ayy_image0083.jpg',
#  './data/train/images/positive/case_M_20181205095418_0U62367120576517_1_007_001-1_a24_ayy_image0033.jpg',
#  './data/train/images/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0763.jpg',
#  './data/train/images/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a13_ayy_image0173.jpg',
#  './data/train/images/positive/case_M_20181001100941_0U62372100109341_1_005_001-1_a2_ayy_image0084.jpg',
#  './data/train/images/positive/case_M_20181018093806_0U62363101890605_1_007_002-1_a3_ayy_image0023.jpg',
#  './data/train/images/positive/case_M_20190112093830_0U62372011292129_1_001_001-1_a10_ayy_image0195.jpg',
#  './data/train/images/positive/case_M_20181019101517_0U62367101935917_1_003_001-1_a12_ayy_image0044.jpg',
#  './data/train/images/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a13_ayy_image0558.jpg',
#  './data/train/images/positive/case_M_20181211093229_0U62367121175028_1_004_001-1_a10_ayy_image0123.jpg',
#  './data/train/images/positive/case_M_20181031103335_0U62368103151535_1_006_001-1_a6_ayy_image0016.jpg',
#  './data/train/images/positive/case_M_20181105095958_0U62368110576557_1_003_002-1_a7_ayy_image0020.jpg',
#  './data/train/images/positive/case_M_20181126095408_0U62367112660907_1_001_002-1_a7_ayy_image0010.jpg',
#  './data/train/images/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a5_ayy_image0121.jpg',
#  './data/train/images/positive/case_M_20181213131150_0U62365121395349_1_002_002-1_a25_ayy_image0144.jpg',
#  './data/train/images/positive/case_M_20190112093830_0U62372011292129_1_001_001-1_a2_ayy_image0057.jpg',
#  './data/train/images/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0564.jpg',
#  './data/train/images/positive/case_M_20181015101337_0U62363101576536_1_005_001-1_a20_ayy_image0034.jpg',
#  './data/train/images/positive/case_M_20181109094641_0U62372110931241_1_005_001-1_a2_ayy_image0042.jpg',
#  './data/train/images/positive/case_M_20190131094104_0U62367013193703_1_003_001-1_a8_ayy_image0119.jpg',
#  './data/train/images/positive/case_M_20190128094801_0U62372012857800_1_002_001-1_a6_ayy_image0141.jpg',
#  './data/train/images/positive/case_M_20181203093846_0U62367120345345_1_005_001-1_a8_ayy_image0001.jpg',
#  './data/train/images/positive/case_M_20181029094800_0U62368102981259_1_005_001-1_a17_ayy_image0007.jpg',
#  './data/train/images/positive/case_M_20190112093830_0U62372011292129_1_001_001-1_a8_ayy_image0109.jpg',
#  './data/train/images/positive/case_M_20181019101517_0U62367101935917_1_003_001-1_a18_ayy_image0278.jpg',
#  './data/train/images/positive/case_M_20181015101337_0U62363101576536_1_005_001-1_a18_ayy_image0001.jpg',
#  './data/train/images/positive/case_M_20190131094104_0U62367013193703_1_003_001-1_a9_ayy_image0089.jpg',
#  './data/train/images/positive/case_M_20181211093229_0U62367121175028_1_004_001-1_a10_ayy_image0059.jpg',
#  './data/train/images/positive/case_M_20181119111911_0U62363111914011_1_005_001-1_a2_ayy_image0059.jpg',
#  './data/train/images/positive/case_M_20181119111911_0U62363111914011_1_005_001-1_a12_ayy_image0111.jpg',
#  './data/train/images/positive/case_M_20181213131150_0U62365121395349_1_002_001-1_a11_ayy_image0032.jpg',
#  './data/train/images/positive/case_M_20181226125224_0U62363122631224_1_003_001-1_a10_ayy_image0371.jpg',
#  './data/train/images/positive/case_M_20181129152014_0U62366112981213_1_001_001-1_a25_ayy_image0090.jpg',
#  './data/train/images/positive/case_M_20190109095638_0U62372010945338_1_003_001-1_a23_ayy_image0001.jpg',
#  './data/train/images/positive/case_M_20181015101337_0U62363101576536_1_005_001-1_a21_ayy_image0026.jpg',
#  './data/train/images/positive/case_M_20190112093830_0U62372011292129_1_001_001-1_a8_ayy_image0014.jpg',
#  './data/train/images/positive/case_M_20190121095240_0U62368012118740_1_004_001-1_a4_ayy_image0005.jpg',
#  './data/train/images/positive/case_M_20181220100816_0U62368122007816_1_002_001-1_a6_ayy_image0046.jpg',
#  './data/train/images/positive/case_M_20190123101017_0U62372012395316_1_004_001-1_a7_ayy_image0063.jpg',
#  './data/train/images/positive/case_M_20181019101517_0U62367101935917_1_003_001-1_a13_ayy_image0041.jpg',
#  './data/train/images/positive/case_M_20181117100025_0U62363111779624_1_007_003-1_a8_ayy_image0219.jpg',
#  './data/train/images/positive/case_M_20181201091914_0U62363120125014_1_005_001-1_a10_ayy_image0153.jpg',
#  './data/train/images/positive/case_M_20181226125224_0U62363122631224_1_003_001-1_a8_ayy_image0226.jpg',
#  './data/train/images/positive/case_M_20181213092448_0U62363121315648_1_003_001-1_a3_ayy_image0014.jpg',
#  './data/train/images/positive/case_M_20181001093706_0U62368100179605_1_004_002-1_a26_ayy_image0031.jpg',
#  './data/train/images/positive/case_M_20190109095638_0U62372010945338_1_003_001-1_a24_ayy_image0072.jpg',
#  './data/train/images/positive/case_M_20181211093229_0U62367121175028_1_002_002-1_a8_ayy_image0053.jpg',
#  './data/train/images/positive/case_M_20181119111911_0U62363111914011_1_005_001-1_a12_ayy_image0500.jpg',
#  './data/train/images/positive/case_M_20181226125224_0U62363122631224_1_003_001-1_a6_ayy_image0032.jpg',
#  './data/train/images/positive/case_M_20181001140915_0U62366100164014_1_001_001-1_a7_ayy_image0086.jpg',
#  './data/train/images/positive/case_M_20181119111911_0U62363111914011_1_005_001-1_a12_ayy_image0121.jpg',
#  './data/train/images/positive/case_M_20190109095638_0U62372010945338_1_001_001-1_a2_ayy_image0013.jpg',
#  './data/train/images/positive/case_M_20181119111911_0U62363111914011_1_005_001-1_a12_ayy_image0304.jpg',
#  './data/train/images/positive/case_M_20181017100226_0U62367101735926_1_007_004-1_a4_ayy_image0193.jpg',
#  './data/train/images/positive/case_M_20190109095638_0U62372010945338_1_001_001-1_a3_ayy_image0016.jpg',
#  './data/train/images/positive/case_M_20181114092617_0U62372111495316_1_007_001-1_a2_ayy_image0066.jpg',
#  './data/train/images/positive/case_M_20190123101017_0U62372012395316_1_004_001-1_a7_ayy_image0069.jpg',
#  './data/train/images/positive/case_M_20181003094031_0U62363100354631_1_001_002-1_a1_ayy_image0169.jpg',
#  ...]

# %% [markdown]
# ##### analyze object density

# %%
density_data = data_processor.generate_object_density_data(F_TRAIN_MASKS_POS)
data_processor.visualize_object_density(density_data)

# %% [markdown]
# ### augment positive frames with flipping & rotating

# %%
augmented_data = data_processor.augment_data_4x4_balance(F_TRAIN_MASKS_POS, 8000)
data_processor.apply_augmentations_to_matching_images(F_TRAIN_IMAGES_POS, augmented_data)

# %% [markdown]
# ##### analyze object density

# %%
density_data = data_processor.generate_object_density_data(F_TRAIN_MASKS_POS)
data_processor.visualize_object_density(density_data)

# %% [markdown]
# ### augment negative frames randomly

# %%
data_processor.augment_random_images(F_TRAIN_IMAGES_NEG, 2000)

# %% [markdown]
# ### remove most abnormal frames

# %%
removed = data_processor.remove_most_abnormal(F_TRAIN_IMAGES_POS, 1380)
data_processor.remove_files_by_base_names(F_TRAIN_MASKS_POS, removed)
# Out:
# ['./data/train/masks/positive/case_M_20190115123306_0U62368011540606_1_002_001-1_a3_ayy_image0033.png',
#  './data/train/masks/positive/case_M_20190110094509_0U62363011095308_1_001_002-1_a2_ayy_image0023_flip_h.png',
#  './data/train/masks/positive/case_M_20190107094528_0U62367010726528_1_002_001-1_a7_ayy_image0104.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a17_ayy_image0171_flip_h.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0169.png',
#  './data/train/masks/positive/case_M_20181018093806_0U62363101890605_1_007_001-1_a1_ayy_image0087.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a17_ayy_image0103_flip_v.png',
#  './data/train/masks/positive/case_M_20190117105747_0U62368011712547_1_002_001-1_a18_ayy_image0038.png',
#  './data/train/masks/positive/case_M_20181019101517_0U62367101935917_1_003_001-1_a17_ayy_image0069.png',
#  './data/train/masks/positive/case_M_20190115123306_0U62368011540606_1_002_001-1_a3_ayy_image0006.png',
#  './data/train/masks/positive/case_M_20190110094509_0U62363011095308_1_001_001-1_a5_ayy_image0082.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0173.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a23_ayy_image0181.png',
#  './data/train/masks/positive/case_M_20190117095926_0U62372011750026_1_002_001-1_a4_ayy_image0081_flip_h.png',
#  './data/train/masks/positive/case_M_20181030122608_0U62363103057807_1_002_003-1_a2_ayy_image0053.png',
#  './data/train/masks/positive/case_M_20181019122218_0U62368101948418_1_002_001-1_a4_ayy_image0010.png',
#  './data/train/masks/positive/case_M_20190115123306_0U62368011540606_1_002_001-1_a3_ayy_image0039.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0515_rotate_180.png',
#  './data/train/masks/positive/case_M_20190110094509_0U62363011095308_1_001_002-1_a2_ayy_image0006.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0404.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a20_ayy_image0123.png',
#  './data/train/masks/positive/case_M_20190117095926_0U62372011750026_1_002_001-1_a4_ayy_image0077_flip_h.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0805_flip_v.png',
#  './data/train/masks/positive/case_M_20181228140523_0U62365122821823_1_001_001-1_a3_ayy_image0131.png',
#  './data/train/masks/positive/case_M_20181018093806_0U62363101890605_1_007_001-1_a1_ayy_image0069_flip_h.png',
#  './data/train/masks/positive/case_M_20181019122218_0U62368101948418_1_002_001-1_a3_ayy_image0003_flip_h.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a3_ayy_image0111.png',
#  './data/train/masks/positive/case_M_20190121095240_0U62368012118740_1_004_001-1_a8_ayy_image0109.png',
#  './data/train/masks/positive/case_M_20190117095926_0U62372011750026_1_002_001-1_a4_ayy_image0079.png',
#  './data/train/masks/positive/case_M_20190110094509_0U62363011095308_1_001_001-1_a5_ayy_image0063_flip_h.png',
#  './data/train/masks/positive/case_M_20190107094528_0U62367010726528_1_002_001-1_a7_ayy_image0106.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0465.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a22_ayy_image0262_flip_v.png',
#  './data/train/masks/positive/case_M_20190110094509_0U62363011095308_1_001_001-1_a5_ayy_image0039.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0852_flip_v.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0900_flip_h.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a23_ayy_image0187.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a23_ayy_image0039.png',
#  './data/train/masks/positive/case_M_20190107094528_0U62367010726528_1_002_001-1_a7_ayy_image0162.png',
#  './data/train/masks/positive/case_M_20190117105747_0U62368011712547_1_002_001-1_a16_ayy_image0010.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0809_rotate_180.png',
#  './data/train/masks/positive/case_M_20181030122608_0U62363103057807_1_002_003-1_a4_ayy_image0019_flip_h.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0977_flip_h.png',
#  './data/train/masks/positive/case_M_20190110094509_0U62363011095308_1_001_002-1_a2_ayy_image0055.png',
#  './data/train/masks/positive/case_M_20190107094528_0U62367010726528_1_002_001-1_a7_ayy_image0154_flip_h.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a20_ayy_image0107_flip_v.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a20_ayy_image0084.png',
#  './data/train/masks/positive/case_M_20190107094528_0U62367010726528_1_002_001-1_a7_ayy_image0006.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a23_ayy_image0165_flip_h.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a23_ayy_image0092.png',
#  './data/train/masks/positive/case_M_20190115123306_0U62368011540606_1_002_001-1_a4_ayy_image0048.png',
#  './data/train/masks/positive/case_M_20181211093229_0U62367121175028_1_004_001-1_a8_ayy_image0039.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0854_flip_v.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a13_ayy_image0272.png',
#  './data/train/masks/positive/case_M_20190107094528_0U62367010726528_1_002_001-1_a7_ayy_image0152_flip_v.png',
#  './data/train/masks/positive/case_M_20190107094528_0U62367010726528_1_002_001-1_a7_ayy_image0110.png',
#  './data/train/masks/positive/case_M_20181211093229_0U62367121175028_1_002_002-1_a3_ayy_image0012.png',
#  './data/train/masks/positive/case_M_20181019122218_0U62368101948418_1_002_001-1_a1_ayy_image0062.png',
#  './data/train/masks/positive/case_M_20181218101803_0U62372121864002_1_001_001-1_a6_ayy_image0095_flip_v.png',
#  './data/train/masks/positive/case_M_20181119111911_0U62363111914011_1_005_001-1_a13_ayy_image0028.png',
#  './data/train/masks/positive/case_M_20181119111911_0U62363111914011_1_005_001-1_a4_ayy_image0048_rotate_180.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a17_ayy_image0114.png',
#  './data/train/masks/positive/case_M_20190109095638_0U62372010945338_1_003_001-1_a24_ayy_image0445_flip_v.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0860_flip_v.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0171_rotate_180.png',
#  './data/train/masks/positive/case_M_20181018093806_0U62363101890605_1_007_001-1_a1_ayy_image0069.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a20_ayy_image0107.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a4_ayy_image0194_flip_v.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0862.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a20_ayy_image0096.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a22_ayy_image0297_flip_v.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0921.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0949_flip_v.png',
#  './data/train/masks/positive/case_M_20181018093806_0U62363101890605_1_007_002-1_a12_ayy_image0026_flip_v.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a17_ayy_image0055.png',
#  './data/train/masks/positive/case_M_20190112093830_0U62372011292129_1_001_001-1_a1_ayy_image0389.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a4_ayy_image0230.png',
#  './data/train/masks/positive/case_M_20190110094509_0U62363011095308_1_001_002-1_a2_ayy_image0057_flip_v.png',
#  './data/train/masks/positive/case_M_20190107094528_0U62367010726528_1_002_001-1_a7_ayy_image0128_flip_h.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0544_flip_h.png',
#  './data/train/masks/positive/case_M_20181218101803_0U62372121864002_1_001_001-1_a4_ayy_image0061.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0037.png',
#  './data/train/masks/positive/case_M_20181119111911_0U62363111914011_1_005_001-1_a1_ayy_image0015.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0406.png',
#  './data/train/masks/positive/case_M_20181207092523_0U62372120765622_1_005_001-1_a18_ayy_image0023.png',
#  './data/train/masks/positive/case_M_20181030122608_0U62363103057807_1_002_003-1_a4_ayy_image0027.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0465_flip_v.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a20_ayy_image0009_flip_h.png',
#  './data/train/masks/positive/case_M_20190115123306_0U62368011540606_1_002_001-1_a4_ayy_image0003.png',
#  './data/train/masks/positive/case_M_20190123101017_0U62372012395316_1_004_001-1_a4_ayy_image0014.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0033.png',
#  './data/train/masks/positive/case_M_20190117095926_0U62372011750026_1_002_001-1_a4_ayy_image0073.png',
#  './data/train/masks/positive/case_M_20181029094800_0U62368102981259_1_002_001-1_a4_ayy_image0004.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0173_flip_v.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0499_flip_h.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a20_ayy_image0007_flip_v.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a13_ayy_image0244.png',
#  './data/train/masks/positive/case_M_20181119111911_0U62363111914011_1_005_001-1_a8_ayy_image0072.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0548_flip_h.png',
#  './data/train/masks/positive/case_M_20181119111911_0U62363111914011_1_005_001-1_a12_ayy_image0407.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a17_ayy_image0067.png',
#  './data/train/masks/positive/case_M_20181030122608_0U62363103057807_1_002_003-1_a2_ayy_image0061.png',
#  './data/train/masks/positive/case_M_20181018093806_0U62363101890605_1_007_001-1_a1_ayy_image0087_flip_v.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a22_ayy_image0258.png',
#  './data/train/masks/positive/case_M_20181030122608_0U62363103057807_1_002_003-1_a4_ayy_image0025_rotate_180.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a13_ayy_image0280_flip_v.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0501_flip_h.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0106.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0455.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a23_ayy_image0106.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0939.png',
#  './data/train/masks/positive/case_M_20190111094523_0U62372011160922_1_004_002-1_a13_ayy_image0029.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a13_ayy_image0282.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a25_ayy_image0043_flip_v.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0098.png',
#  './data/train/masks/positive/case_M_20190107094528_0U62367010726528_1_002_001-1_a7_ayy_image0150_flip_v.png',
#  './data/train/masks/positive/case_M_20190115123306_0U62368011540606_1_002_001-1_a4_ayy_image0050.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0408_flip_v.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0817.png',
#  './data/train/masks/positive/case_M_20181019101517_0U62367101935917_1_003_001-1_a17_ayy_image0069_rotate_180.png',
#  './data/train/masks/positive/case_M_20190107094528_0U62367010726528_1_002_001-1_a7_ayy_image0010.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a23_ayy_image0118.png',
#  './data/train/masks/positive/case_M_20181211093229_0U62367121175028_1_004_001-1_a16_ayy_image0028_flip_h.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a22_ayy_image0109.png',
#  './data/train/masks/positive/case_M_20181019122218_0U62368101948418_1_002_001-1_a2_ayy_image0025.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a22_ayy_image0309_flip_h.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a3_ayy_image0046_flip_h.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a17_ayy_image0120_rotate_180.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0096.png',
#  './data/train/masks/positive/case_M_20190107094528_0U62367010726528_1_002_001-1_a7_ayy_image0118.png',
#  './data/train/masks/positive/case_M_20181025095048_0U62372102595347_1_004_001-1_a13_ayy_image0055.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a23_ayy_image0169.png',
#  './data/train/masks/positive/case_M_20181018093806_0U62363101890605_1_007_002-1_a12_ayy_image0012_flip_v.png',
#  './data/train/masks/positive/case_M_20190115123306_0U62368011540606_1_002_001-1_a4_ayy_image0028.png',
#  './data/train/masks/positive/case_M_20190121100011_0U62372012151511_1_006_002-1_a10_ayy_image0010_flip_h.png',
#  './data/train/masks/positive/case_M_20190121100011_0U62372012151511_1_006_002-1_a10_ayy_image0004.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a3_ayy_image0050.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a5_ayy_image0015.png',
#  './data/train/masks/positive/case_M_20181211093229_0U62367121175028_1_004_001-1_a8_ayy_image0039_flip_v.png',
#  './data/train/masks/positive/case_M_20181217131216_0U62368121700016_1_002_001-1_a6_ayy_image0264.png',
#  './data/train/masks/positive/case_M_20190110094509_0U62363011095308_1_001_002-1_a2_ayy_image0029.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0941_rotate_180.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0424.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a4_ayy_image0200.png',
#  './data/train/masks/positive/case_M_20181129152014_0U62366112981213_1_001_001-1_a25_ayy_image0100.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a22_ayy_image0357_rotate_180.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0507_rotate_180.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a13_ayy_image0339_rotate_180.png',
#  './data/train/masks/positive/case_M_20190107094528_0U62367010726528_1_002_001-1_a7_ayy_image0150.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0428.png',
#  './data/train/masks/positive/case_M_20190110094509_0U62363011095308_1_001_002-1_a2_ayy_image0051.png',
#  './data/train/masks/positive/case_M_20181017100226_0U62367101735926_1_001_002-1_a14_ayy_image0001.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0461_rotate_180.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a22_ayy_image0353.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a17_ayy_image0009.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0580.png',
#  './data/train/masks/positive/case_M_20190107094528_0U62367010726528_1_002_001-1_a7_ayy_image0108.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a22_ayy_image0105.png',
#  './data/train/masks/positive/case_M_20190117095926_0U62372011750026_1_002_001-1_a3_ayy_image0023.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0177.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a20_ayy_image0102_flip_v.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a17_ayy_image0099.png',
#  './data/train/masks/positive/case_M_20190110094509_0U62363011095308_1_001_001-1_a1_ayy_image0013.png',
#  './data/train/masks/positive/case_M_20181019122218_0U62368101948418_1_002_001-1_a4_ayy_image0075_rotate_270.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a23_ayy_image0159.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0191.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0499.png',
#  './data/train/masks/positive/case_M_20190115123306_0U62368011540606_1_002_001-1_a1_ayy_image0053.png',
#  './data/train/masks/positive/case_M_20190107094528_0U62367010726528_1_002_001-1_a7_ayy_image0037.png',
#  './data/train/masks/positive/case_M_20190117105747_0U62368011712547_1_002_001-1_a18_ayy_image0034.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0057_flip_h.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a20_ayy_image0068.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a17_ayy_image0053_flip_v.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0586_flip_v.png',
#  './data/train/masks/positive/case_M_20181218101803_0U62372121864002_1_001_001-1_a6_ayy_image0106.png',
#  './data/train/masks/positive/case_M_20190107094528_0U62367010726528_1_002_001-1_a7_ayy_image0008.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a13_ayy_image0183.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a17_ayy_image0025_flip_v.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a13_ayy_image0203_flip_h.png',
#  './data/train/masks/positive/case_M_20190117105747_0U62368011712547_1_002_001-1_a17_ayy_image0053.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a13_ayy_image0448.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a22_ayy_image0311_flip_h.png',
#  './data/train/masks/positive/case_M_20181018093806_0U62363101890605_1_007_002-1_a12_ayy_image0038.png',
#  './data/train/masks/positive/case_M_20181017100226_0U62367101735926_1_007_003-1_a2_ayy_image0103.png',
#  './data/train/masks/positive/case_M_20181119111911_0U62363111914011_1_005_001-1_a16_ayy_image0167.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a25_ayy_image0041_rotate_180.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0007.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0602.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0396_flip_v.png',
#  './data/train/masks/positive/case_M_20181019122218_0U62368101948418_1_002_001-1_a4_ayy_image0016_flip_h.png',
#  './data/train/masks/positive/case_M_20190110094509_0U62363011095308_1_001_001-1_a5_ayy_image0074.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a22_ayy_image0321_flip_h.png',
#  './data/train/masks/positive/case_M_20181017100226_0U62367101735926_1_001_002-1_a14_ayy_image0001_flip_h.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0809.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0394_rotate_180.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a23_ayy_image0090.png',
#  './data/train/masks/positive/case_M_20190107094528_0U62367010726528_1_002_001-1_a7_ayy_image0142.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0542_flip_h.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a17_ayy_image0099_rotate_180.png',
#  './data/train/masks/positive/case_M_20190110094509_0U62363011095308_1_001_001-1_a5_ayy_image0017.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a17_ayy_image0021_flip_v.png',
#  './data/train/masks/positive/case_M_20190121095240_0U62368012118740_1_005_001-1_a3_ayy_image0088.png',
#  './data/train/masks/positive/case_M_20181218101803_0U62372121864002_1_001_001-1_a6_ayy_image0108.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0112.png',
#  './data/train/masks/positive/case_M_20181018093806_0U62363101890605_1_007_001-1_a1_ayy_image0061_rotate_180.png',
#  './data/train/masks/positive/case_M_20190110094509_0U62363011095308_1_001_001-1_a5_ayy_image0047.png',
#  './data/train/masks/positive/case_M_20181019122218_0U62368101948418_1_002_001-1_a2_ayy_image0033.png',
#  './data/train/masks/positive/case_M_20181218101803_0U62372121864002_1_001_001-1_a4_ayy_image0061_flip_v.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a23_ayy_image0165.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a13_ayy_image0185_flip_h.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0059.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0430.png',
#  './data/train/masks/positive/case_M_20181218101803_0U62372121864002_1_001_001-1_a4_ayy_image0002.png',
#  './data/train/masks/positive/case_M_20190117095926_0U62372011750026_1_002_001-1_a3_ayy_image0013.png',
#  './data/train/masks/positive/case_M_20190117095926_0U62372011750026_1_002_001-1_a4_ayy_image0073_flip_h.png',
#  './data/train/masks/positive/case_M_20181029094800_0U62368102981259_1_002_001-1_a6_ayy_image0068.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a20_ayy_image0050_flip_h.png',
#  './data/train/masks/positive/case_M_20181105095958_0U62368110576557_1_003_002-1_a6_ayy_image0226.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a23_ayy_image0153.png',
#  './data/train/masks/positive/case_M_20190115123306_0U62368011540606_1_002_001-1_a3_ayy_image0089.png',
#  './data/train/masks/positive/case_M_20181017100226_0U62367101735926_1_007_003-1_a2_ayy_image0103_flip_v.png',
#  './data/train/masks/positive/case_M_20181019122218_0U62368101948418_1_002_001-1_a2_ayy_image0025_flip_h.png',
#  './data/train/masks/positive/case_M_20190115123306_0U62368011540606_1_002_001-1_a4_ayy_image0046_flip_v.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0801_flip_v.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0955_flip_h.png',
#  './data/train/masks/positive/case_M_20181018093806_0U62363101890605_1_007_001-1_a1_ayy_image0085.png',
#  './data/train/masks/positive/case_M_20181017100226_0U62367101735926_1_007_004-1_a6_ayy_image0297.png',
#  './data/train/masks/positive/case_M_20190121100011_0U62372012151511_1_006_003-1_a3_ayy_image0007_rotate_180.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a23_ayy_image0031.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a13_ayy_image0262.png',
#  './data/train/masks/positive/case_M_20181120115731_0U62368112064030_1_004_002-1_a16_ayy_image0031.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a20_ayy_image0113_flip_v.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a22_ayy_image0256_rotate_180.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a17_ayy_image0079.png',
#  './data/train/masks/positive/case_M_20190111094523_0U62372011160922_1_004_002-1_a13_ayy_image0072.png',
#  './data/train/masks/positive/case_M_20181019122218_0U62368101948418_1_002_001-1_a2_ayy_image0019.png',
#  './data/train/masks/positive/case_M_20190110094509_0U62363011095308_1_001_002-1_a1_ayy_image0009.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0848.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0513_flip_v.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a4_ayy_image0149_flip_h.png',
#  './data/train/masks/positive/case_M_20181018093806_0U62363101890605_1_007_002-1_a12_ayy_image0034_flip_v.png',
#  './data/train/masks/positive/case_M_20190117105747_0U62368011712547_1_002_001-1_a16_ayy_image0014.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0864.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0471_flip_v.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a4_ayy_image0164_flip_h.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image1012.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a4_ayy_image0176.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a20_ayy_image0125.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0430_flip_v.png',
#  './data/train/masks/positive/case_M_20181119111911_0U62363111914011_1_005_001-1_a13_ayy_image0014.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a22_ayy_image0327.png',
#  './data/train/masks/positive/case_M_20181029094800_0U62368102981259_1_002_001-1_a6_ayy_image0060_flip_v.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a22_ayy_image0317_flip_h.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a17_ayy_image0085.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a13_ayy_image0497.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a13_ayy_image0499.png',
#  './data/train/masks/positive/case_M_20190115123306_0U62368011540606_1_002_001-1_a3_ayy_image0039_flip_h.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a23_ayy_image0142.png',
#  './data/train/masks/positive/case_M_20190110094509_0U62363011095308_1_001_001-1_a5_ayy_image0080.png',
#  './data/train/masks/positive/case_M_20181218101803_0U62372121864002_1_001_001-1_a4_ayy_image0059.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0817_rotate_180.png',
#  './data/train/masks/positive/case_M_20181018093806_0U62363101890605_1_007_001-1_a1_ayy_image0067_flip_v.png',
#  './data/train/masks/positive/case_M_20181211093229_0U62367121175028_1_002_002-1_a9_ayy_image0025.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a3_ayy_image0143_flip_h.png',
#  './data/train/masks/positive/case_M_20181029094800_0U62368102981259_1_002_001-1_a6_ayy_image0058.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a20_ayy_image0115.png',
#  './data/train/masks/positive/case_M_20181031103335_0U62368103151535_1_006_001-1_a4_ayy_image0015_flip_h.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0840_flip_v.png',
#  './data/train/masks/positive/case_M_20181218101803_0U62372121864002_1_001_001-1_a8_ayy_image0006.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0507.png',
#  './data/train/masks/positive/case_M_20181218101803_0U62372121864002_1_001_001-1_a6_ayy_image0101_rotate_180.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a17_ayy_image0067_rotate_180.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a4_ayy_image0178_flip_v.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a3_ayy_image0143.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a17_ayy_image0063.png',
#  './data/train/masks/positive/case_M_20181030122608_0U62363103057807_1_002_003-1_a3_ayy_image0027.png',
#  './data/train/masks/positive/case_M_20190110094509_0U62363011095308_1_001_001-1_a5_ayy_image0009.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0965.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a22_ayy_image0309.png',
#  './data/train/masks/positive/case_M_20181030122608_0U62363103057807_1_002_003-1_a3_ayy_image0023.png',
#  './data/train/masks/positive/case_M_20190110094509_0U62363011095308_1_001_001-1_a5_ayy_image0084_flip_v.png',
#  './data/train/masks/positive/case_M_20190121100011_0U62372012151511_1_006_002-1_a12_ayy_image0008_flip_v.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0420.png',
#  './data/train/masks/positive/case_M_20181119111911_0U62363111914011_1_005_001-1_a13_ayy_image0036_rotate_180.png',
#  './data/train/masks/positive/case_M_20190115123306_0U62368011540606_1_002_001-1_a2_ayy_image0001_flip_v.png',
#  './data/train/masks/positive/case_M_20181105095958_0U62368110576557_1_003_002-1_a6_ayy_image0177_flip_h.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0957_flip_h.png',
#  './data/train/masks/positive/case_M_20190110094509_0U62363011095308_1_001_001-1_a5_ayy_image0003_flip_h.png',
#  './data/train/masks/positive/case_M_20181119111911_0U62363111914011_1_005_001-1_a13_ayy_image0036.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a4_ayy_image0151.png',
#  './data/train/masks/positive/case_M_20190110094509_0U62363011095308_1_001_002-1_a2_ayy_image0057.png',
#  './data/train/masks/positive/case_M_20181220100816_0U62368122007816_1_002_001-1_a6_ayy_image0135.png',
#  './data/train/masks/positive/case_M_20181019101517_0U62367101935917_1_003_001-1_a17_ayy_image0051.png',
#  './data/train/masks/positive/case_M_20181017100226_0U62367101735926_1_007_001-1_a12_ayy_image0052.png',
#  './data/train/masks/positive/case_M_20181119111911_0U62363111914011_1_005_001-1_a2_ayy_image0075.png',
#  './data/train/masks/positive/case_M_20190107094528_0U62367010726528_1_002_001-1_a7_ayy_image0140.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a17_ayy_image0114_flip_h.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0181.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0744.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a4_ayy_image0226.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a20_ayy_image0062_flip_v.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0122_flip_v.png',
#  './data/train/masks/positive/case_M_20181228140523_0U62365122821823_1_001_001-1_a3_ayy_image0134.png',
#  './data/train/masks/positive/case_M_20181211093229_0U62367121175028_1_002_002-1_a7_ayy_image0016_flip_h.png',
#  './data/train/masks/positive/case_M_20190115123306_0U62368011540606_1_002_001-1_a3_ayy_image0002_flip_h.png',
#  './data/train/masks/positive/case_M_20181018093806_0U62363101890605_1_007_001-1_a1_ayy_image0089.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a20_ayy_image0094.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0965_rotate_180.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a4_ayy_image0184_flip_v.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a3_ayy_image0054_rotate_180.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0171.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0503_flip_v.png',
#  './data/train/masks/positive/case_M_20181218101803_0U62372121864002_1_001_001-1_a5_ayy_image0008_rotate_180.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a25_ayy_image0041.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0390.png',
#  './data/train/masks/positive/case_M_20190110094509_0U62363011095308_1_001_001-1_a4_ayy_image0013_flip_v.png',
#  './data/train/masks/positive/case_M_20190115123306_0U62368011540606_1_002_001-1_a3_ayy_image0085_flip_h.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0746.png',
#  './data/train/masks/positive/case_M_20181207092523_0U62372120765622_1_005_001-1_a18_ayy_image0025_flip_v.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0728_flip_v.png',
#  './data/train/masks/positive/case_M_20181207092523_0U62372120765622_1_005_001-1_a15_ayy_image0224_flip_h.png',
#  './data/train/masks/positive/case_M_20190110094509_0U62363011095308_1_001_002-1_a1_ayy_image0033.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a22_ayy_image0307_flip_h.png',
#  './data/train/masks/positive/case_M_20190121095240_0U62368012118740_1_005_001-1_a3_ayy_image0088_rotate_180.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0408.png',
#  './data/train/masks/positive/case_M_20181019122218_0U62368101948418_1_002_001-1_a4_ayy_image0010_rotate_180.png',
#  './data/train/masks/positive/case_M_20181218101803_0U62372121864002_1_001_001-1_a3_ayy_image0018.png',
#  './data/train/masks/positive/case_M_20181211093229_0U62367121175028_1_004_001-1_a15_ayy_image0029_flip_h.png',
#  './data/train/masks/positive/case_M_20181019122218_0U62368101948418_1_002_001-1_a4_ayy_image0020.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a23_ayy_image0161.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0829_flip_h.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0065.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a25_ayy_image0014_flip_v.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0959_flip_v.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0929.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a4_ayy_image0166_flip_h.png',
#  './data/train/masks/positive/case_M_20190121100011_0U62372012151511_1_006_002-1_a12_ayy_image0001.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a13_ayy_image0292.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0600_flip_v.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0540.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a20_ayy_image0003_flip_v.png',
#  './data/train/masks/positive/case_M_20190110094509_0U62363011095308_1_001_002-1_a2_ayy_image0053_rotate_180.png',
#  './data/train/masks/positive/case_M_20190110094509_0U62363011095308_1_001_001-1_a5_ayy_image0001.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a17_ayy_image0053.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a23_ayy_image0096.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a13_ayy_image0337_flip_v.png',
#  './data/train/masks/positive/case_M_20190107094528_0U62367010726528_1_002_001-1_a7_ayy_image0136_rotate_180.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0740_rotate_180.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a4_ayy_image0234.png',
#  './data/train/masks/positive/case_M_20181018093806_0U62363101890605_1_007_002-1_a12_ayy_image0024_flip_v.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a20_ayy_image0052_flip_h.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0396.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0057.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a17_ayy_image0034.png',
#  './data/train/masks/positive/case_M_20190107094528_0U62367010726528_1_002_001-1_a7_ayy_image0166.png',
#  './data/train/masks/positive/case_M_20190109095638_0U62372010945338_1_003_001-1_a24_ayy_image0445.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0961.png',
#  './data/train/masks/positive/case_M_20181218101803_0U62372121864002_1_001_001-1_a5_ayy_image0008.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0850_flip_v.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a3_ayy_image0056.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0588_flip_v.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a23_ayy_image0021.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a17_ayy_image0040_rotate_90.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a20_ayy_image0092.png',
#  './data/train/masks/positive/case_M_20181119111911_0U62363111914011_1_005_001-1_a12_ayy_image0026.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a13_ayy_image0562.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a4_ayy_image0154.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a20_ayy_image0044.png',
#  './data/train/masks/positive/case_M_20181119111911_0U62363111914011_1_005_001-1_a16_ayy_image0167_flip_h.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0215_flip_v.png',
#  './data/train/masks/positive/case_M_20190110094509_0U62363011095308_1_001_002-1_a2_ayy_image0027_flip_h.png',
#  './data/train/masks/positive/case_M_20181017100226_0U62367101735926_1_007_001-1_a4_ayy_image0013.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a23_ayy_image0098.png',
#  './data/train/masks/positive/case_M_20181119111911_0U62363111914011_1_005_001-1_a12_ayy_image0026_flip_h.png',
#  './data/train/masks/positive/case_M_20181022094701_0U62368102271800_1_001_001-1_a10_ayy_image0039.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0981_rotate_180.png',
#  './data/train/masks/positive/case_M_20181018093806_0U62363101890605_1_007_001-1_a1_ayy_image0056_flip_v.png',
#  './data/train/masks/positive/case_M_20190110094509_0U62363011095308_1_001_001-1_a5_ayy_image0065_flip_h.png',
#  './data/train/masks/positive/case_M_20181029094800_0U62368102981259_1_002_001-1_a5_ayy_image0044_flip_v.png',
#  './data/train/masks/positive/case_M_20190110094509_0U62363011095308_1_001_001-1_a1_ayy_image0007.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a20_ayy_image0038_flip_v.png',
#  './data/train/masks/positive/case_M_20181129152014_0U62366112981213_1_001_001-1_a20_ayy_image0001.png',
#  './data/train/masks/positive/case_M_20190115123306_0U62368011540606_1_002_001-1_a3_ayy_image0095.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a17_ayy_image0045.png',
#  './data/train/masks/positive/case_M_20181018093806_0U62363101890605_1_007_002-1_a12_ayy_image0010.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a13_ayy_image0507_flip_h.png',
#  './data/train/masks/positive/case_M_20181218101803_0U62372121864002_1_001_001-1_a6_ayy_image0108_flip_h.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0894_flip_h.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0740.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0604.png',
#  './data/train/masks/positive/case_M_20181019122218_0U62368101948418_1_002_001-1_a4_ayy_image0014_rotate_180.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a22_ayy_image0109_flip_h.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a13_ayy_image0193_flip_v.png',
#  './data/train/masks/positive/case_M_20190110094509_0U62363011095308_1_001_001-1_a5_ayy_image0065.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a17_ayy_image0118_flip_v.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0491.png',
#  './data/train/masks/positive/case_M_20181019122218_0U62368101948418_1_002_001-1_a4_ayy_image0020_rotate_180.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0890_flip_h.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a4_ayy_image0016_flip_v.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a13_ayy_image0264.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a17_ayy_image0085_flip_v.png',
#  './data/train/masks/positive/case_M_20190110094509_0U62363011095308_1_001_002-1_a2_ayy_image0055_flip_v.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0892.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0856_flip_v.png',
#  './data/train/masks/positive/case_M_20181218101803_0U62372121864002_1_001_001-1_a6_ayy_image0037.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0815_flip_h.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0412.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a23_ayy_image0138.png',
#  './data/train/masks/positive/case_M_20181218101803_0U62372121864002_1_001_001-1_a6_ayy_image0097.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0116_rotate_180.png',
#  './data/train/masks/positive/case_M_20190117105747_0U62368011712547_1_002_001-1_a16_ayy_image0004.png',
#  './data/train/masks/positive/case_M_20190117105747_0U62368011712547_1_002_001-1_a18_ayy_image0036_flip_v.png',
#  './data/train/masks/positive/case_M_20181218101803_0U62372121864002_1_001_001-1_a6_ayy_image0033_flip_h.png',
#  './data/train/masks/positive/case_M_20181019122218_0U62368101948418_1_002_001-1_a2_ayy_image0027.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a23_ayy_image0175_flip_v.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0594.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0053.png',
#  './data/train/masks/positive/case_M_20181030122608_0U62363103057807_1_002_002-1_a2_ayy_image0007.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0065_flip_h.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a17_ayy_image0075.png',
#  './data/train/masks/positive/case_M_20181218101803_0U62372121864002_1_001_001-1_a6_ayy_image0112_flip_v.png',
#  './data/train/masks/positive/case_M_20190117105747_0U62368011712547_1_002_001-1_a16_ayy_image0016.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a23_ayy_image0134.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a20_ayy_image0009.png',
#  './data/train/masks/positive/case_M_20181207092523_0U62372120765622_1_005_001-1_a10_ayy_image0053_flip_h.png',
#  './data/train/masks/positive/case_M_20190110094509_0U62363011095308_1_001_002-1_a2_ayy_image0004.png',
#  './data/train/masks/positive/case_M_20190107094528_0U62367010726528_1_002_001-1_a7_ayy_image0039_flip_v.png',
#  './data/train/masks/positive/case_M_20190117105747_0U62368011712547_1_002_001-1_a18_ayy_image0056.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a20_ayy_image0040.png',
#  './data/train/masks/positive/case_M_20190110094509_0U62363011095308_1_001_002-1_a2_ayy_image0016.png',
#  './data/train/masks/positive/case_M_20190115123306_0U62368011540606_1_002_001-1_a3_ayy_image0024.png',
#  './data/train/masks/positive/case_M_20190121095240_0U62368012118740_1_004_001-1_a8_ayy_image0109_rotate_180.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0874.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a4_ayy_image0200_flip_v.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0844_rotate_180.png',
#  './data/train/masks/positive/case_M_20181218101803_0U62372121864002_1_001_001-1_a6_ayy_image0112.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0517_rotate_180.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a22_ayy_image0361.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a20_ayy_image0058.png',
#  './data/train/masks/positive/case_M_20181113100307_0U62372111373406_1_005_001-1_a14_ayy_image0015.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a17_ayy_image0067.png',
#  './data/train/masks/positive/case_M_20181030122608_0U62363103057807_1_002_003-1_a4_ayy_image0019.png',
#  './data/train/masks/positive/case_M_20190115123306_0U62368011540606_1_002_001-1_a3_ayy_image0008_flip_h.png',
#  './data/train/masks/positive/case_M_20190115123306_0U62368011540606_1_002_001-1_a4_ayy_image0044.png',
#  './data/train/masks/positive/case_M_20190110094509_0U62363011095308_1_001_002-1_a2_ayy_image0002.png',
# ...
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a22_ayy_image0264.png',
#  './data/train/masks/positive/case_M_20190117105747_0U62368011712547_1_002_001-1_a18_ayy_image0044.png',
#  './data/train/masks/positive/case_M_20181018093806_0U62363101890605_1_007_002-1_a12_ayy_image0040.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a22_ayy_image0297.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a13_ayy_image0292_rotate_180.png',
#  './data/train/masks/positive/case_M_20190115123306_0U62368011540606_1_002_001-1_a2_ayy_image0019.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0041.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0542.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a4_ayy_image0139_rotate_180.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a17_ayy_image0132.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0191_rotate_90.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image1018_flip_h.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0734.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0063_flip_h.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0825.png',
#  './data/train/masks/positive/case_M_20190107094528_0U62367010726528_1_002_001-1_a7_ayy_image0124.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a22_ayy_image0317.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0548.png',
#  './data/train/masks/positive/case_M_20190110094509_0U62363011095308_1_001_001-1_a5_ayy_image0080_rotate_270.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a17_ayy_image0055.png',
#  './data/train/masks/positive/case_M_20181030122608_0U62363103057807_1_002_003-1_a2_ayy_image0059.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a20_ayy_image0056.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0369_flip_v.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a23_ayy_image0126.png',
#  './data/train/masks/positive/case_M_20181018093806_0U62363101890605_1_007_001-1_a1_ayy_image0083_flip_v.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a17_ayy_image0116_flip_h.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0870.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a17_ayy_image0118.png',
#  './data/train/masks/positive/case_M_20181018093806_0U62363101890605_1_007_002-1_a12_ayy_image0046.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a20_ayy_image0001.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0005.png',
#  './data/train/masks/positive/case_M_20181218101803_0U62372121864002_1_001_001-1_a6_ayy_image0089.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0169_flip_v.png',
#  './data/train/masks/positive/case_M_20190115123306_0U62368011540606_1_002_001-1_a2_ayy_image0001.png',
#  './data/train/masks/positive/case_M_20190107094528_0U62367010726528_1_002_001-1_a7_ayy_image0154.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0059_flip_h.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a17_ayy_image0022.png',
#  './data/train/masks/positive/case_M_20181207092523_0U62372120765622_1_005_001-1_a10_ayy_image0053.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0096_flip_v.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0868_flip_v.png',
#  './data/train/masks/positive/case_M_20181025095048_0U62372102595347_1_004_001-1_a13_ayy_image0055_rotate_180.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0100.png',
#  './data/train/masks/positive/case_M_20190110094509_0U62363011095308_1_001_001-1_a5_ayy_image0037.png',
#  './data/train/masks/positive/case_M_20181018093806_0U62363101890605_1_007_001-1_a1_ayy_image0085_flip_h.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a23_ayy_image0023.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a20_ayy_image0117.png',
#  './data/train/masks/positive/case_M_20181218101803_0U62372121864002_1_001_001-1_a6_ayy_image0097_flip_v.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a22_ayy_image0353_rotate_270.png',
#  './data/train/masks/positive/case_M_20181031103335_0U62368103151535_1_006_001-1_a3_ayy_image0001.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a20_ayy_image0050.png',
#  './data/train/masks/positive/case_M_20190107094528_0U62367010726528_1_002_001-1_a7_ayy_image0156.png',
#  './data/train/masks/positive/case_M_20181018093806_0U62363101890605_1_007_002-1_a12_ayy_image0022.png',
#  './data/train/masks/positive/case_M_20181119111911_0U62363111914011_1_005_001-1_a4_ayy_image0048.png',
#  './data/train/masks/positive/case_M_20190110094509_0U62363011095308_1_001_002-1_a2_ayy_image0029_flip_h.png',
#  './data/train/masks/positive/case_M_20190115123306_0U62368011540606_1_002_001-1_a7_ayy_image0136.png',
#  './data/train/masks/positive/case_M_20190110094509_0U62363011095308_1_001_002-1_a3_ayy_image0022_flip_v.png',
#  './data/train/masks/positive/case_M_20190121095240_0U62368012118740_1_004_001-1_a1_ayy_image0160_flip_v.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0432.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a20_ayy_image0117_flip_v.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0055_flip_h.png',
#  './data/train/masks/positive/case_M_20181105095958_0U62368110576557_1_003_002-1_a6_ayy_image0307.png',
#  './data/train/masks/positive/case_M_20181218101803_0U62372121864002_1_001_001-1_a4_ayy_image0021.png',
#  './data/train/masks/positive/case_M_20181228140523_0U62365122821823_1_001_001-1_a4_ayy_image0006.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0203.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a20_ayy_image0058_rotate_180.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a4_ayy_image0178.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0908.png',
#  './data/train/masks/positive/case_M_20181018093806_0U62363101890605_1_007_002-1_a12_ayy_image0012.png',
#  './data/train/masks/positive/case_M_20181113100307_0U62372111373406_1_005_001-1_a14_ayy_image0011.png',
#  './data/train/masks/positive/case_M_20181018093806_0U62363101890605_1_007_002-1_a12_ayy_image0022_rotate_180.png',
#  './data/train/masks/positive/case_M_20181030122608_0U62363103057807_1_002_003-1_a4_ayy_image0017.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0580_flip_v.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0797.png',
#  './data/train/masks/positive/case_M_20181030122608_0U62363103057807_1_002_003-1_a2_ayy_image0055.png',
#  './data/train/masks/positive/case_M_20190115123306_0U62368011540606_1_002_001-1_a3_ayy_image0085.png',
#  './data/train/masks/positive/case_M_20190115123306_0U62368011540606_1_002_001-1_a4_ayy_image0007.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a20_ayy_image0111.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a20_ayy_image0078.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0975.png',
#  './data/train/masks/positive/case_M_20190115123306_0U62368011540606_1_002_001-1_a4_ayy_image0026.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a4_ayy_image0196.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0819_flip_h.png',
#  './data/train/masks/positive/case_M_20181119111911_0U62363111914011_1_005_001-1_a16_ayy_image0347_rotate_180.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a22_ayy_image0305_flip_h.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a22_ayy_image0335.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0868.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0876_flip_v.png',
#  './data/train/masks/positive/case_M_20181017100226_0U62367101735926_1_007_001-1_a12_ayy_image0058.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0856.png',
#  './data/train/masks/positive/case_M_20190117105747_0U62368011712547_1_002_001-1_a17_ayy_image0047_flip_v.png',
#  './data/train/masks/positive/case_M_20181218101803_0U62372121864002_1_001_001-1_a5_ayy_image0006_flip_h.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a13_ayy_image0564_rotate_180.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0979.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a4_ayy_image0166.png',
#  './data/train/masks/positive/case_M_20181218101803_0U62372121864002_1_001_001-1_a6_ayy_image0099.png',
#  './data/train/masks/positive/case_M_20181017100226_0U62367101735926_1_007_003-1_a9_ayy_image0034.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a4_ayy_image0016.png',
#  './data/train/masks/positive/case_M_20190107094528_0U62367010726528_1_002_001-1_a7_ayy_image0081.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a23_ayy_image0100.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a17_ayy_image0061_flip_v.png',
#  './data/train/masks/positive/case_M_20190107094528_0U62367010726528_1_002_001-1_a7_ayy_image0172.png',
#  './data/train/masks/positive/case_M_20181218101803_0U62372121864002_1_001_001-1_a6_ayy_image0089_flip_v.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a22_ayy_image0105_flip_v.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a23_ayy_image0112.png',
#  './data/train/masks/positive/case_M_20181017100226_0U62367101735926_1_007_004-1_a6_ayy_image0299.png',
#  './data/train/masks/positive/case_M_20190110094509_0U62363011095308_1_001_002-1_a3_ayy_image0032_flip_v.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0538_flip_h.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a25_ayy_image0035_flip_v.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a17_ayy_image0053_flip_v.png',
#  './data/train/masks/positive/case_M_20190115123306_0U62368011540606_1_002_001-1_a3_ayy_image0041.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a20_ayy_image0034.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a20_ayy_image0007.png',
#  './data/train/masks/positive/case_M_20181026100314_0U62363102665613_1_004_001-1_a8_ayy_image0036.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a4_ayy_image0164.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a20_ayy_image0072.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a13_ayy_image0260.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0452_rotate_180.png',
#  './data/train/masks/positive/case_M_20190121100011_0U62372012151511_1_006_002-1_a10_ayy_image0004_flip_h.png',
#  './data/train/masks/positive/case_M_20181211093229_0U62367121175028_1_004_001-1_a16_ayy_image0030.png',
#  './data/train/masks/positive/case_M_20181019122218_0U62368101948418_1_002_001-1_a2_ayy_image0033_flip_v.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0037_flip_h.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0975_flip_v.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0461.png',
#  './data/train/masks/positive/case_M_20181119111911_0U62363111914011_1_005_001-1_a12_ayy_image0206.png',
#  './data/train/masks/positive/case_M_20181019122218_0U62368101948418_1_002_001-1_a4_ayy_image0022.png',
#  './data/train/masks/positive/case_M_20181019122218_0U62368101948418_1_002_001-1_a4_ayy_image0018_rotate_180.png',
#  './data/train/masks/positive/case_M_20190117105747_0U62368011712547_1_002_001-1_a17_ayy_image0049.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a13_ayy_image0327_rotate_180.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0094_flip_v.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a22_ayy_image0215.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0440.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a4_ayy_image0206_flip_v.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a20_ayy_image0123_flip_v.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a17_ayy_image0042_flip_v.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0183_flip_v.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a22_ayy_image0305.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0039_flip_h.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0094.png',
#  './data/train/masks/positive/case_M_20190117105747_0U62368011712547_1_002_001-1_a18_ayy_image0054_flip_h.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a3_ayy_image0046.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a13_ayy_image0280.png',
#  './data/train/masks/positive/case_M_20181228140523_0U62365122821823_1_001_001-1_a4_ayy_image0002.png',
#  './data/train/masks/positive/case_M_20181119111911_0U62363111914011_1_005_001-1_a16_ayy_image0365.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0874_flip_h.png',
#  './data/train/masks/positive/case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0604_flip_v.png',
#  './data/train/masks/positive/case_M_20181119111911_0U62363111914011_1_005_001-1_a13_ayy_image0016.png',
#  './data/train/masks/positive/case_M_20181214095357_0U62368121473456_1_006_003-1_a20_ayy_image0102.png',
#  './data/train/masks/positive/case_M_20190115123306_0U62368011540606_1_002_001-1_a4_ayy_image0048_rotate_180.png',
#  ...]

# %%
data_processor.remove_most_abnormal(F_TRAIN_IMAGES_NEG, 1000)
# Out:
# ['case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005455.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005455_rotate_90.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005438_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005438.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005669.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008578.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008561.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008561_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005446.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005446_rotate_180.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008589.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008589_rotate_270.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008270_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008270.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008584.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009192.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image007782_rotate_180.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image007782.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008584_rotate_90.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007854.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008692.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008602.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008602_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005257.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008454_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008454.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005257_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008466.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008466_rotate_90.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image009522.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008596.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008444.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image007526_rotate_90.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008553_flip_v.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image007526.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004522.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008553.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004957_rotate_180.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004957.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008183_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008183.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009288.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009288_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008478.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008478_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image000151.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image007122.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image007122_flip_v.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image004420.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image004420_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006946.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008239.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006242.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006242_flip_h.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image007127.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009167.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007252.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image007127_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008483.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008483_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009275.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009275_rotate_270.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image003694.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image003694_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008282.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image004055_rotate_180.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009179.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009237.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image004055.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009270.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008203.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008203_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image007357.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009249.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009186.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image002805.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image002805_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006296.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009881_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004923.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009881.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image007357_rotate_270.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007701_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image010803.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008472.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008257.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image007817_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008472_flip_h.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_4_ayy_image000002.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_4_ayy_image000008.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009243.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007701.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009243_rotate_270.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image010210.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image003627.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007311.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008077_rotate_180.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009293.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008077.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image002686_rotate_180.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image010210_rotate_180.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image002686.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004177.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005996.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image004820_flip_v.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image007135.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image005892_rotate_180.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009174.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007311_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image011227.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image011227_flip_h.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image004426.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008765.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005468_rotate_90.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image005892.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image007817.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007849_flip_h.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image009757.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007849.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image009757_rotate_180.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image000838.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004931_rotate_90.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_4_ayy_image000002_rotate_180.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004931.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image009145.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009618.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009618_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005592_rotate_90.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008252.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005592.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image009145_rotate_90.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006192.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image001126_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009392.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009668.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image003706.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009392_flip_v.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image000838_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005887.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007411_rotate_270.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008288_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004455.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008231.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007411.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008288.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image010270_flip_h.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image009763_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image003627_flip_h.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image006263.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006960_rotate_270.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image001737.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006960.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image009763.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image003416.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image000694.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008231_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005699.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006397_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006095.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image011274.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image001923.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image000892_rotate_270.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006095_rotate_90.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006073.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image003786.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008159.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006397.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006073_rotate_90.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image001632.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image001831.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image001967.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image004820.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006392.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005468.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007010.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005881.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image003416_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image003404.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008225.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006059.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image007525.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image002832_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004986_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image010270.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004986.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007263.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image001521.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004417.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006059_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008225_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008218.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image003821.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007010_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006001.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004130.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image001485.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image002351_rotate_270.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image005566.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image001773.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image010575.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008218_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006001_rotate_90.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004455_flip_h.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image008317_rotate_180.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image002351.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image010575_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005005_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007423.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image000892.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image001126.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007263_rotate_180.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008488_rotate_90.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005005.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008488.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image007368.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image009487_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008196.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image001214.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image003184.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004647.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image002832.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image009487.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image002699.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006895.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image007458.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004647_rotate_270.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008196_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image007458_rotate_90.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008211.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image002699_rotate_90.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image000632.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image000761.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image001584.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005699_rotate_270.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008608.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image000209_flip_h.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image000209.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005150.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image004403.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006432.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image010536.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007663.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006432_rotate_180.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009975.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008881.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008608_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image010536_rotate_270.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009975_rotate_180.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image003786_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007663_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image001778.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004004.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008881_rotate_90.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image002174.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image007532.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image002720.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009613.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005252.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007418.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image003448_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004004_rotate_270.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image007532_rotate_270.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005044.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005252_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005323_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005323.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image002014_rotate_180.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image010719_rotate_270.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image010249.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007418_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image003653.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005074.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image002174_rotate_270.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image001783_rotate_90.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image010719.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image003360.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009231.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005852.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image010249_rotate_90.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004535.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008650.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004116.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005098_rotate_90.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007929.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image010413_flip_v.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image009816.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image010413.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image003448.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image001703.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007941.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008643.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image003779.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009968.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007947.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006986.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008858.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image000294.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image002940_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image003838_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008643_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005115.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image003360_rotate_270.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image001703_rotate_90.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009968_rotate_270.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005543.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006986_rotate_90.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image001995.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image000733.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006421_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image002940.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006421.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007947_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005098.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image003779_rotate_270.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image002643.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image011297.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004423.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008521_rotate_90.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004423_flip_h.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image007278.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006460.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image000850.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image003442.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image002014.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004444.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006109.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image011676.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006007.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image003792.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006980.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009214.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009263.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image001584_rotate_90.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005194.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image001619_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004123.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004937_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image000288.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006980_rotate_270.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image000850_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004444_rotate_180.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image003813_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005683.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004937.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image010341.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007059.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006019.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008052.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009840.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004123_flip_v.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image008375.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007588.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006109_rotate_90.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image003813.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006019_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image010341_rotate_90.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009162.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image003792_rotate_180.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image001138.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image000191.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004529_rotate_90.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005924.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image001138_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image007530_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image001905.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004529.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008863.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007327.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009815.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005907.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009203_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image000191_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009203.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007904.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image010005.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005511.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image007530.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009802.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image004267.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image003126.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image003769.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007005.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image010051.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007327_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009767.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image010199_rotate_270.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008245.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image010199.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image003126_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006012.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004428.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image000649.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image008317.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image011268.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009802_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image002817.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image007799.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005079.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009606.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image010051_rotate_270.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image002304.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008494.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007842.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007359.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image003769_rotate_90.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image000761_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008494_rotate_180.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image000688_flip_h.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image000688.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image010162.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image007775_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image007870.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image007775.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009385.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008101.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007359_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image000176.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image003743_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image007617.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image009317_rotate_90.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image007870_rotate_180.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005066.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image001783.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009932.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007904_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009606_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image002123.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004751.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image002444.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007400.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006738.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006805.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image001068_rotate_90.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009493.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008101_rotate_270.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004751_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009704.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image010990.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008431.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004661.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image010990_rotate_180.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008863_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009847.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image002444_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008431_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image002123_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009932_rotate_270.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004136.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image005860.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005066_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004917.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008723.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image002197_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008629.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006427.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image000270.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006738_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004700.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image002488.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image001910.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image010187_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004700_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image003545.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006117.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009704_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image003838.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image010187.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image008112.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image010582.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006744.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007333.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image006558.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image004486.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image003722.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004141.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006127.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image003688.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005846.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image011767.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image002150.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006800.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image002997_rotate_90.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007221.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image002652.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004618.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005167.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image003677.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007456.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image000637.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006260.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image002929.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image003615.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image010846.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image011448.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image008112_flip_v.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image010846_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image011459.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image001749.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008152.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image002460.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004017.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007146.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image008909_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006922.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007333_rotate_90.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004488.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005919.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image002929_rotate_180.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image004999.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image005297.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image001299.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006800_rotate_90.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image000221.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007345.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image010513.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008059.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image004238.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008046.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006626.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004653.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005919_flip_h.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image010513_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image002168.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image002440.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008735.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006857.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_3_ayy_image000173.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image002150_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007953_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007953.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image005619.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006788.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004488_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image003132.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image010491.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007860.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006744_rotate_180.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image004934.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005144_rotate_270.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007353.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008046_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005144.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005109.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007917.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006307_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004952.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image011697.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006795.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image010545.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image001119.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image011052.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004541.jpg',
# ...
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006618.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image001115_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image007699.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image010713_rotate_180.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image001698_rotate_90.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image004681.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image000749.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image003874.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009511_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image010057_rotate_90.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009955.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image004900_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005407.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008514.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image004900.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image008909.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image000749_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image010706.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008888.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image000727_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004011.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006157.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image003820.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007909.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004373.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004011_rotate_270.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image003613.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008893.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image001202.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005912_rotate_270.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005228.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image007699_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image011352.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008704.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image002241.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004286.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image008404.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005798.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image004431_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004516.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image010706_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004630.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image008118.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image000216.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image011168_rotate_270.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006084.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009400.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image004681_rotate_180.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007728_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007650.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004624.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image005415_rotate_270.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009564.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image004431.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image000721.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004580_rotate_90.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004630_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006648.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image001068.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008704_rotate_90.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image000191_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image010034.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006669.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004373_rotate_180.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009400_rotate_180.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008893_flip_h.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image000216_rotate_90.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image004603.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image010790.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004761.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image004070_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image006235.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008106.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image010034_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image003388.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004624_rotate_180.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004706_rotate_180.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009522.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image004940.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image003613_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image003999.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image000721_flip_v.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image000895.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image001709.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009950.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image007634.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007923.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image000332.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image000191.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image002247.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004568_rotate_90.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image001495.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image008558_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image000738_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009511.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004516_rotate_180.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image002704.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image002589.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image004603_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image000332_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008746.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image007623.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004568.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009564_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006157_rotate_180.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009499.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image001046.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image000060_rotate_180.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image011704.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009955_rotate_180.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005228_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image000738.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image008217.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image000920_flip_v.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image002589_rotate_180.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image008722.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image001717.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009950_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image002871.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009013.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006199_rotate_90.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image008176_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007030.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image000920.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image008903.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008514_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007909_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image003945.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009858_rotate_90.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005104.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009858.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image003805.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009733.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image000939.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009748.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image005778.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image011296.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image002704_rotate_90.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image008217_rotate_270.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image000060.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image002637_rotate_180.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image007512.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007193.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image001046_rotate_270.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image000074.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image010000.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image003112.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image005231.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006916.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008398.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008979_flip_v.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image008462.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image002637.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007193_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image000027.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009718.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image008176.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005989.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image010000_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006657.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image006018.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image001171.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006366.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image007256.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image002509.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image000074_rotate_270.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005407_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image006024.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004575.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image008903_rotate_180.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007884.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image002943.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009044.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008681.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007160.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008410.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006375.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image005321.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image008399.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image008844.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image008100.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005989_rotate_90.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image008100_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image007206.jpg']

# %% [markdown]
# ### analyze contrast

# %%
contrast_data = data_processor.analyze_contrast(F_TRAIN_IMAGES)

# %%
data_processor.visualize_contrast_analysis(contrast_data)

# %% [markdown]
# ### analyze color

# %%
color_data = data_processor.analyze_color(F_TRAIN)

# %%
data_processor.visualize_color_analysis(color_data)

# %% [markdown]
# ### merge other datasets

# %%
data_processor.crop_to_square(F_DATASETS)
data_processor.scale_images(F_DATASETS, (512, 512))
# Out:
# Square crop operation completed.
# Processed: 0, Skipped (already square): 5152, Errors: 0
# Scale operation completed.
# Processed: 0, Skipped (already at target resolution): 5152, Errors: 0
# {'processed': 0, 'errors': 0, 'skipped': 5152, 'total': 5152}

# %%
data_processor.copy_all_files(F_DATASET_1_IMAGES, F_TRAIN_IMAGES_POS)
data_processor.copy_all_files(F_DATASET_1_MASKS, F_TRAIN_MASKS_POS)
data_processor.copy_all_files(F_DATASET_2_IMAGES, F_TRAIN_IMAGES_POS)
data_processor.copy_all_files(F_DATASET_2_MASKS, F_TRAIN_MASKS_POS)
# Out:
# Copied: cvc_colodb_209.png
# Copied: cvc_colodb_085.png
# Copied: cvc_colodb_271.png
# Copied: cvc_colodb_016.png
# Copied: cvc_colodb_109.png
# Copied: cvc_colodb_328.png
# Copied: cvc_colodb_035.png
# Copied: cvc_colodb_137.png
# Copied: cvc_colodb_348.png
# Copied: cvc_colodb_105.png
# Copied: cvc_colodb_301.png
# Copied: cvc_colodb_296.png
# Copied: cvc_colodb_195.png
# Copied: cvc_colodb_136.png
# Copied: cvc_colodb_185.png
# Copied: cvc_colodb_249.png
# Copied: cvc_colodb_129.png
# Copied: cvc_colodb_134.png
# Copied: cvc_colodb_155.png
# Copied: cvc_colodb_361.png
# Copied: cvc_colodb_188.png
# Copied: cvc_colodb_261.png
# Copied: cvc_colodb_380.png
# Copied: cvc_colodb_378.png
# Copied: cvc_colodb_213.png
# Copied: cvc_colodb_236.png
# Copied: cvc_colodb_295.png
# Copied: cvc_colodb_170.png
# Copied: cvc_colodb_270.png
# Copied: cvc_colodb_115.png
# Copied: cvc_colodb_037.png
# Copied: cvc_colodb_138.png
# Copied: cvc_colodb_103.png
# Copied: cvc_colodb_174.png
# Copied: cvc_colodb_288.png
# Copied: cvc_colodb_244.png
# Copied: cvc_colodb_303.png
# Copied: cvc_colodb_044.png
# Copied: cvc_colodb_168.png
# Copied: cvc_colodb_315.png
# Copied: cvc_colodb_284.png
# Copied: cvc_colodb_078.png
# Copied: cvc_colodb_366.png
# Copied: cvc_colodb_239.png
# Copied: cvc_colodb_316.png
# Copied: cvc_colodb_241.png
# Copied: cvc_colodb_220.png
# Copied: cvc_colodb_052.png
# Copied: cvc_colodb_119.png
# Copied: cvc_colodb_277.png
# Copied: cvc_colodb_290.png
# Copied: cvc_colodb_238.png
# Copied: cvc_colodb_069.png
# Copied: cvc_colodb_107.png
# Copied: cvc_colodb_334.png
# Copied: cvc_colodb_257.png
# Copied: cvc_colodb_243.png
# Copied: cvc_colodb_071.png
# Copied: cvc_colodb_104.png
# Copied: cvc_colodb_293.png
# Copied: cvc_colodb_021.png
# Copied: cvc_colodb_008.png
# Copied: cvc_colodb_165.png
# Copied: cvc_colodb_130.png
# Copied: cvc_colodb_349.png
# Copied: cvc_colodb_066.png
# Copied: cvc_colodb_088.png
# Copied: cvc_colodb_237.png
# Copied: cvc_colodb_318.png
# Copied: cvc_colodb_101.png
# Copied: cvc_colodb_010.png
# Copied: cvc_colodb_337.png
# Copied: cvc_colodb_214.png
# Copied: cvc_colodb_029.png
# Copied: cvc_colodb_267.png
# Copied: cvc_colodb_033.png
# Copied: cvc_colodb_196.png
# Copied: cvc_colodb_004.png
# Copied: cvc_colodb_364.png
# Copied: cvc_colodb_169.png
# Copied: cvc_colodb_350.png
# Copied: cvc_colodb_003.png
# Copied: cvc_colodb_331.png
# Copied: cvc_colodb_246.png
# Copied: cvc_colodb_127.png
# Copied: cvc_colodb_094.png
# Copied: cvc_colodb_231.png
# Copied: cvc_colodb_111.png
# Copied: cvc_colodb_233.png
# Copied: cvc_colodb_074.png
# Copied: cvc_colodb_363.png
# Copied: cvc_colodb_025.png
# Copied: cvc_colodb_353.png
# Copied: cvc_colodb_225.png
# Copied: cvc_colodb_123.png
# Copied: cvc_colodb_122.png
# Copied: cvc_colodb_340.png
# Copied: cvc_colodb_212.png
# Copied: cvc_colodb_325.png
# Copied: cvc_colodb_019.png
# Copied: cvc_colodb_298.png
# Copied: cvc_colodb_163.png
# Copied: cvc_colodb_262.png
# Copied: cvc_colodb_319.png
# Copied: cvc_colodb_226.png
# Copied: cvc_colodb_254.png
# Copied: cvc_colodb_135.png
# Copied: cvc_colodb_002.png
# Copied: cvc_colodb_200.png
# Copied: cvc_colodb_042.png
# Copied: cvc_colodb_087.png
# Copied: cvc_colodb_346.png
# Copied: cvc_colodb_313.png
# Copied: cvc_colodb_222.png
# Copied: cvc_colodb_287.png
# Copied: cvc_colodb_018.png
# Copied: cvc_colodb_151.png
# Copied: cvc_colodb_305.png
# Copied: cvc_colodb_030.png
# Copied: cvc_colodb_167.png
# Copied: cvc_colodb_367.png
# Copied: cvc_colodb_064.png
# Copied: cvc_colodb_260.png
# Copied: cvc_colodb_056.png
# Copied: cvc_colodb_082.png
# Copied: cvc_colodb_055.png
# Copied: cvc_colodb_046.png
# Copied: cvc_colodb_374.png
# Copied: cvc_colodb_215.png
# Copied: cvc_colodb_076.png
# Copied: cvc_colodb_124.png
# Copied: cvc_colodb_199.png
# Copied: cvc_colodb_108.png
# Copied: cvc_colodb_152.png
# Copied: cvc_colodb_177.png
# Copied: cvc_colodb_278.png
# Copied: cvc_colodb_268.png
# Copied: cvc_colodb_113.png
# Copied: cvc_colodb_309.png
# Copied: cvc_colodb_060.png
# Copied: cvc_colodb_280.png
# Copied: cvc_colodb_343.png
# Copied: cvc_colodb_235.png
# Copied: cvc_colodb_009.png
# Copied: cvc_colodb_141.png
# Copied: cvc_colodb_015.png
# Copied: cvc_colodb_341.png
# Copied: cvc_colodb_001.png
# Copied: cvc_colodb_154.png
# Copied: cvc_colodb_354.png
# Copied: cvc_colodb_072.png
# Copied: cvc_colodb_142.png
# Copied: cvc_colodb_100.png
# Copied: cvc_colodb_344.png
# Copied: cvc_colodb_166.png
# Copied: cvc_colodb_373.png
# Copied: cvc_colodb_291.png
# Copied: cvc_colodb_045.png
# Copied: cvc_colodb_156.png
# Copied: cvc_colodb_007.png
# Copied: cvc_colodb_375.png
# Copied: cvc_colodb_186.png
# Copied: cvc_colodb_207.png
# Copied: cvc_colodb_312.png
# Copied: cvc_colodb_208.png
# Copied: cvc_colodb_024.png
# Copied: cvc_colodb_182.png
# Copied: cvc_colodb_321.png
# Copied: cvc_colodb_282.png
# Copied: cvc_colodb_121.png
# Copied: cvc_colodb_248.png
# Copied: cvc_colodb_125.png
# Copied: cvc_colodb_240.png
# Copied: cvc_colodb_034.png
# Copied: cvc_colodb_098.png
# Copied: cvc_colodb_192.png
# Copied: cvc_colodb_028.png
# Copied: cvc_colodb_114.png
# Copied: cvc_colodb_279.png
# Copied: cvc_colodb_255.png
# Copied: cvc_colodb_126.png
# Copied: cvc_colodb_038.png
# Copied: cvc_colodb_153.png
# Copied: cvc_colodb_117.png
# Copied: cvc_colodb_173.png
# Copied: cvc_colodb_203.png
# Copied: cvc_colodb_075.png
# Copied: cvc_colodb_379.png
# Copied: cvc_colodb_090.png
# Copied: cvc_colodb_320.png
# Copied: cvc_colodb_306.png
# Copied: cvc_colodb_221.png
# Copied: cvc_colodb_323.png
# Copied: cvc_colodb_326.png
# Copied: cvc_colodb_217.png
# Copied: cvc_colodb_258.png
# Copied: cvc_colodb_252.png
# Copied: cvc_colodb_253.png
# Copied: cvc_colodb_081.png
# Copied: cvc_colodb_362.png
# Copied: cvc_colodb_286.png
# Copied: cvc_colodb_146.png
# Copied: cvc_colodb_047.png
# Copied: cvc_colodb_178.png
# Copied: cvc_colodb_358.png
# Copied: cvc_colodb_333.png
# Copied: cvc_colodb_216.png
# Copied: cvc_colodb_219.png
# Copied: cvc_colodb_026.png
# Copied: cvc_colodb_230.png
# Copied: cvc_colodb_053.png
# Copied: cvc_colodb_317.png
# Copied: cvc_colodb_227.png
# Copied: cvc_colodb_250.png
# Copied: cvc_colodb_201.png
# Copied: cvc_colodb_158.png
# Copied: cvc_colodb_070.png
# Copied: cvc_colodb_357.png
# Copied: cvc_colodb_332.png
# Copied: cvc_colodb_187.png
# Copied: cvc_colodb_133.png
# Copied: cvc_colodb_194.png
# Copied: cvc_colodb_289.png
# Copied: cvc_colodb_339.png
# Copied: cvc_colodb_351.png
# Copied: cvc_colodb_096.png
# Copied: cvc_colodb_005.png
# Copied: cvc_colodb_068.png
# Copied: cvc_colodb_140.png
# Copied: cvc_colodb_264.png
# Copied: cvc_colodb_112.png
# Copied: cvc_colodb_281.png
# Copied: cvc_colodb_102.png
# Copied: cvc_colodb_131.png
# Copied: cvc_colodb_336.png
# Copied: cvc_colodb_049.png
# Copied: cvc_colodb_144.png
# Copied: cvc_colodb_180.png
# Copied: cvc_colodb_302.png
# Copied: cvc_colodb_110.png
# Copied: cvc_colodb_041.png
# Copied: cvc_colodb_308.png
# Copied: cvc_colodb_006.png
# Copied: cvc_colodb_245.png
# Copied: cvc_colodb_077.png
# Copied: cvc_colodb_116.png
# Copied: cvc_colodb_150.png
# Copied: cvc_colodb_198.png
# Copied: cvc_colodb_175.png
# Copied: cvc_colodb_234.png
# Copied: cvc_colodb_083.png
# Copied: cvc_colodb_330.png
# Copied: cvc_colodb_164.png
# Copied: cvc_colodb_228.png
# Copied: cvc_colodb_095.png
# Copied: cvc_colodb_269.png
# Copied: cvc_colodb_338.png
# Copied: cvc_colodb_062.png
# Copied: cvc_colodb_314.png
# Copied: cvc_colodb_294.png
# Copied: cvc_colodb_347.png
# Copied: cvc_colodb_171.png
# Copied: cvc_colodb_176.png
# Copied: cvc_colodb_039.png
# Copied: cvc_colodb_162.png
# Copied: cvc_colodb_086.png
# Copied: cvc_colodb_369.png
# Copied: cvc_colodb_292.png
# Copied: cvc_colodb_184.png
# Copied: cvc_colodb_365.png
# Copied: cvc_colodb_149.png
# Copied: cvc_colodb_067.png
# Copied: cvc_colodb_352.png
# Copied: cvc_colodb_335.png
# Copied: cvc_colodb_160.png
# Copied: cvc_colodb_193.png
# Copied: cvc_colodb_120.png
# Copied: cvc_colodb_092.png
# Copied: cvc_colodb_370.png
# Copied: cvc_colodb_172.png
# Copied: cvc_colodb_065.png
# Copied: cvc_colodb_059.png
# Copied: cvc_colodb_324.png
# Copied: cvc_colodb_118.png
# Copied: cvc_colodb_191.png
# Copied: cvc_colodb_297.png
# Copied: cvc_colodb_091.png
# Copied: cvc_colodb_224.png
# Copied: cvc_colodb_161.png
# Copied: cvc_colodb_050.png
# Copied: cvc_colodb_210.png
# Copied: cvc_colodb_179.png
# Copied: cvc_colodb_027.png
# Copied: cvc_colodb_311.png
# Copied: cvc_colodb_190.png
# Copied: cvc_colodb_054.png
# Copied: cvc_colodb_251.png
# Copied: cvc_colodb_159.png
# Copied: cvc_colodb_285.png
# Copied: cvc_colodb_063.png
# Copied: cvc_colodb_097.png
# Copied: cvc_colodb_371.png
# Copied: cvc_colodb_218.png
# Copied: cvc_colodb_036.png
# Copied: cvc_colodb_377.png
# Copied: cvc_colodb_048.png
# Copied: cvc_colodb_273.png
# Copied: cvc_colodb_084.png
# Copied: cvc_colodb_304.png
# Copied: cvc_colodb_265.png
# Copied: cvc_colodb_259.png
# Copied: cvc_colodb_283.png
# Copied: cvc_colodb_310.png
# Copied: cvc_colodb_022.png
# Copied: cvc_colodb_275.png
# Copied: cvc_colodb_014.png
# Copied: cvc_colodb_206.png
# Copied: cvc_colodb_148.png
# Copied: cvc_colodb_327.png
# Copied: cvc_colodb_205.png
# Copied: cvc_colodb_106.png
# Copied: cvc_colodb_093.png
# Copied: cvc_colodb_011.png
# Copied: cvc_colodb_211.png
# Copied: cvc_colodb_266.png
# Copied: cvc_colodb_359.png
# Copied: cvc_colodb_272.png
# Copied: cvc_colodb_329.png
# Copied: cvc_colodb_145.png
# Copied: cvc_colodb_197.png
# Copied: cvc_colodb_204.png
# Copied: cvc_colodb_360.png
# Copied: cvc_colodb_128.png
# Copied: cvc_colodb_372.png
# Copied: cvc_colodb_276.png
# Copied: cvc_colodb_183.png
# Copied: cvc_colodb_307.png
# Copied: cvc_colodb_356.png
# Copied: cvc_colodb_031.png
# Copied: cvc_colodb_051.png
# Copied: cvc_colodb_061.png
# Copied: cvc_colodb_147.png
# Copied: cvc_colodb_043.png
# Copied: cvc_colodb_013.png
# Copied: cvc_colodb_345.png
# Copied: cvc_colodb_202.png
# Copied: cvc_colodb_242.png
# Copied: cvc_colodb_012.png
# Copied: cvc_colodb_223.png
# Copied: cvc_colodb_376.png
# Copied: cvc_colodb_058.png
# Copied: cvc_colodb_040.png
# Copied: cvc_colodb_017.png
# Copied: cvc_colodb_079.png
# Copied: cvc_colodb_080.png
# Copied: cvc_colodb_368.png
# Copied: cvc_colodb_143.png
# Copied: cvc_colodb_342.png
# Copied: cvc_colodb_229.png
# Copied: cvc_colodb_020.png
# Copied: cvc_colodb_073.png
# Copied: cvc_colodb_300.png
# Copied: cvc_colodb_322.png
# Copied: cvc_colodb_099.png
# Copied: cvc_colodb_157.png
# Copied: cvc_colodb_232.png
# Copied: cvc_colodb_247.png
# Copied: cvc_colodb_181.png
# Copied: cvc_colodb_355.png
# Copied: cvc_colodb_189.png
# Copied: cvc_colodb_132.png
# Copied: cvc_colodb_263.png
# Copied: cvc_colodb_274.png
# Copied: cvc_colodb_139.png
# Copied: cvc_colodb_032.png
# Copied: cvc_colodb_299.png
# Copied: cvc_colodb_089.png
# Copied: cvc_colodb_256.png
# Copied: cvc_colodb_057.png
# Copied: cvc_colodb_023.png
# Copied: cvc_colodb_209.png
# Copied: cvc_colodb_085.png
# Copied: cvc_colodb_271.png
# Copied: cvc_colodb_016.png
# Copied: cvc_colodb_109.png
# Copied: cvc_colodb_328.png
# Copied: cvc_colodb_035.png
# Copied: cvc_colodb_137.png
# Copied: cvc_colodb_348.png
# Copied: cvc_colodb_105.png
# Copied: cvc_colodb_301.png
# Copied: cvc_colodb_296.png
# Copied: cvc_colodb_195.png
# Copied: cvc_colodb_136.png
# Copied: cvc_colodb_185.png
# Copied: cvc_colodb_249.png
# Copied: cvc_colodb_129.png
# Copied: cvc_colodb_134.png
# Copied: cvc_colodb_155.png
# Copied: cvc_colodb_361.png
# Copied: cvc_colodb_188.png
# Copied: cvc_colodb_261.png
# Copied: cvc_colodb_380.png
# Copied: cvc_colodb_378.png
# Copied: cvc_colodb_213.png
# Copied: cvc_colodb_236.png
# Copied: cvc_colodb_295.png
# Copied: cvc_colodb_170.png
# Copied: cvc_colodb_270.png
# Copied: cvc_colodb_115.png
# Copied: cvc_colodb_037.png
# Copied: cvc_colodb_138.png
# Copied: cvc_colodb_103.png
# Copied: cvc_colodb_174.png
# Copied: cvc_colodb_288.png
# Copied: cvc_colodb_244.png
# Copied: cvc_colodb_303.png
# Copied: cvc_colodb_044.png
# Copied: cvc_colodb_168.png
# Copied: cvc_colodb_315.png
# Copied: cvc_colodb_284.png
# Copied: cvc_colodb_078.png
# Copied: cvc_colodb_366.png
# Copied: cvc_colodb_239.png
# Copied: cvc_colodb_316.png
# Copied: cvc_colodb_241.png
# Copied: cvc_colodb_220.png
# Copied: cvc_colodb_052.png
# Copied: cvc_colodb_119.png
# Copied: cvc_colodb_277.png
# Copied: cvc_colodb_290.png
# Copied: cvc_colodb_238.png
# Copied: cvc_colodb_069.png
# Copied: cvc_colodb_107.png
# Copied: cvc_colodb_334.png
# Copied: cvc_colodb_257.png
# Copied: cvc_colodb_243.png
# Copied: cvc_colodb_071.png
# Copied: cvc_colodb_104.png
# Copied: cvc_colodb_293.png
# Copied: cvc_colodb_021.png
# Copied: cvc_colodb_008.png
# Copied: cvc_colodb_165.png
# Copied: cvc_colodb_130.png
# Copied: cvc_colodb_349.png
# Copied: cvc_colodb_066.png
# Copied: cvc_colodb_088.png
# Copied: cvc_colodb_237.png
# Copied: cvc_colodb_318.png
# Copied: cvc_colodb_101.png
# Copied: cvc_colodb_010.png
# Copied: cvc_colodb_337.png
# Copied: cvc_colodb_214.png
# Copied: cvc_colodb_029.png
# Copied: cvc_colodb_267.png
# Copied: cvc_colodb_033.png
# Copied: cvc_colodb_196.png
# Copied: cvc_colodb_004.png
# Copied: cvc_colodb_364.png
# Copied: cvc_colodb_169.png
# Copied: cvc_colodb_350.png
# Copied: cvc_colodb_003.png
# Copied: cvc_colodb_331.png
# Copied: cvc_colodb_246.png
# Copied: cvc_colodb_127.png
# Copied: cvc_colodb_094.png
# Copied: cvc_colodb_231.png
# Copied: cvc_colodb_111.png
# Copied: cvc_colodb_233.png
# Copied: cvc_colodb_074.png
# Copied: cvc_colodb_363.png
# Copied: cvc_colodb_025.png
# Copied: cvc_colodb_353.png
# Copied: cvc_colodb_225.png
# Copied: cvc_colodb_123.png
# Copied: cvc_colodb_122.png
# Copied: cvc_colodb_340.png
# Copied: cvc_colodb_212.png
# Copied: cvc_colodb_325.png
# Copied: cvc_colodb_019.png
# Copied: cvc_colodb_298.png
# Copied: cvc_colodb_163.png
# Copied: cvc_colodb_262.png
# Copied: cvc_colodb_319.png
# Copied: cvc_colodb_226.png
# Copied: cvc_colodb_254.png
# Copied: cvc_colodb_135.png
# Copied: cvc_colodb_002.png
# Copied: cvc_colodb_200.png
# Copied: cvc_colodb_042.png
# Copied: cvc_colodb_087.png
# Copied: cvc_colodb_346.png
# Copied: cvc_colodb_313.png
# Copied: cvc_colodb_222.png
# Copied: cvc_colodb_287.png
# Copied: cvc_colodb_018.png
# Copied: cvc_colodb_151.png
# Copied: cvc_colodb_305.png
# Copied: cvc_colodb_030.png
# Copied: cvc_colodb_167.png
# Copied: cvc_colodb_367.png
# Copied: cvc_colodb_064.png
# Copied: cvc_colodb_260.png
# Copied: cvc_colodb_056.png
# Copied: cvc_colodb_082.png
# Copied: cvc_colodb_055.png
# Copied: cvc_colodb_046.png
# Copied: cvc_colodb_374.png
# Copied: cvc_colodb_215.png
# Copied: cvc_colodb_076.png
# Copied: cvc_colodb_124.png
# Copied: cvc_colodb_199.png
# Copied: cvc_colodb_108.png
# Copied: cvc_colodb_152.png
# Copied: cvc_colodb_177.png
# Copied: cvc_colodb_278.png
# Copied: cvc_colodb_268.png
# Copied: cvc_colodb_113.png
# Copied: cvc_colodb_309.png
# Copied: cvc_colodb_060.png
# Copied: cvc_colodb_280.png
# Copied: cvc_colodb_343.png
# Copied: cvc_colodb_235.png
# Copied: cvc_colodb_009.png
# Copied: cvc_colodb_141.png
# Copied: cvc_colodb_015.png
# Copied: cvc_colodb_341.png
# Copied: cvc_colodb_001.png
# Copied: cvc_colodb_154.png
# Copied: cvc_colodb_354.png
# Copied: cvc_colodb_072.png
# Copied: cvc_colodb_142.png
# Copied: cvc_colodb_100.png
# Copied: cvc_colodb_344.png
# Copied: cvc_colodb_166.png
# Copied: cvc_colodb_373.png
# Copied: cvc_colodb_291.png
# Copied: cvc_colodb_045.png
# Copied: cvc_colodb_156.png
# Copied: cvc_colodb_007.png
# Copied: cvc_colodb_375.png
# Copied: cvc_colodb_186.png
# Copied: cvc_colodb_207.png
# Copied: cvc_colodb_312.png
# Copied: cvc_colodb_208.png
# Copied: cvc_colodb_024.png
# Copied: cvc_colodb_182.png
# Copied: cvc_colodb_321.png
# Copied: cvc_colodb_282.png
# Copied: cvc_colodb_121.png
# Copied: cvc_colodb_248.png
# Copied: cvc_colodb_125.png
# Copied: cvc_colodb_240.png
# Copied: cvc_colodb_034.png
# Copied: cvc_colodb_098.png
# Copied: cvc_colodb_192.png
# Copied: cvc_colodb_028.png
# Copied: cvc_colodb_114.png
# Copied: cvc_colodb_279.png
# Copied: cvc_colodb_255.png
# Copied: cvc_colodb_126.png
# Copied: cvc_colodb_038.png
# Copied: cvc_colodb_153.png
# Copied: cvc_colodb_117.png
# Copied: cvc_colodb_173.png
# Copied: cvc_colodb_203.png
# Copied: cvc_colodb_075.png
# Copied: cvc_colodb_379.png
# Copied: cvc_colodb_090.png
# Copied: cvc_colodb_320.png
# Copied: cvc_colodb_306.png
# Copied: cvc_colodb_221.png
# Copied: cvc_colodb_323.png
# Copied: cvc_colodb_326.png
# Copied: cvc_colodb_217.png
# Copied: cvc_colodb_258.png
# Copied: cvc_colodb_252.png
# Copied: cvc_colodb_253.png
# Copied: cvc_colodb_081.png
# Copied: cvc_colodb_362.png
# Copied: cvc_colodb_286.png
# Copied: cvc_colodb_146.png
# Copied: cvc_colodb_047.png
# Copied: cvc_colodb_178.png
# Copied: cvc_colodb_358.png
# Copied: cvc_colodb_333.png
# Copied: cvc_colodb_216.png
# Copied: cvc_colodb_219.png
# Copied: cvc_colodb_026.png
# Copied: cvc_colodb_230.png
# Copied: cvc_colodb_053.png
# Copied: cvc_colodb_317.png
# Copied: cvc_colodb_227.png
# Copied: cvc_colodb_250.png
# Copied: cvc_colodb_201.png
# Copied: cvc_colodb_158.png
# Copied: cvc_colodb_070.png
# Copied: cvc_colodb_357.png
# Copied: cvc_colodb_332.png
# Copied: cvc_colodb_187.png
# Copied: cvc_colodb_133.png
# Copied: cvc_colodb_194.png
# Copied: cvc_colodb_289.png
# Copied: cvc_colodb_339.png
# Copied: cvc_colodb_351.png
# Copied: cvc_colodb_096.png
# Copied: cvc_colodb_005.png
# Copied: cvc_colodb_068.png
# Copied: cvc_colodb_140.png
# Copied: cvc_colodb_264.png
# Copied: cvc_colodb_112.png
# Copied: cvc_colodb_281.png
# Copied: cvc_colodb_102.png
# Copied: cvc_colodb_131.png
# Copied: cvc_colodb_336.png
# Copied: cvc_colodb_049.png
# Copied: cvc_colodb_144.png
# Copied: cvc_colodb_180.png
# Copied: cvc_colodb_302.png
# Copied: cvc_colodb_110.png
# Copied: cvc_colodb_041.png
# Copied: cvc_colodb_308.png
# Copied: cvc_colodb_006.png
# Copied: cvc_colodb_245.png
# Copied: cvc_colodb_077.png
# Copied: cvc_colodb_116.png
# Copied: cvc_colodb_150.png
# Copied: cvc_colodb_198.png
# Copied: cvc_colodb_175.png
# Copied: cvc_colodb_234.png
# Copied: cvc_colodb_083.png
# Copied: cvc_colodb_330.png
# Copied: cvc_colodb_164.png
# Copied: cvc_colodb_228.png
# Copied: cvc_colodb_095.png
# Copied: cvc_colodb_269.png
# Copied: cvc_colodb_338.png
# Copied: cvc_colodb_062.png
# Copied: cvc_colodb_314.png
# Copied: cvc_colodb_294.png
# Copied: cvc_colodb_347.png
# Copied: cvc_colodb_171.png
# Copied: cvc_colodb_176.png
# Copied: cvc_colodb_039.png
# Copied: cvc_colodb_162.png
# Copied: cvc_colodb_086.png
# Copied: cvc_colodb_369.png
# Copied: cvc_colodb_292.png
# Copied: cvc_colodb_184.png
# Copied: cvc_colodb_365.png
# Copied: cvc_colodb_149.png
# Copied: cvc_colodb_067.png
# Copied: cvc_colodb_352.png
# Copied: cvc_colodb_335.png
# Copied: cvc_colodb_160.png
# Copied: cvc_colodb_193.png
# Copied: cvc_colodb_120.png
# Copied: cvc_colodb_092.png
# Copied: cvc_colodb_370.png
# Copied: cvc_colodb_172.png
# Copied: cvc_colodb_065.png
# Copied: cvc_colodb_059.png
# Copied: cvc_colodb_324.png
# Copied: cvc_colodb_118.png
# Copied: cvc_colodb_191.png
# Copied: cvc_colodb_297.png
# Copied: cvc_colodb_091.png
# Copied: cvc_colodb_224.png
# Copied: cvc_colodb_161.png
# Copied: cvc_colodb_050.png
# Copied: cvc_colodb_210.png
# Copied: cvc_colodb_179.png
# Copied: cvc_colodb_027.png
# Copied: cvc_colodb_311.png
# Copied: cvc_colodb_190.png
# Copied: cvc_colodb_054.png
# Copied: cvc_colodb_251.png
# Copied: cvc_colodb_159.png
# Copied: cvc_colodb_285.png
# Copied: cvc_colodb_063.png
# Copied: cvc_colodb_097.png
# Copied: cvc_colodb_371.png
# Copied: cvc_colodb_218.png
# Copied: cvc_colodb_036.png
# Copied: cvc_colodb_377.png
# Copied: cvc_colodb_048.png
# Copied: cvc_colodb_273.png
# Copied: cvc_colodb_084.png
# Copied: cvc_colodb_304.png
# Copied: cvc_colodb_265.png
# Copied: cvc_colodb_259.png
# Copied: cvc_colodb_283.png
# Copied: cvc_colodb_310.png
# Copied: cvc_colodb_022.png
# Copied: cvc_colodb_275.png
# Copied: cvc_colodb_014.png
# Copied: cvc_colodb_206.png
# Copied: cvc_colodb_148.png
# Copied: cvc_colodb_327.png
# Copied: cvc_colodb_205.png
# Copied: cvc_colodb_106.png
# Copied: cvc_colodb_093.png
# Copied: cvc_colodb_011.png
# Copied: cvc_colodb_211.png
# Copied: cvc_colodb_266.png
# Copied: cvc_colodb_359.png
# Copied: cvc_colodb_272.png
# Copied: cvc_colodb_329.png
# Copied: cvc_colodb_145.png
# Copied: cvc_colodb_197.png
# Copied: cvc_colodb_204.png
# Copied: cvc_colodb_360.png
# Copied: cvc_colodb_128.png
# Copied: cvc_colodb_372.png
# Copied: cvc_colodb_276.png
# Copied: cvc_colodb_183.png
# Copied: cvc_colodb_307.png
# Copied: cvc_colodb_356.png
# Copied: cvc_colodb_031.png
# Copied: cvc_colodb_051.png
# Copied: cvc_colodb_061.png
# Copied: cvc_colodb_147.png
# Copied: cvc_colodb_043.png
# Copied: cvc_colodb_013.png
# Copied: cvc_colodb_345.png
# Copied: cvc_colodb_202.png
# Copied: cvc_colodb_242.png
# Copied: cvc_colodb_012.png
# Copied: cvc_colodb_223.png
# Copied: cvc_colodb_376.png
# Copied: cvc_colodb_058.png
# Copied: cvc_colodb_040.png
# Copied: cvc_colodb_017.png
# Copied: cvc_colodb_079.png
# Copied: cvc_colodb_080.png
# Copied: cvc_colodb_368.png
# Copied: cvc_colodb_143.png
# Copied: cvc_colodb_342.png
# Copied: cvc_colodb_229.png
# Copied: cvc_colodb_020.png
# Copied: cvc_colodb_073.png
# Copied: cvc_colodb_300.png
# Copied: cvc_colodb_322.png
# Copied: cvc_colodb_099.png
# Copied: cvc_colodb_157.png
# Copied: cvc_colodb_232.png
# Copied: cvc_colodb_247.png
# Copied: cvc_colodb_181.png
# Copied: cvc_colodb_355.png
# Copied: cvc_colodb_189.png
# Copied: cvc_colodb_132.png
# Copied: cvc_colodb_263.png
# Copied: cvc_colodb_274.png
# Copied: cvc_colodb_139.png
# Copied: cvc_colodb_032.png
# Copied: cvc_colodb_299.png
# Copied: cvc_colodb_089.png
# Copied: cvc_colodb_256.png
# Copied: cvc_colodb_057.png
# Copied: cvc_colodb_023.png
# Copied: bkai_igh_021bab9fc7330398846f67b5df7cdf3f.jpeg
# Copied: bkai_igh_f04350ffd6984cbcc6d6bf62f215f0da.jpeg
# Copied: bkai_igh_7712a48e11d579d903c7d178f6ea0ad8.jpeg
# Copied: bkai_igh_19d9ae2a9833aa6b8232510939c091a7.jpeg
# Copied: bkai_igh_33408da4bcab47c3fb256f174ae992b9.jpeg
# Copied: bkai_igh_ccacf464aa36bf7c09a3bb0e5ca15941.jpeg
# Copied: bkai_igh_f2c6d40b3bbba8f6c704801b37705c1e.jpeg
# Copied: bkai_igh_4837f2a0f1536ad3f6a5664c1711b62f.jpeg
# Copied: bkai_igh_15334875343f27ebc5d92b9076135d76.jpeg
# Copied: bkai_igh_8841d318d1f625619d9ae2a9833aa6b8.jpeg
# Copied: bkai_igh_4a1e4062d81e095fdc7f720eff82f514.jpeg
# Copied: bkai_igh_fb256f174ae992b915a51625559c7e61.jpeg
# Copied: bkai_igh_86f6e366943c17f87cf12b41e5e9e504.jpeg
# Copied: bkai_igh_d81526eb91e2da9e6afaef7fdb2d45b2.jpeg
# Copied: bkai_igh_78a91391adc0bb223c4eaf3372eae567.jpeg
# Copied: bkai_igh_04ccdc265a0b0a1230b118fa8625605d.jpeg
# Copied: bkai_igh_af622c3b3e57249fe9959a80703003d2.jpeg
# Copied: bkai_igh_839a76eaf622c3b3e57249fe9959a807.jpeg
# Copied: bkai_igh_cc89c96ddca6ee1af35b65bd9ea42cfc.jpeg
# Copied: bkai_igh_03983064a3eb4d49033c03b0af70cc0f.jpeg
# Copied: bkai_igh_37f538abe9de67869ac66e565c5d4340.jpeg
# Copied: bkai_igh_15c88d81a4106de1bdb8f4c31cfc1c9d.jpeg
# Copied: bkai_igh_6c08a1d1ad8f2c5f72724e00d827b8bc.jpeg
# Copied: bkai_igh_db782ca0a994927d8d739c25f1ed7a64.jpeg
# Copied: bkai_igh_145a7d8d3b6c0ed754f28ca745212295.jpeg
# Copied: bkai_igh_9ac66e565c5d4340aa5f7804c34a359b.jpeg
# Copied: bkai_igh_b2b535797395305af926a6f23c5d6d5f.jpeg
# Copied: bkai_igh_cf1f4b331a412fc44655fb51f809d3dd.jpeg
# Copied: bkai_igh_0bbd4ce2a1405f7d507592b964b7955a.jpeg
# Copied: bkai_igh_e28799235026b3550534bca540e24f48.jpeg
# Copied: bkai_igh_0f1536ad3f6a5664c1711b62f15ec83b.jpeg
# Copied: bkai_igh_f1ec859759b7c8743c61a01e80947f9c.jpeg
# Copied: bkai_igh_74d6c748c41743c6c08a1d1ad8f2c5f7.jpeg
# Copied: bkai_igh_99fdc98376290081835cf877e004e8bf.jpeg
# Copied: bkai_igh_f55b0b4c4137c02accbfc1328f439a11.jpeg
# Copied: bkai_igh_0e1797c77826f9a7021bab9fc7330398.jpeg
# Copied: bkai_igh_b41e5e9e5040781d54ffd6a8ee924dbd.jpeg
# Copied: bkai_igh_047dc0cbb58aa032554b5eb4fcf0130a.jpeg
# Copied: bkai_igh_4be168d9510588bec07c38c5d07e6080.jpeg
# Copied: bkai_igh_f70cc0f6d32b726342865f6c240449ad.jpeg
# Copied: bkai_igh_40676289b3e732adb4c5d1580670d78b.jpeg
# Copied: bkai_igh_a0b0a1230b118fa8625605da2023387f.jpeg
# Copied: bkai_igh_caf386f6e366943c17f87cf12b41e5e9.jpeg
# Copied: bkai_igh_8d3b6c0ed754f28ca745212295dd5423.jpeg
# Copied: bkai_igh_f0625f608b4ce97629ab559b28f39a54.jpeg
# Copied: bkai_igh_23099dd2eedba39099848c4425bf33b9.jpeg
# Copied: bkai_igh_41680cab5509b367b7048eb17aeed141.jpeg
# Copied: bkai_igh_cbc04772d9e593b6be1ac29adbe86f03.jpeg
# Copied: bkai_igh_7f23de79be0dba1f3cf29dff2864e2d8.jpeg
# Copied: bkai_igh_fd7da881fe4727080cae6daedd989517.jpeg
# Copied: bkai_igh_9bbb402345d341253851bc866ebe4d18.jpeg
# Copied: bkai_igh_76d0bbd4ce2a1405f7d507592b964b79.jpeg
# Copied: bkai_igh_66e15c4d0e0a4ceed0afc48dbdf68c4e.jpeg
# Copied: bkai_igh_051fc90e85d064f787d4be168d951058.jpeg
# Copied: bkai_igh_af386f6e366943c17f87cf12b41e5e9e.jpeg
# Copied: bkai_igh_7f9b9d49e2f4ee17979870116d06046f.jpeg
# Copied: bkai_igh_fcfedb5eb2a0e4b50889d874c68c030b.jpeg
# Copied: bkai_igh_d066b37f538abe9de67869ac66e565c5.jpeg
# Copied: bkai_igh_bd80d0a4d5777bbe9ebe3853f4fadef8.jpeg
# Copied: bkai_igh_c8c2e5a64a8bd16f2523acfd87d330a5.jpeg
# Copied: bkai_igh_dbd7e6afd56ea7bc4ba26c86b345408c.jpeg
# Copied: bkai_igh_cfedb5eb2a0e4b50889d874c68c030b9.jpeg
# Copied: bkai_igh_c34a359bbb402345d341253851bc866e.jpeg
# Copied: bkai_igh_bca73d5379c7c851a508273160e13bac.jpeg
# Copied: bkai_igh_298e11bb07c70f3701ae6bcec5dd8e74.jpeg
# Copied: bkai_igh_23c4eaf3372eae567c94ea04c603f909.jpeg
# Copied: bkai_igh_fa54aa1b27918630bfd2a52829ab4e75.jpeg
# Copied: bkai_igh_269959350e7998934d417cb2eb1ef57a.jpeg
# Copied: bkai_igh_c7c851a508273160e13bac7541424475.jpeg
# Copied: bkai_igh_16d4ca6160127cd1d5ff99c267599fc4.jpeg
# Copied: bkai_igh_6953ad88e16d4ca6160127cd1d5ff99c.jpeg
# Copied: bkai_igh_9fbb63b28163a745959c03983064a3eb.jpeg
# Copied: bkai_igh_7918630bfd2a52829ab4e7568cb49a3c.jpeg
# Copied: bkai_igh_28f39a546f6eeb0a13b346f09286c94c.jpeg
# Copied: bkai_igh_9c990b4e2a6e51d077bad31c8c5f54ff.jpeg
# Copied: bkai_igh_3b0e4909384b57bb6a052600f1f93e95.jpeg
# Copied: bkai_igh_f55177a34fc01019eec999fd84e679b0.jpeg
# Copied: bkai_igh_886d1697f8af9b550c1bce23b1fdd80a.jpeg
# Copied: bkai_igh_c11d4f50e412144f0496b83ef461c2a3.jpeg
# Copied: bkai_igh_0ebce6347c491b37c8c2e5a64a8bd16f.jpeg
# Copied: bkai_igh_195f853af7f8a4df1ec859759b7c8743.jpeg
# Copied: bkai_igh_c10e2b0e33fa12bfcd6da15fc656702f.jpeg
# Copied: bkai_igh_03f909df7cd066b37f538abe9de67869.jpeg
# Copied: bkai_igh_543f0dc6b7268821d173263d7be7e12d.jpeg
# Copied: bkai_igh_b28f39a546f6eeb0a13b346f09286c94.jpeg
# Copied: bkai_igh_8379499640676289b3e732adb4c5d158.jpeg
# Copied: bkai_igh_a55aadaa77712a48e11d579d903c7d17.jpeg
# Copied: bkai_igh_87d4878a9bf8a6f4d4987ea3b4bae567.jpeg
# Copied: bkai_igh_e85d064f787d4be168d9510588bec07c.jpeg
# Copied: bkai_igh_7d4c9ac32dd04cf2a6a01668d0ceca24.jpeg
# Copied: bkai_igh_a0b47aa6b7b1fecb5579bf4a5ced589c.jpeg
# Copied: bkai_igh_1fd8bbf118acd7936140a2d5fc1443c4.jpeg
# Copied: bkai_igh_7ae8395e56a6d9ba9d45c3dbc695325d.jpeg
# Copied: bkai_igh_aa3657e4314fe384eb2ba3adfda6c189.jpeg
# Copied: bkai_igh_b672ab3492fc6239c86a73f97dd5277d.jpeg
# Copied: bkai_igh_535797395305af926a6f23c5d6d5f35f.jpeg
# Copied: bkai_igh_602b296cc5cfd263f1f90be287992350.jpeg
# Copied: bkai_igh_2f514f401ea0bd55b1393e2ef89424de.jpeg
# Copied: bkai_igh_d287a51b9298e11bb07c70f3701ae6bc.jpeg
# Copied: bkai_igh_833aa6b8232510939c091a7915c942b2.jpeg
# Copied: bkai_igh_774229fe1bce59ddf92e76900d229db6.jpeg
# Copied: bkai_igh_41a8490fd7df8e26031fbb5e52c41545.jpeg
# Copied: bkai_igh_4539ef2424a9218697283baa3657e431.jpeg
# Copied: bkai_igh_0317371a966bf4b3466463a3c64db170.jpeg
# Copied: bkai_igh_fb96d0815334875343f27ebc5d92b907.jpeg
# Copied: bkai_igh_fb51f809d3ddb54343665e7e177b15df.jpeg
# Copied: bkai_igh_ae567c94ea04c603f909df7cd066b37f.jpeg
# Copied: bkai_igh_16d06046f5d8dd18841d318d1f625619.jpeg
# Copied: bkai_igh_8ca0adabead1ae730831caf386f6e366.jpeg
# Copied: bkai_igh_b4ce97629ab559b28f39a546f6eeb0a1.jpeg
# Copied: bkai_igh_bbdc734839a76eaf622c3b3e57249fe9.jpeg
# Copied: bkai_igh_cfd263f1f90be28799235026b3550534.jpeg
# Copied: bkai_igh_305af926a6f23c5d6d5f35f66adf95b2.jpeg
# Copied: bkai_igh_dad260bfcb4443de3ef69f6db0340991.jpeg
# Copied: bkai_igh_cd9dd77aef5ef26a77ecc564cdc70626.jpeg
# Copied: bkai_igh_9ab4e7568cb49a3c530b99ec16e8b659.jpeg
# Copied: bkai_igh_af3866269959350e7998934d417cb2eb.jpeg
# Copied: bkai_igh_536ad3f6a5664c1711b62f15ec83b97b.jpeg
# Copied: bkai_igh_b79b6669075945dc8ec8f02000f9b6c9.jpeg
# Copied: bkai_igh_443de3ef69f6db034099130d98309817.jpeg
# Copied: bkai_igh_4b5dec33fd6aab9f0df70e20bccce75a.jpeg
# Copied: bkai_igh_565c5d4340aa5f7804c34a359bbb4023.jpeg
# Copied: bkai_igh_3297c819c908954bb13d3727c7e5e106.jpeg
# Copied: bkai_igh_9a1db782ca0a994927d8d739c25f1ed7.jpeg
# Copied: bkai_igh_54bf951276e3f404b79b6669075945dc.jpeg
# Copied: bkai_igh_00fd197cd955fa095f978455cef3593c.jpeg
# Copied: bkai_igh_4284d7a5b6b0449922d6157edc3d82df.jpeg
# Copied: bkai_igh_7395305af926a6f23c5d6d5f35f66adf.jpeg
# Copied: bkai_igh_abead1ae730831caf386f6e366943c17.jpeg
# Copied: bkai_igh_5a1d7a36ccf1225024da63fb9a76b926.jpeg
# Copied: bkai_igh_5ca159410b9fdbdd46f680afdd43725a.jpeg
# Copied: bkai_igh_0adabead1ae730831caf386f6e366943.jpeg
# Copied: bkai_igh_0bd55b1393e2ef89424de1556a26c8eb.jpeg
# Copied: bkai_igh_fea6923881bf04350ffd6984cbcc6d6b.jpeg
# Copied: bkai_igh_cb4443de3ef69f6db034099130d98309.jpeg
# Copied: bkai_igh_0aa5f7804c34a359bbb402345d341253.jpeg
# Copied: bkai_igh_60f2965341caf528ca0adabead1ae730.jpeg
# Copied: bkai_igh_ad1ae730831caf386f6e366943c17f87.jpeg
# Copied: bkai_igh_8f2c5f72724e00d827b8bcf15050fb9a.jpeg
# Copied: bkai_igh_74868eb60861ee1ff0b8a4f6b85d841f.jpeg
# Copied: bkai_igh_02345d341253851bc866ebe4d18d5401.jpeg
# Copied: bkai_igh_4a3eb4d49033c03b0af70cc0f6d32b72.jpeg
# Copied: bkai_igh_4ebafbd9871ca68e0d4bcbe0f5192e72.jpeg
# Copied: bkai_igh_2cbbcfa4baf3866269959350e7998934.jpeg
# Copied: bkai_igh_2829ab4e7568cb49a3c530b99ec16e8b.jpeg
# Copied: bkai_igh_36ccf1225024da63fb9a76b92633408d.jpeg
# Copied: bkai_igh_bb223c4eaf3372eae567c94ea04c603f.jpeg
# Copied: bkai_igh_bdfb928d788e4237a32841b23099dd2e.jpeg
# Copied: bkai_igh_b4ec3d46e602b296cc5cfd263f1f90be.jpeg
# Copied: bkai_igh_b6692e6be5e8f14e1e0ae936de314f2d.jpeg
# Copied: bkai_igh_f428c953248704ccdc265a0b0a1230b1.jpeg
# Copied: bkai_igh_26231002ec4a1fe748f3085f1ce88cbd.jpeg
# Copied: bkai_igh_b09d1fc6869d7b4193425b976973f13d.jpeg
# Copied: bkai_igh_984cbcc6d6bf62f215f0da4ad3a7ab8d.jpeg
# Copied: bkai_igh_9d9ae2a9833aa6b8232510939c091a79.jpeg
# Copied: bkai_igh_09817287a8aef566999467c2a48847ae.jpeg
# Copied: bkai_igh_7b8bcf15050fb9af0ef92846b60b1a38.jpeg
# Copied: bkai_igh_1fcf0625f608b4ce97629ab559b28f39.jpeg
# Copied: bkai_igh_926a6f23c5d6d5f35f66adf95b204727.jpeg
# Copied: bkai_igh_2be8379499640676289b3e732adb4c5d.jpeg
# Copied: bkai_igh_94abb47953b0e4909384b57bb6a05260.jpeg
# Copied: bkai_igh_7955a1d7a36ccf1225024da63fb9a76b.jpeg
# Copied: bkai_igh_6fb2b87fbbcfdfb3ea1dd1faa864b404.jpeg
# Copied: bkai_igh_6c6f4f219688c7e39b3608a3d372b89e.jpeg
# Copied: bkai_igh_7e6080779715c88d81a4106de1bdb8f4.jpeg
# Copied: bkai_igh_3b28163a745959c03983064a3eb4d490.jpeg
# Copied: bkai_igh_c466c16952b6692e6be5e8f14e1e0ae9.jpeg
# Copied: bkai_igh_954a51c9bf1440f929906d164fe7b83a.jpeg
# Copied: bkai_igh_76135d76d0bbd4ce2a1405f7d507592b.jpeg
# Copied: bkai_igh_5401f659532897255ce2dd4ae1b0f124.jpeg
# Copied: bkai_igh_608b4ce97629ab559b28f39a546f6eeb.jpeg
# Copied: bkai_igh_afbd9871ca68e0d4bcbe0f5192e72f65.jpeg
# Copied: bkai_igh_367f150f68fa7ee0ca748f990aeafa35.jpeg
# Copied: bkai_igh_0b47aa6b7b1fecb5579bf4a5ced589c4.jpeg
# Copied: bkai_igh_64a3eb4d49033c03b0af70cc0f6d32b7.jpeg
# Copied: bkai_igh_91adc0bb223c4eaf3372eae567c94ea0.jpeg
# Copied: bkai_igh_6c487ffa651b4774229fe1bce59ddf92.jpeg
# Copied: bkai_igh_d0815334875343f27ebc5d92b9076135.jpeg
# Copied: bkai_igh_d4f13ccf1f4b331a412fc44655fb51f8.jpeg
# Copied: bkai_igh_1f659532897255ce2dd4ae1b0f124dbc.jpeg
# Copied: bkai_igh_b6aa460a22abd004c33abf3ae2136cd9.jpeg
# Copied: bkai_igh_2da9e6afaef7fdb2d45b21960c94b0aa.jpeg
# Copied: bkai_igh_f759a3a33a0565586918cd5eb80e67c9.jpeg
# Copied: bkai_igh_697f8af9b550c1bce23b1fdd80af3fef.jpeg
# Copied: bkai_igh_88aa03c2820362736055807907941a84.jpeg
# Copied: bkai_igh_b37c8c2e5a64a8bd16f2523acfd87d33.jpeg
# Copied: bkai_igh_cd59f911f025ba0e3b6d0bf0b5633059.jpeg
# Copied: bkai_igh_66943c17f87cf12b41e5e9e5040781d5.jpeg
# Copied: bkai_igh_e11bb07c70f3701ae6bcec5dd8e74f18.jpeg
# Copied: bkai_igh_6900d229db65646d81526eb91e2da9e6.jpeg
# Copied: bkai_igh_e23b1fdd80af3feff05dec1eb3a70b14.jpeg
# Copied: bkai_igh_00d827b8bcf15050fb9af0ef92846b60.jpeg
# Copied: bkai_igh_771e7606cb09d1fc6869d7b4193425b9.jpeg
# Copied: bkai_igh_6aa73b7f23de79be0dba1f3cf29dff28.jpeg
# Copied: bkai_igh_fdcc58c9c990b4e2a6e51d077bad31c8.jpeg
# Copied: bkai_igh_ea1dd1faa864b404e18eeb228517f470.jpeg
# Copied: bkai_igh_c6869d7b4193425b976973f13dd311a6.jpeg
# Copied: bkai_igh_41545ba55aadaa77712a48e11d579d90.jpeg
# Copied: bkai_igh_63a987f428c953248704ccdc265a0b0a.jpeg
# Copied: bkai_igh_da43f71d4dc3ddad260bfcb4443de3ef.jpeg
# Copied: bkai_igh_11c4aa179344271fa54aa1b27918630b.jpeg
# Copied: bkai_igh_50c1bce23b1fdd80af3feff05dec1eb3.jpeg
# Copied: bkai_igh_ce15c1346e62522325c1b9c4fc9cbe1e.jpeg
# Copied: bkai_igh_117c6599c6dc55c83a46ce2be9800e6c.jpeg
# Copied: bkai_igh_8df9da738683543f0dc6b7268821d173.jpeg
# Copied: bkai_igh_02000f9b6c911c4aa179344271fa54aa.jpeg
# Copied: bkai_igh_ff0b8a4f6b85d841fcef620546518773.jpeg
# Copied: bkai_igh_b0af70cc0f6d32b726342865f6c24044.jpeg
# Copied: bkai_igh_01ff069910ea2abe3c84417fda801941.jpeg
# Copied: bkai_igh_65586918cd5eb80e67c9c8d5ce0c9495.jpeg
# Copied: bkai_igh_bf0b5633059989805234e222e19769fa.jpeg
# Copied: bkai_igh_a3adfda6c1899fdc98376290081835cf.jpeg
# Copied: bkai_igh_3b51209db6dcdda5cc8a788edaeb6aa4.jpeg
# Copied: bkai_igh_38aa0ef759a3a33a0565586918cd5eb8.jpeg
# Copied: bkai_igh_b57bb6a052600f1f93e952886d1697f8.jpeg
# Copied: bkai_igh_e2a1405f7d507592b964b7955a1d7a36.jpeg
# Copied: bkai_igh_c2820362736055807907941a8490fd7d.jpeg
# Copied: bkai_igh_5959c03983064a3eb4d49033c03b0af7.jpeg
# Copied: bkai_igh_076135d76d0bbd4ce2a1405f7d507592.jpeg
# Copied: bkai_igh_b7f23de79be0dba1f3cf29dff2864e2d.jpeg
# Copied: bkai_igh_337948a41964c1d4f50a5f3601ad4f13.jpeg
# Copied: bkai_igh_f489284b8e6953ad88e16d4ca6160127.jpeg
# Copied: bkai_igh_d7a64d0efccacf464aa36bf7c09a3bb0.jpeg
# Copied: bkai_igh_06cb09d1fc6869d7b4193425b976973f.jpeg
# Copied: bkai_igh_1c74143555dbf9c4ebafbd9871ca68e0.jpeg
# Copied: bkai_igh_25af63a987f428c953248704ccdc265a.jpeg
# Copied: bkai_igh_cf1225024da63fb9a76b92633408da4b.jpeg
# Copied: bkai_igh_c9d82404c5709ec7f1fc395e7c47889e.jpeg
# Copied: bkai_igh_da9e6afaef7fdb2d45b21960c94b0aab.jpeg
# Copied: bkai_igh_2bb3c7abacdbd7e6afd56ea7bc4ba26c.jpeg
# Copied: bkai_igh_2b4eebc9e5a87e443434ac60af15041b.jpeg
# Copied: bkai_igh_5b1393e2ef89424de1556a26c8eba4c1.jpeg
# Copied: bkai_igh_052600f1f93e952886d1697f8af9b550.jpeg
# Copied: bkai_igh_6c04414eaa922bca73d5379c7c851a50.jpeg
# Copied: bkai_igh_b60f2965341caf528ca0adabead1ae73.jpeg
# Copied: bkai_igh_9b99df08854bf951276e3f404b79b666.jpeg
# Copied: bkai_igh_c98376290081835cf877e004e8bfb905.jpeg
# Copied: bkai_igh_8a9bf8a6f4d4987ea3b4bae5672a2301.jpeg
# Copied: bkai_igh_a34fc01019eec999fd84e679b05f9a5e.jpeg
# Copied: bkai_igh_dff2864e2d89df283ecd59f911f025ba.jpeg
# Copied: bkai_igh_c6239c86a73f97dd5277dd17ba487d48.jpeg
# Copied: bkai_igh_6e9bd5f0d1fd8bbf118acd7936140a2d.jpeg
# Copied: bkai_igh_2345d341253851bc866ebe4d18d5401f.jpeg
# Copied: bkai_igh_33059989805234e222e19769fa2d37d3.jpeg
# Copied: bkai_igh_4a17af18f72c8e6166a915669c99390d.jpeg
# Copied: bkai_igh_0b9afea6923881bf04350ffd6984cbcc.jpeg
# Copied: bkai_igh_aa77712a48e11d579d903c7d178f6ea0.jpeg
# Copied: bkai_igh_38a1eecd70ebce6347c491b37c8c2e5a.jpeg
# Copied: bkai_igh_384eb2ba3adfda6c1899fdc983762900.jpeg
# Copied: bkai_igh_0e3b6d0bf0b5633059989805234e222e.jpeg
# Copied: bkai_igh_5b4c10e2b0e33fa12bfcd6da15fc6567.jpeg
# Copied: bkai_igh_c8c5f54ffaa27a623511c38948af83d1.jpeg
# Copied: bkai_igh_301ff069910ea2abe3c84417fda80194.jpeg
# Copied: bkai_igh_bb3c7abacdbd7e6afd56ea7bc4ba26c8.jpeg
# Copied: bkai_igh_b0e5ca159410b9fdbdd46f680afdd437.jpeg
# Copied: bkai_igh_e76900d229db65646d81526eb91e2da9.jpeg
# Copied: bkai_igh_c866ebe4d18d5401f659532897255ce2.jpeg
# Copied: bkai_igh_5fdc7f720eff82f514f401ea0bd55b13.jpeg
# Copied: bkai_igh_4fc58bdb26679bff55177a34fc01019e.jpeg
# Copied: bkai_igh_b7ad1cf2eb9d32a3dc907950289e976c.jpeg
# Copied: bkai_igh_d9510588bec07c38c5d07e6080779715.jpeg
# Copied: bkai_igh_865f6c240449ad43fe2cd066b9fdbc3b.jpeg
# Copied: bkai_igh_f7f63cd771e7606cb09d1fc6869d7b41.jpeg
# Copied: bkai_igh_19410b1fcf0625f608b4ce97629ab559.jpeg
# Copied: bkai_igh_ec1eb3a70b145a7d8d3b6c0ed754f28c.jpeg
# Copied: bkai_igh_a46ce2be9800e6c6f4f219688c7e39b3.jpeg
# Copied: bkai_igh_124dbc13ca0eaf044301ff069910ea2a.jpeg
# Copied: bkai_igh_3d5379c7c851a508273160e13bac7541.jpeg
# Copied: bkai_igh_1caf528ca0adabead1ae730831caf386.jpeg
# Copied: bkai_igh_acfd87d330a5a97b8eb5a9a8a8d7fcc9.jpeg
# Copied: bkai_igh_a95e926dde14f129dc9bac4af05b1c40.jpeg
# Copied: bkai_igh_910ea2abe3c84417fda8019410b1fcf0.jpeg
# Copied: bkai_igh_37705c1e555525d4f09ce7270bfec57e.jpeg
# Copied: bkai_igh_841d318d1f625619d9ae2a9833aa6b82.jpeg
# Copied: bkai_igh_24dbc13ca0eaf044301ff069910ea2ab.jpeg
# Copied: bkai_igh_7c38c5d07e6080779715c88d81a4106d.jpeg
# Copied: bkai_igh_a26c86b345408cc3736e216b08d23728.jpeg
# Copied: bkai_igh_342865f6c240449ad43fe2cd066b9fdb.jpeg
# Copied: bkai_igh_ce2a1405f7d507592b964b7955a1d7a3.jpeg
# Copied: bkai_igh_80779715c88d81a4106de1bdb8f4c31c.jpeg
# Copied: bkai_igh_44271fa54aa1b27918630bfd2a52829a.jpeg
# Copied: bkai_igh_695325ded465efde988dfb96d0815334.jpeg
# Copied: bkai_igh_c5f72724e00d827b8bcf15050fb9af0e.jpeg
# Copied: bkai_igh_c2a337948a41964c1d4f50a5f3601ad4.jpeg
# Copied: bkai_igh_72eae567c94ea04c603f909df7cd066b.jpeg
# Copied: bkai_igh_f809d3ddb54343665e7e177b15dfae76.jpeg
# Copied: bkai_igh_580670d78b9d054d694539ef2424a921.jpeg
# Copied: bkai_igh_bd70f618d52893a23c466c16952b6692.jpeg
# Copied: bkai_igh_5c3dbc695325ded465efde988dfb96d0.jpeg
# Copied: bkai_igh_da45ffe51330463d287a51b9298e11bb.jpeg
# Copied: bkai_igh_7dd17ba487d4878a9bf8a6f4d4987ea3.jpeg
# Copied: bkai_igh_5da2023387fd56c04414eaa922bca73d.jpeg
# Copied: bkai_igh_2a48e11d579d903c7d178f6ea0ad83b8.jpeg
# Copied: bkai_igh_57bb6a052600f1f93e952886d1697f8a.jpeg
# Copied: bkai_igh_ded465efde988dfb96d0815334875343.jpeg
# Copied: bkai_igh_b7955a1d7a36ccf1225024da63fb9a76.jpeg
# Copied: bkai_igh_3f6a5664c1711b62f15ec83b97bb11e8.jpeg
# Copied: bkai_igh_ff13a2da7be59a5529406ac1c91f53b8.jpeg
# Copied: bkai_igh_c1e555525d4f09ce7270bfec57e44168.jpeg
# Copied: bkai_igh_db4c5d1580670d78b9d054d694539ef2.jpeg
# Copied: bkai_igh_8c41743c6c08a1d1ad8f2c5f72724e00.jpeg
# Copied: bkai_igh_f970db3f998752a9fd5decebad6c688b.jpeg
# Copied: bkai_igh_b9d49e2f4ee17979870116d06046f5d8.jpeg
# Copied: bkai_igh_0528810e9d05be942fd5dd0902e0db22.jpeg
# Copied: bkai_igh_9424de1556a26c8eba4c1db1a0b47aa6.jpeg
# Copied: bkai_igh_c270866fd3c396490cf7bdbdb19b7afe.jpeg
# Copied: bkai_igh_2315b4c10e2b0e33fa12bfcd6da15fc6.jpeg
# Copied: bkai_igh_22af6b2da43f71d4dc3ddad260bfcb44.jpeg
# Copied: bkai_igh_07907941a8490fd7df8e26031fbb5e52.jpeg
# Copied: bkai_igh_15a51625559c7e610b1531871f2fd85a.jpeg
# Copied: bkai_igh_222e19769fa2d37d32780fd497e1c0e9.jpeg
# Copied: bkai_igh_61a01e80947f9c02314fc58bdb26679b.jpeg
# Copied: bkai_igh_b4c4137c02accbfc1328f439a117d3f8.jpeg
# Copied: bkai_igh_d4ae1b0f124dbc13ca0eaf044301ff06.jpeg
# Copied: bkai_igh_5646d81526eb91e2da9e6afaef7fdb2d.jpeg
# Copied: bkai_igh_e9127e9632a3c6f7f7fb2a643f15bd02.jpeg
# Copied: bkai_igh_a77ecc564cdc70626ab4ec3d46e602b2.jpeg
# Copied: bkai_igh_db034099130d98309817287a8aef5669.jpeg
# Copied: bkai_igh_db55759486b8aa1b8f79bd9d436e9bd5.jpeg
# Copied: bkai_igh_04c34a359bbb402345d341253851bc86.jpeg
# Copied: bkai_igh_95dd542315b4c10e2b0e33fa12bfcd6d.jpeg
# Copied: bkai_igh_04f234b701fc691ffa02f6068b683019.jpeg
# Copied: bkai_igh_11f025ba0e3b6d0bf0b5633059989805.jpeg
# Copied: bkai_igh_aa982e29fb841ad9698b3cb63f254f6b.jpeg
# Copied: bkai_igh_e29fb841ad9698b3cb63f254f6b90e3f.jpeg
# Copied: bkai_igh_1f3cf29dff2864e2d89df283ecd59f91.jpeg
# Copied: bkai_igh_230b118fa8625605da2023387fd56c04.jpeg
# Copied: bkai_igh_6000fdd3a3c17a94fd7da881fe472708.jpeg
# Copied: bkai_igh_6d06046f5d8dd18841d318d1f625619d.jpeg
# Copied: bkai_igh_21fbbec5a215f0f235a823d5349ab65a.jpeg
# Copied: bkai_igh_cdda5cc8a788edaeb6aa460a22abd004.jpeg
# Copied: bkai_igh_9fdc98376290081835cf877e004e8bfb.jpeg
# Copied: bkai_igh_947f9c02314fc58bdb26679bff55177a.jpeg
# Copied: bkai_igh_2780fd497e1c0e9082ea2c193ac8d551.jpeg
# Copied: bkai_igh_3f1f90be28799235026b3550534bca54.jpeg
# Copied: bkai_igh_0449ad43fe2cd066b9fdbc3bbc04a3af.jpeg
# Copied: bkai_igh_769fa2d37d32780fd497e1c0e9082ea2.jpeg
# Copied: bkai_igh_749a0d21db70dd094a7f32574d6c748c.jpeg
# Copied: bkai_igh_3b0af70cc0f6d32b726342865f6c2404.jpeg
# Copied: bkai_igh_f8a6f4d4987ea3b4bae5672a230194c5.jpeg
# Copied: bkai_igh_874c68c030b9afea6923881bf04350ff.jpeg
# Copied: bkai_igh_3a7b24423d5c7edd718176ef3065837c.jpeg
# Copied: bkai_igh_75945dc8ec8f02000f9b6c911c4aa179.jpeg
# Copied: bkai_igh_b51f809d3ddb54343665e7e177b15dfa.jpeg
# Copied: bkai_igh_bc13ca0eaf044301ff069910ea2abe3c.jpeg
# Copied: bkai_igh_0eaf044301ff069910ea2abe3c84417f.jpeg
# Copied: bkai_igh_33fa12bfcd6da15fc656702fa602bb3c.jpeg
# Copied: bkai_igh_f1f90be28799235026b3550534bca540.jpeg
# Copied: bkai_igh_9d054d694539ef2424a9218697283baa.jpeg
# Copied: bkai_igh_d351db40939d9a2f94285ef2a23f9dbb.jpeg
# Copied: bkai_igh_f02000f9b6c911c4aa179344271fa54a.jpeg
# Copied: bkai_igh_234e222e19769fa2d37d32780fd497e1.jpeg
# Copied: bkai_igh_65ddfd1518a2710d568df17586ad8f32.jpeg
# Copied: bkai_igh_17ba487d4878a9bf8a6f4d4987ea3b4b.jpeg
# Copied: bkai_igh_3983064a3eb4d49033c03b0af70cc0f6.jpeg
# Copied: bkai_igh_b96d0815334875343f27ebc5d92b9076.jpeg
# Copied: bkai_igh_424a9218697283baa3657e4314fe384e.jpeg
# Copied: bkai_igh_3fb9a76b92633408da4bcab47c3fb256.jpeg
# Copied: bkai_igh_4c34a359bbb402345d341253851bc866.jpeg
# Copied: bkai_igh_7f538abe9de67869ac66e565c5d4340a.jpeg
# Copied: bkai_igh_6999467c2a48847ae8395e56a6d9ba9d.jpeg
# Copied: bkai_igh_4ec3d46e602b296cc5cfd263f1f90be2.jpeg
# Copied: bkai_igh_25605da2023387fd56c04414eaa922bc.jpeg
# Copied: bkai_igh_a54aa1b27918630bfd2a52829ab4e756.jpeg
# Copied: bkai_igh_da881fe4727080cae6daedd989517cb8.jpeg
# Copied: bkai_igh_8aef566999467c2a48847ae8395e56a6.jpeg
# Copied: bkai_igh_7e4314fe384eb2ba3adfda6c1899fdc9.jpeg
# Copied: bkai_igh_152b672ab3492fc6239c86a73f97dd52.jpeg
# Copied: bkai_igh_5a793c4a1e4062d81e095fdc7f720eff.jpeg
# Copied: bkai_igh_be11d0309d1dff09b8405734fbeedd0f.jpeg
# Copied: bkai_igh_e20bccce75a793c4a1e4062d81e095fd.jpeg
# Copied: bkai_igh_465efde988dfb96d0815334875343f27.jpeg
# Copied: bkai_igh_79344271fa54aa1b27918630bfd2a528.jpeg
# Copied: bkai_igh_0fb9af0ef92846b60b1a38a1eecd70eb.jpeg
# Copied: bkai_igh_c748c41743c6c08a1d1ad8f2c5f72724.jpeg
# Copied: bkai_igh_835c525af63a987f428c953248704ccd.jpeg
# Copied: bkai_igh_80cab5509b367b7048eb17aeed141edb.jpeg
# Copied: bkai_igh_9f21b248d152b672ab3492fc6239c86a.jpeg
# Copied: bkai_igh_17f87cf12b41e5e9e5040781d54ffd6a.jpeg
# Copied: bkai_igh_3983ebff13a2da7be59a5529406ac1c9.jpeg
# Copied: bkai_igh_a1d1ad8f2c5f72724e00d827b8bcf150.jpeg
# Copied: bkai_igh_2abe3c84417fda8019410b1fcf0625f6.jpeg
# Copied: bkai_igh_4774229fe1bce59ddf92e76900d229db.jpeg
# Copied: bkai_igh_d7a36ccf1225024da63fb9a76b926334.jpeg
# Copied: bkai_igh_df283ecd59f911f025ba0e3b6d0bf0b5.jpeg
# Copied: bkai_igh_ac813fe3ccba3e032dd2948a80c64378.jpeg
# Copied: bkai_igh_6c688b8ec74baddc22268d4b4ef4d95c.jpeg
# Copied: bkai_igh_629ab559b28f39a546f6eeb0a13b346f.jpeg
# Copied: bkai_igh_081835cf877e004e8bfb905b78a91391.jpeg
# Copied: bkai_igh_7c8743c61a01e80947f9c02314fc58bd.jpeg
# Copied: bkai_igh_800c683ca4074c2f49c6f0fca6a4248a.jpeg
# Copied: bkai_igh_47c491b37c8c2e5a64a8bd16f2523acf.jpeg
# Copied: bkai_igh_40e24f489284b8e6953ad88e16d4ca61.jpeg
# Copied: bkai_igh_149398b798da48d679d7c7c8d3d96fb2.jpeg
# Copied: bkai_igh_9d45c3dbc695325ded465efde988dfb9.jpeg
# Copied: bkai_igh_c1899fdc98376290081835cf877e004e.jpeg
# Copied: bkai_igh_3881bf04350ffd6984cbcc6d6bf62f21.jpeg
# Copied: bkai_igh_099130d98309817287a8aef566999467.jpeg
# Copied: bkai_igh_d1fd8bbf118acd7936140a2d5fc1443c.jpeg
# Copied: bkai_igh_14fc58bdb26679bff55177a34fc01019.jpeg
# Copied: bkai_igh_eb2a0e4b50889d874c68c030b9afea69.jpeg
# Copied: bkai_igh_97f8af9b550c1bce23b1fdd80af3feff.jpeg
# Copied: bkai_igh_6b92633408da4bcab47c3fb256f174ae.jpeg
# Copied: bkai_igh_799235026b3550534bca540e24f48928.jpeg
# Copied: bkai_igh_1276e3f404b79b6669075945dc8ec8f0.jpeg
# Copied: bkai_igh_d37d32780fd497e1c0e9082ea2c193ac.jpeg
# Copied: bkai_igh_fd6984cbcc6d6bf62f215f0da4ad3a7a.jpeg
# Copied: bkai_igh_a8bd16f2523acfd87d330a5a97b8eb5a.jpeg
# Copied: bkai_igh_da63fb9a76b92633408da4bcab47c3fb.jpeg
# Copied: bkai_igh_53851bc866ebe4d18d5401f659532897.jpeg
# Copied: bkai_igh_13ccf1f4b331a412fc44655fb51f809d.jpeg
# Copied: bkai_igh_d8d3b6c0ed754f28ca745212295dd542.jpeg
# Copied: bkai_igh_0351267e98bd886544a2a98ee309ce76.jpeg
# Copied: bkai_igh_ad260bfcb4443de3ef69f6db03409913.jpeg
# Copied: bkai_igh_b204727fdcfa030228a69b99df08854b.jpeg
# Copied: bkai_igh_a412fc44655fb51f809d3ddb54343665.jpeg
# Copied: bkai_igh_bd9ea42cfcfedb5eb2a0e4b50889d874.jpeg
# Copied: bkai_igh_93c4a1e4062d81e095fdc7f720eff82f.jpeg
# Copied: bkai_igh_42315b4c10e2b0e33fa12bfcd6da15fc.jpeg
# Copied: bkai_igh_db70dd094a7f32574d6c748c41743c6c.jpeg
# Copied: bkai_igh_39099848c4425bf33b9b001c13a3d810.jpeg
# Copied: bkai_igh_4f4999a2e79fbc24ef8cde99f0444123.jpeg
# Copied: bkai_igh_38485beb48f0be11d0309d1dff09b840.jpeg
# Copied: bkai_igh_963e1713a8763b8318ecf467d7ad048d.jpeg
# Copied: bkai_igh_fc01019eec999fd84e679b05f9a5e1ac.jpeg
# Copied: bkai_igh_ad4f13ccf1f4b331a412fc44655fb51f.jpeg
# Copied: bkai_igh_d197cd955fa095f978455cef3593cef2.jpeg
# Copied: bkai_igh_3fb256f174ae992b915a51625559c7e6.jpeg
# Copied: bkai_igh_d1fc6869d7b4193425b976973f13dd31.jpeg
# Copied: bkai_igh_f29dff2864e2d89df283ecd59f911f02.jpeg
# Copied: bkai_igh_6df5630c2f4fc276ed9f178dc2f4af62.jpeg
# Copied: bkai_igh_a7ab8df9da738683543f0dc6b7268821.jpeg
# Copied: bkai_igh_2f94722af7f63cd771e7606cb09d1fc6.jpeg
# Copied: bkai_igh_dec33fd6aab9f0df70e20bccce75a793.jpeg
# Copied: bkai_igh_86a73f97dd5277dd17ba487d4878a9bf.jpeg
# Copied: bkai_igh_025ba0e3b6d0bf0b5633059989805234.jpeg
# Copied: bkai_igh_a9218697283baa3657e4314fe384eb2b.jpeg
# Copied: bkai_igh_dfda6c1899fdc98376290081835cf877.jpeg
# Copied: bkai_igh_509b367b7048eb17aeed141edb07bf21.jpeg
# Copied: bkai_igh_3c5d6d5f35f66adf95b204727fdcfa03.jpeg
# Copied: bkai_igh_59989805234e222e19769fa2d37d3278.jpeg
# Copied: bkai_igh_3b97bb11e8e0c4416c1931960ff3574f.jpeg
# Copied: bkai_igh_ceea11957998906d3694abb47953b0e4.jpeg
# Copied: bkai_igh_d771e7606cb09d1fc6869d7b4193425b.jpeg
# Copied: bkai_igh_f3cf29dff2864e2d89df283ecd59f911.jpeg
# Copied: bkai_igh_eaa922bca73d5379c7c851a508273160.jpeg
# Copied: bkai_igh_84eb2ba3adfda6c1899fdc9837629008.jpeg
# Copied: bkai_igh_39d9a2f94285ef2a23f9dbbb7bb39ba2.jpeg
# Copied: bkai_igh_284b8e6953ad88e16d4ca6160127cd1d.jpeg
# Copied: bkai_igh_1b9298e11bb07c70f3701ae6bcec5dd8.jpeg
# Copied: bkai_igh_d92b9076135d76d0bbd4ce2a1405f7d5.jpeg
# Copied: bkai_igh_c2f4af626650908b1cb932a767bf5487.jpeg
# Copied: bkai_igh_d054d694539ef2424a9218697283baa3.jpeg
# Copied: bkai_igh_ac8d551c149b60f2965341caf528ca0a.jpeg
# Copied: bkai_igh_a032554b5eb4fcf0130a76ba2ea3ad77.jpeg
# Copied: bkai_igh_9b6c911c4aa179344271fa54aa1b2791.jpeg
# Copied: bkai_igh_23387fd56c04414eaa922bca73d5379c.jpeg
# Copied: bkai_igh_90be28799235026b3550534bca540e24.jpeg
# Copied: bkai_igh_2a23f9dbbb7bb39ba25b3887ffdc8d09.jpeg
# Copied: bkai_igh_3f909df7cd066b37f538abe9de67869a.jpeg
# Copied: bkai_igh_b5eda45ffe51330463d287a51b9298e1.jpeg
# Copied: bkai_igh_bc866ebe4d18d5401f659532897255ce.jpeg
# Copied: bkai_igh_64c1d4f50a5f3601ad4f13ccf1f4b331.jpeg
# Copied: bkai_igh_e4d18d5401f659532897255ce2dd4ae1.jpeg
# Copied: bkai_igh_ba3137327e936a4fa0fbb89bdd490629.jpeg
# Copied: bkai_igh_10a38713b2aa6ce8d1cf6644589e532a.jpeg
# Copied: bkai_igh_9c7c851a508273160e13bac754142447.jpeg
# Copied: bkai_igh_46d0a6085835c525af63a987f428c953.jpeg
# Copied: bkai_igh_30831caf386f6e366943c17f87cf12b4.jpeg
# Copied: bkai_igh_d507592b964b7955a1d7a36ccf122502.jpeg
# Copied: bkai_igh_276e3f404b79b6669075945dc8ec8f02.jpeg
# Copied: bkai_igh_0449922d6157edc3d82df22c41b503dc.jpeg
# Copied: bkai_igh_83ecd59f911f025ba0e3b6d0bf0b5633.jpeg
# Copied: bkai_igh_4c31cfc1c9d33f3a7b24423d5c7edd71.jpeg
# Copied: bkai_igh_59ba2bbb610fe8c30d660e70f44c2b89.jpeg
# Copied: bkai_igh_f12b41e5e9e5040781d54ffd6a8ee924.jpeg
# Copied: bkai_igh_309817287a8aef566999467c2a48847a.jpeg
# Copied: bkai_igh_34e222e19769fa2d37d32780fd497e1c.jpeg
# Copied: bkai_igh_77826f9a7021bab9fc7330398846f67b.jpeg
# Copied: bkai_igh_3725a8bbcc89c96ddca6ee1af35b65bd.jpeg
# Copied: bkai_igh_7953b0e4909384b57bb6a052600f1f93.jpeg
# Copied: bkai_igh_489284b8e6953ad88e16d4ca6160127c.jpeg
# Copied: bkai_igh_75a793c4a1e4062d81e095fdc7f720ef.jpeg
# Copied: bkai_igh_5d52941e2705bf4d2ccdc92fcae40458.jpeg
# Copied: bkai_igh_606cb09d1fc6869d7b4193425b976973.jpeg
# Copied: bkai_igh_fe51330463d287a51b9298e11bb07c70.jpeg
# Copied: bkai_igh_9b28f39a546f6eeb0a13b346f09286c9.jpeg
# Copied: bkai_igh_7915c942b2f94722af7f63cd771e7606.jpeg
# Copied: bkai_igh_09384b57bb6a052600f1f93e952886d1.jpeg
# Copied: bkai_igh_aef5ef26a77ecc564cdc70626ab4ec3d.jpeg
# Copied: bkai_igh_68f9d4c331587f9b9d49e2f4ee179798.jpeg
# Copied: bkai_igh_0a1230b118fa8625605da2023387fd56.jpeg
# Copied: bkai_igh_5af63a987f428c953248704ccdc265a0.jpeg
# Copied: bkai_igh_683543f0dc6b7268821d173263d7be7e.jpeg
# Copied: bkai_igh_467e5cbc04772d9e593b6be1ac29adbe.jpeg
# Copied: bkai_igh_c4c65193c5141a869d6643c270866fd3.jpeg
# Copied: bkai_igh_43c61a01e80947f9c02314fc58bdb266.jpeg
# Copied: bkai_igh_52a9fd5decebad6c688b8ec74baddc22.jpeg
# Copied: bkai_igh_b145a7d8d3b6c0ed754f28ca74521229.jpeg
# ...
# Copied: bkai_igh_ef3065837ced5c7e06678d2a72ddff0b.jpeg
# Copied: bkai_igh_33aa6b8232510939c091a7915c942b2f.jpeg
# Copied: bkai_igh_93a23c466c16952b6692e6be5e8f14e1.jpeg
# Copied: bkai_igh_31871f2fd85a04faeeb2b53579739530.jpeg
# Copied: bkai_igh_cd771e7606cb09d1fc6869d7b4193425.jpeg
# Copied: bkai_igh_60b1a38a1eecd70ebce6347c491b37c8.jpeg
# Copied: bkai_igh_56ea7bc4ba26c86b345408cc3736e216.jpeg
# Copied: bkai_igh_ed351db40939d9a2f94285ef2a23f9db.jpeg
# Copied: bkai_igh_f3372eae567c94ea04c603f909df7cd0.jpeg
# Copied: bkai_igh_532897255ce2dd4ae1b0f124dbc13ca0.jpeg
# Copied: bkai_igh_72f65ddfd1518a2710d568df17586ad8.jpeg
# Copied: bkai_igh_99130d98309817287a8aef566999467c.jpeg
# Copied: bkai_igh_0a6085835c525af63a987f428c953248.jpeg
# Copied: bkai_igh_df08854bf951276e3f404b79b6669075.jpeg
# Copied: bkai_igh_7e6afd56ea7bc4ba26c86b345408cc37.jpeg
# Copied: bkai_igh_1ffb963e1713a8763b8318ecf467d7ad.jpeg
# Copied: bkai_igh_f608b4ce97629ab559b28f39a546f6ee.jpeg
# Copied: bkai_igh_8b2be8379499640676289b3e732adb4c.jpeg
# Copied: bkai_igh_f622c3b3e57249fe9959a80703003d2c.jpeg
# Copied: bkai_igh_cc564cdc70626ab4ec3d46e602b296cc.jpeg
# Copied: bkai_igh_1a65d2b46d0a6085835c525af63a987f.jpeg
# Copied: bkai_igh_d152b672ab3492fc6239c86a73f97dd5.jpeg
# Copied: bkai_igh_3b8cac03290f1b976b7a7efc10b1300c.jpeg
# Copied: bkai_igh_5605da2023387fd56c04414eaa922bca.jpeg
# Copied: bkai_igh_a4df1ec859759b7c8743c61a01e80947.jpeg
# Copied: bkai_igh_afdd43725a8bbcc89c96ddca6ee1af35.jpeg
# Copied: bkai_igh_a0a994927d8d739c25f1ed7a64d0efcc.jpeg
# Copied: bkai_igh_a65d2b46d0a6085835c525af63a987f4.jpeg
# Copied: bkai_igh_925eb8e72a8438aa0ef759a3a33a0565.jpeg
# Copied: bkai_igh_dd989517cb8041ed86e58224cb76a67d.jpeg
# Copied: bkai_igh_e2ef89424de1556a26c8eba4c1db1a0b.jpeg
# Copied: bkai_igh_eb91e2da9e6afaef7fdb2d45b21960c9.jpeg
# Copied: bkai_igh_033c03b0af70cc0f6d32b726342865f6.jpeg
# Copied: bkai_igh_9350e7998934d417cb2eb1ef57af2ed9.jpeg
# Copied: bkai_igh_18fa8625605da2023387fd56c04414ea.jpeg
# Copied: bkai_igh_5050fb9af0ef92846b60b1a38a1eecd7.jpeg
# Copied: bkai_igh_2fa602bb3c7abacdbd7e6afd56ea7bc4.jpeg
# Copied: bkai_igh_dda5cc8a788edaeb6aa460a22abd004c.jpeg
# Copied: bkai_igh_d8dd18841d318d1f625619d9ae2a9833.jpeg
# Copied: bkai_igh_50ffd6984cbcc6d6bf62f215f0da4ad3.jpeg
# Copied: bkai_igh_09df7cd066b37f538abe9de67869ac66.jpeg
# Copied: bkai_igh_aa27a623511c38948af83d1d25aa3966.jpeg
# Copied: bkai_igh_8a1eecd70ebce6347c491b37c8c2e5a6.jpeg
# Copied: bkai_igh_e1b0f124dbc13ca0eaf044301ff06991.jpeg
# Copied: bkai_igh_f0b8a4f6b85d841fcef620546518773b.jpeg
# Copied: bkai_igh_53248704ccdc265a0b0a1230b118fa86.jpeg
# Copied: bkai_igh_852ba517fa9498f7b9d151055ea9b16b.jpeg
# Copied: bkai_igh_b8232510939c091a7915c942b2f94722.jpeg
# Copied: bkai_igh_b701fc691ffa02f6068b683019e0c84a.jpeg
# Copied: bkai_igh_866269959350e7998934d417cb2eb1ef.jpeg
# Copied: bkai_igh_670d78b9d054d694539ef2424a921869.jpeg
# Copied: bkai_igh_c08a1d1ad8f2c5f72724e00d827b8bcf.jpeg
# Copied: bkai_igh_f2523acfd87d330a5a97b8eb5a9a8a8d.jpeg
# Copied: bkai_igh_6f5d8dd18841d318d1f625619d9ae2a9.jpeg
# Copied: bkai_igh_4fd7da881fe4727080cae6daedd98951.jpeg
# Copied: bkai_igh_a04c603f909df7cd066b37f538abe9de.jpeg
# Copied: bkai_igh_1b248d152b672ab3492fc6239c86a73f.jpeg
# Copied: bkai_igh_d318d1f625619d9ae2a9833aa6b82325.jpeg
# Copied: bkai_igh_af7f63cd771e7606cb09d1fc6869d7b4.jpeg
# Copied: bkai_igh_35f66adf95b204727fdcfa030228a69b.jpeg
# Copied: bkai_igh_ad3a7ab8df9da738683543f0dc6b7268.jpeg
# Copied: bkai_igh_cc01dd78294679c9cbb2a365b5574868.jpeg
# Copied: bkai_igh_28559ba2bbb610fe8c30d660e70f44c2.jpeg
# Copied: bkai_igh_ceceffce15c1346e62522325c1b9c4fc.jpeg
# Copied: bkai_igh_5a0b0a1230b118fa8625605da2023387.jpeg
# Copied: bkai_igh_04414eaa922bca73d5379c7c851a5082.jpeg
# Copied: bkai_igh_893a23c466c16952b6692e6be5e8f14e.jpeg
# Copied: bkai_igh_491b37c8c2e5a64a8bd16f2523acfd87.jpeg
# Copied: bkai_igh_38713b2aa6ce8d1cf6644589e532a9ee.jpeg
# Copied: bkai_igh_eb4d49033c03b0af70cc0f6d32b72634.jpeg
# Copied: bkai_igh_c1d4f50a5f3601ad4f13ccf1f4b331a4.jpeg
# Copied: bkai_igh_bc9e5a87e443434ac60af15041b1e56c.jpeg
# Copied: bkai_igh_ca745212295dd542315b4c10e2b0e33f.jpeg
# Copied: bkai_igh_20362736055807907941a8490fd7df8e.jpeg
# Copied: bkai_igh_79d7c7c8d3d96fb2b87fbbcfdfb3ea1d.jpeg
# Copied: bkai_igh_94ea04c603f909df7cd066b37f538abe.jpeg
# Copied: bkai_igh_e33fa12bfcd6da15fc656702fa602bb3.jpeg
# Copied: bkai_igh_5a64a8bd16f2523acfd87d330a5a97b8.jpeg
# Copied: bkai_igh_fe9959a80703003d2cbbcfa4baf38662.jpeg
# Copied: bkai_igh_a0565586918cd5eb80e67c9c8d5ce0c9.jpeg
# Copied: bkai_igh_f35edeb1919e5149b7e87593ab2925eb.jpeg
# Copied: bkai_igh_78dc2f4af626650908b1cb932a767bf5.jpeg
# Copied: bkai_igh_ee17979870116d06046f5d8dd18841d3.jpeg
# Copied: bkai_igh_7ad649676a1d6240619ebebe9e9c9d00.jpeg
# Copied: bkai_igh_8489f25621ee6b2905cb608d298528ce.jpeg
# Copied: bkai_igh_76b92633408da4bcab47c3fb256f174a.jpeg
# Copied: bkai_igh_8ee924dbd70f618d52893a23c466c169.jpeg
# Copied: bkai_igh_e9959a80703003d2cbbcfa4baf386626.jpeg
# Copied: bkai_igh_0676289b3e732adb4c5d1580670d78b9.jpeg
# Copied: bkai_igh_6db034099130d98309817287a8aef566.jpeg
# Copied: bkai_igh_871ca68e0d4bcbe0f5192e72f65ddfd1.jpeg
# Copied: bkai_igh_51c149b60f2965341caf528ca0adabea.jpeg
# Copied: bkai_igh_948a41964c1d4f50a5f3601ad4f13ccf.jpeg
# Copied: bkai_igh_952b6692e6be5e8f14e1e0ae936de314.jpeg
# Copied: bkai_igh_dfef33d144fda8daadc8dd23ae214d84.jpeg
# Copied: bkai_igh_92b964b7955a1d7a36ccf1225024da63.jpeg
# Copied: bkai_igh_a0ad83b8cac03290f1b976b7a7efc10b.jpeg
# Copied: bkai_igh_9a3a33a0565586918cd5eb80e67c9c8d.jpeg
# Copied: bkai_igh_e565c5d4340aa5f7804c34a359bbb402.jpeg
# Copied: bkai_igh_f4f219688c7e39b3608a3d372b89ec27.jpeg
# Copied: bkai_igh_dfae76b9a1db782ca0a994927d8d739c.jpeg
# Copied: bkai_igh_0e85d064f787d4be168d9510588bec07.jpeg
# Copied: bkai_igh_ecc564cdc70626ab4ec3d46e602b296c.jpeg
# Copied: bkai_igh_4af626650908b1cb932a767bf5487ced.jpeg
# Copied: bkai_igh_ef92846b60b1a38a1eecd70ebce6347c.jpeg
# Copied: bkai_igh_6ef3065837ced5c7e06678d2a72ddff0.jpeg
# Copied: bkai_igh_83d1d25aa396694c7a8607b26231002e.jpeg
# Copied: bkai_igh_e3b6d0bf0b5633059989805234e222e1.jpeg
# Copied: bkai_igh_1b976b7a7efc10b1300cb1b387133b51.jpeg
# Copied: bkai_igh_f3ae2136cd9dd77aef5ef26a77ecc564.jpeg
# Copied: bkai_igh_84b5dec33fd6aab9f0df70e20bccce75.jpeg
# Copied: bkai_igh_4425bf33b9b001c13a3d810b000db557.jpeg
# Copied: bkai_igh_5f66adf95b204727fdcfa030228a69b9.jpeg
# Copied: bkai_igh_a4baf3866269959350e7998934d417cb.jpeg
# Copied: bkai_igh_2c41545ba55aadaa77712a48e11d579d.jpeg
# Copied: bkai_igh_d6c688b8ec74baddc22268d4b4ef4d95.jpeg
# Copied: bkai_igh_5433a925101416ae101f07b34db8907f.jpeg
# Copied: bkai_igh_b5633059989805234e222e19769fa2d3.jpeg
# Copied: bkai_igh_9e5040781d54ffd6a8ee924dbd70f618.jpeg
# Copied: bkai_igh_f800c683ca4074c2f49c6f0fca6a4248.jpeg
# Copied: bkai_igh_3abf3ae2136cd9dd77aef5ef26a77ecc.jpeg
# Copied: bkai_igh_7629ab559b28f39a546f6eeb0a13b346.jpeg
# Copied: bkai_igh_a80703003d2cbbcfa4baf38662699593.jpeg
# Copied: bkai_igh_5cc8a788edaeb6aa460a22abd004c33a.jpeg
# Copied: bkai_igh_89805234e222e19769fa2d37d32780fd.jpeg
# Copied: bkai_igh_12295dd542315b4c10e2b0e33fa12bfc.jpeg
# Copied: bkai_igh_3d46e602b296cc5cfd263f1f90be2879.jpeg
# Copied: bkai_igh_2abd004c33abf3ae2136cd9dd77aef5e.jpeg
# Copied: bkai_igh_01c13a3d810b000db55759486b8aa1b8.jpeg
# Copied: bkai_igh_08d237285e26c90e1797c77826f9a702.jpeg
# Copied: bkai_igh_bd55b1393e2ef89424de1556a26c8eba.jpeg
# Copied: bkai_igh_daeb6aa460a22abd004c33abf3ae2136.jpeg
# Copied: bkai_igh_054d694539ef2424a9218697283baa36.jpeg
# Copied: bkai_igh_9c02314fc58bdb26679bff55177a34fc.jpeg
# Copied: bkai_igh_18d5401f659532897255ce2dd4ae1b0f.jpeg
# Copied: bkai_igh_ab47c3fb256f174ae992b915a5162555.jpeg
# Copied: bkai_igh_59bbb402345d341253851bc866ebe4d1.jpeg
# Copied: bkai_igh_ae992b915a51625559c7e610b1531871.jpeg
# Copied: bkai_igh_0f618d52893a23c466c16952b6692e6b.jpeg
# Copied: bkai_igh_8e5ad89d2844837f2a0f1536ad3f6a56.jpeg
# Copied: bkai_igh_32897255ce2dd4ae1b0f124dbc13ca0e.jpeg
# Copied: bkai_igh_2d6157edc3d82df22c41b503dc19ce17.jpeg
# Copied: bkai_igh_8f02000f9b6c911c4aa179344271fa54.jpeg
# Copied: bkai_igh_dbc3bbc04a3afe1f119f21b248d152b6.jpeg
# Copied: bkai_igh_79be0dba1f3cf29dff2864e2d89df283.jpeg
# Copied: bkai_igh_2d95e6c487ffa651b4774229fe1bce59.jpeg
# Copied: bkai_igh_47f9c02314fc58bdb26679bff55177a3.jpeg
# Copied: bkai_igh_376290081835cf877e004e8bfb905b78.jpeg
# Copied: bkai_igh_c94ea04c603f909df7cd066b37f538ab.jpeg
# Copied: bkai_igh_8a2710d568df17586ad8f3297c819c90.jpeg
# Copied: bkai_igh_d260bfcb4443de3ef69f6db034099130.jpeg
# Copied: bkai_igh_449922d6157edc3d82df22c41b503dc1.jpeg
# Copied: bkai_igh_911f025ba0e3b6d0bf0b563305998980.jpeg
# Copied: bkai_igh_bab9fc7330398846f67b5df7cdf3f33c.jpeg
# Copied: bkai_igh_177a34fc01019eec999fd84e679b05f9.jpeg
# Copied: bkai_igh_802cf912d7aa982e29fb841ad9698b3c.jpeg
# Copied: bkai_igh_56025866e15c4d0e0a4ceed0afc48dbd.jpeg
# Copied: bkai_igh_730831caf386f6e366943c17f87cf12b.jpeg
# Copied: bkai_igh_abbdc734839a76eaf622c3b3e57249fe.jpeg
# Copied: bkai_igh_f95b204727fdcfa030228a69b99df088.jpeg
# Copied: bkai_igh_ce23b1fdd80af3feff05dec1eb3a70b1.jpeg
# Copied: bkai_igh_424de1556a26c8eba4c1db1a0b47aa6b.jpeg
# Copied: bkai_igh_3de79be0dba1f3cf29dff2864e2d89df.jpeg
# Copied: bkai_igh_64cdc70626ab4ec3d46e602b296cc5cf.jpeg
# Copied: bkai_igh_646f2f0bb8dc11d4f50e412144f0496b.jpeg
# Copied: bkai_igh_aa179344271fa54aa1b27918630bfd2a.jpeg
# Copied: bkai_igh_0496b83ef461c2a337948a41964c1d4f.jpeg
# Copied: bkai_igh_ebce6347c491b37c8c2e5a64a8bd16f2.jpeg
# Copied: bkai_igh_1d4dc3ddad260bfcb4443de3ef69f6db.jpeg
# Copied: bkai_igh_1db40939d9a2f94285ef2a23f9dbbb7b.jpeg
# Copied: bkai_igh_960c94b0aab4c024a573c692195f853a.jpeg
# Copied: bkai_igh_c89c96ddca6ee1af35b65bd9ea42cfcf.jpeg
# Copied: bkai_igh_aa1b27918630bfd2a52829ab4e7568cb.jpeg
# Copied: bkai_igh_afd56ea7bc4ba26c86b345408cc3736e.jpeg
# Copied: bkai_igh_c4ba26c86b345408cc3736e216b08d23.jpeg
# Copied: bkai_igh_26f9a7021bab9fc7330398846f67b5df.jpeg
# Copied: bkai_igh_fe1bce59ddf92e76900d229db65646d8.jpeg
# Copied: bkai_igh_9499640676289b3e732adb4c5d158067.jpeg
# Copied: bkai_igh_9a76eaf622c3b3e57249fe9959a80703.jpeg
# Copied: bkai_igh_e2f4ee17979870116d06046f5d8dd188.jpeg
# Copied: bkai_igh_9df283ecd59f911f025ba0e3b6d0bf0b.jpeg
# Copied: bkai_igh_3b3e57249fe9959a80703003d2cbbcfa.jpeg
# Copied: bkai_igh_6239c86a73f97dd5277dd17ba487d487.jpeg
# Copied: bkai_igh_763bdfb928d788e4237a32841b23099d.jpeg
# Copied: bkai_igh_a3bb0e5ca159410b9fdbdd46f680afdd.jpeg
# Copied: bkai_igh_8683543f0dc6b7268821d173263d7be7.jpeg
# Copied: bkai_igh_bc04772d9e593b6be1ac29adbe86f03d.jpeg
# Copied: bkai_igh_dd04cf2a6a01668d0ceca24cbb22edbd.jpeg
# Copied: bkai_igh_c1db1a0b47aa6b7b1fecb5579bf4a5ce.jpeg
# Copied: bkai_igh_6dde14f129dc9bac4af05b1c40a6615f.jpeg
# Copied: bkai_igh_9d33f3a7b24423d5c7edd718176ef306.jpeg
# Copied: bkai_igh_60a22abd004c33abf3ae2136cd9dd77a.jpeg
# Copied: bkai_igh_f6d32b726342865f6c240449ad43fe2c.jpeg
# Copied: bkai_igh_fbbcfdfb3ea1dd1faa864b404e18eeb2.jpeg
# Copied: bkai_igh_1743c6c08a1d1ad8f2c5f72724e00d82.jpeg
# Copied: bkai_igh_b99df08854bf951276e3f404b79b6669.jpeg
# Copied: bkai_igh_50e4e40d61c9248a714683983ebff13a.jpeg
# Copied: bkai_igh_697283baa3657e4314fe384eb2ba3adf.jpeg
# Copied: bkai_igh_fc10b1300cb1b387133b51209db6dcdd.jpeg
# Copied: bkai_igh_3492fc6239c86a73f97dd5277dd17ba4.jpeg
# Copied: bkai_igh_28ca0adabead1ae730831caf386f6e36.jpeg
# Copied: bkai_igh_d80176c9f800c683ca4074c2f49c6f0f.jpeg
# Copied: bkai_igh_a8aef566999467c2a48847ae8395e56a.jpeg
# Copied: bkai_igh_5e04f4999a2e79fbc24ef8cde99f0444.jpeg
# Copied: bkai_igh_17287a8aef566999467c2a48847ae839.jpeg
# Copied: bkai_igh_4bcab47c3fb256f174ae992b915a5162.jpeg
# Copied: bkai_igh_193ac8d551c149b60f2965341caf528c.jpeg
# Copied: bkai_igh_7b34db8907f74aefafdacfbed351db40.jpeg
# Copied: bkai_igh_497e1c0e9082ea2c193ac8d551c149b6.jpeg
# Copied: bkai_igh_39a76eaf622c3b3e57249fe9959a8070.jpeg
# Copied: bkai_igh_229fe1bce59ddf92e76900d229db6564.jpeg
# Copied: bkai_igh_c7abacdbd7e6afd56ea7bc4ba26c86b3.jpeg
# Copied: bkai_igh_70866fd3c396490cf7bdbdb19b7afea1.jpeg
# Copied: bkai_igh_4da63fb9a76b92633408da4bcab47c3f.jpeg
# Copied: bkai_igh_1573af7f31f04dc06992d92472facb34.jpeg
# Copied: bkai_igh_441680cab5509b367b7048eb17aeed14.jpeg
# Copied: bkai_igh_877e004e8bfb905b78a91391adc0bb22.jpeg
# Copied: bkai_igh_3ad88e16d4ca6160127cd1d5ff99c267.jpeg
# Copied: bkai_igh_e51330463d287a51b9298e11bb07c70f.jpeg
# Copied: bkai_igh_59ddf92e76900d229db65646d81526eb.jpeg
# Copied: bkai_igh_912c4fd31aaeec7b426bacd147ad6496.jpeg
# Copied: bkai_igh_3736e216b08d237285e26c90e1797c77.jpeg
# Copied: bkai_igh_c688b8ec74baddc22268d4b4ef4d95ce.jpeg
# Copied: bkai_igh_077bad31c8c5f54ffaa27a623511c389.jpeg
# Copied: bkai_igh_dacfbed351db40939d9a2f94285ef2a2.jpeg
# Copied: bkai_igh_a052600f1f93e952886d1697f8af9b55.jpeg
# Copied: bkai_igh_bc4ba26c86b345408cc3736e216b08d2.jpeg
# Copied: bkai_igh_51eedf26ed414a42bec7a5fdbaf27600.jpeg
# Copied: bkai_igh_7d507592b964b7955a1d7a36ccf12250.jpeg
# Copied: bkai_igh_e4909384b57bb6a052600f1f93e95288.jpeg
# Copied: bkai_igh_db65646d81526eb91e2da9e6afaef7fd.jpeg
# Copied: bkai_igh_d6d5f35f66adf95b204727fdcfa03022.jpeg
# Copied: bkai_igh_c86b345408cc3736e216b08d237285e2.jpeg
# Copied: bkai_igh_c17f87cf12b41e5e9e5040781d54ffd6.jpeg
# Copied: bkai_igh_5e1069646f2f0bb8dc11d4f50e412144.jpeg
# Copied: bkai_igh_f625619d9ae2a9833aa6b8232510939c.jpeg
# Copied: bkai_igh_e2136cd9dd77aef5ef26a77ecc564cdc.jpeg
# Copied: bkai_igh_1e555525d4f09ce7270bfec57e441680.jpeg
# Copied: bkai_igh_9d2844837f2a0f1536ad3f6a5664c171.jpeg
# Copied: bkai_igh_87cf12b41e5e9e5040781d54ffd6a8ee.jpeg
# Copied: bkai_igh_1ff069910ea2abe3c84417fda8019410.jpeg
# Copied: bkai_igh_e732adb4c5d1580670d78b9d054d6945.jpeg
# Copied: bkai_igh_3e732adb4c5d1580670d78b9d054d694.jpeg
# Copied: bkai_igh_a64a8bd16f2523acfd87d330a5a97b8e.jpeg
# Copied: bkai_igh_8da4bcab47c3fb256f174ae992b915a5.jpeg
# Copied: bkai_igh_837f2a0f1536ad3f6a5664c1711b62f1.jpeg
# Copied: bkai_igh_fa4baf3866269959350e7998934d417c.jpeg
# Copied: bkai_igh_7b4193425b976973f13dd311a65d2b46.jpeg
# Copied: bkai_igh_81fe4727080cae6daedd989517cb8041.jpeg
# Copied: bkai_igh_e9e5040781d54ffd6a8ee924dbd70f61.jpeg
# Copied: bkai_igh_b74a29abdb047dc0cbb58aa032554b5e.jpeg
# Copied: bkai_igh_408cc3736e216b08d237285e26c90e17.jpeg
# Copied: bkai_igh_bfcd6da15fc656702fa602bb3c7abacd.jpeg
# Copied: bkai_igh_cd066b37f538abe9de67869ac66e565c.jpeg
# Copied: bkai_igh_2a52829ab4e7568cb49a3c530b99ec16.jpeg
# Copied: bkai_igh_340aa5f7804c34a359bbb402345d3412.jpeg
# Copied: bkai_igh_d8d739c25f1ed7a64d0efccacf464aa3.jpeg
# Copied: bkai_igh_cc0f6d32b726342865f6c240449ad43f.jpeg
# Copied: bkai_igh_d24a2ac9e88b2be8379499640676289b.jpeg
# Copied: bkai_igh_7f8a4df1ec859759b7c8743c61a01e80.jpeg
# Copied: bkai_igh_fcb4443de3ef69f6db034099130d9830.jpeg
# Copied: bkai_igh_0bfd2a52829ab4e7568cb49a3c530b99.jpeg
# Copied: bkai_igh_588bec07c38c5d07e6080779715c88d8.jpeg
# Copied: bkai_igh_a59c7de13a35276a476420655433a925.jpeg
# Copied: bkai_igh_69ac66e565c5d4340aa5f7804c34a359.jpeg
# Copied: bkai_igh_f0dc6b7268821d173263d7be7e12deff.jpeg
# Copied: bkai_igh_b3a70b145a7d8d3b6c0ed754f28ca745.jpeg
# Copied: bkai_igh_c8d3d96fb2b87fbbcfdfb3ea1dd1faa8.jpeg
# Copied: bkai_igh_4c1d4f50a5f3601ad4f13ccf1f4b331a.jpeg
# Copied: bkai_igh_47953b0e4909384b57bb6a052600f1f9.jpeg
# Copied: bkai_igh_c859759b7c8743c61a01e80947f9c023.jpeg
# Copied: bkai_igh_2b964b7955a1d7a36ccf1225024da63f.jpeg
# Copied: bkai_igh_48704ccdc265a0b0a1230b118fa86256.jpeg
# Copied: bkai_igh_ef69f6db034099130d98309817287a8a.jpeg
# Copied: bkai_igh_b4774229fe1bce59ddf92e76900d229d.jpeg
# Copied: bkai_igh_cfd87d330a5a97b8eb5a9a8a8d7fcc9d.jpeg
# Copied: bkai_igh_540e24f489284b8e6953ad88e16d4ca6.jpeg
# Copied: bkai_igh_decfb143c57d89102ba1cef745d73912.jpeg
# Copied: bkai_igh_2eb9d32a3dc907950289e976c7250de9.jpeg
# Copied: bkai_igh_225024da63fb9a76b92633408da4bcab.jpeg
# Copied: bkai_igh_d330a5a97b8eb5a9a8a8d7fcc9df8e5a.jpeg
# Copied: bkai_igh_713a8763b8318ecf467d7ad048df39be.jpeg
# Copied: bkai_igh_faeeb2b535797395305af926a6f23c5d.jpeg
# Copied: bkai_igh_74d32ab35c9c40e48620fad66c39a6d3.jpeg
# Copied: bkai_igh_abdb047dc0cbb58aa032554b5eb4fcf0.jpeg
# Copied: bkai_igh_80703003d2cbbcfa4baf386626995935.jpeg
# Copied: bkai_igh_a2bbb610fe8c30d660e70f44c2b89cc0.jpeg
# Copied: bkai_igh_ca73d5379c7c851a508273160e13bac7.jpeg
# Copied: bkai_igh_6eb91e2da9e6afaef7fdb2d45b21960c.jpeg
# Copied: bkai_igh_a7b24423d5c7edd718176ef3065837ce.jpeg

# %% [markdown]
# ### validation split

# %%
moved = data_processor.move_random_n_images(F_TRAIN_IMAGES_POS, F_VAL_IMAGES_POS, 4000)
data_processor.move_images_by_name(F_TRAIN_MASKS_POS, F_VAL_MASKS_POS, moved)
# Out:
# ['case_M_20181010094822_0U62363101085921_1_003_001-1_a4_ayy_image0007.png',
#  'case_M_20190128094801_0U62372012857800_1_002_001-1_a6_ayy_image0009.png',
#  'case_M_20190110094509_0U62363011095308_1_001_002-1_a2_ayy_image0077_flip_v.png',
#  'case_M_20181010094822_0U62363101085921_1_003_001-1_a1_ayy_image0227_flip_v.png',
#  'case_M_20181017100226_0U62367101735926_1_007_004-1_a6_ayy_image0013.png',
#  'case_M_20181226125224_0U62363122631224_1_003_001-1_a5_ayy_image0162.png',
#  'case_M_20181010094822_0U62363101085921_1_003_001-1_a1_ayy_image0168_flip_h.png',
#  'case_M_20181213131150_0U62365121395349_1_002_002-1_a18_ayy_image0044.png',
#  'case_M_20181025095048_0U62372102595347_1_004_001-1_a17_ayy_image0092.png',
#  'case_M_20181217131216_0U62368121700016_1_002_001-1_a10_ayy_image0166.png',
#  'case_M_20181015101337_0U62363101576536_1_005_001-1_a21_ayy_image0267_flip_h.png',
#  'case_M_20181217131216_0U62368121700016_1_002_001-1_a10_ayy_image0041_flip_h.png',
#  'case_M_20181119111911_0U62363111914011_1_005_001-1_a8_ayy_image0104.png',
#  'case_M_20181022094701_0U62368102271800_1_005_001-1_a2_ayy_image0042_flip_h.png',
#  'case_M_20190126102153_0U62372012695352_1_001_001-1_a3_ayy_image0030_rotate_180.png',
#  'case_M_20181022094701_0U62368102271800_1_005_001-1_a1_ayy_image0023_flip_v.png',
#  'case_M_20181019101517_0U62367101935917_1_003_001-1_a18_ayy_image0069.png',
#  'case_M_20190121095240_0U62368012118740_1_005_001-1_a1_ayy_image0287_flip_h.png',
#  'case_M_20181025095048_0U62372102595347_1_004_001-1_a15_ayy_image0139.png',
#  'case_M_20181226125224_0U62363122631224_1_003_001-1_a1_ayy_image0055.png',
#  'case_M_20190115123306_0U62368011540606_1_002_001-1_a7_ayy_image0025.png',
#  'cvc_colodb_271.png',
#  'bkai_igh_8841d318d1f625619d9ae2a9833aa6b8.jpeg',
#  'case_M_20181018093806_0U62363101890605_1_007_002-1_a14_ayy_image0021_rotate_180.png',
#  'case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0009_flip_v.png',
#  'case_M_20181015101337_0U62363101576536_1_005_001-1_a14_ayy_image0008_rotate_180.png',
#  'case_M_20190115123306_0U62368011540606_1_002_001-1_a7_ayy_image0080_flip_v.png',
#  'case_M_20181119111911_0U62363111914011_1_005_001-1_a16_ayy_image0191.png',
#  'case_M_20181213131150_0U62365121395349_1_002_002-1_a25_ayy_image0176.png',
#  'case_M_20190117095926_0U62372011750026_1_002_001-1_a4_ayy_image0051.png',
#  'case_M_20190115123306_0U62368011540606_1_002_001-1_a5_ayy_image0035.png',
#  'bkai_igh_86f6e366943c17f87cf12b41e5e9e504.jpeg',
#  'case_M_20190128094801_0U62372012857800_1_002_001-1_a7_ayy_image0002.png',
#  'case_M_20181003094031_0U62363100354631_1_001_002-1_a1_ayy_image0584_flip_v.png',
#  'case_M_20181109101724_0U62368110954624_1_005_001-1_a1_ayy_image0017_flip_h.png',
#  'case_M_20181117100025_0U62363111779624_1_007_003-1_a8_ayy_image0332.png',
#  'case_M_20190121095240_0U62368012118740_1_005_001-1_a3_ayy_image0082.png',
#  'case_M_20181018093806_0U62363101890605_1_007_002-1_a1_ayy_image0027.png',
#  'case_M_20181004093748_0U62372100445348_1_001_001-1_a4_ayy_image0033.png',
#  'case_M_20181019122218_0U62368101948418_1_002_001-1_a4_ayy_image0063.png',
#  'case_M_20181015101337_0U62363101576536_1_005_001-1_a21_ayy_image0247_rotate_180.png',
#  'case_M_20181207092523_0U62372120765622_1_005_001-1_a9_ayy_image0005.png',
#  'case_M_20190109095638_0U62372010945338_1_001_001-1_a2_ayy_image0076.png',
#  'case_M_20190121095240_0U62368012118740_1_005_001-1_a2_ayy_image0215.png',
#  'case_M_20190121095240_0U62368012118740_1_005_001-1_a3_ayy_image0157.png',
#  'case_M_20181212144657_0U62366121262556_1_001_002-1_a2_ayy_image0021.png',
#  'case_M_20190121095240_0U62368012118740_1_005_001-1_a1_ayy_image0212.png',
#  'case_M_20181010094822_0U62363101085921_1_003_001-1_a7_ayy_image0069.png',
#  'case_M_20190117095926_0U62372011750026_1_002_001-1_a1_ayy_image0020.png',
#  'case_M_20181015101337_0U62363101576536_1_005_001-1_a21_ayy_image0243.png',
#  'case_M_20190117105747_0U62368011712547_1_004_001-1_a13_ayy_image0211.png',
#  'case_M_20181018093806_0U62363101890605_1_007_002-1_a12_ayy_image0056_flip_h.png',
#  'case_M_20190109095638_0U62372010945338_1_003_001-1_a30_ayy_image0002.png',
#  'case_M_20181017100226_0U62367101735926_1_007_004-1_a6_ayy_image0211.png',
#  'case_M_20181025093921_0U62363102537521_1_002_001-1_a10_ayy_image0031.png',
#  'case_M_20181026100314_0U62363102665613_1_004_001-1_a4_ayy_image0051.png',
#  'case_M_20181018093806_0U62363101890605_1_007_001-1_a3_ayy_image0002.png',
#  'bkai_igh_cc89c96ddca6ee1af35b65bd9ea42cfc.jpeg',
#  'case_M_20190126102153_0U62372012695352_1_001_001-1_a3_ayy_image0002.png',
#  'case_M_20181119111911_0U62363111914011_1_005_001-1_a12_ayy_image0383_flip_v.png',
#  'case_M_20181017095127_0U62372101720327_1_001_001-1_a1_ayy_image0039_flip_v.png',
#  'case_M_20190128094801_0U62372012857800_1_002_001-1_a3_ayy_image0012.png',
#  'case_M_20181019101517_0U62367101935917_1_003_001-1_a18_ayy_image0067.png',
#  'case_M_20190115123306_0U62368011540606_1_002_001-1_a6_ayy_image0144_flip_v.png',
#  'case_M_20181015101337_0U62363101576536_1_005_002-1_a9_ayy_image0083.png',
#  'case_M_20181031103335_0U62368103151535_1_006_001-1_a4_ayy_image0086.png',
#  'case_M_20181025095048_0U62372102595347_1_004_001-1_a14_ayy_image0026_rotate_270.png',
#  'case_M_20181226125224_0U62363122631224_1_003_001-1_a5_ayy_image0105.png',
#  'case_M_20181017100226_0U62367101735926_1_007_004-1_a4_ayy_image0228.png',
#  'case_M_20181017100226_0U62367101735926_1_007_003-1_a7_ayy_image0027.png',
#  'case_M_20190109095638_0U62372010945338_1_003_001-1_a22_ayy_image0021.png',
#  'case_M_20190110094922_0U62372011079621_1_005_002-1_a1_ayy_image0026.png',
#  'case_M_20181029094800_0U62368102981259_1_005_001-1_a15_ayy_image0176.png',
#  'case_M_20190117095926_0U62372011750026_1_002_001-1_a4_ayy_image0031.png',
#  'case_M_20181017100226_0U62367101735926_1_007_003-1_a6_ayy_image0054_flip_h.png',
#  'case_M_20181017100226_0U62367101735926_1_005_001-1_a3_ayy_image0014.png',
#  'case_M_20181004093748_0U62372100445348_1_001_001-1_a4_ayy_image0055.png',
#  'bkai_igh_db782ca0a994927d8d739c25f1ed7a64.jpeg',
#  'case_M_20181126140908_0U62368112685907_1_004_001-1_a13_ayy_image0027.png',
#  'case_M_20181109101724_0U62368110954624_1_005_001-1_a3_ayy_image0031.png',
#  'case_M_20181105095958_0U62368110576557_1_003_002-1_a6_ayy_image0329_flip_v.png',
#  'case_M_20190128094801_0U62372012857800_1_002_001-1_a13_ayy_image0013_flip_v.png',
#  'case_M_20181105095958_0U62368110576557_1_003_002-1_a6_ayy_image0410_rotate_180.png',
#  'case_M_20190131094104_0U62367013193703_1_003_001-1_a9_ayy_image0207.png',
#  'case_M_20181211093229_0U62367121175028_1_004_001-1_a16_ayy_image0044.png',
#  'case_M_20190121095240_0U62368012118740_1_004_001-1_a4_ayy_image0033_rotate_180.png',
#  'case_M_20190131094430_0U62372013151529_1_003_001-1_a5_ayy_image0031_flip_h.png',
#  'case_M_20190115123306_0U62368011540606_1_002_001-1_a4_ayy_image0182_flip_h.png',
#  'case_M_20181211093229_0U62367121175028_1_004_001-1_a10_ayy_image0071_rotate_180.png',
#  'case_M_20181117100025_0U62363111779624_1_007_003-1_a8_ayy_image0121.png',
#  'case_M_20181025093921_0U62363102537521_1_002_001-1_a1_ayy_image0026.png',
#  'case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0929_flip_v.png',
#  'case_M_20181106093315_0U62372110682814_1_007_001-1_a2_ayy_image0015_flip_v.png',
#  'case_M_20190116094421_0U62363011675020_1_004_001-1_a4_ayy_image0052_flip_h.png',
#  'case_M_20181029094800_0U62368102981259_1_005_001-1_a14_ayy_image0048.png',
#  'case_M_20181022094701_0U62368102271800_1_001_001-1_a11_ayy_image0027_flip_h.png',
#  'case_M_20181004130627_0U62365100475026_1_002_001-1_a3_ayy_image0008_flip_h.png',
#  'case_M_20181019122218_0U62368101948418_1_002_001-1_a4_ayy_image0053.png',
#  'case_M_20181213131150_0U62365121395349_1_002_001-1_a8_ayy_image0018.png',
#  'case_M_20181030122608_0U62363103057807_1_002_002-1_a2_ayy_image0013_flip_h.png',
#  'case_M_20181018093806_0U62363101890605_1_007_002-1_a12_ayy_image0038_flip_v.png',
#  'case_M_20190110094922_0U62372011079621_1_005_002-1_a1_ayy_image0036.png',
#  'case_M_20190109095638_0U62372010945338_1_001_001-1_a2_ayy_image0074.png',
#  'case_M_20181004140507_0U62366100460906_1_001_001-1_a1_ayy_image0028.png',
#  'case_M_20181025095048_0U62372102595347_1_004_001-1_a17_ayy_image0113.png',
#  'case_M_20181119111911_0U62363111914011_1_005_001-1_a12_ayy_image0034_flip_v.png',
#  'case_M_20181022094701_0U62368102271800_1_005_001-1_a2_ayy_image0102_flip_v.png',
#  'bkai_igh_f1ec859759b7c8743c61a01e80947f9c.jpeg',
#  'case_M_20181105095958_0U62368110576557_1_003_002-1_a7_ayy_image0052_flip_v.png',
#  'case_M_20181018093806_0U62363101890605_1_007_002-1_a8_ayy_image0023_flip_v.png',
#  'case_M_20181001100941_0U62372100109341_1_005_001-1_a2_ayy_image0115.png',
#  'case_M_20181022094701_0U62368102271800_1_005_001-1_a3_ayy_image0124_flip_v.png',
#  'case_M_20181217131216_0U62368121700016_1_002_001-1_a10_ayy_image0022_flip_v.png',
#  'case_M_20181015101337_0U62363101576536_1_005_001-1_a21_ayy_image0228_flip_v.png',
#  'case_M_20181226125224_0U62363122631224_1_003_001-1_a8_ayy_image0151.png',
#  'case_M_20181106093315_0U62372110682814_1_007_001-1_a6_ayy_image0026.png',
#  'cvc_colodb_136.png',
#  'case_M_20190116094421_0U62363011675020_1_004_001-1_a6_ayy_image0030.png',
#  'case_M_20181029094800_0U62368102981259_1_005_001-1_a15_ayy_image0110_flip_v.png',
#  'case_M_20181025095048_0U62372102595347_1_004_001-1_a14_ayy_image0036.png',
#  'case_M_20190128094801_0U62372012857800_1_002_001-1_a13_ayy_image0042_flip_h.png',
#  'case_M_20181015101337_0U62363101576536_1_005_002-1_a18_ayy_image0024_flip_h.png',
#  'case_M_20181029094800_0U62368102981259_1_002_001-1_a5_ayy_image0030.png',
#  'case_M_20181109101724_0U62368110954624_1_005_001-1_a3_ayy_image0021.png',
#  'case_M_20190121095240_0U62368012118740_1_005_001-1_a1_ayy_image0415.png',
#  'case_M_20181010094822_0U62363101085921_1_003_001-1_a1_ayy_image0204.png',
#  'case_M_20190121095240_0U62368012118740_1_005_001-1_a1_ayy_image0451_flip_h.png',
#  'case_M_20181010094822_0U62363101085921_1_003_001-1_a4_ayy_image0145_rotate_180.png',
#  'case_M_20181025095048_0U62372102595347_1_004_001-1_a13_ayy_image0009_flip_h.png',
#  'case_M_20181017100226_0U62367101735926_1_007_003-1_a2_ayy_image0061_rotate_90.png',
#  'case_M_20190115123306_0U62368011540606_1_002_001-1_a6_ayy_image0223.png',
#  'case_M_20181119111911_0U62363111914011_1_005_001-1_a6_ayy_image0045.png',
#  'case_M_20181029094800_0U62368102981259_1_005_001-1_a12_ayy_image0027.png',
#  'case_M_20181017100226_0U62367101735926_1_007_003-1_a4_ayy_image0057.png',
#  'bkai_igh_0e1797c77826f9a7021bab9fc7330398.jpeg',
#  'case_M_20181106093315_0U62372110682814_1_007_001-1_a6_ayy_image0026_flip_v.png',
#  'case_M_20181010094822_0U62363101085921_1_003_001-1_a3_ayy_image0020.png',
#  'case_M_20181226125224_0U62363122631224_1_003_001-1_a2_ayy_image0081_rotate_180.png',
#  'case_M_20181226125224_0U62363122631224_1_003_001-1_a5_ayy_image0091.png',
#  'case_M_20181001100941_0U62372100109341_1_005_001-1_a10_ayy_image0024.png',
#  'case_M_20190115123306_0U62368011540606_1_002_001-1_a4_ayy_image0155.png',
#  'case_M_20190117105747_0U62368011712547_1_002_001-1_a18_ayy_image0011.png',
#  'case_M_20181017100226_0U62367101735926_1_007_003-1_a2_ayy_image0050.png',
#  'case_M_20181217131216_0U62368121700016_1_002_001-1_a10_ayy_image0166_flip_v.png',
#  'case_M_20190110094509_0U62363011095308_1_001_001-1_a2_ayy_image0029_flip_h.png',
#  'bkai_igh_f70cc0f6d32b726342865f6c240449ad.jpeg',
#  'case_M_20181207092523_0U62372120765622_1_005_001-1_a17_ayy_image0074.png',
#  'bkai_igh_a0b0a1230b118fa8625605da2023387f.jpeg',
#  'case_M_20181003094031_0U62363100354631_1_001_002-1_a1_ayy_image0058.png',
#  'case_M_20190116093042_0U62372011685941_1_001_001-1_a4_ayy_image0007.png',
#  'case_M_20181112100700_0U62368111270359_1_005_001-1_a11_ayy_image0023.png',
#  'case_M_20181010094822_0U62363101085921_1_003_001-1_a4_ayy_image0072.png',
#  'case_M_20181022094701_0U62368102271800_1_005_001-1_a2_ayy_image0082.png',
#  'case_M_20190116093042_0U62372011685941_1_001_001-1_a5_ayy_image0026.png',
#  'case_M_20181217131216_0U62368121700016_1_002_001-1_a10_ayy_image0144_flip_h.png',
#  'case_M_20190115123306_0U62368011540606_1_002_001-1_a5_ayy_image0033.png',
#  'case_M_20190121095240_0U62368012118740_1_004_001-1_a5_ayy_image0095.png',
#  'case_M_20181029094800_0U62368102981259_1_005_001-1_a12_ayy_image0170_flip_v.png',
#  'case_M_20181109094641_0U62372110931241_1_005_001-1_a1_ayy_image0059_rotate_180.png',
#  'case_M_20181004130627_0U62365100475026_1_002_001-1_a3_ayy_image0032_flip_h.png',
#  'case_M_20190130094921_0U62367013093720_1_009_001-1_a5_ayy_image0024.png',
#  'case_M_20181105095958_0U62368110576557_1_003_002-1_a6_ayy_image0350.png',
#  'case_M_20190110094509_0U62363011095308_1_001_002-1_a4_ayy_image0084_rotate_180.png',
#  'case_M_20181025095048_0U62372102595347_1_004_001-1_a17_ayy_image0088.png',
#  'case_M_20181025095048_0U62372102595347_1_004_001-1_a7_ayy_image0001.png',
#  'case_M_20181022094701_0U62368102271800_1_005_001-1_a3_ayy_image0163.png',
#  'bkai_igh_23099dd2eedba39099848c4425bf33b9.jpeg',
#  'case_M_20181228140523_0U62365122821823_1_001_001-1_a3_ayy_image0172.png',
#  'case_M_20181109094641_0U62372110931241_1_005_001-1_a4_ayy_image0121.png',
#  'case_M_20181105095958_0U62368110576557_1_003_002-1_a9_ayy_image0019.png',
#  'case_M_20181025095048_0U62372102595347_1_004_001-1_a8_ayy_image0082.png',
#  'case_M_20181203093846_0U62367120345345_1_005_001-1_a7_ayy_image0030.png',
#  'case_M_20181025095048_0U62372102595347_1_004_001-1_a8_ayy_image0167.png',
#  'case_M_20181019101517_0U62367101935917_1_003_001-1_a18_ayy_image0033_flip_v.png',
#  'cvc_colodb_134.png',
#  'case_M_20181109094641_0U62372110931241_1_005_001-1_a1_ayy_image0023.png',
#  'case_M_20181017100226_0U62367101735926_1_001_002-1_a15_ayy_image0105.png',
#  'case_M_20181029094800_0U62368102981259_1_002_001-1_a5_ayy_image0012.png',
#  'bkai_igh_fd7da881fe4727080cae6daedd989517.jpeg',
#  'case_M_20181203093846_0U62367120345345_1_005_001-1_a7_ayy_image0038_flip_h.png',
#  'case_M_20181018093806_0U62363101890605_1_007_002-1_a8_ayy_image0031.png',
#  'cvc_colodb_361.png',
#  'bkai_igh_76d0bbd4ce2a1405f7d507592b964b79.jpeg',
#  'case_M_20190110094509_0U62363011095308_1_001_001-1_a1_ayy_image0019.png',
#  'case_M_20181126095408_0U62367112660907_1_001_002-1_a6_ayy_image0031_flip_h.png',
#  'case_M_20190130094921_0U62367013093720_1_009_001-1_a7_ayy_image0057_flip_v.png',
#  'case_M_20181004130627_0U62365100475026_1_002_001-1_a3_ayy_image0001.png',
#  'case_M_20181211093229_0U62367121175028_1_004_001-1_a8_ayy_image0003.png',
#  'case_M_20181026100314_0U62363102665613_1_004_001-1_a4_ayy_image0049_rotate_90.png',
#  'bkai_igh_051fc90e85d064f787d4be168d951058.jpeg',
#  'case_M_20181213131150_0U62365121395349_1_002_002-1_a25_ayy_image0178.png',
#  'case_M_20181010094822_0U62363101085921_1_003_001-1_a1_ayy_image0231_flip_h.png',
#  'case_M_20190109095638_0U62372010945338_1_001_001-1_a1_ayy_image0024.png',
#  'case_M_20181018093806_0U62363101890605_1_007_002-1_a11_ayy_image0014.png',
#  'case_M_20181026100314_0U62363102665613_1_004_001-1_a4_ayy_image0066_flip_h.png',
#  'case_M_20190109095638_0U62372010945338_1_003_001-1_a23_ayy_image0520.png',
#  'case_M_20190109095638_0U62372010945338_1_003_001-1_a23_ayy_image0430.png',
#  'case_M_20181017100226_0U62367101735926_1_007_004-1_a4_ayy_image0136.png',
#  'case_M_20181017100226_0U62367101735926_1_007_004-1_a6_ayy_image0080.png',
#  'case_M_20181004130627_0U62365100475026_1_002_001-1_a5_ayy_image0084.png',
#  'case_M_20190121095240_0U62368012118740_1_005_001-1_a1_ayy_image0332.png',
#  'case_M_20181010094822_0U62363101085921_1_003_001-1_a2_ayy_image0056.png',
#  'case_M_20181126095408_0U62367112660907_1_001_002-1_a3_ayy_image0014_rotate_180.png',
#  'case_M_20181017100226_0U62367101735926_1_007_003-1_a9_ayy_image0002.png',
#  'case_M_20181004140507_0U62366100460906_1_001_001-1_a1_ayy_image0036_flip_v.png',
#  'bkai_igh_c8c2e5a64a8bd16f2523acfd87d330a5.jpeg',
#  'case_M_20181017100226_0U62367101735926_1_007_004-1_a4_ayy_image0321.png',
#  'case_M_20181212144657_0U62366121262556_1_001_002-1_a2_ayy_image0058.png',
#  'case_M_20181220100816_0U62368122007816_1_002_001-1_a7_ayy_image0057.png',
#  'case_M_20190131094104_0U62367013193703_1_003_001-1_a9_ayy_image0203_flip_h.png',
#  'case_M_20181029094800_0U62368102981259_1_005_001-1_a15_ayy_image0081.png',
#  'case_M_20181019101517_0U62367101935917_1_003_001-1_a14_ayy_image0038.png',
#  'case_M_20190116094421_0U62363011675020_1_004_001-1_a6_ayy_image0044_flip_h.png',
#  'case_M_20181207092523_0U62372120765622_1_005_001-1_a12_ayy_image0053.png',
#  'case_M_20181205095418_0U62367120576517_1_007_001-1_a22_ayy_image0073.png',
#  'case_M_20181025095048_0U62372102595347_1_004_001-1_a7_ayy_image0015.png',
#  'case_M_20181129152014_0U62366112981213_1_001_001-1_a17_ayy_image0040.png',
#  'case_M_20190117095926_0U62372011750026_1_002_001-1_a4_ayy_image0047_flip_v.png',
#  'case_M_20181119111911_0U62363111914011_1_005_001-1_a16_ayy_image0446_flip_h.png',
#  'case_M_20190131094104_0U62367013193703_1_003_001-1_a9_ayy_image0191_flip_v.png',
#  'case_M_20190131094104_0U62367013193703_1_003_001-1_a9_ayy_image0101.png',
#  'bkai_igh_cfedb5eb2a0e4b50889d874c68c030b9.jpeg',
#  'case_M_20181018093806_0U62363101890605_1_007_001-1_a1_ayy_image0154_flip_v.png',
#  'case_M_20181022094701_0U62368102271800_1_001_001-1_a11_ayy_image0070_flip_v.png',
#  'case_M_20181025093921_0U62363102537521_1_002_001-1_a9_ayy_image0069.png',
#  'case_M_20181010094822_0U62363101085921_1_003_001-1_a13_ayy_image0205.png',
#  'case_M_20181211093229_0U62367121175028_1_002_002-1_a2_ayy_image0053_flip_v.png',
#  'case_M_20181025095048_0U62372102595347_1_004_001-1_a17_ayy_image0094.png',
#  'case_M_20181025095048_0U62372102595347_1_004_001-1_a13_ayy_image0043_rotate_180.png',
#  'case_M_20190123101017_0U62372012395316_1_004_001-1_a2_ayy_image0013_flip_v.png',
#  'case_M_20181213131150_0U62365121395349_1_002_002-1_a25_ayy_image0023.png',
#  'case_M_20181212144657_0U62366121262556_1_001_001-1_a41_ayy_image0013.png',
#  'case_M_20181010094822_0U62363101085921_1_003_001-1_a13_ayy_image0463.png',
#  'case_M_20181017100226_0U62367101735926_1_007_001-1_a2_ayy_image0001.png',
#  'case_M_20181001140915_0U62366100164014_1_001_001-1_a4_ayy_image0030.png',
#  'case_M_20181026100314_0U62363102665613_1_004_001-1_a5_ayy_image0082.png',
#  'case_M_20181211093229_0U62367121175028_1_004_001-1_a8_ayy_image0009_rotate_180.png',
#  'case_M_20181217131216_0U62368121700016_1_002_001-1_a10_ayy_image0012_flip_v.png',
#  'case_M_20181001140915_0U62366100164014_1_001_001-1_a5_ayy_image0002_flip_h.png',
#  'case_M_20181017100226_0U62367101735926_1_007_004-1_a4_ayy_image0084_flip_h.png',
#  'case_M_20190109095638_0U62372010945338_1_003_001-1_a28_ayy_image0059_flip_h.png',
#  'case_M_20181029094800_0U62368102981259_1_005_001-1_a15_ayy_image0219.png',
#  'case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0015.png',
#  'case_M_20181213092448_0U62363121315648_1_003_001-1_a1_ayy_image0034_flip_h.png',
#  'case_M_20181213092448_0U62363121315648_1_003_001-1_a1_ayy_image0038_flip_h.png',
#  'case_M_20181010094822_0U62363101085921_1_003_001-1_a13_ayy_image0195.png',
#  'case_M_20190115123306_0U62368011540606_1_002_001-1_a5_ayy_image0142.png',
#  'case_M_20181025095048_0U62372102595347_1_004_001-1_a8_ayy_image0048.png',
#  'case_M_20190115123306_0U62368011540606_1_002_001-1_a4_ayy_image0163_rotate_180.png',
#  'case_M_20181207092523_0U62372120765622_1_005_001-1_a10_ayy_image0036_flip_h.png',
#  'case_M_20190109095638_0U62372010945338_1_001_001-1_a1_ayy_image0015.png',
#  'case_M_20190115123306_0U62368011540606_1_002_001-1_a7_ayy_image0106.png',
#  'case_M_20190115123306_0U62368011540606_1_002_001-1_a5_ayy_image0140.png',
#  'case_M_20181017100226_0U62367101735926_1_007_004-1_a4_ayy_image0398_flip_h.png',
#  'case_M_20190116094421_0U62363011675020_1_004_001-1_a8_ayy_image0059.png',
#  'case_M_20181026100314_0U62363102665613_1_004_001-1_a7_ayy_image0007.png',
#  'case_M_20181004140507_0U62366100460906_1_001_001-1_a1_ayy_image0034_flip_h.png',
#  'case_M_20181017100226_0U62367101735926_1_007_004-1_a6_ayy_image0082.png',
#  'case_M_20181226125224_0U62363122631224_1_003_001-1_a10_ayy_image0213.png',
#  'bkai_igh_fa54aa1b27918630bfd2a52829ab4e75.jpeg',
#  'case_M_20181105095958_0U62368110576557_1_003_002-1_a7_ayy_image0076.png',
#  'case_M_20181213092448_0U62363121315648_1_003_001-1_a1_ayy_image0027.png',
#  'case_M_20190109095638_0U62372010945338_1_001_001-1_a3_ayy_image0048_rotate_180.png',
#  'case_M_20181212144657_0U62366121262556_1_001_001-1_a42_ayy_image0039.png',
#  'case_M_20181226125224_0U62363122631224_1_003_001-1_a5_ayy_image0129.png',
#  'case_M_20181001093706_0U62368100179605_1_004_002-1_a26_ayy_image0062_rotate_180.png',
#  'case_M_20181119111911_0U62363111914011_1_005_001-1_a16_ayy_image0237.png',
#  'case_M_20181220100816_0U62368122007816_1_002_001-1_a7_ayy_image0085.png',
#  'case_M_20181030135203_0U62365103062502_1_001_001-1_a3_ayy_image0018_flip_h.png',
#  'case_M_20181217131216_0U62368121700016_1_002_001-1_a6_ayy_image0410.png',
#  'case_M_20181110093525_0U62372111056224_1_004_001-1_a2_ayy_image0035_flip_v.png',
#  'case_M_20181019101517_0U62367101935917_1_003_001-1_a15_ayy_image0045.png',
#  'case_M_20181004093748_0U62372100445348_1_001_001-1_a4_ayy_image0157.png',
#  'case_M_20181129152014_0U62366112981213_1_001_001-1_a19_ayy_image0164.png',
#  'case_M_20190112093830_0U62372011292129_1_001_001-1_a1_ayy_image0292_rotate_180.png',
#  'case_M_20190107094528_0U62367010726528_1_002_002-1_a5_ayy_image0065.png',
#  'case_M_20181019101517_0U62367101935917_1_003_001-1_a13_ayy_image0094.png',
#  'cvc_colodb_115.png',
#  'case_M_20190116094421_0U62363011675020_1_004_001-1_a8_ayy_image0026_flip_v.png',
#  'case_M_20181019101517_0U62367101935917_1_003_001-1_a17_ayy_image0015.png',
#  'case_M_20190117105747_0U62368011712547_1_004_001-1_a13_ayy_image0249.png',
#  'case_M_20190121095240_0U62368012118740_1_005_001-1_a1_ayy_image0086.png',
#  'case_M_20181227102913_0U62363122725013_1_004_001-1_a9_ayy_image0003.png',
#  'case_M_20190121095240_0U62368012118740_1_005_001-1_a1_ayy_image0076.png',
#  'case_M_20190112093830_0U62372011292129_1_001_001-1_a8_ayy_image0059_flip_h.png',
#  'case_M_20190128094801_0U62372012857800_1_002_001-1_a13_ayy_image0121_flip_h.png',
#  'case_M_20190116094421_0U62363011675020_1_002_001-1_a2_ayy_image0061.png',
#  'case_M_20181017100226_0U62367101735926_1_007_001-1_a4_ayy_image0064.png',
#  'case_M_20190121095240_0U62368012118740_1_005_001-1_a1_ayy_image0015.png',
#  'case_M_20181017100226_0U62367101735926_1_001_002-1_a15_ayy_image0152_flip_h.png',
#  'case_M_20181017100226_0U62367101735926_1_007_003-1_a4_ayy_image0026.png',
#  'case_M_20181031103335_0U62368103151535_1_006_001-1_a1_ayy_image0016_flip_h.png',
#  'case_M_20181119111911_0U62363111914011_1_005_001-1_a12_ayy_image0225.png',
#  'bkai_igh_886d1697f8af9b550c1bce23b1fdd80a.jpeg',
#  'case_M_20181109094641_0U62372110931241_1_005_001-1_a4_ayy_image0121_rotate_90.png',
#  'case_M_20181110093525_0U62372111056224_1_004_001-1_a2_ayy_image0055.png',
#  'case_M_20181119111911_0U62363111914011_1_005_001-1_a16_ayy_image0056_flip_v.png',
#  'case_M_20181119111911_0U62363111914011_1_005_001-1_a16_ayy_image0333_flip_v.png',
#  'bkai_igh_195f853af7f8a4df1ec859759b7c8743.jpeg',
#  'case_M_20181117100025_0U62363111779624_1_007_003-1_a8_ayy_image0077.png',
#  'case_M_20181017100226_0U62367101735926_1_007_004-1_a4_ayy_image0451.png',
#  'bkai_igh_543f0dc6b7268821d173263d7be7e12d.jpeg',
#  'case_M_20190109095638_0U62372010945338_1_003_002-1_a2_ayy_image0093_rotate_180.png',
#  'bkai_igh_b28f39a546f6eeb0a13b346f09286c94.jpeg',
#  'case_M_20181227102913_0U62363122725013_1_004_001-1_a9_ayy_image0003_flip_h.png',
#  'case_M_20181022094701_0U62368102271800_1_005_001-1_a2_ayy_image0106.png',
#  'case_M_20190121095240_0U62368012118740_1_005_001-1_a1_ayy_image0299_flip_h.png',
#  'bkai_igh_8379499640676289b3e732adb4c5d158.jpeg',
#  'case_M_20181117100025_0U62363111779624_1_007_003-1_a8_ayy_image0134_flip_h.png',
#  'case_M_20181119111911_0U62363111914011_1_005_001-1_a12_ayy_image0348.png',
#  'case_M_20181117100025_0U62363111779624_1_007_003-1_a2_ayy_image0024.png',
#  'case_M_20181017100226_0U62367101735926_1_001_002-1_a15_ayy_image0132.png',
#  'case_M_20181117100025_0U62363111779624_1_007_003-1_a8_ayy_image0422.png',
#  'bkai_igh_a55aadaa77712a48e11d579d903c7d17.jpeg',
#  'case_M_20181227102913_0U62363122725013_1_004_001-1_a8_ayy_image0137.png',
#  'bkai_igh_e85d064f787d4be168d9510588bec07c.jpeg',
#  'case_M_20181025095048_0U62372102595347_1_004_001-1_a14_ayy_image0050.png',
#  'case_M_20190111094523_0U62372011160922_1_005_001-1_a2_ayy_image0009.png',
#  'case_M_20190112093830_0U62372011292129_1_001_001-1_a2_ayy_image0042.png',
#  'case_M_20181022094701_0U62368102271800_1_001_001-1_a10_ayy_image0070_flip_v.png',
#  'case_M_20190115123306_0U62368011540606_1_002_001-1_a6_ayy_image0035_flip_v.png',
#  'case_M_20181119111911_0U62363111914011_1_005_001-1_a16_ayy_image0242_rotate_180.png',
#  'case_M_20181022094701_0U62368102271800_1_005_001-1_a2_ayy_image0046_flip_h.png',
#  'case_M_20181119111911_0U62363111914011_1_005_001-1_a3_ayy_image0022_flip_v.png',
#  'case_M_20181212144657_0U62366121262556_1_001_001-1_a43_ayy_image0025_rotate_90.png',
#  'case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0367_flip_v.png',
#  'case_M_20190128094801_0U62372012857800_1_002_001-1_a6_ayy_image0003.png',
#  'case_M_20181017100226_0U62367101735926_1_005_001-1_a3_ayy_image0107.png',
#  'case_M_20190115123306_0U62368011540606_1_002_001-1_a6_ayy_image0100.png',
#  'case_M_20181119111911_0U62363111914011_1_005_001-1_a12_ayy_image0030_flip_h.png',
#  'case_M_20181220100816_0U62368122007816_1_002_001-1_a7_ayy_image0008.png',
#  'case_M_20190107094528_0U62367010726528_1_002_002-1_a5_ayy_image0016.png',
#  'case_M_20190109095638_0U62372010945338_1_003_001-1_a24_ayy_image0099_rotate_180.png',
#  'case_M_20190115123306_0U62368011540606_1_002_001-1_a6_ayy_image0126_rotate_180.png',
#  'case_M_20181025095048_0U62372102595347_1_004_001-1_a8_ayy_image0155_rotate_180.png',
#  'case_M_20181004140507_0U62366100460906_1_001_001-1_a1_ayy_image0001.png',
#  'bkai_igh_7ae8395e56a6d9ba9d45c3dbc695325d.jpeg',
#  'bkai_igh_b672ab3492fc6239c86a73f97dd5277d.jpeg',
#  'case_M_20190112093830_0U62372011292129_1_001_001-1_a10_ayy_image0098.png',
#  'case_M_20190121095240_0U62368012118740_1_005_001-1_a2_ayy_image0217_rotate_180.png',
#  'case_M_20181015093223_0U62372101593722_1_007_002-1_a12_ayy_image0023.png',
#  'case_M_20181018093806_0U62363101890605_1_007_002-1_a14_ayy_image0029_rotate_180.png',
#  'case_M_20181109101724_0U62368110954624_1_005_001-1_a3_ayy_image0060_flip_h.png',
#  'case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0475.png',
#  'case_M_20181029094800_0U62368102981259_1_005_001-1_a15_ayy_image0112_rotate_270.png',
#  'case_M_20181010094822_0U62363101085921_1_003_001-1_a17_ayy_image0117_flip_v.png',
#  'case_M_20190109095638_0U62372010945338_1_003_001-1_a22_ayy_image0140_rotate_180.png',
#  'case_M_20181110093525_0U62372111056224_1_004_001-1_a2_ayy_image0013.png',
#  'case_M_20181025093921_0U62363102537521_1_002_001-1_a1_ayy_image0056_flip_h.png',
#  'case_M_20190116094421_0U62363011675020_1_004_001-1_a8_ayy_image0077.png',
#  'cvc_colodb_103.png',
#  'case_M_20181213092448_0U62363121315648_1_003_001-1_a14_ayy_image0013.png',
#  'case_M_20181119111911_0U62363111914011_1_005_001-1_a9_ayy_image0032.png',
#  'case_M_20181017100226_0U62367101735926_1_007_004-1_a4_ayy_image0430.png',
#  'case_M_20181025093921_0U62363102537521_1_002_001-1_a1_ayy_image0088.png',
#  'case_M_20181003094031_0U62363100354631_1_001_002-1_a1_ayy_image0527_rotate_180.png',
#  'case_M_20181019101517_0U62367101935917_1_003_001-1_a18_ayy_image0128_rotate_180.png',
#  'case_M_20190116094421_0U62363011675020_1_004_001-1_a4_ayy_image0043_flip_v.png',
#  'case_M_20181226125224_0U62363122631224_1_003_001-1_a6_ayy_image0002.png',
#  'case_M_20181227102913_0U62363122725013_1_004_001-1_a11_ayy_image0001.png',
#  'cvc_colodb_174.png',
#  'case_M_20181214095357_0U62368121473456_1_005_001-1_a3_ayy_image0049_rotate_180.png',
#  'case_M_20181019122218_0U62368101948418_1_002_001-1_a4_ayy_image0114.png',
#  'case_M_20181213131150_0U62365121395349_1_002_002-1_a25_ayy_image0068.png',
#  'case_M_20181207092523_0U62372120765622_1_005_001-1_a10_ayy_image0049_flip_h.png',
#  'case_M_20190116094421_0U62363011675020_1_002_001-1_a2_ayy_image0053.png',
#  'bkai_igh_2f514f401ea0bd55b1393e2ef89424de.jpeg',
#  'case_M_20181019101517_0U62367101935917_1_003_001-1_a15_ayy_image0112.png',
#  'case_M_20181112100700_0U62368111270359_1_005_001-1_a11_ayy_image0102.png',
#  'case_M_20181003094031_0U62363100354631_1_001_002-1_a1_ayy_image0082.png',
#  'case_M_20190110094509_0U62363011095308_1_001_001-1_a3_ayy_image0002_flip_v.png',
#  'case_M_20181025095048_0U62372102595347_1_004_001-1_a5_ayy_image0026_flip_h.png',
#  'case_M_20181017095127_0U62372101720327_1_001_001-1_a1_ayy_image0024_rotate_180.png',
#  'case_M_20181001100941_0U62372100109341_1_005_001-1_a2_ayy_image0113_rotate_90.png',
#  'case_M_20190116094421_0U62363011675020_1_004_001-1_a4_ayy_image0043.png',
#  'case_M_20181227102913_0U62363122725013_1_004_001-1_a9_ayy_image0007_flip_h.png',
#  'case_M_20181120115731_0U62368112064030_1_001_001-1_a4_ayy_image0033.png',
#  'case_M_20181018093806_0U62363101890605_1_007_002-1_a6_ayy_image0016_rotate_180.png',
#  'case_M_20181017100226_0U62367101735926_1_007_001-1_a4_ayy_image0003.png',
#  'case_M_20181025093921_0U62363102537521_1_002_001-1_a11_ayy_image0038.png',
#  'case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0440_flip_h.png',
#  'case_M_20181018093806_0U62363101890605_1_007_002-1_a7_ayy_image0023.png',
#  'cvc_colodb_303.png',
#  'case_M_20181017100226_0U62367101735926_1_007_001-1_a12_ayy_image0074_flip_h.png',
#  'case_M_20181025095048_0U62372102595347_1_004_001-1_a2_ayy_image0035.png',
#  'case_M_20190128094801_0U62372012857800_1_002_001-1_a6_ayy_image0056_rotate_180.png',
#  'case_M_20181025093921_0U62363102537521_1_002_001-1_a11_ayy_image0006.png',
#  'case_M_20181029094800_0U62368102981259_1_002_001-1_a5_ayy_image0010.png',
#  'case_M_20181017100226_0U62367101735926_1_007_001-1_a12_ayy_image0080_flip_h.png',
#  'case_M_20181022094701_0U62368102271800_1_005_001-1_a1_ayy_image0013.png',
#  'case_M_20190117095926_0U62372011750026_1_002_001-1_a4_ayy_image0092_flip_v.png',
#  'case_M_20181109094641_0U62372110931241_1_005_001-1_a4_ayy_image0046.png',
#  'case_M_20190121095240_0U62368012118740_1_004_001-1_a9_ayy_image0035.png',
#  'case_M_20181019101517_0U62367101935917_1_003_001-1_a14_ayy_image0121_flip_h.png',
#  'case_M_20181214095357_0U62368121473456_1_006_003-1_a17_ayy_image0128_flip_h.png',
#  'case_M_20181109094641_0U62372110931241_1_005_001-1_a1_ayy_image0053.png',
#  'case_M_20181001140915_0U62366100164014_1_001_001-1_a7_ayy_image0048_rotate_180.png',
#  'case_M_20190109095638_0U62372010945338_1_003_001-1_a24_ayy_image0417_rotate_180.png',
#  'case_M_20181025095048_0U62372102595347_1_004_001-1_a15_ayy_image0072.png',
#  'case_M_20181119111911_0U62363111914011_1_005_001-1_a12_ayy_image0022.png',
#  'bkai_igh_16d06046f5d8dd18841d318d1f625619.jpeg',
#  'case_M_20181117100025_0U62363111779624_1_007_003-1_a8_ayy_image0469.png',
#  'case_M_20181119111911_0U62363111914011_1_005_001-1_a16_ayy_image0149_flip_h.png',
#  'case_M_20181117100025_0U62363111779624_1_007_003-1_a8_ayy_image0087_flip_v.png',
#  'case_M_20181018093806_0U62363101890605_1_007_002-1_a7_ayy_image0029.png',
#  'case_M_20181010094822_0U62363101085921_1_003_001-1_a2_ayy_image0066_flip_h.png',
#  'case_M_20190117105747_0U62368011712547_1_004_001-1_a13_ayy_image0125.png',
#  'case_M_20181017100226_0U62367101735926_1_007_004-1_a4_ayy_image0276_flip_h.png',
#  'case_M_20181029094800_0U62368102981259_1_002_001-1_a4_ayy_image0008.png',
#  'case_M_20181213131150_0U62365121395349_1_002_001-1_a9_ayy_image0044.png',
#  'case_M_20190131094430_0U62372013151529_1_003_001-1_a4_ayy_image0039.png',
#  'case_M_20190117095926_0U62372011750026_1_002_001-1_a4_ayy_image0086_flip_h.png',
#  'case_M_20190112093830_0U62372011292129_1_001_001-1_a1_ayy_image0241.png',
#  'case_M_20181025095048_0U62372102595347_1_004_001-1_a3_ayy_image0007.png',
#  'case_M_20181119111911_0U62363111914011_1_005_001-1_a4_ayy_image0068.png',
#  'case_M_20190109095638_0U62372010945338_1_003_001-1_a24_ayy_image0253.png',
#  'case_M_20181106093315_0U62372110682814_1_007_001-1_a1_ayy_image0029.png',
#  'case_M_20190109095638_0U62372010945338_1_003_001-1_a24_ayy_image0259_flip_h.png',
#  'case_M_20181214095357_0U62368121473456_1_006_003-1_a4_ayy_image0083.png',
#  'case_M_20181212144657_0U62366121262556_1_001_001-1_a42_ayy_image0014.png',
#  'case_M_20181129152014_0U62366112981213_1_001_001-1_a25_ayy_image0023.png',
#  'case_M_20181018093806_0U62363101890605_1_006_001-1_a2_ayy_image0099.png',
#  'case_M_20190121095240_0U62368012118740_1_005_001-1_a1_ayy_image0032.png',
#  'case_M_20181218101803_0U62372121864002_1_001_001-1_a5_ayy_image0002.png',
#  'case_M_20181117100025_0U62363111779624_1_007_003-1_a1_ayy_image0010.png',
#  'case_M_20181015101337_0U62363101576536_1_005_002-1_a9_ayy_image0071.png',
#  'case_M_20181017095127_0U62372101720327_1_001_001-1_a1_ayy_image0057_flip_h.png',
#  'case_M_20181214095357_0U62368121473456_1_006_003-1_a4_ayy_image0052_rotate_270.png',
#  'case_M_20190130094921_0U62367013093720_1_009_001-1_a7_ayy_image0045.png',
#  'case_M_20181207092523_0U62372120765622_1_005_001-1_a17_ayy_image0066_flip_v.png',
#  'case_M_20190131094104_0U62367013193703_1_003_001-1_a9_ayy_image0081.png',
#  'case_M_20190130094921_0U62367013093720_1_009_001-1_a5_ayy_image0048_rotate_180.png',
#  'case_M_20181025095048_0U62372102595347_1_004_001-1_a14_ayy_image0058.png',
#  'case_M_20181119111911_0U62363111914011_1_005_001-1_a16_ayy_image0282.png',
#  'bkai_igh_af3866269959350e7998934d417cb2eb.jpeg',
#  'case_M_20181010094822_0U62363101085921_1_003_001-1_a7_ayy_image0026_flip_h.png',
#  'case_M_20181119111911_0U62363111914011_1_005_001-1_a19_ayy_image0046.png',
#  'case_M_20181205095418_0U62367120576517_1_007_001-1_a22_ayy_image0079.png',
#  'case_M_20181025095048_0U62372102595347_1_004_001-1_a17_ayy_image0036.png',
#  'case_M_20190117095926_0U62372011750026_1_002_001-1_a3_ayy_image0009_flip_h.png',
#  'case_M_20190131094104_0U62367013193703_1_003_001-1_a9_ayy_image0008.png',
#  'case_M_20190109095638_0U62372010945338_1_003_001-1_a22_ayy_image0130.png',
#  'case_M_20181212144657_0U62366121262556_1_001_002-1_a2_ayy_image0050_flip_v.png',
#  'case_M_20181029094800_0U62368102981259_1_002_001-1_a5_ayy_image0038.png',
#  'case_M_20181217131216_0U62368121700016_1_002_001-1_a10_ayy_image0132_flip_v.png',
#  'case_M_20190121095240_0U62368012118740_1_004_001-1_a9_ayy_image0039.png',
#  'bkai_igh_b79b6669075945dc8ec8f02000f9b6c9.jpeg',
#  'case_M_20190116094421_0U62363011675020_1_004_001-1_a6_ayy_image0023_flip_v.png',
#  'case_M_20181119111911_0U62363111914011_1_005_001-1_a12_ayy_image0413.png',
#  'case_M_20190117095926_0U62372011750026_1_002_001-1_a4_ayy_image0067.png',
#  'case_M_20181117100025_0U62363111779624_1_007_003-1_a2_ayy_image0026.png',
#  'case_M_20181029094800_0U62368102981259_1_002_001-1_a6_ayy_image0024.png',
#  'case_M_20181105095958_0U62368110576557_1_003_002-1_a7_ayy_image0117_flip_v.png',
#  'case_M_20181214095357_0U62368121473456_1_006_003-1_a25_ayy_image0010.png',
#  'case_M_20181019101517_0U62367101935917_1_003_001-1_a18_ayy_image0031_flip_v.png',
#  'case_M_20181213131150_0U62365121395349_1_002_002-1_a25_ayy_image0005.png',
#  'case_M_20181019101517_0U62367101935917_1_003_001-1_a14_ayy_image0131_rotate_270.png',
#  'case_M_20181211093229_0U62367121175028_1_004_001-1_a4_ayy_image0039.png',
#  'case_M_20181211093229_0U62367121175028_1_002_002-1_a11_ayy_image0030.png',
#  'case_M_20190121095240_0U62368012118740_1_005_001-1_a1_ayy_image0001.png',
#  'case_M_20181120115731_0U62368112064030_1_004_002-1_a16_ayy_image0013.png',
#  'case_M_20181217131216_0U62368121700016_1_002_001-1_a10_ayy_image0085.png',
#  'case_M_20190121095240_0U62368012118740_1_005_001-1_a2_ayy_image0193.png',
#  'case_M_20181117100025_0U62363111779624_1_007_003-1_a8_ayy_image0018.png',
#  'case_M_20181203093846_0U62367120345345_1_005_001-1_a6_ayy_image0021.png',
#  'case_M_20181211093229_0U62367121175028_1_004_001-1_a4_ayy_image0005.png',
#  'case_M_20181020093033_0U62363102007833_1_003_001-1_a23_ayy_image0001.png',
#  'case_M_20181022094701_0U62368102271800_1_001_001-1_a11_ayy_image0060.png',
#  'case_M_20190128094801_0U62372012857800_1_002_001-1_a7_ayy_image0008_flip_v.png',
#  'case_M_20190126102153_0U62372012695352_1_001_001-1_a4_ayy_image0013.png',
#  'case_M_20181010094822_0U62363101085921_1_003_001-1_a4_ayy_image0050.png',
#  'case_M_20190116094421_0U62363011675020_1_004_001-1_a4_ayy_image0074.png',
#  'case_M_20181025095048_0U62372102595347_1_004_001-1_a15_ayy_image0002.png',
#  'case_M_20181025095048_0U62372102595347_1_004_001-1_a15_ayy_image0247.png',
#  'case_M_20181113100307_0U62372111373406_1_005_001-1_a23_ayy_image0030_rotate_180.png',
#  'case_M_20181119111911_0U62363111914011_1_005_001-1_a12_ayy_image0326.png',
#  'case_M_20181114092617_0U62372111495316_1_007_001-1_a2_ayy_image0021.png',
#  'case_M_20181113100307_0U62372111373406_1_005_001-1_a26_ayy_image0172.png',
#  'case_M_20181211093229_0U62367121175028_1_002_002-1_a8_ayy_image0076.png',
#  'case_M_20181109094641_0U62372110931241_1_005_001-1_a1_ayy_image0037.png',
#  'case_M_20181120115731_0U62368112064030_1_004_002-1_a16_ayy_image0005.png',
#  'case_M_20190121095240_0U62368012118740_1_005_001-1_a1_ayy_image0330.png',
#  'case_M_20190109095638_0U62372010945338_1_003_001-1_a23_ayy_image0404_rotate_180.png',
#  'case_M_20181018093806_0U62363101890605_1_007_001-1_a1_ayy_image0184_rotate_180.png',
#  'case_M_20181214095357_0U62368121473456_1_006_003-1_a20_ayy_image0019_flip_h.png',
#  'case_M_20181022094701_0U62368102271800_1_001_001-1_a10_ayy_image0049.png',
#  'case_M_20181025095048_0U62372102595347_1_004_001-1_a17_ayy_image0001.png',
#  'case_M_20181129152014_0U62366112981213_1_001_001-1_a19_ayy_image0059.png',
#  'case_M_20190107094528_0U62367010726528_1_002_001-1_a5_ayy_image0030_flip_v.png',
#  'case_M_20181029094800_0U62368102981259_1_002_001-1_a5_ayy_image0042.png',
#  'case_M_20181025095048_0U62372102595347_1_004_001-1_a2_ayy_image0068.png',
#  'case_M_20190130094921_0U62367013093720_1_009_001-1_a7_ayy_image0008_rotate_180.png',
#  'case_M_20181212144657_0U62366121262556_1_001_002-1_a2_ayy_image0021_flip_v.png',
#  'case_M_20190116094421_0U62363011675020_1_004_001-1_a4_ayy_image0072_flip_v.png',
#  'case_M_20181018093806_0U62363101890605_1_007_002-1_a11_ayy_image0004.png',
#  'case_M_20181117100025_0U62363111779624_1_007_003-1_a6_ayy_image0020_flip_v.png',
#  'bkai_igh_5a1d7a36ccf1225024da63fb9a76b926.jpeg',
#  'case_M_20181022094701_0U62368102271800_1_001_001-1_a10_ayy_image0076_rotate_180.png',
#  'case_M_20181226125224_0U62363122631224_1_003_001-1_a5_ayy_image0079.png',
#  'case_M_20190109095638_0U62372010945338_1_003_001-1_a22_ayy_image0025_flip_v.png',
#  'case_M_20181017100226_0U62367101735926_1_007_004-1_a4_ayy_image0112_rotate_180.png',
#  'case_M_20181022094701_0U62368102271800_1_005_001-1_a2_ayy_image0104.png',
#  'case_M_20181211093229_0U62367121175028_1_004_001-1_a12_ayy_image0028_rotate_180.png',
#  'case_M_20181015093223_0U62372101593722_1_007_002-1_a12_ayy_image0021.png',
#  'case_M_20190121095240_0U62368012118740_1_005_001-1_a3_ayy_image0113_flip_v.png',
#  'case_M_20181022094701_0U62368102271800_1_001_001-1_a11_ayy_image0054_rotate_180.png',
#  'case_M_20181129152014_0U62366112981213_1_001_001-1_a21_ayy_image0054_flip_v.png',
#  'case_M_20181214095357_0U62368121473456_1_006_003-1_a17_ayy_image0159.png',
#  'case_M_20181105095958_0U62368110576557_1_003_002-1_a6_ayy_image0341_flip_v.png',
#  'case_M_20181217131216_0U62368121700016_1_002_001-1_a10_ayy_image0162_rotate_180.png',
#  'case_M_20181109101724_0U62368110954624_1_005_001-1_a3_ayy_image0011_rotate_180.png',
#  'case_M_20181010094822_0U62363101085921_1_003_001-1_a4_ayy_image0072_rotate_180.png',
#  'case_M_20181025095048_0U62372102595347_1_004_001-1_a10_ayy_image0003.png',
#  'case_M_20190115123306_0U62368011540606_1_002_001-1_a6_ayy_image0053.png',
#  'case_M_20181119111911_0U62363111914011_1_005_001-1_a12_ayy_image0036_flip_h.png',
#  'case_M_20181119111911_0U62363111914011_1_005_001-1_a16_ayy_image0003_flip_h.png',
#  'case_M_20181119111911_0U62363111914011_1_005_001-1_a12_ayy_image0067_flip_v.png',
#  'case_M_20181010094822_0U62363101085921_1_003_001-1_a7_ayy_image0065.png',
#  'case_M_20181017100226_0U62367101735926_1_007_003-1_a9_ayy_image0046_flip_v.png',
#  'case_M_20181025095048_0U62372102595347_1_004_001-1_a8_ayy_image0066_flip_h.png',
#  'case_M_20181119111911_0U62363111914011_1_005_001-1_a16_ayy_image0042_flip_v.png',
#  'case_M_20181213092448_0U62363121315648_1_003_001-1_a14_ayy_image0054.png',
#  'case_M_20181029094800_0U62368102981259_1_005_001-1_a15_ayy_image0176_flip_v.png',
#  'case_M_20181120115731_0U62368112064030_1_004_001-1_a42_ayy_image0032_flip_v.png',
#  'case_M_20190112093830_0U62372011292129_1_001_001-1_a1_ayy_image0253_flip_h.png',
#  'case_M_20181017100226_0U62367101735926_1_007_001-1_a12_ayy_image0121_flip_h.png',
#  'case_M_20190109095638_0U62372010945338_1_003_001-1_a23_ayy_image0513.png',
#  'case_M_20181214095357_0U62368121473456_1_006_003-1_a22_ayy_image0085_rotate_180.png',
#  'bkai_igh_fea6923881bf04350ffd6984cbcc6d6b.jpeg',
#  'case_M_20181001140915_0U62366100164014_1_001_001-1_a4_ayy_image0026.png',
#  'case_M_20190107094528_0U62367010726528_1_002_001-1_a7_ayy_image0020_rotate_180.png',
#  'case_M_20181129152014_0U62366112981213_1_001_001-1_a25_ayy_image0110.png',
#  'case_M_20181010094822_0U62363101085921_1_003_001-1_a13_ayy_image0341_flip_v.png',
#  'case_M_20181227102913_0U62363122725013_1_004_001-1_a8_ayy_image0145_flip_h.png',
#  'case_M_20181019122218_0U62368101948418_1_002_001-1_a1_ayy_image0034.png',
#  'case_M_20181112100700_0U62368111270359_1_005_001-1_a11_ayy_image0135.png',
#  'case_M_20181117100025_0U62363111779624_1_007_003-1_a8_ayy_image0310_rotate_180.png',
#  'case_M_20190117105747_0U62368011712547_1_004_001-1_a13_ayy_image0227.png',
#  'case_M_20181217131216_0U62368121700016_1_002_001-1_a10_ayy_image0140_rotate_180.png',
#  'case_M_20181018093806_0U62363101890605_1_007_001-1_a1_ayy_image0058.png',
#  'case_M_20181017100226_0U62367101735926_1_007_004-1_a6_ayy_image0011.png',
#  'case_M_20190111094523_0U62372011160922_1_005_001-1_a1_ayy_image0042.png',
#  'bkai_igh_8f2c5f72724e00d827b8bcf15050fb9a.jpeg',
#  'case_M_20181025095048_0U62372102595347_1_004_001-1_a7_ayy_image0050.png',
#  'case_M_20181018093806_0U62363101890605_1_007_002-1_a12_ayy_image0016.png',
#  'case_M_20181211093229_0U62367121175028_1_002_002-1_a8_ayy_image0078_rotate_180.png',
#  'case_M_20181029094800_0U62368102981259_1_005_001-1_a14_ayy_image0032.png',
#  'case_M_20181017100226_0U62367101735926_1_007_003-1_a7_ayy_image0010.png',
#  'case_M_20181126140908_0U62368112685907_1_004_001-1_a14_ayy_image0083_flip_v.png',
#  'case_M_20181110093525_0U62372111056224_1_004_001-1_a2_ayy_image0060_flip_v.png',
#  'case_M_20181019101517_0U62367101935917_1_003_001-1_a11_ayy_image0097.png',
#  'case_M_20190123101017_0U62372012395316_1_004_001-1_a7_ayy_image0011_flip_h.png',
#  'case_M_20181030135203_0U62365103062502_1_001_001-1_a3_ayy_image0036.png',
#  'case_M_20181017100226_0U62367101735926_1_007_004-1_a4_ayy_image0374.png',
#  'case_M_20190121095240_0U62368012118740_1_005_001-1_a1_ayy_image0540_rotate_180.png',
#  'case_M_20181004130627_0U62365100475026_1_002_001-1_a3_ayy_image0056_flip_v.png',
#  'case_M_20181110093525_0U62372111056224_1_004_001-1_a2_ayy_image0090_flip_h.png',
#  'case_M_20181003094031_0U62363100354631_1_001_002-1_a13_ayy_image0068_rotate_180.png',
#  'case_M_20181211093229_0U62367121175028_1_002_002-1_a9_ayy_image0044.png',
#  'case_M_20181022094701_0U62368102271800_1_005_001-1_a4_ayy_image0094.png',
#  'case_M_20181018093806_0U62363101890605_1_007_001-1_a1_ayy_image0020.png',
#  'bkai_igh_4a3eb4d49033c03b0af70cc0f6d32b72.jpeg',
#  'bkai_igh_2cbbcfa4baf3866269959350e7998934.jpeg',
#  'case_M_20190109095638_0U62372010945338_1_003_001-1_a28_ayy_image0029.png',
#  'case_M_20190121095240_0U62368012118740_1_004_001-1_a3_ayy_image0031.png',
#  'case_M_20190111094523_0U62372011160922_1_004_002-1_a14_ayy_image0012.png',
#  'case_M_20190126102153_0U62372012695352_1_001_001-1_a1_ayy_image0063.png',
#  'case_M_20181017100226_0U62367101735926_1_007_004-1_a4_ayy_image0357_flip_h.png',
#  'case_M_20181109094641_0U62372110931241_1_005_001-1_a2_ayy_image0022_rotate_180.png',
#  'case_M_20190115123306_0U62368011540606_1_002_001-1_a6_ayy_image0031.png',
#  'case_M_20181213092448_0U62363121315648_1_003_001-1_a4_ayy_image0003_rotate_180.png',
#  'case_M_20181117100025_0U62363111779624_1_007_003-1_a8_ayy_image0392.png',
#  'case_M_20181015101337_0U62363101576536_1_005_001-1_a14_ayy_image0014_flip_h.png',
#  'case_M_20181025095048_0U62372102595347_1_004_001-1_a11_ayy_image0090.png',
#  'case_M_20181025093921_0U62363102537521_1_002_001-1_a11_ayy_image0055.png',
#  'case_M_20181117100025_0U62363111779624_1_007_003-1_a1_ayy_image0014_rotate_90.png',
#  'case_M_20181126140908_0U62368112685907_1_004_001-1_a14_ayy_image0072.png',
#  'case_M_20181117100025_0U62363111779624_1_007_003-1_a8_ayy_image0180.png',
#  'case_M_20181126095408_0U62367112660907_1_001_002-1_a3_ayy_image0024_flip_h.png',
#  'case_M_20190115123306_0U62368011540606_1_002_001-1_a5_ayy_image0009.png',
#  'case_M_20181010094822_0U62363101085921_1_003_001-1_a15_ayy_image0436.png',
#  'case_M_20181213092448_0U62363121315648_1_003_001-1_a3_ayy_image0077.png',
#  'case_M_20190115123306_0U62368011540606_1_002_001-1_a6_ayy_image0047.png',
#  'case_M_20181015101337_0U62363101576536_1_005_001-1_a21_ayy_image0230.png',
#  'case_M_20190130094921_0U62367013093720_1_009_001-1_a5_ayy_image0050_flip_h.png',
#  'case_M_20190121095240_0U62368012118740_1_005_001-1_a2_ayy_image0124.png',
#  'case_M_20190121095240_0U62368012118740_1_004_001-1_a9_ayy_image0029.png',
#  'bkai_igh_b6692e6be5e8f14e1e0ae936de314f2d.jpeg',
#  'case_M_20181029094800_0U62368102981259_1_002_001-1_a4_ayy_image0037.png',
#  'case_M_20181126095408_0U62367112660907_1_001_002-1_a6_ayy_image0013_rotate_90.png',
#  'case_M_20181025095048_0U62372102595347_1_004_001-1_a11_ayy_image0005_flip_v.png',
#  'case_M_20181025095048_0U62372102595347_1_004_001-1_a13_ayy_image0051_rotate_180.png',
#  'bkai_igh_f428c953248704ccdc265a0b0a1230b1.jpeg',
#  'case_M_20181025093921_0U62363102537521_1_002_001-1_a1_ayy_image0052.png',
#  'case_M_20190112093830_0U62372011292129_1_001_001-1_a6_ayy_image0011_rotate_180.png',
#  'case_M_20181207092523_0U62372120765622_1_002_001-1_a2_ayy_image0018_flip_v.png',
#  'case_M_20181010094822_0U62363101085921_1_003_001-1_a17_ayy_image0010_flip_v.png',
#  'case_M_20181018093806_0U62363101890605_1_006_001-1_a1_ayy_image0021.png',
#  'case_M_20181226125224_0U62363122631224_1_003_001-1_a10_ayy_image0130.png',
#  'case_M_20181106093315_0U62372110682814_1_007_001-1_a6_ayy_image0016.png',
#  'case_M_20181227102913_0U62363122725013_1_004_001-1_a8_ayy_image0005.png',
#  'case_M_20190117105747_0U62368011712547_1_004_001-1_a13_ayy_image0237.png',
#  'case_M_20181003094031_0U62363100354631_1_001_002-1_a1_ayy_image0556.png',
#  'case_M_20181018093806_0U62363101890605_1_007_002-1_a10_ayy_image0070.png',
#  'case_M_20181228140523_0U62365122821823_1_001_001-1_a3_ayy_image0144.png',
#  'cvc_colodb_104.png',
#  'case_M_20181129152014_0U62366112981213_1_001_001-1_a17_ayy_image0107.png',
#  'case_M_20181003094031_0U62363100354631_1_001_002-1_a1_ayy_image0131_rotate_180.png',
#  'case_M_20181117100025_0U62363111779624_1_007_003-1_a7_ayy_image0006_flip_h.png',
#  'case_M_20181025095048_0U62372102595347_1_004_001-1_a11_ayy_image0064_flip_v.png',
#  'case_M_20181025093921_0U62363102537521_1_002_001-1_a10_ayy_image0078.png',
#  'case_M_20190109095638_0U62372010945338_1_003_001-1_a24_ayy_image0139.png',
#  'case_M_20181211093229_0U62367121175028_1_004_001-1_a7_ayy_image0018.png',
#  'case_M_20190121095240_0U62368012118740_1_004_001-1_a7_ayy_image0047.png',
#  'case_M_20181119111911_0U62363111914011_1_005_001-1_a16_ayy_image0030.png',
#  'case_M_20181017100226_0U62367101735926_1_007_003-1_a7_ayy_image0006.png',
#  'cvc_colodb_021.png',
#  'case_M_20181031103335_0U62368103151535_1_006_001-1_a1_ayy_image0036_flip_h.png',
#  'case_M_20190116094421_0U62363011675020_1_004_001-1_a2_ayy_image0029.png',
#  'bkai_igh_926a6f23c5d6d5f35f66adf95b204727.jpeg',
#  'case_M_20181207092523_0U62372120765622_1_002_001-1_a2_ayy_image0022_flip_v.png',
#  'case_M_20190117095926_0U62372011750026_1_002_001-1_a4_ayy_image0037_rotate_180.png',
#  'case_M_20181117100025_0U62363111779624_1_007_003-1_a8_ayy_image0434_rotate_180.png',
# ...
#  'case_M_20181030135203_0U62365103062502_1_001_001-1_a3_ayy_image0010_flip_h.png',
#  'case_M_20181114092617_0U62372111495316_1_007_001-1_a5_ayy_image0026.png',
#  'case_M_20181109094641_0U62372110931241_1_005_001-1_a1_ayy_image0008.png',
#  'case_M_20181022094701_0U62368102271800_1_005_001-1_a2_ayy_image0092_flip_h.png',
#  'case_M_20181025093921_0U62363102537521_1_002_001-1_a11_ayy_image0091.png',
#  'case_M_20181119111911_0U62363111914011_1_005_001-1_a13_ayy_image0014_flip_v.png',
#  'case_M_20181026100314_0U62363102665613_1_004_001-1_a4_ayy_image0031_flip_h.png',
#  'case_M_20181019101517_0U62367101935917_1_003_001-1_a12_ayy_image0030_flip_h.png',
#  'bkai_igh_ce15c1346e62522325c1b9c4fc9cbe1e.jpeg',
#  'case_M_20190112093830_0U62372011292129_1_001_001-1_a1_ayy_image0268.png',
#  'case_M_20181126140908_0U62368112685907_1_004_001-1_a14_ayy_image0040_flip_h.png',
#  'case_M_20181203093846_0U62367120345345_1_005_001-1_a8_ayy_image0053_rotate_180.png',
#  'case_M_20181129152014_0U62366112981213_1_001_001-1_a19_ayy_image0002.png',
#  'case_M_20181119111911_0U62363111914011_1_005_001-1_a12_ayy_image0194.png',
#  'case_M_20181205095418_0U62367120576517_1_007_001-1_a24_ayy_image0086_flip_h.png',
#  'case_M_20181019101517_0U62367101935917_1_003_001-1_a15_ayy_image0116_flip_h.png',
#  'case_M_20181113100307_0U62372111373406_1_005_001-1_a26_ayy_image0111.png',
#  'case_M_20181019101517_0U62367101935917_1_003_001-1_a18_ayy_image0010.png',
#  'case_M_20190112093830_0U62372011292129_1_001_001-1_a1_ayy_image0247_rotate_180.png',
#  'case_M_20181119111911_0U62363111914011_1_005_001-1_a12_ayy_image0032_flip_h.png',
#  'case_M_20181031103335_0U62368103151535_1_006_001-1_a1_ayy_image0050_flip_h.png',
#  'case_M_20181109094641_0U62372110931241_1_005_001-1_a2_ayy_image0063.png',
#  'case_M_20190128094801_0U62372012857800_1_002_001-1_a6_ayy_image0108_flip_h.png',
#  'case_M_20190116094421_0U62363011675020_1_004_001-1_a6_ayy_image0074_flip_v.png',
#  'case_M_20181025095048_0U62372102595347_1_004_001-1_a8_ayy_image0186_flip_v.png',
#  'bkai_igh_02000f9b6c911c4aa179344271fa54aa.jpeg',
#  'case_M_20181010094822_0U62363101085921_1_003_001-1_a1_ayy_image0065.png',
#  'case_M_20190116094421_0U62363011675020_1_004_001-1_a4_ayy_image0070.png',
#  'case_M_20181010094822_0U62363101085921_1_003_001-1_a4_ayy_image0058.png',
#  'case_M_20181010094822_0U62363101085921_1_003_001-1_a2_ayy_image0062_flip_h.png',
#  'case_M_20181226125224_0U62363122631224_1_003_001-1_a8_ayy_image0009.png',
#  'case_M_20181114092617_0U62372111495316_1_007_001-1_a5_ayy_image0026_flip_v.png',
#  'case_M_20181017100226_0U62367101735926_1_001_002-1_a15_ayy_image0030_flip_h.png',
#  'case_M_20181010094822_0U62363101085921_1_003_001-1_a1_ayy_image0206.png',
#  'case_M_20181025095048_0U62372102595347_1_004_001-1_a11_ayy_image0112.png',
#  'case_M_20181201091914_0U62363120125014_1_005_001-1_a10_ayy_image0074_flip_h.png',
#  'case_M_20181025095048_0U62372102595347_1_004_001-1_a17_ayy_image0036_flip_h.png',
#  'case_M_20181226125224_0U62363122631224_1_003_001-1_a6_ayy_image0048_flip_h.png',
#  'case_M_20181117100025_0U62363111779624_1_007_003-1_a1_ayy_image0012_rotate_90.png',
#  'bkai_igh_bf0b5633059989805234e222e19769fa.jpeg',
#  'case_M_20181004130627_0U62365100475026_1_002_001-1_a5_ayy_image0026.png',
#  'case_M_20181022094701_0U62368102271800_1_005_001-1_a2_ayy_image0080_rotate_180.png',
#  'case_M_20181119111911_0U62363111914011_1_005_001-1_a8_ayy_image0088.png',
#  'case_M_20190121095240_0U62368012118740_1_005_001-1_a3_ayy_image0153_flip_h.png',
#  'case_M_20181025095048_0U62372102595347_1_004_001-1_a8_ayy_image0131_flip_h.png',
#  'case_M_20181017100226_0U62367101735926_1_005_001-1_a7_ayy_image0019.png',
#  'case_M_20190109095638_0U62372010945338_1_001_001-1_a3_ayy_image0060_flip_h.png',
#  'case_M_20181214095357_0U62368121473456_1_006_003-1_a17_ayy_image0124.png',
#  'case_M_20190115123306_0U62368011540606_1_002_001-1_a5_ayy_image0088.png',
#  'case_M_20181126095408_0U62367112660907_1_001_002-1_a6_ayy_image0048.png',
#  'case_M_20181029094800_0U62368102981259_1_005_001-1_a12_ayy_image0116.png',
#  'case_M_20181017100226_0U62367101735926_1_007_003-1_a2_ayy_image0087_flip_h.png',
#  'case_M_20181017100226_0U62367101735926_1_007_004-1_a4_ayy_image0361_flip_v.png',
#  'cvc_colodb_331.png',
#  'case_M_20181220100816_0U62368122007816_1_002_001-1_a7_ayy_image0089.png',
#  'case_M_20181022094701_0U62368102271800_1_005_001-1_a3_ayy_image0068.png',
#  'case_M_20181119111911_0U62363111914011_1_005_001-1_a12_ayy_image0054_flip_v.png',
#  'case_M_20190107094528_0U62367010726528_1_002_001-1_a5_ayy_image0061.png',
#  'case_M_20190131094104_0U62367013193703_1_003_001-1_a8_ayy_image0046.png',
#  'case_M_20181212144657_0U62366121262556_1_001_001-1_a43_ayy_image0040_flip_h.png',
#  'case_M_20190115123306_0U62368011540606_1_002_001-1_a5_ayy_image0060.png',
#  'case_M_20181025095048_0U62372102595347_1_004_001-1_a7_ayy_image0052.png',
#  'case_M_20190115123306_0U62368011540606_1_002_001-1_a4_ayy_image0167_flip_v.png',
#  'case_M_20181119111911_0U62363111914011_1_005_001-1_a16_ayy_image0028_flip_h.png',
#  'case_M_20190116094421_0U62363011675020_1_002_001-1_a2_ayy_image0005.png',
#  'case_M_20190130094921_0U62367013093720_1_009_001-1_a7_ayy_image0039.png',
#  'case_M_20190112093830_0U62372011292129_1_001_001-1_a1_ayy_image0150.png',
#  'bkai_igh_337948a41964c1d4f50a5f3601ad4f13.jpeg',
#  'case_M_20181117100025_0U62363111779624_1_007_003-1_a1_ayy_image0002.png',
#  'case_M_20190110094509_0U62363011095308_1_001_002-1_a4_ayy_image0088_rotate_270.png',
#  'case_M_20190110094509_0U62363011095308_1_001_002-1_a4_ayy_image0040_flip_v.png',
#  'case_M_20181025093921_0U62363102537521_1_002_001-1_a9_ayy_image0046.png',
#  'case_M_20190116093042_0U62372011685941_1_001_001-1_a5_ayy_image0040_rotate_180.png',
#  'case_M_20181017100226_0U62367101735926_1_007_004-1_a4_ayy_image0232.png',
#  'case_M_20181207092523_0U62372120765622_1_005_001-1_a11_ayy_image0031.png',
#  'case_M_20181018093806_0U62363101890605_1_007_001-1_a1_ayy_image0050.png',
#  'case_M_20181211093229_0U62367121175028_1_002_002-1_a7_ayy_image0003.png',
#  'case_M_20181217131216_0U62368121700016_1_002_001-1_a10_ayy_image0221_flip_v.png',
#  'case_M_20181203093846_0U62367120345345_1_005_001-1_a8_ayy_image0066_flip_v.png',
#  'case_M_20181226125224_0U62363122631224_1_003_001-1_a4_ayy_image0044.png',
#  'case_M_20181017100226_0U62367101735926_1_007_001-1_a4_ayy_image0009.png',
#  'case_M_20181010094822_0U62363101085921_1_003_001-1_a13_ayy_image0509_rotate_180.png',
#  'case_M_20181026100314_0U62363102665613_1_004_001-1_a5_ayy_image0060.png',
#  'case_M_20181022094701_0U62368102271800_1_005_001-1_a3_ayy_image0033_rotate_90.png',
#  'case_M_20181105095958_0U62368110576557_1_003_002-1_a6_ayy_image0346_flip_v.png',
#  'case_M_20190126102153_0U62372012695352_1_001_001-1_a4_ayy_image0157.png',
#  'case_M_20181112100700_0U62368111270359_1_005_001-1_a11_ayy_image0035.png',
#  'case_M_20181203093846_0U62367120345345_1_005_001-1_a7_ayy_image0015_flip_v.png',
#  'case_M_20181022094701_0U62368102271800_1_001_001-1_a11_ayy_image0035_flip_v.png',
#  'case_M_20181025095048_0U62372102595347_1_004_001-1_a5_ayy_image0057_flip_v.png',
#  'case_M_20181203093846_0U62367120345345_1_005_001-1_a5_ayy_image0027_rotate_270.png',
#  'case_M_20190115123306_0U62368011540606_1_002_001-1_a6_ayy_image0122_flip_h.png',
#  'case_M_20181004093748_0U62372100445348_1_001_001-1_a8_ayy_image0006.png',
#  'case_M_20181203093846_0U62367120345345_1_005_001-1_a8_ayy_image0053.png',
#  'case_M_20190128094801_0U62372012857800_1_002_001-1_a6_ayy_image0053.png',
#  'case_M_20181025095048_0U62372102595347_1_004_001-1_a2_ayy_image0031.png',
#  'case_M_20190121095240_0U62368012118740_1_005_001-1_a2_ayy_image0056_flip_h.png',
#  'case_M_20190115123306_0U62368011540606_1_002_001-1_a4_ayy_image0107.png',
#  'case_M_20181211093229_0U62367121175028_1_002_002-1_a3_ayy_image0041.png',
#  'case_M_20181207092523_0U62372120765622_1_005_001-1_a17_ayy_image0064_flip_v.png',
#  'case_M_20181109094641_0U62372110931241_1_005_001-1_a4_ayy_image0006.png',
#  'case_M_20181017100226_0U62367101735926_1_007_004-1_a6_ayy_image0136.png',
#  'case_M_20181004093748_0U62372100445348_1_001_001-1_a8_ayy_image0085.png',
#  'case_M_20190109095638_0U62372010945338_1_003_001-1_a24_ayy_image0168_rotate_180.png',
#  'case_M_20181203093846_0U62367120345345_1_005_001-1_a7_ayy_image0056.png',
#  'case_M_20190109095638_0U62372010945338_1_003_002-1_a2_ayy_image0077.png',
#  'case_M_20181212144657_0U62366121262556_1_001_002-1_a2_ayy_image0066_rotate_180.png',
#  'case_M_20190115123306_0U62368011540606_1_002_001-1_a6_ayy_image0021_flip_v.png',
#  'case_M_20181117100025_0U62363111779624_1_007_003-1_a6_ayy_image0008.png',
#  'case_M_20190121095240_0U62368012118740_1_005_001-1_a2_ayy_image0226_rotate_180.png',
#  'case_M_20181017095127_0U62372101720327_1_001_001-1_a3_ayy_image0012.png',
#  'case_M_20181117100025_0U62363111779624_1_007_003-1_a8_ayy_image0388_flip_v.png',
#  'case_M_20181010094822_0U62363101085921_1_003_001-1_a13_ayy_image0600_flip_v.png',
#  'case_M_20181010094822_0U62363101085921_1_003_001-1_a13_ayy_image0167_flip_v.png',
#  'case_M_20181211093229_0U62367121175028_1_004_001-1_a10_ayy_image0077.png',
#  'case_M_20190115123306_0U62368011540606_1_002_001-1_a6_ayy_image0236.png',
#  'case_M_20181119111911_0U62363111914011_1_005_001-1_a19_ayy_image0010.png',
#  'case_M_20181119111911_0U62363111914011_1_005_001-1_a12_ayy_image0243_flip_h.png',
#  'case_M_20190111094523_0U62372011160922_1_004_002-1_a13_ayy_image0023_flip_h.png',
#  'case_M_20181109094641_0U62372110931241_1_005_001-1_a2_ayy_image0126.png',
#  'case_M_20181129152014_0U62366112981213_1_001_001-1_a19_ayy_image0081.png',
#  'case_M_20181015101337_0U62363101576536_1_005_002-1_a9_ayy_image0061.png',
#  'case_M_20181120115731_0U62368112064030_1_001_001-1_a4_ayy_image0007.png',
#  'case_M_20181017100226_0U62367101735926_1_007_003-1_a6_ayy_image0042.png',
#  'case_M_20181211093229_0U62367121175028_1_004_001-1_a12_ayy_image0048.png',
#  'case_M_20181018093806_0U62363101890605_1_007_001-1_a3_ayy_image0061_rotate_270.png',
#  'case_M_20181126140908_0U62368112685907_1_004_001-1_a17_ayy_image0026.png',
#  'bkai_igh_6c04414eaa922bca73d5379c7c851a50.jpeg',
#  'bkai_igh_b60f2965341caf528ca0adabead1ae73.jpeg',
#  'case_M_20181025093921_0U62363102537521_1_002_001-1_a10_ayy_image0017_flip_h.png',
#  'case_M_20181117100025_0U62363111779624_1_007_003-1_a8_ayy_image0312_flip_v.png',
#  'case_M_20190123101017_0U62372012395316_1_004_001-1_a4_ayy_image0048.png',
#  'case_M_20190117095926_0U62372011750026_1_002_001-1_a1_ayy_image0036.png',
#  'case_M_20190117095926_0U62372011750026_1_002_001-1_a5_ayy_image0008_rotate_270.png',
#  'case_M_20190116094421_0U62363011675020_1_002_001-1_a1_ayy_image0026.png',
#  'case_M_20181029094800_0U62368102981259_1_005_001-1_a15_ayy_image0138.png',
#  'case_M_20181019122218_0U62368101948418_1_002_001-1_a4_ayy_image0045.png',
#  'case_M_20181214095357_0U62368121473456_1_006_003-1_a20_ayy_image0023_rotate_180.png',
#  'case_M_20181018093806_0U62363101890605_1_007_002-1_a1_ayy_image0029.png',
#  'case_M_20190109095638_0U62372010945338_1_003_001-1_a28_ayy_image0089.png',
#  'case_M_20181018093806_0U62363101890605_1_007_002-1_a6_ayy_image0008.png',
#  'case_M_20190128094801_0U62372012857800_1_002_001-1_a6_ayy_image0076.png',
#  'case_M_20181001100941_0U62372100109341_1_005_001-1_a2_ayy_image0139.png',
#  'case_M_20181117100025_0U62363111779624_1_007_003-1_a5_ayy_image0011_flip_v.png',
#  'case_M_20181226125224_0U62363122631224_1_003_001-1_a8_ayy_image0068.png',
#  'case_M_20181017100226_0U62367101735926_1_007_004-1_a6_ayy_image0315.png',
#  'case_M_20181211093229_0U62367121175028_1_004_001-1_a10_ayy_image0015.png',
#  'case_M_20181017100226_0U62367101735926_1_007_003-1_a6_ayy_image0044.png',
#  'case_M_20181017095127_0U62372101720327_1_001_001-1_a1_ayy_image0012.png',
#  'case_M_20181212144657_0U62366121262556_1_001_001-1_a43_ayy_image0034.png',
#  'case_M_20181015101337_0U62363101576536_1_005_001-1_a21_ayy_image0263.png',
#  'case_M_20181220100816_0U62368122007816_1_002_001-1_a7_ayy_image0008_rotate_180.png',
#  'case_M_20190128094801_0U62372012857800_1_002_001-1_a6_ayy_image0080.png',
#  'case_M_20190128094801_0U62372012857800_1_002_001-1_a13_ayy_image0009.png',
#  'case_M_20190115123306_0U62368011540606_1_002_001-1_a7_ayy_image0035.png',
#  'case_M_20181018093806_0U62363101890605_1_006_001-1_a1_ayy_image0001_flip_h.png',
#  'case_M_20181110093525_0U62372111056224_1_004_001-1_a2_ayy_image0027_flip_v.png',
#  'case_M_20181214095357_0U62368121473456_1_006_003-1_a22_ayy_image0069_flip_h.png',
#  'case_M_20181117100025_0U62363111779624_1_007_003-1_a8_ayy_image0471.png',
#  'case_M_20190112093830_0U62372011292129_1_001_001-1_a6_ayy_image0044.png',
#  'case_M_20181017100226_0U62367101735926_1_007_003-1_a9_ayy_image0050_flip_h.png',
#  'case_M_20181119111911_0U62363111914011_1_005_001-1_a6_ayy_image0035_rotate_180.png',
#  'case_M_20181106093315_0U62372110682814_1_007_001-1_a3_ayy_image0020_flip_v.png',
#  'case_M_20181207092523_0U62372120765622_1_005_001-1_a10_ayy_image0020.png',
#  'case_M_20181213131150_0U62365121395349_1_002_001-1_a9_ayy_image0056_flip_v.png',
#  'case_M_20181015101337_0U62363101576536_1_005_002-1_a9_ayy_image0040_flip_v.png',
#  'case_M_20181106093315_0U62372110682814_1_007_001-1_a6_ayy_image0042.png',
#  'case_M_20181020093033_0U62363102007833_1_003_002-1_a1_ayy_image0004.png',
#  'case_M_20181211093229_0U62367121175028_1_004_001-1_a12_ayy_image0085.png',
#  'case_M_20190126102153_0U62372012695352_1_001_001-1_a4_ayy_image0151.png',
#  'case_M_20190115123306_0U62368011540606_1_002_001-1_a6_ayy_image0181.png',
#  'case_M_20181004130627_0U62365100475026_1_002_001-1_a5_ayy_image0127.png',
#  'case_M_20181129152014_0U62366112981213_1_001_001-1_a19_ayy_image0016_flip_v.png',
#  'case_M_20181025095048_0U62372102595347_1_004_001-1_a8_ayy_image0066.png',
#  'case_M_20181129152014_0U62366112981213_1_001_001-1_a21_ayy_image0011.png',
#  'case_M_20181214095357_0U62368121473456_1_006_003-1_a5_ayy_image0055_flip_v.png',
#  'bkai_igh_4a17af18f72c8e6166a915669c99390d.jpeg',
#  'case_M_20181117100025_0U62363111779624_1_007_003-1_a8_ayy_image0119_flip_v.png',
#  'case_M_20190117095926_0U62372011750026_1_002_001-1_a1_ayy_image0030.png',
#  'case_M_20181004093748_0U62372100445348_1_001_001-1_a4_ayy_image0142_rotate_180.png',
#  'case_M_20190109095638_0U62372010945338_1_003_001-1_a30_ayy_image0071_flip_v.png',
#  'case_M_20181109094641_0U62372110931241_1_005_001-1_a4_ayy_image0018.png',
#  'case_M_20181017100226_0U62367101735926_1_007_001-1_a4_ayy_image0052.png',
#  'case_M_20181001140915_0U62366100164014_1_001_001-1_a4_ayy_image0042.png',
#  'case_M_20190121095240_0U62368012118740_1_005_001-1_a1_ayy_image0518_rotate_90.png',
#  'case_M_20190115123306_0U62368011540606_1_002_001-1_a6_ayy_image0003_flip_h.png',
#  'case_M_20190110094509_0U62363011095308_1_001_001-1_a2_ayy_image0045.png',
#  'case_M_20181226125224_0U62363122631224_1_003_001-1_a2_ayy_image0075.png',
#  'case_M_20181010094822_0U62363101085921_1_003_001-1_a17_ayy_image0059_flip_v.png',
#  'case_M_20181025093921_0U62363102537521_1_002_001-1_a1_ayy_image0070.png',
#  'case_M_20181019122218_0U62368101948418_1_002_001-1_a3_ayy_image0001.png',
#  'case_M_20181105095958_0U62368110576557_1_003_002-1_a9_ayy_image0044.png',
#  'bkai_igh_38a1eecd70ebce6347c491b37c8c2e5a.jpeg',
#  'case_M_20181220100816_0U62368122007816_1_002_001-1_a7_ayy_image0063.png',
#  'case_M_20181019101517_0U62367101935917_1_003_001-1_a18_ayy_image0116.png',
#  'case_M_20181001100941_0U62372100109341_1_005_001-1_a2_ayy_image0028_rotate_90.png',
#  'case_M_20190107094528_0U62367010726528_1_002_001-1_a5_ayy_image0016_flip_h.png',
#  'case_M_20190121095240_0U62368012118740_1_004_001-1_a8_ayy_image0184_flip_h.png',
#  'case_M_20181214095357_0U62368121473456_1_006_003-1_a22_ayy_image0016_flip_v.png',
#  'case_M_20181025095048_0U62372102595347_1_004_001-1_a8_ayy_image0068.png',
#  'case_M_20181227102913_0U62363122725013_1_004_001-1_a11_ayy_image0015.png',
#  'case_M_20181026100314_0U62363102665613_1_004_001-1_a4_ayy_image0060.png',
#  'case_M_20181015101337_0U62363101576536_1_005_002-1_a9_ayy_image0061_rotate_180.png',
#  'case_M_20181120115731_0U62368112064030_1_001_001-1_a6_ayy_image0003_flip_v.png',
#  ...]

# %%
data_processor.move_random_n_images(F_TRAIN_IMAGES_NEG, F_VAL_IMAGES_NEG, 1000)
# Out:
# ['case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image007679.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image003660.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image003540.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007936.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image002799_rotate_90.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image000110_rotate_270.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image001332_flip_h.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image000293.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image001814.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image007201.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image003337.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image003669_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image001949_rotate_270.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image010396.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image003366_rotate_180.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image000180.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image001285.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image005629.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image006122.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image003032.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image004176.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image007800.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image006229_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image000273_flip_v.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image010262.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image006877_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image002893_rotate_270.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image011185_rotate_90.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image005024.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image005778_rotate_270.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image000634.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image006576.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image007068.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image000521_rotate_90.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image006359.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image000086.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image001362.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image001248.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image010822_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image003434.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005161.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image001337.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image002356.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image006465.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image001496.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image001691.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007613_rotate_90.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image002015.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image005952.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image001591_rotate_270.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image004643_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image000385_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005568.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image011493.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005525_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image007212.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image005531_rotate_270.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image011562.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008687.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image004842.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image002669_rotate_270.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image001165.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image005242.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image004323_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image007335.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image005461_rotate_270.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image008958_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image000476.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image005031_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image003888.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image002244.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_3_ayy_image000065.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image009976_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image000578.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image001711_flip_h.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image010228.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image009641.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image001796.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image004968.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004337.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image001457.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image006309.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009919.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image002190_flip_h.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image003278.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image000940.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image003363.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005137.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image001031_flip_h.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image006874.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image003177_rotate_270.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image005683.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image003577.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image000514.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image007628.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image003936.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006543_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image004208_flip_v.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image004627_rotate_270.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image006049_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image004110.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image001055.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image008311.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image004514.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008784.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image000821.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image007592_rotate_270.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image000870_rotate_90.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image002588.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image001008_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image004597.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image001299.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004191_rotate_270.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image005828_rotate_270.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image008826_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image000934.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image003065.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image007718_rotate_180.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image007628_rotate_180.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image004992_rotate_180.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007502.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image010299.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image001297.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image010094_flip_h.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image000584.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image003473.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image001995.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image002828.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image006399_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image005691_flip_v.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image010311_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image010730_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007477.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image010081.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image011323.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image004747.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007339_rotate_180.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008501.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image006981.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image000240.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image001673_rotate_270.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image002223_rotate_180.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image006241.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image003157.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image000378.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004719.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image000142.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image002657.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image003048_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image002910.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image006326.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image002632.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image007288.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image004532.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image006913.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image003391.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image000876_rotate_180.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image002546.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image003701_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004865.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image010464.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004281_rotate_180.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image002998_rotate_180.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image006490_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image002954.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image002450_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009864.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image007910.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image000803.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image010385_flip_h.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image001426_flip_v.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image003604.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image003533_rotate_180.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004712_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007448_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image001323_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image002518.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image008531.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_3_ayy_image000123.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image010651.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image000629_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image002406.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image004862.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008072.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image000818_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004022.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image004848.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image002155.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image001107.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image005311_rotate_180.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image004777_rotate_180.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image000663.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image003410.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image009221_flip_v.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image009641_flip_v.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image004570.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image001426.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006525.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006717_flip_h.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image000412.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image010766.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image005664.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009853.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004851.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image006894_rotate_90.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image004348_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image002257.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image002931_flip_v.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image005132.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image009648_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image003041_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005481.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004196_flip_v.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image002271.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image005483.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image011459.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image009674.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image001328.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004493_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image001197.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image000534.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image006686_rotate_180.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image005706_rotate_180.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image002524.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image002334.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image004101.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image003819.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004860_rotate_90.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image010150_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image010088.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image007788_flip_v.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image005467.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image009926.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image005086.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image009085.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image007862.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image008017_flip_v.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image006365.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image007230_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image006576_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image001989.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image010923.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image003889.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image007724.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image003730_rotate_90.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008934_rotate_180.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image003727_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image001010.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image000027_rotate_90.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image005624.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005476.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image003341.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image000781.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image010930.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005710.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image002216.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image001431.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image005483.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image007452_rotate_180.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image000243.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image003480.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image000345.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image005756_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image002666_rotate_270.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image001427_flip_h.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image011538.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image002002.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image008820.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image003735_rotate_90.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image003910.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image004905_flip_h.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image006309_flip_h.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image002559.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image006489.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image007108_rotate_270.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image010831.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image002942_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image001292.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image000110.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image011544.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image007886_flip_h.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image005237_rotate_90.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image004609.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image010108.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image006987.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image003757.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image004413_rotate_90.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image003089.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image000686_rotate_90.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image009950_flip_h.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image001000.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image005079.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image000715.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image000014.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image006756.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image001124.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image006844.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004731.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image006682_flip_v.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image003244_flip_h.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_3_ayy_image000014.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image008300_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image006179.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image004409.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image001342.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image000888.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image002228_flip_h.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image000179.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image011623.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image007102.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image000144.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image011029.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image002092_flip_h.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image010148.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image001173.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image000663_rotate_270.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005350.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image002620.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image007217.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image003768.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image006709.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004069.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image003626.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image006141_rotate_270.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image003056.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image002384.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image011414_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image003165.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image004190.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image004133_flip_h.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image001261.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image009469.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image004642.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image000057.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image010078.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image000590.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image002615.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image004038_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image002436_rotate_180.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image002998.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image004115.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image006998_rotate_180.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004158_flip_v.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image002330_rotate_180.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image007441.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image005026_rotate_270.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image004810.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image006587_rotate_180.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image007246_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image000478_rotate_270.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image000339_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image004505.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006225.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image007199_rotate_90.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image004800.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image006724.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image009352.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008072_flip_v.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image003837.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image004827.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image000779.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image002137.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image006417.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image003170.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image007365.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image003094.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image010456_flip_h.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image006918_rotate_90.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004256.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image010620.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image003120.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image000657.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image008169.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image004632.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image007666.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image002390_rotate_270.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image004328_rotate_270.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image000245.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_3_ayy_image000084.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image002179.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005758.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image010613.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image002642_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image006334.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image000016.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008112.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image007666_rotate_90.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image006018_rotate_180.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image001656.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image005368.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image001255_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image000720_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image005507_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006750_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009099.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image000001.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image008476.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image002575_rotate_180.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image003717_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image000645.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image005787.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image003893.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image006588.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image004529.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image004873.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image006369_rotate_270.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image006731.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image003324.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image009408.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image002753_flip_v.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image006707.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004392.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image000797.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004611_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image001652_rotate_270.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image009140_rotate_270.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009081.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image006568_flip_v.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image007304.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image003948_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image007266.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image011308.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image008671.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image005450_flip_v.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image001480.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image006216_flip_v.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image007435.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006612.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image009706_flip_h.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image010345_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image003745.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image004207.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image003801.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005556.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image007241_rotate_180.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image002699.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image006833.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image002936.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image011164.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image009849_rotate_180.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image006256_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005269.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image006698.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image007150.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007502_rotate_90.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image004654_rotate_90.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image008891.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image000318.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004789.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image004317.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image000542_rotate_270.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image010721.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004196.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image004871.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image002216.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image010169.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009439_rotate_270.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image001334.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image002514.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image004097.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image005212.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image010419.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image005433.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image003987.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image004866_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image002022_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006079_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image001410.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image008410.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image003305.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image009242.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image005731.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image007055.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image000549_rotate_270.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image002899_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image003490.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006599_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image000802_rotate_180.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image010550.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009451_rotate_180.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image005220.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image001139_rotate_180.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image000919.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image010217.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image000964.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image005942.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image003684_flip_h.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image003980.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image002366.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image004409_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image000879.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image000938.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image009968.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image003006.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image008245.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image008489_flip_v.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image000756.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image010715_rotate_270.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005276.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image009628.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image002571.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005735.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image006424_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image007057_flip_v.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image007597_rotate_90.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image002337_rotate_90.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image005450.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image001687.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image004161.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image002712.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image006588_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image005218_flip_h.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image003149.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image003793.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image011425.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image009032_rotate_270.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image010332.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image006992.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image008703_flip_h.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image006495.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image003757_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006771.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image003548.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image001667.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_3_ayy_image000129_rotate_270.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image002359.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image003866.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008687_rotate_180.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image001619.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image011251.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image007406_rotate_180.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image001283_rotate_180.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image011119.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image002417_rotate_90.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image002656.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image007422_rotate_180.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image001193.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image003138_rotate_180.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image005756.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image011318.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009626_rotate_270.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008165.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image006458.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004898.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image006745.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image000601_rotate_180.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image004337.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image001180.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image010528.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006717.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image005909_rotate_270.jpg',
# ...
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007831_flip_v.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image001864.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image000069_rotate_180.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image004150_rotate_270.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image000951.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image004215.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image001596.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image001280_rotate_270.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image010774.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008802_rotate_270.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image005592.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image003054_rotate_270.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image003266.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_3_ayy_image000006_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image000028_rotate_180.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image003043.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009626.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image006938_rotate_270.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image007858.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image006774_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image001404_rotate_180.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_3_ayy_image000053.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image006529.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image004704_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image011011.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image007679_rotate_270.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image004816_flip_h.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image005524.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image003377_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image003160.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image004328.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image009492.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image006071.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image002723.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image008630.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image011664.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image001649.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image011063.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image002936_flip_v.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image001286_flip_h.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image006107_rotate_270.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image002299.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007618.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image000391_rotate_180.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image004122_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image007751.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image003026.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image010550_flip_h.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image007409.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image001973.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_3_ayy_image000047.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image011590.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image001802.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image010397.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007965.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image004514_rotate_180.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image000675_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image011406.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image005291_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005024_rotate_270.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007087.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004745_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image002223.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image011322.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image004765.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image005311.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image001437.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image003857.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008369_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005624_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image002570.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image006874_rotate_90.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image004969.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009111.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image005250_rotate_180.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image000056.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image002222.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image002530.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image006135.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image006546_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image007852.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_3_ayy_image000200.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005525.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image002270.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004795.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image001545.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008001_rotate_180.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image010461.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image005936.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image005461.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image007079_rotate_180.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image007573.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image002964.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image000847.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image006607_rotate_90.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image002025_rotate_90.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image003901.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image008874.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image007511.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image006882.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image000217.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image006620_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image003975.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007339.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image002041.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image001099_flip_h.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image003641_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image000303.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image010052.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image008715.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image000531_rotate_180.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image002913.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image002363.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image004587.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image010274_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005532.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image005275.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image002149.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image001009.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_2_ayy_image000012_rotate_270.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image001235.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image004878.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image005512.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image001050.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image011258_flip_h.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image003509_flip_v.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image011489_flip_v.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image006442.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image000994.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image002669.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005970.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image000656.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image008849.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image000784_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image000629.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image007011.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image004881.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image006766.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image002039.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image008343_rotate_180.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image010840.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005208_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image011394.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_3_ayy_image000158.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image003165.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image011618.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image006964_rotate_270.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image007597.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007735.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image006082.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image001063.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image005316.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image006640.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image007374.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image005901.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image008709.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image008052_flip_h.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image011221_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image004117.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image000654.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image000427.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image005800.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image000971_flip_v.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image006882_rotate_90.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image007707_flip_h.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image003377.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image005693.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image004025_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image005159_rotate_270.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image003382.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image005699.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image007928.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image005454.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image011328_rotate_180.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image002405.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image000855_rotate_90.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image000483_flip_v.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image006223_rotate_90.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image010859.jpg',
#  'case_M_20181024134247_0U62368102492146_1_002_001-1_Negative_ayy_image007238.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image006241.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image007490.jpg',
#  'case_M_20181109094641_0U62372110931241_1_003_001-1_Negative_ayy_image009370_rotate_90.jpg',
#  'case_M_20181109094641_0U62372110931241_1_007_001-1_Negative_ayy_image007886.jpg']

# %% [markdown]
# ### save polygon coordinates

# %%
data_processor.masks_to_polygons(F_TRAIN_IMAGES_POS, F_TRAIN_MASKS_POS, F_TRAIN_LABELS)
data_processor.create_empty_text_files(F_TRAIN_IMAGES_NEG, F_TRAIN_LABELS)
data_processor.masks_to_polygons(F_VAL_IMAGES_POS, F_VAL_MASKS_POS, F_VAL_LABELS)
data_processor.create_empty_text_files(F_VAL_IMAGES_NEG, F_VAL_LABELS)
# Out:
# Skipping invalid contour in case_M_20181001140915_0U62366100164014_1_001_001-1_a4_ayy_image0046_rotate_180.png
# Skipping invalid contour in case_M_20181119111911_0U62363111914011_1_005_001-1_a12_ayy_image0060_flip_v.png
# Skipping invalid contour in case_M_20181119111911_0U62363111914011_1_005_001-1_a12_ayy_image0060_flip_v.png
# Skipping invalid contour in case_M_20181119111911_0U62363111914011_1_005_001-1_a12_ayy_image0060_flip_v.png
# Skipping invalid contour in case_M_20181119111911_0U62363111914011_1_005_001-1_a12_ayy_image0060_flip_v.png
# Skipping invalid contour in case_M_20181119111911_0U62363111914011_1_005_001-1_a16_ayy_image0231_flip_v.png
# Skipping invalid contour in case_M_20181119111911_0U62363111914011_1_005_001-1_a16_ayy_image0231_flip_v.png
# Skipping invalid contour in case_M_20181119111911_0U62363111914011_1_005_001-1_a16_ayy_image0231_flip_v.png
# Skipping invalid contour in case_M_20181119111911_0U62363111914011_1_005_001-1_a16_ayy_image0231_flip_v.png
# Skipping invalid contour in case_M_20181119111911_0U62363111914011_1_005_001-1_a16_ayy_image0231_flip_v.png
# Skipping invalid contour in case_M_20181119111911_0U62363111914011_1_005_001-1_a16_ayy_image0231_flip_v.png
# Skipping invalid contour in case_M_20181119111911_0U62363111914011_1_005_001-1_a16_ayy_image0231_flip_v.png
# Skipping invalid contour in case_M_20181004130627_0U62365100475026_1_002_001-1_a5_ayy_image0123.png
# Skipping invalid contour in case_M_20181004130627_0U62365100475026_1_002_001-1_a5_ayy_image0123.png
# Skipping invalid contour in case_M_20190109095638_0U62372010945338_1_003_001-1_a24_ayy_image0441_flip_v.png
# Skipping invalid contour in case_M_20190109095638_0U62372010945338_1_003_001-1_a24_ayy_image0441_flip_v.png
# Skipping invalid contour in case_M_20190109095638_0U62372010945338_1_003_001-1_a24_ayy_image0441_flip_v.png
# Skipping invalid contour in case_M_20181119111911_0U62363111914011_1_005_001-1_a12_ayy_image0326_flip_h.png
# Skipping invalid contour in case_M_20181119111911_0U62363111914011_1_005_001-1_a12_ayy_image0326_flip_h.png
# Skipping invalid contour in case_M_20181119111911_0U62363111914011_1_005_001-1_a12_ayy_image0326_flip_h.png
# Skipping invalid contour in case_M_20190115123306_0U62368011540606_1_002_001-1_a3_ayy_image0097_flip_h.png
# Skipping invalid contour in case_M_20190115123306_0U62368011540606_1_002_001-1_a3_ayy_image0097_flip_h.png
# Skipping invalid contour in case_M_20190115123306_0U62368011540606_1_002_001-1_a3_ayy_image0097_flip_h.png
# Skipping invalid contour in bkai_igh_021bab9fc7330398846f67b5df7cdf3f.jpeg
# Skipping invalid contour in bkai_igh_021bab9fc7330398846f67b5df7cdf3f.jpeg
# Skipping invalid contour in bkai_igh_021bab9fc7330398846f67b5df7cdf3f.jpeg
# Skipping invalid contour in bkai_igh_021bab9fc7330398846f67b5df7cdf3f.jpeg
# Skipping invalid contour in bkai_igh_021bab9fc7330398846f67b5df7cdf3f.jpeg
# Skipping invalid contour in bkai_igh_021bab9fc7330398846f67b5df7cdf3f.jpeg
# Skipping invalid contour in bkai_igh_021bab9fc7330398846f67b5df7cdf3f.jpeg
# Skipping invalid contour in bkai_igh_021bab9fc7330398846f67b5df7cdf3f.jpeg
# Skipping invalid contour in bkai_igh_021bab9fc7330398846f67b5df7cdf3f.jpeg
# Skipping invalid contour in bkai_igh_021bab9fc7330398846f67b5df7cdf3f.jpeg
# Skipping invalid contour in bkai_igh_021bab9fc7330398846f67b5df7cdf3f.jpeg
# Skipping invalid contour in bkai_igh_021bab9fc7330398846f67b5df7cdf3f.jpeg
# Skipping invalid contour in bkai_igh_021bab9fc7330398846f67b5df7cdf3f.jpeg
# Skipping invalid contour in bkai_igh_021bab9fc7330398846f67b5df7cdf3f.jpeg
# Skipping invalid contour in bkai_igh_021bab9fc7330398846f67b5df7cdf3f.jpeg
# Skipping invalid contour in bkai_igh_021bab9fc7330398846f67b5df7cdf3f.jpeg
# Skipping invalid contour in bkai_igh_021bab9fc7330398846f67b5df7cdf3f.jpeg
# Skipping invalid contour in bkai_igh_021bab9fc7330398846f67b5df7cdf3f.jpeg
# Skipping invalid contour in bkai_igh_021bab9fc7330398846f67b5df7cdf3f.jpeg
# Skipping invalid contour in bkai_igh_021bab9fc7330398846f67b5df7cdf3f.jpeg
# Skipping invalid contour in bkai_igh_021bab9fc7330398846f67b5df7cdf3f.jpeg
# Skipping invalid contour in bkai_igh_021bab9fc7330398846f67b5df7cdf3f.jpeg
# Skipping invalid contour in bkai_igh_021bab9fc7330398846f67b5df7cdf3f.jpeg
# Skipping invalid contour in bkai_igh_021bab9fc7330398846f67b5df7cdf3f.jpeg
# Skipping invalid contour in case_M_20181207092523_0U62372120765622_1_005_001-1_a12_ayy_image0051_flip_h.png
# Skipping invalid contour in case_M_20190112093830_0U62372011292129_1_001_001-1_a6_ayy_image0017.png
# Skipping invalid contour in case_M_20190109095638_0U62372010945338_1_003_001-1_a23_ayy_image0432_flip_v.png
# Skipping invalid contour in case_M_20181017100226_0U62367101735926_1_007_001-1_a3_ayy_image0014.png
# Skipping invalid contour in case_M_20181017100226_0U62367101735926_1_007_001-1_a3_ayy_image0014.png
# Skipping invalid contour in bkai_igh_f04350ffd6984cbcc6d6bf62f215f0da.jpeg
# Skipping invalid contour in bkai_igh_f04350ffd6984cbcc6d6bf62f215f0da.jpeg
# Skipping invalid contour in bkai_igh_f04350ffd6984cbcc6d6bf62f215f0da.jpeg
# Skipping invalid contour in bkai_igh_f04350ffd6984cbcc6d6bf62f215f0da.jpeg
# Skipping invalid contour in bkai_igh_f04350ffd6984cbcc6d6bf62f215f0da.jpeg
# Skipping invalid contour in bkai_igh_f04350ffd6984cbcc6d6bf62f215f0da.jpeg
# Skipping invalid contour in bkai_igh_f04350ffd6984cbcc6d6bf62f215f0da.jpeg
# Skipping invalid contour in bkai_igh_f04350ffd6984cbcc6d6bf62f215f0da.jpeg
# Skipping invalid contour in bkai_igh_f04350ffd6984cbcc6d6bf62f215f0da.jpeg
# Skipping invalid contour in case_M_20181213131150_0U62365121395349_1_002_001-1_a9_ayy_image0058_rotate_180.png
# Skipping invalid contour in case_M_20181017100226_0U62367101735926_1_007_004-1_a4_ayy_image0408.png
# Skipping invalid contour in case_M_20181017100226_0U62367101735926_1_007_004-1_a4_ayy_image0408.png
# Skipping invalid contour in case_M_20181017100226_0U62367101735926_1_007_004-1_a4_ayy_image0408.png
# Skipping invalid contour in case_M_20181019101517_0U62367101935917_1_003_001-1_a11_ayy_image0006_flip_h.png
# Skipping invalid contour in case_M_20181019101517_0U62367101935917_1_003_001-1_a11_ayy_image0006_flip_h.png
# Skipping invalid contour in case_M_20181120115731_0U62368112064030_1_001_001-1_a7_ayy_image0006_flip_v.png
# Skipping invalid contour in case_M_20181120115731_0U62368112064030_1_001_001-1_a7_ayy_image0006_flip_v.png
# Skipping invalid contour in case_M_20181120115731_0U62368112064030_1_001_001-1_a7_ayy_image0006_flip_v.png
# Skipping invalid contour in case_M_20181120115731_0U62368112064030_1_001_001-1_a7_ayy_image0006_flip_v.png
# Skipping invalid contour in case_M_20181211093229_0U62367121175028_1_002_002-1_a11_ayy_image0087_rotate_180.png
# Skipping invalid contour in case_M_20181211093229_0U62367121175028_1_002_002-1_a11_ayy_image0087_rotate_180.png
# Skipping invalid contour in case_M_20181211093229_0U62367121175028_1_002_002-1_a11_ayy_image0087_rotate_180.png
# Skipping invalid contour in case_M_20190126102153_0U62372012695352_1_001_001-1_a1_ayy_image0018.png
# Skipping invalid contour in case_M_20181119111911_0U62363111914011_1_005_001-1_a3_ayy_image0080_flip_h.png
# Skipping invalid contour in case_M_20181119111911_0U62363111914011_1_005_001-1_a3_ayy_image0080_flip_h.png
# Skipping invalid contour in case_M_20181119111911_0U62363111914011_1_005_001-1_a3_ayy_image0080_flip_h.png
# Skipping invalid contour in case_M_20181203093846_0U62367120345345_1_005_001-1_a10_ayy_image0061.png
# Skipping invalid contour in case_M_20181025093921_0U62363102537521_1_002_001-1_a10_ayy_image0013_flip_h.png
# Skipping invalid contour in case_M_20181018093806_0U62363101890605_1_007_001-1_a1_ayy_image0113.png
# Skipping invalid contour in case_M_20181129152014_0U62366112981213_1_001_001-1_a17_ayy_image0182_rotate_90.png
# Skipping invalid contour in case_M_20181129152014_0U62366112981213_1_001_001-1_a17_ayy_image0182_rotate_90.png
# Skipping invalid contour in case_M_20181025095048_0U62372102595347_1_004_001-1_a8_ayy_image0137_flip_h.png
# Skipping invalid contour in case_M_20181025095048_0U62372102595347_1_004_001-1_a8_ayy_image0137_flip_h.png
# Skipping invalid contour in case_M_20181001100941_0U62372100109341_1_005_001-1_a2_ayy_image0082.png
# Skipping invalid contour in bkai_igh_7712a48e11d579d903c7d178f6ea0ad8.jpeg
# Skipping invalid contour in bkai_igh_7712a48e11d579d903c7d178f6ea0ad8.jpeg
# Skipping invalid contour in bkai_igh_7712a48e11d579d903c7d178f6ea0ad8.jpeg
# Skipping invalid contour in bkai_igh_7712a48e11d579d903c7d178f6ea0ad8.jpeg
# Skipping invalid contour in bkai_igh_7712a48e11d579d903c7d178f6ea0ad8.jpeg
# Skipping invalid contour in bkai_igh_7712a48e11d579d903c7d178f6ea0ad8.jpeg
# Skipping invalid contour in bkai_igh_7712a48e11d579d903c7d178f6ea0ad8.jpeg
# Skipping invalid contour in bkai_igh_7712a48e11d579d903c7d178f6ea0ad8.jpeg
# Skipping invalid contour in bkai_igh_7712a48e11d579d903c7d178f6ea0ad8.jpeg
# Skipping invalid contour in bkai_igh_7712a48e11d579d903c7d178f6ea0ad8.jpeg
# Skipping invalid contour in bkai_igh_7712a48e11d579d903c7d178f6ea0ad8.jpeg
# Skipping invalid contour in bkai_igh_7712a48e11d579d903c7d178f6ea0ad8.jpeg
# Skipping invalid contour in bkai_igh_7712a48e11d579d903c7d178f6ea0ad8.jpeg
# Skipping invalid contour in bkai_igh_7712a48e11d579d903c7d178f6ea0ad8.jpeg
# Skipping invalid contour in bkai_igh_7712a48e11d579d903c7d178f6ea0ad8.jpeg
# Skipping invalid contour in bkai_igh_7712a48e11d579d903c7d178f6ea0ad8.jpeg
# Skipping invalid contour in bkai_igh_7712a48e11d579d903c7d178f6ea0ad8.jpeg
# Skipping invalid contour in bkai_igh_19d9ae2a9833aa6b8232510939c091a7.jpeg
# Skipping invalid contour in bkai_igh_19d9ae2a9833aa6b8232510939c091a7.jpeg
# Skipping invalid contour in bkai_igh_19d9ae2a9833aa6b8232510939c091a7.jpeg
# Skipping invalid contour in bkai_igh_19d9ae2a9833aa6b8232510939c091a7.jpeg
# Skipping invalid contour in bkai_igh_19d9ae2a9833aa6b8232510939c091a7.jpeg
# Skipping invalid contour in bkai_igh_19d9ae2a9833aa6b8232510939c091a7.jpeg
# Skipping invalid contour in bkai_igh_19d9ae2a9833aa6b8232510939c091a7.jpeg
# Skipping invalid contour in bkai_igh_19d9ae2a9833aa6b8232510939c091a7.jpeg
# Skipping invalid contour in bkai_igh_19d9ae2a9833aa6b8232510939c091a7.jpeg
# Skipping invalid contour in bkai_igh_19d9ae2a9833aa6b8232510939c091a7.jpeg
# Skipping invalid contour in bkai_igh_19d9ae2a9833aa6b8232510939c091a7.jpeg
# Skipping invalid contour in bkai_igh_19d9ae2a9833aa6b8232510939c091a7.jpeg
# Skipping invalid contour in bkai_igh_19d9ae2a9833aa6b8232510939c091a7.jpeg
# Skipping invalid contour in bkai_igh_19d9ae2a9833aa6b8232510939c091a7.jpeg
# Skipping invalid contour in bkai_igh_19d9ae2a9833aa6b8232510939c091a7.jpeg
# Skipping invalid contour in bkai_igh_19d9ae2a9833aa6b8232510939c091a7.jpeg
# Skipping invalid contour in bkai_igh_19d9ae2a9833aa6b8232510939c091a7.jpeg
# Skipping invalid contour in bkai_igh_19d9ae2a9833aa6b8232510939c091a7.jpeg
# Skipping invalid contour in bkai_igh_19d9ae2a9833aa6b8232510939c091a7.jpeg
# Skipping invalid contour in bkai_igh_19d9ae2a9833aa6b8232510939c091a7.jpeg
# Skipping invalid contour in bkai_igh_19d9ae2a9833aa6b8232510939c091a7.jpeg
# Skipping invalid contour in bkai_igh_19d9ae2a9833aa6b8232510939c091a7.jpeg
# Skipping invalid contour in bkai_igh_19d9ae2a9833aa6b8232510939c091a7.jpeg
# Skipping invalid contour in bkai_igh_19d9ae2a9833aa6b8232510939c091a7.jpeg
# Skipping invalid contour in bkai_igh_19d9ae2a9833aa6b8232510939c091a7.jpeg
# Skipping invalid contour in bkai_igh_19d9ae2a9833aa6b8232510939c091a7.jpeg
# Skipping invalid contour in bkai_igh_19d9ae2a9833aa6b8232510939c091a7.jpeg
# Skipping invalid contour in bkai_igh_19d9ae2a9833aa6b8232510939c091a7.jpeg
# Skipping invalid contour in bkai_igh_19d9ae2a9833aa6b8232510939c091a7.jpeg
# Skipping invalid contour in bkai_igh_19d9ae2a9833aa6b8232510939c091a7.jpeg
# Skipping invalid contour in bkai_igh_19d9ae2a9833aa6b8232510939c091a7.jpeg
# Skipping invalid contour in case_M_20181029094800_0U62368102981259_1_005_001-1_a15_ayy_image0189.png
# Skipping invalid contour in case_M_20181214095357_0U62368121473456_1_006_003-1_a5_ayy_image0142_flip_h.png
# Skipping invalid contour in case_M_20181214095357_0U62368121473456_1_006_003-1_a4_ayy_image0091_flip_h.png
# Skipping invalid contour in case_M_20181214095357_0U62368121473456_1_006_003-1_a4_ayy_image0091_flip_h.png
# Skipping invalid contour in bkai_igh_33408da4bcab47c3fb256f174ae992b9.jpeg
# Skipping invalid contour in bkai_igh_33408da4bcab47c3fb256f174ae992b9.jpeg
# Skipping invalid contour in bkai_igh_33408da4bcab47c3fb256f174ae992b9.jpeg
# Skipping invalid contour in bkai_igh_33408da4bcab47c3fb256f174ae992b9.jpeg
# Skipping invalid contour in bkai_igh_33408da4bcab47c3fb256f174ae992b9.jpeg
# Skipping invalid contour in bkai_igh_33408da4bcab47c3fb256f174ae992b9.jpeg
# Skipping invalid contour in bkai_igh_33408da4bcab47c3fb256f174ae992b9.jpeg
# Skipping invalid contour in bkai_igh_33408da4bcab47c3fb256f174ae992b9.jpeg
# Skipping invalid contour in case_M_20190112093830_0U62372011292129_1_001_001-1_a10_ayy_image0108.png
# Skipping invalid contour in case_M_20181029094800_0U62368102981259_1_005_001-1_a12_ayy_image0031_rotate_180.png
# Skipping invalid contour in cvc_colodb_209.png
# Skipping invalid contour in case_M_20181019101517_0U62367101935917_1_003_001-1_a13_ayy_image0004.png
# Skipping invalid contour in case_M_20181019101517_0U62367101935917_1_003_001-1_a13_ayy_image0004.png
# Skipping invalid contour in case_M_20181019101517_0U62367101935917_1_003_001-1_a13_ayy_image0004.png
# Skipping invalid contour in case_M_20181019101517_0U62367101935917_1_003_001-1_a13_ayy_image0004.png
# Skipping invalid contour in case_M_20181030122608_0U62363103057807_1_002_002-1_a2_ayy_image0033.png
# Skipping invalid contour in case_M_20181117100025_0U62363111779624_1_007_003-1_a8_ayy_image0061_rotate_180.png
# Skipping invalid contour in case_M_20181019101517_0U62367101935917_1_003_001-1_a15_ayy_image0017_flip_h.png
# Skipping invalid contour in case_M_20181212144657_0U62366121262556_1_001_002-1_a2_ayy_image0088_flip_h.png
# Skipping invalid contour in case_M_20181212144657_0U62366121262556_1_001_002-1_a2_ayy_image0088_flip_h.png
# Skipping invalid contour in case_M_20181212144657_0U62366121262556_1_001_002-1_a2_ayy_image0088_flip_h.png
# Skipping invalid contour in case_M_20181212144657_0U62366121262556_1_001_002-1_a2_ayy_image0088_flip_h.png
# Skipping invalid contour in case_M_20190109095638_0U62372010945338_1_003_002-1_a2_ayy_image0126.png
# Skipping invalid contour in case_M_20190109095638_0U62372010945338_1_003_002-1_a2_ayy_image0126.png
# Skipping invalid contour in case_M_20190109095638_0U62372010945338_1_003_002-1_a2_ayy_image0126.png
# Skipping invalid contour in case_M_20181205095418_0U62367120576517_1_007_001-1_a22_ayy_image0027_rotate_180.png
# Skipping invalid contour in cvc_colodb_085.png
# Skipping invalid contour in cvc_colodb_085.png
# Skipping invalid contour in cvc_colodb_085.png
# Skipping invalid contour in case_M_20181207092523_0U62372120765622_1_005_001-1_a15_ayy_image0252_flip_h.png
# Skipping invalid contour in case_M_20181207092523_0U62372120765622_1_005_001-1_a15_ayy_image0252_flip_h.png
# Skipping invalid contour in case_M_20181207092523_0U62372120765622_1_005_001-1_a15_ayy_image0252_flip_h.png
# Skipping invalid contour in case_M_20181207092523_0U62372120765622_1_005_001-1_a15_ayy_image0252_flip_h.png
# Skipping invalid contour in bkai_igh_ccacf464aa36bf7c09a3bb0e5ca15941.jpeg
# Skipping invalid contour in bkai_igh_ccacf464aa36bf7c09a3bb0e5ca15941.jpeg
# Skipping invalid contour in bkai_igh_ccacf464aa36bf7c09a3bb0e5ca15941.jpeg
# Skipping invalid contour in bkai_igh_ccacf464aa36bf7c09a3bb0e5ca15941.jpeg
# Skipping invalid contour in bkai_igh_ccacf464aa36bf7c09a3bb0e5ca15941.jpeg
# Skipping invalid contour in bkai_igh_ccacf464aa36bf7c09a3bb0e5ca15941.jpeg
# Skipping invalid contour in bkai_igh_ccacf464aa36bf7c09a3bb0e5ca15941.jpeg
# Skipping invalid contour in bkai_igh_ccacf464aa36bf7c09a3bb0e5ca15941.jpeg
# Skipping invalid contour in bkai_igh_ccacf464aa36bf7c09a3bb0e5ca15941.jpeg
# Skipping invalid contour in bkai_igh_ccacf464aa36bf7c09a3bb0e5ca15941.jpeg
# Skipping invalid contour in case_M_20181126095408_0U62367112660907_1_001_002-1_a4_ayy_image0014_flip_h.png
# Skipping invalid contour in bkai_igh_f2c6d40b3bbba8f6c704801b37705c1e.jpeg
# Skipping invalid contour in bkai_igh_f2c6d40b3bbba8f6c704801b37705c1e.jpeg
# Skipping invalid contour in bkai_igh_f2c6d40b3bbba8f6c704801b37705c1e.jpeg
# Skipping invalid contour in bkai_igh_f2c6d40b3bbba8f6c704801b37705c1e.jpeg
# Skipping invalid contour in bkai_igh_f2c6d40b3bbba8f6c704801b37705c1e.jpeg
# Skipping invalid contour in bkai_igh_f2c6d40b3bbba8f6c704801b37705c1e.jpeg
# Skipping invalid contour in bkai_igh_f2c6d40b3bbba8f6c704801b37705c1e.jpeg
# Skipping invalid contour in bkai_igh_f2c6d40b3bbba8f6c704801b37705c1e.jpeg
# Skipping invalid contour in bkai_igh_f2c6d40b3bbba8f6c704801b37705c1e.jpeg
# Skipping invalid contour in bkai_igh_f2c6d40b3bbba8f6c704801b37705c1e.jpeg
# Skipping invalid contour in bkai_igh_f2c6d40b3bbba8f6c704801b37705c1e.jpeg
# Skipping invalid contour in bkai_igh_f2c6d40b3bbba8f6c704801b37705c1e.jpeg
# Skipping invalid contour in bkai_igh_f2c6d40b3bbba8f6c704801b37705c1e.jpeg
# Skipping invalid contour in bkai_igh_f2c6d40b3bbba8f6c704801b37705c1e.jpeg
# Skipping invalid contour in bkai_igh_f2c6d40b3bbba8f6c704801b37705c1e.jpeg
# Skipping invalid contour in bkai_igh_f2c6d40b3bbba8f6c704801b37705c1e.jpeg
# Skipping invalid contour in bkai_igh_f2c6d40b3bbba8f6c704801b37705c1e.jpeg
# Skipping invalid contour in bkai_igh_f2c6d40b3bbba8f6c704801b37705c1e.jpeg
# Skipping invalid contour in bkai_igh_f2c6d40b3bbba8f6c704801b37705c1e.jpeg
# Skipping invalid contour in bkai_igh_f2c6d40b3bbba8f6c704801b37705c1e.jpeg
# Skipping invalid contour in bkai_igh_f2c6d40b3bbba8f6c704801b37705c1e.jpeg
# Skipping invalid contour in bkai_igh_f2c6d40b3bbba8f6c704801b37705c1e.jpeg
# Skipping invalid contour in bkai_igh_f2c6d40b3bbba8f6c704801b37705c1e.jpeg
# Skipping invalid contour in bkai_igh_f2c6d40b3bbba8f6c704801b37705c1e.jpeg
# Skipping invalid contour in bkai_igh_f2c6d40b3bbba8f6c704801b37705c1e.jpeg
# Skipping invalid contour in bkai_igh_f2c6d40b3bbba8f6c704801b37705c1e.jpeg
# Skipping invalid contour in bkai_igh_f2c6d40b3bbba8f6c704801b37705c1e.jpeg
# Skipping invalid contour in bkai_igh_f2c6d40b3bbba8f6c704801b37705c1e.jpeg
# Skipping invalid contour in bkai_igh_f2c6d40b3bbba8f6c704801b37705c1e.jpeg
# Skipping invalid contour in bkai_igh_f2c6d40b3bbba8f6c704801b37705c1e.jpeg
# Skipping invalid contour in bkai_igh_4837f2a0f1536ad3f6a5664c1711b62f.jpeg
# Skipping invalid contour in bkai_igh_4837f2a0f1536ad3f6a5664c1711b62f.jpeg
# Skipping invalid contour in bkai_igh_4837f2a0f1536ad3f6a5664c1711b62f.jpeg
# Skipping invalid contour in bkai_igh_4837f2a0f1536ad3f6a5664c1711b62f.jpeg
# Skipping invalid contour in bkai_igh_4837f2a0f1536ad3f6a5664c1711b62f.jpeg
# Skipping invalid contour in bkai_igh_4837f2a0f1536ad3f6a5664c1711b62f.jpeg
# Skipping invalid contour in bkai_igh_4837f2a0f1536ad3f6a5664c1711b62f.jpeg
# Skipping invalid contour in bkai_igh_4837f2a0f1536ad3f6a5664c1711b62f.jpeg
# Skipping invalid contour in bkai_igh_4837f2a0f1536ad3f6a5664c1711b62f.jpeg
# Skipping invalid contour in bkai_igh_4837f2a0f1536ad3f6a5664c1711b62f.jpeg
# Skipping invalid contour in bkai_igh_4837f2a0f1536ad3f6a5664c1711b62f.jpeg
# Skipping invalid contour in bkai_igh_4837f2a0f1536ad3f6a5664c1711b62f.jpeg
# Skipping invalid contour in bkai_igh_4837f2a0f1536ad3f6a5664c1711b62f.jpeg
# Skipping invalid contour in bkai_igh_4837f2a0f1536ad3f6a5664c1711b62f.jpeg
# Skipping invalid contour in bkai_igh_4837f2a0f1536ad3f6a5664c1711b62f.jpeg
# Skipping invalid contour in bkai_igh_4837f2a0f1536ad3f6a5664c1711b62f.jpeg
# Skipping invalid contour in bkai_igh_4837f2a0f1536ad3f6a5664c1711b62f.jpeg
# Skipping invalid contour in bkai_igh_4837f2a0f1536ad3f6a5664c1711b62f.jpeg
# Skipping invalid contour in bkai_igh_4837f2a0f1536ad3f6a5664c1711b62f.jpeg
# Skipping invalid contour in bkai_igh_4837f2a0f1536ad3f6a5664c1711b62f.jpeg
# Skipping invalid contour in bkai_igh_4837f2a0f1536ad3f6a5664c1711b62f.jpeg
# Skipping invalid contour in bkai_igh_4837f2a0f1536ad3f6a5664c1711b62f.jpeg
# Skipping invalid contour in bkai_igh_4837f2a0f1536ad3f6a5664c1711b62f.jpeg
# Skipping invalid contour in bkai_igh_4837f2a0f1536ad3f6a5664c1711b62f.jpeg
# Skipping invalid contour in bkai_igh_4837f2a0f1536ad3f6a5664c1711b62f.jpeg
# Skipping invalid contour in bkai_igh_4837f2a0f1536ad3f6a5664c1711b62f.jpeg
# Skipping invalid contour in bkai_igh_4837f2a0f1536ad3f6a5664c1711b62f.jpeg
# Skipping invalid contour in bkai_igh_4837f2a0f1536ad3f6a5664c1711b62f.jpeg
# Skipping invalid contour in case_M_20190123101017_0U62372012395316_1_004_001-1_a8_ayy_image0219.png
# Skipping invalid contour in case_M_20190123101017_0U62372012395316_1_004_001-1_a8_ayy_image0219.png
# Skipping invalid contour in case_M_20190123101017_0U62372012395316_1_004_001-1_a8_ayy_image0219.png
# Skipping invalid contour in case_M_20181015101337_0U62363101576536_1_005_001-1_a21_ayy_image0186.png
# Skipping invalid contour in bkai_igh_15334875343f27ebc5d92b9076135d76.jpeg
# Skipping invalid contour in bkai_igh_15334875343f27ebc5d92b9076135d76.jpeg
# Skipping invalid contour in bkai_igh_15334875343f27ebc5d92b9076135d76.jpeg
# Skipping invalid contour in bkai_igh_15334875343f27ebc5d92b9076135d76.jpeg
# Skipping invalid contour in bkai_igh_15334875343f27ebc5d92b9076135d76.jpeg
# Skipping invalid contour in bkai_igh_15334875343f27ebc5d92b9076135d76.jpeg
# Skipping invalid contour in bkai_igh_15334875343f27ebc5d92b9076135d76.jpeg
# Skipping invalid contour in bkai_igh_15334875343f27ebc5d92b9076135d76.jpeg
# Skipping invalid contour in bkai_igh_15334875343f27ebc5d92b9076135d76.jpeg
# Skipping invalid contour in bkai_igh_15334875343f27ebc5d92b9076135d76.jpeg
# Skipping invalid contour in bkai_igh_15334875343f27ebc5d92b9076135d76.jpeg
# Skipping invalid contour in bkai_igh_15334875343f27ebc5d92b9076135d76.jpeg
# Skipping invalid contour in case_M_20181029094800_0U62368102981259_1_005_001-1_a18_ayy_image0139.png
# Skipping invalid contour in case_M_20181029094800_0U62368102981259_1_005_001-1_a18_ayy_image0139.png
# Skipping invalid contour in case_M_20181029094800_0U62368102981259_1_005_001-1_a18_ayy_image0139.png
# Skipping invalid contour in bkai_igh_4a1e4062d81e095fdc7f720eff82f514.jpeg
# Skipping invalid contour in bkai_igh_4a1e4062d81e095fdc7f720eff82f514.jpeg
# Skipping invalid contour in bkai_igh_4a1e4062d81e095fdc7f720eff82f514.jpeg
# Skipping invalid contour in bkai_igh_4a1e4062d81e095fdc7f720eff82f514.jpeg
# Skipping invalid contour in bkai_igh_4a1e4062d81e095fdc7f720eff82f514.jpeg
# Skipping invalid contour in case_M_20181019101517_0U62367101935917_1_003_001-1_a14_ayy_image0081_flip_v.png
# Skipping invalid contour in case_M_20181019101517_0U62367101935917_1_003_001-1_a14_ayy_image0081_flip_v.png
# Skipping invalid contour in case_M_20181019101517_0U62367101935917_1_003_001-1_a14_ayy_image0081_flip_v.png
# Skipping invalid contour in case_M_20181025095048_0U62372102595347_1_004_001-1_a8_ayy_image0082_flip_h.png
# Skipping invalid contour in case_M_20181119111911_0U62363111914011_1_005_001-1_a12_ayy_image0389.png
# Skipping invalid contour in case_M_20190110094509_0U62363011095308_1_001_002-1_a2_ayy_image0089_rotate_180.png
# Skipping invalid contour in case_M_20190110094509_0U62363011095308_1_001_002-1_a2_ayy_image0089_rotate_180.png
# Skipping invalid contour in case_M_20190110094509_0U62363011095308_1_001_002-1_a2_ayy_image0089_rotate_180.png
# Skipping invalid contour in case_M_20181010094822_0U62363101085921_1_003_001-1_a1_ayy_image0134_flip_v.png
# Skipping invalid contour in case_M_20190116093042_0U62372011685941_1_001_001-1_a3_ayy_image0103_flip_v.png
# Skipping invalid contour in case_M_20190115123306_0U62368011540606_1_002_001-1_a6_ayy_image0148.png
# Skipping invalid contour in case_M_20190115123306_0U62368011540606_1_002_001-1_a6_ayy_image0148.png
# Skipping invalid contour in case_M_20190115123306_0U62368011540606_1_002_001-1_a6_ayy_image0148.png
# Skipping invalid contour in case_M_20181017100226_0U62367101735926_1_007_001-1_a12_ayy_image0068_rotate_90.png
# Skipping invalid contour in case_M_20181017100226_0U62367101735926_1_007_001-1_a12_ayy_image0068_rotate_90.png
# Skipping invalid contour in case_M_20181017100226_0U62367101735926_1_007_001-1_a12_ayy_image0068_rotate_90.png
# Skipping invalid contour in case_M_20181017100226_0U62367101735926_1_007_001-1_a12_ayy_image0068_rotate_90.png
# Skipping invalid contour in case_M_20181019122218_0U62368101948418_1_002_001-1_a4_ayy_image0112.png
# Skipping invalid contour in case_M_20181019122218_0U62368101948418_1_002_001-1_a4_ayy_image0112.png
# Skipping invalid contour in case_M_20181019122218_0U62368101948418_1_002_001-1_a4_ayy_image0112.png
# Skipping invalid contour in case_M_20181019122218_0U62368101948418_1_002_001-1_a4_ayy_image0112.png
# Skipping invalid contour in case_M_20181113100307_0U62372111373406_1_005_001-1_a15_ayy_image0016_flip_h.png
# Skipping invalid contour in case_M_20181113100307_0U62372111373406_1_005_001-1_a15_ayy_image0016_flip_h.png
# Skipping invalid contour in case_M_20181113100307_0U62372111373406_1_005_001-1_a15_ayy_image0016_flip_h.png
# Skipping invalid contour in case_M_20181113100307_0U62372111373406_1_005_001-1_a15_ayy_image0016_flip_h.png
# Skipping invalid contour in case_M_20181214095357_0U62368121473456_1_006_003-1_a22_ayy_image0053_flip_h.png
# Skipping invalid contour in case_M_20190126102153_0U62372012695352_1_001_001-1_a3_ayy_image0016_flip_v.png
# Skipping invalid contour in case_M_20190110094509_0U62363011095308_1_001_002-1_a4_ayy_image0033.png
# Skipping invalid contour in case_M_20190110094509_0U62363011095308_1_001_002-1_a4_ayy_image0033.png
# Skipping invalid contour in case_M_20190110094509_0U62363011095308_1_001_002-1_a4_ayy_image0033.png
# Skipping invalid contour in case_M_20190110094509_0U62363011095308_1_001_002-1_a4_ayy_image0033.png
# Skipping invalid contour in case_M_20190110094509_0U62363011095308_1_001_002-1_a4_ayy_image0033.png
# Skipping invalid contour in case_M_20181025095048_0U62372102595347_1_004_001-1_a8_ayy_image0157.png
# Skipping invalid contour in bkai_igh_fb256f174ae992b915a51625559c7e61.jpeg
# Skipping invalid contour in bkai_igh_fb256f174ae992b915a51625559c7e61.jpeg
# Skipping invalid contour in bkai_igh_fb256f174ae992b915a51625559c7e61.jpeg
# Skipping invalid contour in bkai_igh_fb256f174ae992b915a51625559c7e61.jpeg
# Skipping invalid contour in bkai_igh_fb256f174ae992b915a51625559c7e61.jpeg
# Skipping invalid contour in bkai_igh_fb256f174ae992b915a51625559c7e61.jpeg
# Skipping invalid contour in bkai_igh_fb256f174ae992b915a51625559c7e61.jpeg
# Skipping invalid contour in bkai_igh_fb256f174ae992b915a51625559c7e61.jpeg
# Skipping invalid contour in bkai_igh_fb256f174ae992b915a51625559c7e61.jpeg
# Skipping invalid contour in bkai_igh_fb256f174ae992b915a51625559c7e61.jpeg
# Skipping invalid contour in bkai_igh_fb256f174ae992b915a51625559c7e61.jpeg
# Skipping invalid contour in bkai_igh_fb256f174ae992b915a51625559c7e61.jpeg
# Skipping invalid contour in bkai_igh_fb256f174ae992b915a51625559c7e61.jpeg
# Skipping invalid contour in bkai_igh_fb256f174ae992b915a51625559c7e61.jpeg
# Skipping invalid contour in bkai_igh_fb256f174ae992b915a51625559c7e61.jpeg
# Skipping invalid contour in bkai_igh_fb256f174ae992b915a51625559c7e61.jpeg
# Skipping invalid contour in bkai_igh_fb256f174ae992b915a51625559c7e61.jpeg
# Skipping invalid contour in bkai_igh_fb256f174ae992b915a51625559c7e61.jpeg
# Skipping invalid contour in bkai_igh_fb256f174ae992b915a51625559c7e61.jpeg
# Skipping invalid contour in bkai_igh_fb256f174ae992b915a51625559c7e61.jpeg
# Skipping invalid contour in bkai_igh_fb256f174ae992b915a51625559c7e61.jpeg
# Skipping invalid contour in bkai_igh_fb256f174ae992b915a51625559c7e61.jpeg
# Skipping invalid contour in case_M_20181018093806_0U62363101890605_1_006_001-1_a2_ayy_image0097.png
# Skipping invalid contour in case_M_20181113100307_0U62372111373406_1_005_001-1_a15_ayy_image0024_flip_v.png
# Skipping invalid contour in case_M_20181026100314_0U62363102665613_1_004_001-1_a4_ayy_image0060_flip_h.png
# Skipping invalid contour in case_M_20181026100314_0U62363102665613_1_004_001-1_a4_ayy_image0060_flip_h.png
# Skipping invalid contour in case_M_20181026100314_0U62363102665613_1_004_001-1_a4_ayy_image0060_flip_h.png
# Skipping invalid contour in case_M_20181213092448_0U62363121315648_1_003_001-1_a14_ayy_image0048.png
# Skipping invalid contour in case_M_20181213092448_0U62363121315648_1_003_001-1_a14_ayy_image0048.png
# Skipping invalid contour in case_M_20190126102153_0U62372012695352_1_001_001-1_a4_ayy_image0005.png
# Skipping invalid contour in case_M_20190126102153_0U62372012695352_1_001_001-1_a4_ayy_image0005.png
# Skipping invalid contour in case_M_20190121095240_0U62368012118740_1_004_001-1_a4_ayy_image0023.png
# Skipping invalid contour in case_M_20181015101337_0U62363101576536_1_005_002-1_a8_ayy_image0002_flip_v.png
# Skipping invalid contour in case_M_20181109094641_0U62372110931241_1_005_001-1_a1_ayy_image0004.png
# Skipping invalid contour in case_M_20190116094421_0U62363011675020_1_004_001-1_a2_ayy_image0073.png
# Skipping invalid contour in cvc_colodb_016.png
# Skipping invalid contour in cvc_colodb_016.png
# Skipping invalid contour in cvc_colodb_016.png
# Skipping invalid contour in case_M_20181213131150_0U62365121395349_1_002_002-1_a18_ayy_image0034.png
# Skipping invalid contour in case_M_20181029094800_0U62368102981259_1_005_001-1_a18_ayy_image0083.png
# Skipping invalid contour in case_M_20181029094800_0U62368102981259_1_005_001-1_a18_ayy_image0083.png
# Skipping invalid contour in case_M_20190117105747_0U62368011712547_1_002_001-1_a18_ayy_image0034_rotate_180.png
# Skipping invalid contour in case_M_20181113100307_0U62372111373406_1_005_001-1_a14_ayy_image0017.png
# Skipping invalid contour in case_M_20181019101517_0U62367101935917_1_003_001-1_a14_ayy_image0121.png
# Skipping invalid contour in case_M_20181019101517_0U62367101935917_1_003_001-1_a14_ayy_image0121.png
# Skipping invalid contour in cvc_colodb_109.png
# Skipping invalid contour in case_M_20181019101517_0U62367101935917_1_003_001-1_a13_ayy_image0077.png
# Skipping invalid contour in case_M_20181019101517_0U62367101935917_1_003_001-1_a13_ayy_image0077.png
# Skipping invalid contour in case_M_20181113100307_0U62372111373406_1_005_001-1_a26_ayy_image0178_flip_v.png
# Skipping invalid contour in case_M_20181003094031_0U62363100354631_1_001_002-1_a1_ayy_image0523_flip_h.png
# Skipping invalid contour in case_M_20181003094031_0U62363100354631_1_001_002-1_a1_ayy_image0523_flip_h.png
# Skipping invalid contour in case_M_20181105095958_0U62368110576557_1_003_002-1_a6_ayy_image0429.png
# Skipping invalid contour in case_M_20181004130627_0U62365100475026_1_002_001-1_a3_ayy_image0030_flip_h.png
# Skipping invalid contour in case_M_20181004130627_0U62365100475026_1_002_001-1_a3_ayy_image0030_flip_h.png
# Skipping invalid contour in case_M_20181018093806_0U62363101890605_1_007_002-1_a3_ayy_image0066.png
# Skipping invalid contour in case_M_20190130094921_0U62367013093720_1_009_001-1_a7_ayy_image0055_flip_v.png
# Skipping invalid contour in case_M_20190130094921_0U62367013093720_1_009_001-1_a7_ayy_image0055_flip_v.png
# Skipping invalid contour in case_M_20181119111911_0U62363111914011_1_005_001-1_a16_ayy_image0177.png
# Skipping invalid contour in case_M_20181119111911_0U62363111914011_1_005_001-1_a16_ayy_image0177.png
# Skipping invalid contour in case_M_20181029094800_0U62368102981259_1_005_001-1_a14_ayy_image0030_flip_v.png
# Skipping invalid contour in case_M_20181029094800_0U62368102981259_1_005_001-1_a14_ayy_image0030_flip_v.png
# Skipping invalid contour in case_M_20181029094800_0U62368102981259_1_005_001-1_a14_ayy_image0030_flip_v.png
# Skipping invalid contour in case_M_20181029094800_0U62368102981259_1_005_001-1_a14_ayy_image0030_flip_v.png
# Skipping invalid contour in case_M_20181029094800_0U62368102981259_1_005_001-1_a14_ayy_image0030_flip_v.png
# Skipping invalid contour in case_M_20190115123306_0U62368011540606_1_002_001-1_a4_ayy_image0184.png
# Skipping invalid contour in case_M_20190128094801_0U62372012857800_1_002_001-1_a6_ayy_image0116_flip_h.png
# Skipping invalid contour in case_M_20181018093806_0U62363101890605_1_007_001-1_a3_ayy_image0016.png
# Skipping invalid contour in case_M_20181003094031_0U62363100354631_1_001_002-1_a13_ayy_image0058_flip_v.png
# Skipping invalid contour in case_M_20181003094031_0U62363100354631_1_001_002-1_a13_ayy_image0058_flip_v.png
# Skipping invalid contour in case_M_20181017100226_0U62367101735926_1_007_001-1_a3_ayy_image0012.png
# Skipping invalid contour in case_M_20181017100226_0U62367101735926_1_007_001-1_a3_ayy_image0012.png
# Skipping invalid contour in case_M_20181017100226_0U62367101735926_1_007_001-1_a3_ayy_image0012.png
# Skipping invalid contour in cvc_colodb_328.png
# Skipping invalid contour in case_M_20190112093830_0U62372011292129_1_001_001-1_a1_ayy_image0187_flip_h.png
# Skipping invalid contour in case_M_20190112093830_0U62372011292129_1_001_001-1_a1_ayy_image0187_flip_h.png
# Skipping invalid contour in case_M_20181109094641_0U62372110931241_1_005_001-1_a1_ayy_image0019_flip_h.png
# Skipping invalid contour in case_M_20190110094509_0U62363011095308_1_001_001-1_a3_ayy_image0010_flip_h.png
# Skipping invalid contour in case_M_20181214095357_0U62368121473456_1_006_003-1_a7_ayy_image0027.png
# Skipping invalid contour in case_M_20181214095357_0U62368121473456_1_006_003-1_a4_ayy_image0046.png
# Skipping invalid contour in case_M_20181029094800_0U62368102981259_1_005_001-1_a12_ayy_image0010_flip_h.png
# Skipping invalid contour in case_M_20181029094800_0U62368102981259_1_005_001-1_a12_ayy_image0010_flip_h.png
# Skipping invalid contour in case_M_20181029094800_0U62368102981259_1_005_001-1_a12_ayy_image0010_flip_h.png
# Skipping invalid contour in case_M_20190109095638_0U62372010945338_1_003_001-1_a22_ayy_image0092.png
# Skipping invalid contour in case_M_20190109095638_0U62372010945338_1_003_001-1_a22_ayy_image0092.png
# Skipping invalid contour in case_M_20190109095638_0U62372010945338_1_003_001-1_a22_ayy_image0092.png
# Skipping invalid contour in case_M_20190109095638_0U62372010945338_1_003_001-1_a22_ayy_image0092.png
# Skipping invalid contour in case_M_20190109095638_0U62372010945338_1_003_001-1_a22_ayy_image0092.png
# Skipping invalid contour in bkai_igh_d81526eb91e2da9e6afaef7fdb2d45b2.jpeg
# Skipping invalid contour in bkai_igh_d81526eb91e2da9e6afaef7fdb2d45b2.jpeg
# Skipping invalid contour in bkai_igh_d81526eb91e2da9e6afaef7fdb2d45b2.jpeg
# Skipping invalid contour in bkai_igh_d81526eb91e2da9e6afaef7fdb2d45b2.jpeg
# Skipping invalid contour in bkai_igh_d81526eb91e2da9e6afaef7fdb2d45b2.jpeg
# Skipping invalid contour in bkai_igh_d81526eb91e2da9e6afaef7fdb2d45b2.jpeg
# Skipping invalid contour in bkai_igh_d81526eb91e2da9e6afaef7fdb2d45b2.jpeg
# Skipping invalid contour in bkai_igh_d81526eb91e2da9e6afaef7fdb2d45b2.jpeg
# Skipping invalid contour in bkai_igh_d81526eb91e2da9e6afaef7fdb2d45b2.jpeg
# Skipping invalid contour in bkai_igh_d81526eb91e2da9e6afaef7fdb2d45b2.jpeg
# Skipping invalid contour in bkai_igh_d81526eb91e2da9e6afaef7fdb2d45b2.jpeg
# Skipping invalid contour in bkai_igh_d81526eb91e2da9e6afaef7fdb2d45b2.jpeg
# Skipping invalid contour in bkai_igh_d81526eb91e2da9e6afaef7fdb2d45b2.jpeg
# Skipping invalid contour in bkai_igh_d81526eb91e2da9e6afaef7fdb2d45b2.jpeg
# Skipping invalid contour in bkai_igh_d81526eb91e2da9e6afaef7fdb2d45b2.jpeg
# Skipping invalid contour in bkai_igh_d81526eb91e2da9e6afaef7fdb2d45b2.jpeg
# Skipping invalid contour in bkai_igh_d81526eb91e2da9e6afaef7fdb2d45b2.jpeg
# Skipping invalid contour in bkai_igh_d81526eb91e2da9e6afaef7fdb2d45b2.jpeg
# Skipping invalid contour in case_M_20190121095240_0U62368012118740_1_004_001-1_a5_ayy_image0022_flip_h.png
# Skipping invalid contour in case_M_20190121095240_0U62368012118740_1_004_001-1_a5_ayy_image0022_flip_h.png
# Skipping invalid contour in case_M_20190131094104_0U62367013193703_1_003_001-1_a7_ayy_image0010_flip_v.png
# Skipping invalid contour in case_M_20181113100307_0U62372111373406_1_005_001-1_a26_ayy_image0140.png
# Skipping invalid contour in case_M_20181113100307_0U62372111373406_1_005_001-1_a26_ayy_image0140.png
# Skipping invalid contour in case_M_20181113100307_0U62372111373406_1_005_001-1_a26_ayy_image0140.png
# Skipping invalid contour in case_M_20181113100307_0U62372111373406_1_005_001-1_a26_ayy_image0140.png
# Skipping invalid contour in case_M_20181113100307_0U62372111373406_1_005_001-1_a26_ayy_image0140.png
# Skipping invalid contour in case_M_20181113100307_0U62372111373406_1_005_001-1_a26_ayy_image0140.png
# Skipping invalid contour in case_M_20181018093806_0U62363101890605_1_007_002-1_a14_ayy_image0055.png
# Skipping invalid contour in case_M_20181018093806_0U62363101890605_1_007_002-1_a14_ayy_image0055.png
# Skipping invalid contour in case_M_20181207092523_0U62372120765622_1_002_001-1_a4_ayy_image0020.png
# Skipping invalid contour in bkai_igh_78a91391adc0bb223c4eaf3372eae567.jpeg
# Skipping invalid contour in bkai_igh_78a91391adc0bb223c4eaf3372eae567.jpeg
# Skipping invalid contour in bkai_igh_78a91391adc0bb223c4eaf3372eae567.jpeg
# Skipping invalid contour in bkai_igh_78a91391adc0bb223c4eaf3372eae567.jpeg
# Skipping invalid contour in bkai_igh_78a91391adc0bb223c4eaf3372eae567.jpeg
# Skipping invalid contour in bkai_igh_78a91391adc0bb223c4eaf3372eae567.jpeg
# Skipping invalid contour in bkai_igh_78a91391adc0bb223c4eaf3372eae567.jpeg
# Skipping invalid contour in bkai_igh_78a91391adc0bb223c4eaf3372eae567.jpeg
# Skipping invalid contour in bkai_igh_78a91391adc0bb223c4eaf3372eae567.jpeg
# Skipping invalid contour in bkai_igh_78a91391adc0bb223c4eaf3372eae567.jpeg
# Skipping invalid contour in bkai_igh_78a91391adc0bb223c4eaf3372eae567.jpeg
# Skipping invalid contour in bkai_igh_78a91391adc0bb223c4eaf3372eae567.jpeg
# Skipping invalid contour in bkai_igh_78a91391adc0bb223c4eaf3372eae567.jpeg
# Skipping invalid contour in case_M_20190123101017_0U62372012395316_1_004_001-1_a5_ayy_image0053.png
# Skipping invalid contour in case_M_20190123101017_0U62372012395316_1_004_001-1_a5_ayy_image0053.png
# Skipping invalid contour in case_M_20190123101017_0U62372012395316_1_004_001-1_a5_ayy_image0053.png
# Skipping invalid contour in cvc_colodb_035.png
# Skipping invalid contour in cvc_colodb_035.png
# Skipping invalid contour in cvc_colodb_035.png
# Skipping invalid contour in case_M_20190121095240_0U62368012118740_1_005_001-1_a1_ayy_image0453.png
# Skipping invalid contour in case_M_20190121095240_0U62368012118740_1_005_001-1_a1_ayy_image0453.png
# Skipping invalid contour in case_M_20190121095240_0U62368012118740_1_005_001-1_a1_ayy_image0453.png
# Skipping invalid contour in case_M_20190121095240_0U62368012118740_1_005_001-1_a1_ayy_image0453.png
# Skipping invalid contour in case_M_20190109095638_0U62372010945338_1_003_001-1_a24_ayy_image0212_rotate_180.png
# Skipping invalid contour in case_M_20190109095638_0U62372010945338_1_003_001-1_a24_ayy_image0212_rotate_180.png
# Skipping invalid contour in case_M_20190109095638_0U62372010945338_1_003_001-1_a24_ayy_image0212_rotate_180.png
# Skipping invalid contour in case_M_20181025095048_0U62372102595347_1_004_001-1_a11_ayy_image0096.png
# Skipping invalid contour in case_M_20181025095048_0U62372102595347_1_004_001-1_a11_ayy_image0096.png
# Skipping invalid contour in case_M_20181105095958_0U62368110576557_1_003_002-1_a7_ayy_image0064.png
# Skipping invalid contour in case_M_20181105095958_0U62368110576557_1_003_002-1_a7_ayy_image0064.png
# Skipping invalid contour in case_M_20181105095958_0U62368110576557_1_003_002-1_a7_ayy_image0064.png
# Skipping invalid contour in case_M_20181105095958_0U62368110576557_1_003_002-1_a7_ayy_image0064.png
# Skipping invalid contour in case_M_20190112093830_0U62372011292129_1_001_001-1_a1_ayy_image0134_flip_h.png
# Skipping invalid contour in bkai_igh_04ccdc265a0b0a1230b118fa8625605d.jpeg
# Skipping invalid contour in bkai_igh_04ccdc265a0b0a1230b118fa8625605d.jpeg
# Skipping invalid contour in bkai_igh_04ccdc265a0b0a1230b118fa8625605d.jpeg
# Skipping invalid contour in bkai_igh_04ccdc265a0b0a1230b118fa8625605d.jpeg
# Skipping invalid contour in bkai_igh_04ccdc265a0b0a1230b118fa8625605d.jpeg
# Skipping invalid contour in bkai_igh_04ccdc265a0b0a1230b118fa8625605d.jpeg
# Skipping invalid contour in bkai_igh_04ccdc265a0b0a1230b118fa8625605d.jpeg
# Skipping invalid contour in bkai_igh_04ccdc265a0b0a1230b118fa8625605d.jpeg
# Skipping invalid contour in bkai_igh_04ccdc265a0b0a1230b118fa8625605d.jpeg
# Skipping invalid contour in bkai_igh_04ccdc265a0b0a1230b118fa8625605d.jpeg
# Skipping invalid contour in bkai_igh_04ccdc265a0b0a1230b118fa8625605d.jpeg
# Skipping invalid contour in bkai_igh_04ccdc265a0b0a1230b118fa8625605d.jpeg
# Skipping invalid contour in bkai_igh_04ccdc265a0b0a1230b118fa8625605d.jpeg
# Skipping invalid contour in bkai_igh_04ccdc265a0b0a1230b118fa8625605d.jpeg
# Skipping invalid contour in bkai_igh_04ccdc265a0b0a1230b118fa8625605d.jpeg
# Skipping invalid contour in bkai_igh_04ccdc265a0b0a1230b118fa8625605d.jpeg
# Skipping invalid contour in bkai_igh_04ccdc265a0b0a1230b118fa8625605d.jpeg
# Skipping invalid contour in case_M_20190107094528_0U62367010726528_1_002_002-1_a3_ayy_image0047.png
# Skipping invalid contour in case_M_20190109095638_0U62372010945338_1_001_001-1_a1_ayy_image0011.png
# Skipping invalid contour in case_M_20181017100226_0U62367101735926_1_007_004-1_a4_ayy_image0151_flip_h.png
# Skipping invalid contour in case_M_20181017100226_0U62367101735926_1_007_004-1_a4_ayy_image0151_flip_h.png
# Skipping invalid contour in case_M_20181017100226_0U62367101735926_1_007_004-1_a4_ayy_image0151_flip_h.png
# Skipping invalid contour in case_M_20181017100226_0U62367101735926_1_007_004-1_a4_ayy_image0151_flip_h.png
# Skipping invalid contour in case_M_20181004140507_0U62366100460906_1_001_001-1_a2_ayy_image0038.png
# Skipping invalid contour in case_M_20181025093921_0U62363102537521_1_002_001-1_a11_ayy_image0036_flip_h.png
# Skipping invalid contour in case_M_20181025093921_0U62363102537521_1_002_001-1_a11_ayy_image0036_flip_h.png
# Skipping invalid contour in case_M_20181025093921_0U62363102537521_1_002_001-1_a11_ayy_image0036_flip_h.png
# Skipping invalid contour in case_M_20181025093921_0U62363102537521_1_002_001-1_a11_ayy_image0036_flip_h.png
# Skipping invalid contour in case_M_20181025093921_0U62363102537521_1_002_001-1_a11_ayy_image0036_flip_h.png
# Skipping invalid contour in case_M_20181025093921_0U62363102537521_1_002_001-1_a11_ayy_image0036_flip_h.png
# Skipping invalid contour in case_M_20181212144657_0U62366121262556_1_001_001-1_a43_ayy_image0046.png
# Skipping invalid contour in case_M_20190109095638_0U62372010945338_1_001_001-1_a1_ayy_image0032.png
# Skipping invalid contour in case_M_20181029094800_0U62368102981259_1_002_001-1_a5_ayy_image0034_flip_v.png
# Skipping invalid contour in case_M_20181018093806_0U62363101890605_1_006_001-1_a1_ayy_image0001.png
# Skipping invalid contour in case_M_20181018093806_0U62363101890605_1_006_001-1_a1_ayy_image0001.png
# Skipping invalid contour in case_M_20181003094031_0U62363100354631_1_001_002-1_a1_ayy_image0005.png
# Skipping invalid contour in case_M_20181003094031_0U62363100354631_1_001_002-1_a1_ayy_image0005.png
# Skipping invalid contour in case_M_20181117100025_0U62363111779624_1_007_003-1_a8_ayy_image0206.png
# Skipping invalid contour in case_M_20181117100025_0U62363111779624_1_007_003-1_a8_ayy_image0206.png
# Skipping invalid contour in case_M_20181117100025_0U62363111779624_1_007_003-1_a8_ayy_image0206.png
# Skipping invalid contour in bkai_igh_af622c3b3e57249fe9959a80703003d2.jpeg
# Skipping invalid contour in bkai_igh_af622c3b3e57249fe9959a80703003d2.jpeg
# Skipping invalid contour in bkai_igh_af622c3b3e57249fe9959a80703003d2.jpeg
# Skipping invalid contour in bkai_igh_af622c3b3e57249fe9959a80703003d2.jpeg
# Skipping invalid contour in bkai_igh_af622c3b3e57249fe9959a80703003d2.jpeg
# Skipping invalid contour in bkai_igh_af622c3b3e57249fe9959a80703003d2.jpeg
# Skipping invalid contour in bkai_igh_af622c3b3e57249fe9959a80703003d2.jpeg
# Skipping invalid contour in bkai_igh_af622c3b3e57249fe9959a80703003d2.jpeg
# Skipping invalid contour in bkai_igh_af622c3b3e57249fe9959a80703003d2.jpeg
# Skipping invalid contour in bkai_igh_af622c3b3e57249fe9959a80703003d2.jpeg
# Skipping invalid contour in bkai_igh_af622c3b3e57249fe9959a80703003d2.jpeg
# Skipping invalid contour in bkai_igh_af622c3b3e57249fe9959a80703003d2.jpeg
# Skipping invalid contour in bkai_igh_af622c3b3e57249fe9959a80703003d2.jpeg
# Skipping invalid contour in bkai_igh_af622c3b3e57249fe9959a80703003d2.jpeg
# Skipping invalid contour in bkai_igh_af622c3b3e57249fe9959a80703003d2.jpeg
# Skipping invalid contour in bkai_igh_af622c3b3e57249fe9959a80703003d2.jpeg
# Skipping invalid contour in bkai_igh_af622c3b3e57249fe9959a80703003d2.jpeg
# Skipping invalid contour in bkai_igh_af622c3b3e57249fe9959a80703003d2.jpeg
# Skipping invalid contour in bkai_igh_af622c3b3e57249fe9959a80703003d2.jpeg
# Skipping invalid contour in bkai_igh_af622c3b3e57249fe9959a80703003d2.jpeg
# Skipping invalid contour in bkai_igh_af622c3b3e57249fe9959a80703003d2.jpeg
# Skipping invalid contour in bkai_igh_af622c3b3e57249fe9959a80703003d2.jpeg
# Skipping invalid contour in bkai_igh_af622c3b3e57249fe9959a80703003d2.jpeg
# Skipping invalid contour in bkai_igh_af622c3b3e57249fe9959a80703003d2.jpeg
# Skipping invalid contour in bkai_igh_af622c3b3e57249fe9959a80703003d2.jpeg
# Skipping invalid contour in bkai_igh_af622c3b3e57249fe9959a80703003d2.jpeg
# Skipping invalid contour in bkai_igh_af622c3b3e57249fe9959a80703003d2.jpeg
# Skipping invalid contour in bkai_igh_af622c3b3e57249fe9959a80703003d2.jpeg
# Skipping invalid contour in bkai_igh_af622c3b3e57249fe9959a80703003d2.jpeg
# Skipping invalid contour in bkai_igh_af622c3b3e57249fe9959a80703003d2.jpeg
# Skipping invalid contour in bkai_igh_af622c3b3e57249fe9959a80703003d2.jpeg
# Skipping invalid contour in bkai_igh_af622c3b3e57249fe9959a80703003d2.jpeg
# Skipping invalid contour in bkai_igh_af622c3b3e57249fe9959a80703003d2.jpeg
# Skipping invalid contour in bkai_igh_af622c3b3e57249fe9959a80703003d2.jpeg
# Skipping invalid contour in bkai_igh_af622c3b3e57249fe9959a80703003d2.jpeg
# Skipping invalid contour in bkai_igh_af622c3b3e57249fe9959a80703003d2.jpeg
# Skipping invalid contour in bkai_igh_af622c3b3e57249fe9959a80703003d2.jpeg
# Skipping invalid contour in bkai_igh_af622c3b3e57249fe9959a80703003d2.jpeg
# Skipping invalid contour in bkai_igh_839a76eaf622c3b3e57249fe9959a807.jpeg
# Skipping invalid contour in bkai_igh_839a76eaf622c3b3e57249fe9959a807.jpeg
# Skipping invalid contour in bkai_igh_839a76eaf622c3b3e57249fe9959a807.jpeg
# Skipping invalid contour in bkai_igh_839a76eaf622c3b3e57249fe9959a807.jpeg
# Skipping invalid contour in bkai_igh_839a76eaf622c3b3e57249fe9959a807.jpeg
# Skipping invalid contour in bkai_igh_839a76eaf622c3b3e57249fe9959a807.jpeg
# Skipping invalid contour in bkai_igh_839a76eaf622c3b3e57249fe9959a807.jpeg
# Skipping invalid contour in bkai_igh_839a76eaf622c3b3e57249fe9959a807.jpeg
# Skipping invalid contour in bkai_igh_839a76eaf622c3b3e57249fe9959a807.jpeg
# Skipping invalid contour in bkai_igh_839a76eaf622c3b3e57249fe9959a807.jpeg
# Skipping invalid contour in bkai_igh_839a76eaf622c3b3e57249fe9959a807.jpeg
# Skipping invalid contour in bkai_igh_839a76eaf622c3b3e57249fe9959a807.jpeg
# Skipping invalid contour in bkai_igh_839a76eaf622c3b3e57249fe9959a807.jpeg
# Skipping invalid contour in bkai_igh_839a76eaf622c3b3e57249fe9959a807.jpeg
# Skipping invalid contour in bkai_igh_839a76eaf622c3b3e57249fe9959a807.jpeg
# Skipping invalid contour in bkai_igh_839a76eaf622c3b3e57249fe9959a807.jpeg
# Skipping invalid contour in bkai_igh_839a76eaf622c3b3e57249fe9959a807.jpeg
# Skipping invalid contour in bkai_igh_839a76eaf622c3b3e57249fe9959a807.jpeg
# Skipping invalid contour in bkai_igh_839a76eaf622c3b3e57249fe9959a807.jpeg
# Skipping invalid contour in bkai_igh_839a76eaf622c3b3e57249fe9959a807.jpeg
# Skipping invalid contour in bkai_igh_839a76eaf622c3b3e57249fe9959a807.jpeg
# Skipping invalid contour in bkai_igh_839a76eaf622c3b3e57249fe9959a807.jpeg
# Skipping invalid contour in bkai_igh_839a76eaf622c3b3e57249fe9959a807.jpeg
# Skipping invalid contour in bkai_igh_839a76eaf622c3b3e57249fe9959a807.jpeg
# Skipping invalid contour in case_M_20181226125224_0U62363122631224_1_003_001-1_a8_ayy_image0170.png
# Skipping invalid contour in case_M_20181226125224_0U62363122631224_1_003_001-1_a8_ayy_image0170.png
# Skipping invalid contour in cvc_colodb_137.png
# Skipping invalid contour in cvc_colodb_137.png
# Skipping invalid contour in cvc_colodb_137.png
# ...
# Skipping invalid contour in case_M_20190123101017_0U62372012395316_1_004_001-1_a8_ayy_image0223.png
# Skipping invalid contour in case_M_20190123101017_0U62372012395316_1_004_001-1_a8_ayy_image0223.png
# Skipping invalid contour in case_M_20181120115731_0U62368112064030_1_001_001-1_a7_ayy_image0030.png
# Skipping invalid contour in case_M_20181019101517_0U62367101935917_1_003_001-1_a17_ayy_image0029_flip_v.png
# Skipping invalid contour in case_M_20181019101517_0U62367101935917_1_003_001-1_a17_ayy_image0029_flip_v.png
# Skipping invalid contour in case_M_20190131094430_0U62372013151529_1_003_001-1_a5_ayy_image0096.png
# Skipping invalid contour in case_M_20190131094430_0U62372013151529_1_003_001-1_a5_ayy_image0096.png
# Skipping invalid contour in case_M_20190131094430_0U62372013151529_1_003_001-1_a5_ayy_image0096.png
# Skipping invalid contour in case_M_20181029094800_0U62368102981259_1_005_001-1_a12_ayy_image0002_flip_h.png
# Skipping invalid contour in case_M_20181029094800_0U62368102981259_1_005_001-1_a12_ayy_image0002_flip_h.png
# Skipping invalid contour in case_M_20181217131216_0U62368121700016_1_002_001-1_a10_ayy_image0043.png
# Skipping invalid contour in case_M_20181211093229_0U62367121175028_1_004_001-1_a16_ayy_image0024_rotate_180.png
# Skipping invalid contour in case_M_20190107094528_0U62367010726528_1_002_001-1_a5_ayy_image0058_rotate_180.png
# Skipping invalid contour in case_M_20190107094528_0U62367010726528_1_002_001-1_a5_ayy_image0058_rotate_180.png
# Skipping invalid contour in case_M_20190128094801_0U62372012857800_1_002_001-1_a3_ayy_image0024_flip_h.png
# Skipping invalid contour in case_M_20181019101517_0U62367101935917_1_003_001-1_a11_ayy_image0064_flip_h.png
# Skipping invalid contour in case_M_20181019101517_0U62367101935917_1_003_001-1_a11_ayy_image0064_flip_h.png
# Skipping invalid contour in case_M_20181019101517_0U62367101935917_1_003_001-1_a11_ayy_image0064_flip_h.png
# Skipping invalid contour in case_M_20181217131216_0U62368121700016_1_002_001-1_a6_ayy_image0245_flip_v.png
# Skipping invalid contour in case_M_20181029094800_0U62368102981259_1_005_001-1_a15_ayy_image0002.png
# Skipping invalid contour in case_M_20181029094800_0U62368102981259_1_005_001-1_a15_ayy_image0002.png
# Skipping invalid contour in case_M_20181018093806_0U62363101890605_1_007_001-1_a1_ayy_image0042.png
# Skipping invalid contour in case_M_20181004130627_0U62365100475026_1_002_001-1_a5_ayy_image0090.png
# Skipping invalid contour in case_M_20181117100025_0U62363111779624_1_007_003-1_a8_ayy_image0400_rotate_180.png
# Skipping invalid contour in case_M_20181025095048_0U62372102595347_1_004_001-1_a6_ayy_image0023.png
# Skipping invalid contour in case_M_20181025095048_0U62372102595347_1_004_001-1_a6_ayy_image0023.png
# Skipping invalid contour in case_M_20190117095926_0U62372011750026_1_002_001-1_a1_ayy_image0024_flip_h.png
# Skipping invalid contour in case_M_20190117095926_0U62372011750026_1_002_001-1_a1_ayy_image0024_flip_h.png
# Skipping invalid contour in case_M_20190117095926_0U62372011750026_1_002_001-1_a1_ayy_image0024_flip_h.png
# Skipping invalid contour in case_M_20190117095926_0U62372011750026_1_002_001-1_a1_ayy_image0024_flip_h.png
# Skipping invalid contour in case_M_20181201091914_0U62363120125014_1_005_001-1_a10_ayy_image0011_rotate_180.png
# Skipping invalid contour in case_M_20181018093806_0U62363101890605_1_007_002-1_a10_ayy_image0070.png
# Skipping invalid contour in case_M_20181004130627_0U62365100475026_1_002_001-1_a5_ayy_image0036.png
# Skipping invalid contour in case_M_20181004130627_0U62365100475026_1_002_001-1_a5_ayy_image0036.png
# Skipping invalid contour in case_M_20181003094031_0U62363100354631_1_001_002-1_a13_ayy_image0056_rotate_180.png
# Skipping invalid contour in case_M_20181003094031_0U62363100354631_1_001_002-1_a13_ayy_image0056_rotate_180.png
# Skipping invalid contour in case_M_20181003094031_0U62363100354631_1_001_002-1_a13_ayy_image0056_rotate_180.png
# Skipping invalid contour in case_M_20181003094031_0U62363100354631_1_001_002-1_a13_ayy_image0056_rotate_180.png
# Skipping invalid contour in case_M_20181025093921_0U62363102537521_1_002_001-1_a11_ayy_image0053_flip_v.png
# Skipping invalid contour in case_M_20181025093921_0U62363102537521_1_002_001-1_a11_ayy_image0053_flip_v.png
# Skipping invalid contour in case_M_20181025095048_0U62372102595347_1_004_001-1_a3_ayy_image0013.png
# Skipping invalid contour in case_M_20181029094800_0U62368102981259_1_005_001-1_a15_ayy_image0081_flip_v.png
# Skipping invalid contour in case_M_20181029094800_0U62368102981259_1_005_001-1_a15_ayy_image0081_flip_v.png
# Skipping invalid contour in case_M_20181019101517_0U62367101935917_1_003_001-1_a18_ayy_image0128_rotate_180.png
# Skipping invalid contour in case_M_20181019101517_0U62367101935917_1_003_001-1_a18_ayy_image0128_rotate_180.png
# Skipping invalid contour in case_M_20181019101517_0U62367101935917_1_003_001-1_a18_ayy_image0128_rotate_180.png
# Skipping invalid contour in case_M_20181029094800_0U62368102981259_1_005_001-1_a15_ayy_image0219.png
# Skipping invalid contour in case_M_20181029094800_0U62368102981259_1_005_001-1_a15_ayy_image0219.png
# Skipping invalid contour in case_M_20181029094800_0U62368102981259_1_005_001-1_a15_ayy_image0219.png
# Skipping invalid contour in case_M_20181029094800_0U62368102981259_1_005_001-1_a15_ayy_image0219.png
# Skipping invalid contour in case_M_20181029094800_0U62368102981259_1_005_001-1_a15_ayy_image0219.png
# Skipping invalid contour in case_M_20181029094800_0U62368102981259_1_005_001-1_a15_ayy_image0219.png
# Skipping invalid contour in case_M_20190121095240_0U62368012118740_1_004_001-1_a5_ayy_image0100.png
# Skipping invalid contour in case_M_20190121095240_0U62368012118740_1_004_001-1_a5_ayy_image0100.png
# Skipping invalid contour in case_M_20190121095240_0U62368012118740_1_004_001-1_a5_ayy_image0100.png
# Skipping invalid contour in case_M_20181018093806_0U62363101890605_1_006_001-1_a3_ayy_image0039_rotate_90.png
# Skipping invalid contour in case_M_20181018093806_0U62363101890605_1_006_001-1_a3_ayy_image0039_rotate_90.png
# Skipping invalid contour in case_M_20190121095240_0U62368012118740_1_004_001-1_a6_ayy_image0008.png
# Skipping invalid contour in case_M_20190121095240_0U62368012118740_1_004_001-1_a6_ayy_image0008.png
# Skipping invalid contour in case_M_20190121095240_0U62368012118740_1_004_001-1_a6_ayy_image0008.png
# Skipping invalid contour in case_M_20190121095240_0U62368012118740_1_004_001-1_a6_ayy_image0008.png
# Skipping invalid contour in case_M_20190121095240_0U62368012118740_1_004_001-1_a6_ayy_image0008.png
# Skipping invalid contour in case_M_20190121095240_0U62368012118740_1_004_001-1_a6_ayy_image0008.png
# Skipping invalid contour in case_M_20190121095240_0U62368012118740_1_004_001-1_a6_ayy_image0008.png
# Skipping invalid contour in case_M_20181017100226_0U62367101735926_1_007_004-1_a6_ayy_image0132.png
# Skipping invalid contour in case_M_20190116093042_0U62372011685941_1_001_001-1_a1_ayy_image0005.png
# Skipping invalid contour in case_M_20181214095357_0U62368121473456_1_005_001-1_a3_ayy_image0009.png
# Skipping invalid contour in case_M_20181220100816_0U62368122007816_1_002_001-1_a7_ayy_image0075.png
# Skipping invalid contour in case_M_20181126140908_0U62368112685907_1_004_001-1_a17_ayy_image0116.png
# Skipping invalid contour in case_M_20181211093229_0U62367121175028_1_004_001-1_a17_ayy_image0040.png
# Skipping invalid contour in case_M_20181117100025_0U62363111779624_1_007_003-1_a1_ayy_image0002.png
# Skipping invalid contour in case_M_20181117100025_0U62363111779624_1_007_003-1_a1_ayy_image0002.png
# Skipping invalid contour in case_M_20181017100226_0U62367101735926_1_007_003-1_a10_ayy_image0029_flip_h.png
# Skipping invalid contour in case_M_20190115123306_0U62368011540606_1_002_001-1_a5_ayy_image0188.png
# Skipping invalid contour in case_M_20190115123306_0U62368011540606_1_002_001-1_a5_ayy_image0188.png
# Skipping invalid contour in case_M_20190115123306_0U62368011540606_1_002_001-1_a5_ayy_image0188.png
# Skipping invalid contour in case_M_20181025093921_0U62363102537521_1_002_001-1_a10_ayy_image0001_flip_h.png
# Skipping invalid contour in case_M_20181025093921_0U62363102537521_1_002_001-1_a10_ayy_image0001_flip_h.png
# Skipping invalid contour in case_M_20181029094800_0U62368102981259_1_005_001-1_a15_ayy_image0116.png
# Skipping invalid contour in case_M_20181029094800_0U62368102981259_1_005_001-1_a15_ayy_image0116.png
# Skipping invalid contour in case_M_20181029094800_0U62368102981259_1_005_001-1_a15_ayy_image0116.png
# Skipping invalid contour in bkai_igh_faeeb2b535797395305af926a6f23c5d.jpeg
# Skipping invalid contour in bkai_igh_faeeb2b535797395305af926a6f23c5d.jpeg
# Skipping invalid contour in bkai_igh_faeeb2b535797395305af926a6f23c5d.jpeg
# Skipping invalid contour in bkai_igh_faeeb2b535797395305af926a6f23c5d.jpeg
# Skipping invalid contour in bkai_igh_faeeb2b535797395305af926a6f23c5d.jpeg
# Skipping invalid contour in bkai_igh_faeeb2b535797395305af926a6f23c5d.jpeg
# Skipping invalid contour in bkai_igh_faeeb2b535797395305af926a6f23c5d.jpeg
# Skipping invalid contour in bkai_igh_faeeb2b535797395305af926a6f23c5d.jpeg
# Skipping invalid contour in bkai_igh_faeeb2b535797395305af926a6f23c5d.jpeg
# Skipping invalid contour in bkai_igh_faeeb2b535797395305af926a6f23c5d.jpeg
# Skipping invalid contour in bkai_igh_faeeb2b535797395305af926a6f23c5d.jpeg
# Skipping invalid contour in bkai_igh_faeeb2b535797395305af926a6f23c5d.jpeg
# Skipping invalid contour in bkai_igh_faeeb2b535797395305af926a6f23c5d.jpeg
# Skipping invalid contour in bkai_igh_faeeb2b535797395305af926a6f23c5d.jpeg
# Skipping invalid contour in bkai_igh_faeeb2b535797395305af926a6f23c5d.jpeg
# Skipping invalid contour in bkai_igh_faeeb2b535797395305af926a6f23c5d.jpeg
# Skipping invalid contour in bkai_igh_faeeb2b535797395305af926a6f23c5d.jpeg
# Skipping invalid contour in bkai_igh_faeeb2b535797395305af926a6f23c5d.jpeg
# Skipping invalid contour in bkai_igh_faeeb2b535797395305af926a6f23c5d.jpeg
# Skipping invalid contour in bkai_igh_faeeb2b535797395305af926a6f23c5d.jpeg
# Skipping invalid contour in bkai_igh_faeeb2b535797395305af926a6f23c5d.jpeg
# Skipping invalid contour in bkai_igh_faeeb2b535797395305af926a6f23c5d.jpeg
# Skipping invalid contour in bkai_igh_faeeb2b535797395305af926a6f23c5d.jpeg
# Skipping invalid contour in bkai_igh_faeeb2b535797395305af926a6f23c5d.jpeg
# Skipping invalid contour in bkai_igh_faeeb2b535797395305af926a6f23c5d.jpeg
# Skipping invalid contour in bkai_igh_faeeb2b535797395305af926a6f23c5d.jpeg
# Skipping invalid contour in bkai_igh_faeeb2b535797395305af926a6f23c5d.jpeg
# Skipping invalid contour in bkai_igh_faeeb2b535797395305af926a6f23c5d.jpeg
# Skipping invalid contour in bkai_igh_faeeb2b535797395305af926a6f23c5d.jpeg
# Skipping invalid contour in bkai_igh_faeeb2b535797395305af926a6f23c5d.jpeg
# Skipping invalid contour in bkai_igh_faeeb2b535797395305af926a6f23c5d.jpeg
# Skipping invalid contour in case_M_20181214095357_0U62368121473456_1_006_003-1_a20_ayy_image0054_flip_v.png
# Skipping invalid contour in case_M_20190121095240_0U62368012118740_1_004_001-1_a4_ayy_image0090_flip_v.png
# Skipping invalid contour in case_M_20181003094031_0U62363100354631_1_001_002-1_a13_ayy_image0101.png
# Skipping invalid contour in case_M_20181017100226_0U62367101735926_1_007_004-1_a6_ayy_image0025.png
# Skipping invalid contour in case_M_20190117095926_0U62372011750026_1_002_001-1_a4_ayy_image0051.png
# Skipping invalid contour in case_M_20181010094822_0U62363101085921_1_003_001-1_a2_ayy_image0054.png
# Skipping invalid contour in case_M_20181117100025_0U62363111779624_1_007_003-1_a2_ayy_image0012.png
# Skipping invalid contour in case_M_20181109094641_0U62372110931241_1_005_001-1_a4_ayy_image0040.png
# Skipping invalid contour in case_M_20190121095240_0U62368012118740_1_005_001-1_a1_ayy_image0218_flip_v.png
# Skipping invalid contour in case_M_20190121095240_0U62368012118740_1_005_001-1_a1_ayy_image0218_flip_v.png
# Skipping invalid contour in case_M_20190128094801_0U62372012857800_1_002_001-1_a6_ayy_image0080.png
# Skipping invalid contour in case_M_20181211093229_0U62367121175028_1_002_002-1_a3_ayy_image0018.png
# Skipping invalid contour in case_M_20181003094031_0U62363100354631_1_001_002-1_a1_ayy_image0574_flip_v.png
# Skipping invalid contour in case_M_20181119111911_0U62363111914011_1_005_001-1_a12_ayy_image0379_rotate_180.png
# Skipping invalid contour in case_M_20181119111911_0U62363111914011_1_005_001-1_a12_ayy_image0379_rotate_180.png
# Skipping invalid contour in case_M_20181119111911_0U62363111914011_1_005_001-1_a12_ayy_image0379_rotate_180.png
# Skipping invalid contour in case_M_20181019122218_0U62368101948418_1_002_001-1_a4_ayy_image0069.png
# Skipping invalid contour in case_M_20181019122218_0U62368101948418_1_002_001-1_a4_ayy_image0069.png
# Skipping invalid contour in case_M_20181010094822_0U62363101085921_1_003_001-1_a1_ayy_image0022.png
# Skipping invalid contour in case_M_20181010094822_0U62363101085921_1_003_001-1_a1_ayy_image0022.png
# Skipping invalid contour in case_M_20181017100226_0U62367101735926_1_007_001-1_a4_ayy_image0058_flip_h.png
# Skipping invalid contour in case_M_20181017100226_0U62367101735926_1_007_001-1_a4_ayy_image0058_flip_h.png
# Skipping invalid contour in case_M_20181017100226_0U62367101735926_1_007_001-1_a4_ayy_image0058_flip_h.png
# Skipping invalid contour in case_M_20181019101517_0U62367101935917_1_003_001-1_a15_ayy_image0001.png
# Skipping invalid contour in case_M_20181117100025_0U62363111779624_1_007_003-1_a8_ayy_image0378_rotate_180.png
# Skipping invalid contour in case_M_20181117100025_0U62363111779624_1_007_003-1_a8_ayy_image0378_rotate_180.png
# Skipping invalid contour in case_M_20181226125224_0U62363122631224_1_003_001-1_a8_ayy_image0062_flip_h.png
# Skipping invalid contour in case_M_20181025095048_0U62372102595347_1_004_001-1_a17_ayy_image0019.png
# Skipping invalid contour in case_M_20181025095048_0U62372102595347_1_004_001-1_a17_ayy_image0019.png
# Skipping invalid contour in case_M_20190121095240_0U62368012118740_1_005_001-1_a1_ayy_image0520_flip_v.png
# Skipping invalid contour in bkai_igh_ca73d5379c7c851a508273160e13bac7.jpeg
# Skipping invalid contour in bkai_igh_ca73d5379c7c851a508273160e13bac7.jpeg
# Skipping invalid contour in bkai_igh_ca73d5379c7c851a508273160e13bac7.jpeg
# Skipping invalid contour in bkai_igh_ca73d5379c7c851a508273160e13bac7.jpeg
# Skipping invalid contour in bkai_igh_ca73d5379c7c851a508273160e13bac7.jpeg
# Skipping invalid contour in bkai_igh_ca73d5379c7c851a508273160e13bac7.jpeg
# Skipping invalid contour in bkai_igh_ca73d5379c7c851a508273160e13bac7.jpeg
# Skipping invalid contour in bkai_igh_ca73d5379c7c851a508273160e13bac7.jpeg
# Skipping invalid contour in bkai_igh_ca73d5379c7c851a508273160e13bac7.jpeg
# Skipping invalid contour in bkai_igh_ca73d5379c7c851a508273160e13bac7.jpeg
# Skipping invalid contour in bkai_igh_ca73d5379c7c851a508273160e13bac7.jpeg
# Skipping invalid contour in bkai_igh_ca73d5379c7c851a508273160e13bac7.jpeg
# Skipping invalid contour in bkai_igh_ca73d5379c7c851a508273160e13bac7.jpeg
# Skipping invalid contour in bkai_igh_ca73d5379c7c851a508273160e13bac7.jpeg
# Skipping invalid contour in case_M_20190128094801_0U62372012857800_1_002_001-1_a6_ayy_image0029.png
# Skipping invalid contour in case_M_20181017100226_0U62367101735926_1_001_002-1_a15_ayy_image0075_flip_h.png
# Skipping invalid contour in case_M_20181212144657_0U62366121262556_1_001_002-1_a2_ayy_image0023_flip_v.png
# Skipping invalid contour in case_M_20181017100226_0U62367101735926_1_007_003-1_a7_ayy_image0006.png
# Skipping invalid contour in case_M_20190121095240_0U62368012118740_1_004_001-1_a5_ayy_image0041.png
# Skipping invalid contour in case_M_20190121095240_0U62368012118740_1_004_001-1_a5_ayy_image0041.png
# Skipping invalid contour in case_M_20190121095240_0U62368012118740_1_004_001-1_a5_ayy_image0041.png
# Skipping invalid contour in case_M_20190121095240_0U62368012118740_1_004_001-1_a5_ayy_image0041.png
# Skipping invalid contour in case_M_20181214095357_0U62368121473456_1_006_003-1_a25_ayy_image0010.png
# Finished processing. Skipped 0 masks due to loading failures. Created 0 empty annotation files.

# %% [markdown]
# #### check

# %%
data_processor.visualize_polygon(F_TRAIN_MASKS_POS, F_TRAIN_LABELS)

# %% [markdown]
# ### create empty masks in train and val

# %%
data_processor.create_empty_masks(F_TRAIN_IMAGES_NEG, F_TRAIN_MASKS_NEG, data_processor.mask_extension)
data_processor.create_empty_masks(F_VAL_IMAGES_NEG, F_VAL_MASKS_NEG, data_processor.mask_extension)
# Out:
# Clearing existing directory: ./data/train/masks/negative
# Analyzing image resolutions...
# Found 1 unique resolutions across 4000 images
# Creating template black images...
# Created template black image: 512x512
# Generating output images...
# Progress: 50 images created
# Progress: 100 images created
# Progress: 150 images created
# Progress: 200 images created
# Progress: 250 images created
# Progress: 300 images created
# Progress: 350 images created
# Progress: 400 images created
# Progress: 450 images created
# Progress: 500 images created
# Progress: 550 images created
# Progress: 600 images created
# Progress: 650 images created
# Progress: 700 images created
# Progress: 750 images created
# Progress: 800 images created
# Progress: 850 images created
# Progress: 900 images created
# Progress: 950 images created
# Progress: 1000 images created
# Progress: 1050 images created
# Progress: 1100 images created
# Progress: 1150 images created
# Progress: 1200 images created
# Progress: 1250 images created
# Progress: 1300 images created
# Progress: 1350 images created
# Progress: 1400 images created
# Progress: 1450 images created
# Progress: 1500 images created
# Progress: 1550 images created
# Progress: 1600 images created
# Progress: 1650 images created
# Progress: 1700 images created
# Progress: 1750 images created
# Progress: 1800 images created
# Progress: 1850 images created
# Progress: 1900 images created
# Progress: 1950 images created
# Progress: 2000 images created
# Progress: 2050 images created
# Progress: 2100 images created
# Progress: 2150 images created
# Progress: 2200 images created
# Progress: 2250 images created
# Progress: 2300 images created
# Progress: 2350 images created
# Progress: 2400 images created
# Progress: 2450 images created
# Progress: 2500 images created
# Progress: 2550 images created
# Progress: 2600 images created
# Progress: 2650 images created
# Progress: 2700 images created
# Progress: 2750 images created
# Progress: 2800 images created
# Progress: 2850 images created
# Progress: 2900 images created
# Progress: 2950 images created
# Progress: 3000 images created
# Progress: 3050 images created
# Progress: 3100 images created
# Progress: 3150 images created
# Progress: 3200 images created
# Progress: 3250 images created
# Progress: 3300 images created
# Progress: 3350 images created
# Progress: 3400 images created
# Progress: 3450 images created
# Progress: 3500 images created
# Progress: 3550 images created
# Progress: 3600 images created
# Progress: 3650 images created
# Progress: 3700 images created
# Progress: 3750 images created
# Progress: 3800 images created
# Progress: 3850 images created
# Progress: 3900 images created
# Progress: 3950 images created
# Progress: 4000 images created
#
# Summary: Created 4000 black images in ./data/train/masks/negative
# Unique resolutions: 1
# Clearing existing directory: ./data/val/masks/negative
# Analyzing image resolutions...
# Found 1 unique resolutions across 1000 images
# Creating template black images...
# Created template black image: 512x512
# Generating output images...
# Progress: 50 images created
# Progress: 100 images created
# Progress: 150 images created
# Progress: 200 images created
# Progress: 250 images created
# Progress: 300 images created
# Progress: 350 images created
# Progress: 400 images created
# Progress: 450 images created
# Progress: 500 images created
# Progress: 550 images created
# Progress: 600 images created
# Progress: 650 images created
# Progress: 700 images created
# Progress: 750 images created
# Progress: 800 images created
# Progress: 850 images created
# Progress: 900 images created
# Progress: 950 images created
# Progress: 1000 images created
#
# Summary: Created 1000 black images in ./data/val/masks/negative
# Unique resolutions: 1
# {'total_processed': 1000,
#  'unique_resolutions': 1,
#  'created_images': 1000,
#  'skipped_files': []}

# %% [markdown]
# ### mix positive and negatives in train and val

# %%
data_processor.flatten_directory(F_TRAIN_IMAGES)
data_processor.flatten_directory(F_TRAIN_MASKS)
data_processor.flatten_directory(F_VAL_IMAGES)
data_processor.flatten_directory(F_VAL_MASKS)

# %% [markdown]
# ## trying stuff

# %%
data_processor.compare_filenames(F_TRAIN_MASKS, F_TRAIN_LABELS)

# %%
data_processor.recreate_images_from_arrays(F_TEST)
